# %%
import os
import time
import random

import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt

from torch.distributions.binomial import Binomial
from torch.distributions.bernoulli import Bernoulli
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader 

from transformers import DataCollatorForLanguageModeling, BertForMaskedLM
from transformers import Trainer, TrainingArguments
from transformers import get_linear_schedule_with_warmup, AdamW

from tokens import WordLevelBertTokenizer
from vocab import create_vocab
from data import CausalBertDataset, MLMDataset
from causal_bert import CausalBOW

# %%
bsz = 256
epoch = 300
hidden_size = 64

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '7'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def true_casual_effect(data_loader, effect='ate', estimation='q'):
    assert effect == 'ate' and estimation == 'q', f'unallowed effect/estimation: {effect}/{estimation}'
    
    dataset = data_loader.dataset
    
    Q1 = dataset.treatment * dataset.response + (1 - dataset.treatment) * dataset.pseudo_response
    Q1 = Q1.cpu().data.numpy().squeeze()

    Q0 = dataset.treatment * dataset.pseudo_response + (1 - dataset.treatment) * dataset.response
    Q0 = Q0.cpu().data.numpy().squeeze()

    treatment = dataset.treatment.cpu().data.numpy().squeeze()
    prop_scores = dataset.prop_score.cpu().data.numpy().squeeze()
    
    if estimation == 'q':
        if effect == 'att':
            phi = (treatment * (Q1 - Q0))
            return phi.sum() / treatment.sum()
        elif effect == 'ate':
            return (Q1 - Q0).mean()
        
    elif estimation == 'plugin':
        phi = (prop_scores * (Q1 - Q0)).mean()
        if effect == 'att':
            return phi / treatment.mean()
        elif effect == 'ate': 
            return phi
        
def est_casual_effect(data_loader, model, effect='ate', estimation='q', eval_loss=True, **kwargs):
    # We use `real_treatment` here to emphasize the estimations use real instead of estimated treatment.
    real_response, real_treatment = [], []
    prop_scores, Q1, Q0 = [], [], []

    if eval_loss:
        g_loss = kwargs.get('g_loss')
        q_loss = kwargs.get('q_loss')
        g_loss_test, q1_loss_test, q0_loss_test  = [], [], []
    model.eval()
    for idx, (tokens, treatment, response) in enumerate(data_loader):
        real_response.append(response.cpu().data.numpy().squeeze())
        real_treatment.append(treatment.cpu().data.numpy().squeeze())

        prop_score, q1, q0 = model(tokens)
        
        prop_scores.append(prop_score.cpu().data.numpy().squeeze())
        Q1.append(q1.cpu().data.numpy().squeeze())
        Q0.append(q0.cpu().data.numpy().squeeze())
        
        if eval_loss:
            g_loss_val  = g_loss(prop_score, treatment)
            q1_loss_val = q_loss(q1[treatment==1], response[treatment==1])
            q0_loss_val = q_loss(q0[treatment==0], response[treatment==0])
            
            g_loss_test.append(g_loss_val.item())
            q1_loss_test.append(q1_loss_val.item())
            q0_loss_test.append(q0_loss_val.item())
            
    real_response = np.concatenate(real_response, axis=0)
    real_treatment = np.concatenate(real_treatment, axis=0)

    Q1 = np.concatenate(Q1, axis=0)
    Q0 = np.concatenate(Q0, axis=0)
    prop_scores = np.concatenate(prop_scores, axis=0)
    
    
    g_loss = np.array(g_loss_test).mean() if eval_loss else None
    q1_loss = np.array(q1_loss_test).mean() if eval_loss else None
    q0_loss = np.array(q0_loss_test).mean() if eval_loss else None

    model.train()
    
    if estimation == 'q':
        if effect == 'att':
            phi = (real_treatment * (Q1 - Q0))
            return phi.sum() / real_treatment.sum(), g_loss, q1_loss, q0_loss
        elif effect == 'ate':
            return (Q1 - Q0).mean(), g_loss, q1_loss, q0_loss

    elif estimation == 'plugin':
        phi = (prop_scores * (Q1 - Q0)).mean()
        if effect == 'att':
            return phi / real_treatment.mean(), g_loss, q1_loss, q0_loss
        elif effect == 'ate':
            return phi, g_loss, q1_loss, q0_loss
        

def show_result(train_loss_hist, test_loss_hist, est_effect, real, unadjust, epoch):
    train_loss_hist = np.array(train_loss_hist)
    test_loss_hist = np.array(test_loss_hist)
    est_effect = np.array(est_effect)
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    lns1 = ax.plot(np.arange(epoch), test_loss_hist, label='test loss')

    ax_r = plt.twinx()
    lns2 = ax_r.plot(np.arange(epoch), est_effect, color='coral', label='estimate ATE')
    lns3 = ax_r.plot(np.arange(epoch), np.ones(epoch) * real, color='red', ls='--', label='real ATE')
    lns4 = ax_r.plot(np.arange(epoch), np.ones(epoch) * unadjust, color='green', ls='--', label='unadjusted ATE')

    lns = lns1+lns2+lns3+lns4
    labs = [l.get_label() for l in lns]
    ax_r.legend(lns, labs, loc=0)
    plt.show()

# %% [markdown]
# # LOW

# %%
vocab = create_vocab(merged=True, uni_diag=True)
tokenizer = WordLevelBertTokenizer(vocab)

alpha = 0.25
beta = 1.
c = 0.2
i = 0.

# %%
start = time.time()
trainset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                             alpha=alpha, beta=beta, c=c, i=i, 
                             group=list(range(1)), max_length=512, min_length=10,
                             truncate_method='first', device=device, seed=1)

print(f'Load training set in {(time.time() - start):.2f} sec')

start = time.time()
testset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                            alpha=alpha, beta=beta, c=c, i=i, 
                            group=[9], max_length=512, min_length=10,
                            truncate_method='first', device=device)

print(f'Load validation set in {(time.time() - start):.2f} sec')
# Out:
# Load training set in 70.28 sec
# Load validation set in 69.91 sec

# %%
train_loader = DataLoader(trainset, batch_size=bsz, drop_last=True, shuffle=True)
test_loader = DataLoader(testset, batch_size=2048, drop_last=True, shuffle=True)

# %%
real_att_q = true_casual_effect(test_loader)

print(f'Real: [effect: ate], [estimation: q], [value: {real_att_q:.5f}]')
print(f'Unadjusted: [value: {(testset.response[testset.treatment == 1].mean() - testset.response[testset.treatment == 0].mean()).item():.4f}]')
# Out:
# Real: [effect: ate], [estimation: q], [value: 0.06317]
# Unadjusted: [value: 0.0919]

# %%
trained_bert = '/nfs/turbo/lsa-regier/bert-results/results/behrt/MLM/merged/unidiag/checkpoint-6018425/'
# trained_bert = '/home/liutianc/emr/bert/results/behrt/MLM/merged/unidiag/checkpoint-6018425/'

model = BertForMaskedLM.from_pretrained(trained_bert)
token_embed = model.get_input_embeddings()
model = CausalBOW(token_embed, learnable_docu_embed=False, hidden_size=hidden_size, prop_is_logit=True).to(device)

pos_portion = trainset.treatment.mean()
pos_weight = (1 - pos_portion) / pos_portion

# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
epoch_iter = len(train_loader)
total_steps = epoch * epoch_iter

optimizer = AdamW(model.parameters(), lr=1e-4, eps=1e-8)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

q_loss = nn.BCELoss()
# prop_score_loss = nn.BCELoss()
prop_score_loss = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# Please specify the effect and estimation we want to use here.
effect = 'ate'
estimation = 'q'

effect = effect.lower()
estimation = estimation.lower()
assert effect in ['att', 'ate'], f'Wrong effect: {effect}...'
assert estimation in ['q', 'plugin'], f'Wrong estimation: {estimation}...'

# %%
rs_loss, rq1_loss, rq0_loss = [0.] * 3

train_loss_hist, test_loss_hist, est_effect = [], [], []
for e in range(1, epoch + 1):
    model.train()
    start = time.time()
    run_loss = 0.
    for idx, (tokens, treatment, response) in enumerate(train_loader):
        optimizer.zero_grad()
        prop_score, q1, q0 = model(tokens)
        
        loss = prop_score_loss(prop_score, treatment)
        if len(response[treatment == 1]) > 0:
            loss += q_loss(q1[treatment==1], response[treatment==1])# * pos_weight
            
        if len(response[treatment == 0]) > 0:
            loss += q_loss(q0[treatment==0], response[treatment==0])
            
        loss.backward()
        
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)    
        optimizer.step()
        scheduler.step()

        run_loss += loss.item()
        
    run_idx = idx

    # Evaluation.
    train_loss = run_loss / (run_idx + 1)
    train_effect, _, _, _ = est_casual_effect(train_loader, model, effect, estimation, eval_loss=False)
    test_effect, g_loss_test, q1_loss_test, q0_loss_test = est_casual_effect(test_loader, model, effect, estimation, g_loss=prop_score_loss, q_loss=q_loss)
    test_loss = q1_loss_test + q0_loss_test
    test_loss += g_loss_test
    
    train_loss_hist.append(train_loss)
    test_loss_hist.append(test_loss)
    est_effect.append(test_effect)
    print(f'''epoch: {e} / {epoch}, time cost: {(time.time() - start):.2f} sec, 
          Loss: [Train: {train_loss:.5f}], [Test: {test_loss:.5f}],
          Effect: [{effect}-{estimation}], [train: {train_effect:.5f}], [test: {test_effect:.5f}]''')
    print('*'* 80)
    start = time.time()
    run_loss = 0.

print('Finish training...')

# With only 1 group(s) to train.
# Out:
# epoch: 1 / 100, time cost: 38.32 sec,
#           Loss: [Train: 2.42557], [Test: 2.42818],
#           Effect: [ate-q], [train: 0.09094], [test: 0.09094]
# ********************************************************************************
# epoch: 2 / 100, time cost: 45.34 sec,
#           Loss: [Train: 2.42154], [Test: 2.42451],
#           Effect: [ate-q], [train: 0.07791], [test: 0.07791]
# ********************************************************************************
# epoch: 3 / 100, time cost: 42.38 sec,
#           Loss: [Train: 2.41686], [Test: 2.42006],
#           Effect: [ate-q], [train: 0.08017], [test: 0.08017]
# ********************************************************************************
# epoch: 4 / 100, time cost: 44.38 sec,
#           Loss: [Train: 2.41157], [Test: 2.41554],
#           Effect: [ate-q], [train: 0.09110], [test: 0.09110]
# ********************************************************************************
# epoch: 5 / 100, time cost: 42.04 sec,
#           Loss: [Train: 2.40616], [Test: 2.41145],
#           Effect: [ate-q], [train: 0.08759], [test: 0.08762]
# ********************************************************************************
# epoch: 6 / 100, time cost: 41.48 sec,
#           Loss: [Train: 2.40165], [Test: 2.40891],
#           Effect: [ate-q], [train: 0.08109], [test: 0.08114]
# ********************************************************************************
# epoch: 7 / 100, time cost: 43.35 sec,
#           Loss: [Train: 2.39776], [Test: 2.40681],
#           Effect: [ate-q], [train: 0.08807], [test: 0.08814]
# ********************************************************************************
# epoch: 8 / 100, time cost: 43.67 sec,
#           Loss: [Train: 2.39439], [Test: 2.40489],
#           Effect: [ate-q], [train: 0.08837], [test: 0.08846]
# ********************************************************************************
# epoch: 9 / 100, time cost: 41.81 sec,
#           Loss: [Train: 2.39187], [Test: 2.40401],
#           Effect: [ate-q], [train: 0.07820], [test: 0.07829]
# ********************************************************************************
# epoch: 10 / 100, time cost: 44.99 sec,
#           Loss: [Train: 2.38897], [Test: 2.40362],
#           Effect: [ate-q], [train: 0.06235], [test: 0.06246]
# ********************************************************************************
# epoch: 11 / 100, time cost: 43.08 sec,
#           Loss: [Train: 2.38626], [Test: 2.40235],
#           Effect: [ate-q], [train: 0.08227], [test: 0.08237]
# ********************************************************************************
# epoch: 12 / 100, time cost: 42.47 sec,
#           Loss: [Train: 2.38352], [Test: 2.40122],
#           Effect: [ate-q], [train: 0.07765], [test: 0.07776]
# ********************************************************************************
# epoch: 13 / 100, time cost: 42.36 sec,
#           Loss: [Train: 2.38135], [Test: 2.40184],
#           Effect: [ate-q], [train: 0.07189], [test: 0.07202]
# ********************************************************************************
# epoch: 14 / 100, time cost: 42.31 sec,
#           Loss: [Train: 2.37869], [Test: 2.40093],
#           Effect: [ate-q], [train: 0.06596], [test: 0.06612]
# ********************************************************************************
# epoch: 15 / 100, time cost: 42.27 sec,
#           Loss: [Train: 2.37572], [Test: 2.40055],
#           Effect: [ate-q], [train: 0.07281], [test: 0.07301]
# ********************************************************************************
# epoch: 16 / 100, time cost: 42.02 sec,
#           Loss: [Train: 2.37270], [Test: 2.40004],
#           Effect: [ate-q], [train: 0.06953], [test: 0.06975]
# ********************************************************************************
# epoch: 17 / 100, time cost: 42.06 sec,
#           Loss: [Train: 2.36896], [Test: 2.40081],
#           Effect: [ate-q], [train: 0.05878], [test: 0.05906]
# ********************************************************************************
# epoch: 18 / 100, time cost: 42.35 sec,
#           Loss: [Train: 2.36515], [Test: 2.40071],
#           Effect: [ate-q], [train: 0.07393], [test: 0.07425]
# ********************************************************************************
# epoch: 19 / 100, time cost: 42.41 sec,
#           Loss: [Train: 2.36066], [Test: 2.40134],
#           Effect: [ate-q], [train: 0.07388], [test: 0.07425]
# ********************************************************************************
# epoch: 20 / 100, time cost: 42.60 sec,
#           Loss: [Train: 2.35536], [Test: 2.40310],
#           Effect: [ate-q], [train: 0.06316], [test: 0.06357]
# ********************************************************************************
# epoch: 21 / 100, time cost: 42.55 sec,
#           Loss: [Train: 2.34979], [Test: 2.40485],
#           Effect: [ate-q], [train: 0.05659], [test: 0.05703]
# ********************************************************************************
# epoch: 22 / 100, time cost: 42.57 sec,
#           Loss: [Train: 2.34355], [Test: 2.41027],
#           Effect: [ate-q], [train: 0.02872], [test: 0.02916]
# ********************************************************************************
# epoch: 23 / 100, time cost: 42.65 sec,
#           Loss: [Train: 2.33720], [Test: 2.41188],
#           Effect: [ate-q], [train: 0.05039], [test: 0.05091]
# ********************************************************************************
# epoch: 24 / 100, time cost: 42.80 sec,
#           Loss: [Train: 2.33062], [Test: 2.41467],
#           Effect: [ate-q], [train: 0.05670], [test: 0.05720]
# ********************************************************************************
# epoch: 25 / 100, time cost: 42.72 sec,
#           Loss: [Train: 2.32426], [Test: 2.42175],
#           Effect: [ate-q], [train: 0.04287], [test: 0.04339]
# ********************************************************************************
# epoch: 26 / 100, time cost: 42.27 sec,
#           Loss: [Train: 2.31822], [Test: 2.42561],
#           Effect: [ate-q], [train: 0.10744], [test: 0.10814]
# ********************************************************************************
# epoch: 27 / 100, time cost: 42.30 sec,
#           Loss: [Train: 2.31182], [Test: 2.43135],
#           Effect: [ate-q], [train: 0.04380], [test: 0.04437]
# ********************************************************************************
# epoch: 28 / 100, time cost: 42.13 sec,
#           Loss: [Train: 2.30683], [Test: 2.43702],
#           Effect: [ate-q], [train: 0.04431], [test: 0.04489]
# ********************************************************************************
# epoch: 29 / 100, time cost: 42.25 sec,
#           Loss: [Train: 2.30136], [Test: 2.43921],
#           Effect: [ate-q], [train: 0.05852], [test: 0.05911]
# ********************************************************************************
# epoch: 30 / 100, time cost: 42.32 sec,
#           Loss: [Train: 2.29539], [Test: 2.44686],
#           Effect: [ate-q], [train: 0.09610], [test: 0.09684]
# ********************************************************************************
# epoch: 31 / 100, time cost: 42.55 sec,
#           Loss: [Train: 2.29044], [Test: 2.45153],
#           Effect: [ate-q], [train: 0.03942], [test: 0.04001]
# ********************************************************************************
# epoch: 32 / 100, time cost: 42.28 sec,
#           Loss: [Train: 2.28541], [Test: 2.45726],
#           Effect: [ate-q], [train: 0.08710], [test: 0.08782]
# ********************************************************************************
# epoch: 33 / 100, time cost: 42.38 sec,
#           Loss: [Train: 2.28065], [Test: 2.46134],
#           Effect: [ate-q], [train: 0.08268], [test: 0.08341]
# ********************************************************************************
# epoch: 34 / 100, time cost: 42.07 sec,
#           Loss: [Train: 2.27595], [Test: 2.46668],
#           Effect: [ate-q], [train: 0.06813], [test: 0.06885]
# ********************************************************************************
# epoch: 35 / 100, time cost: 42.19 sec,
#           Loss: [Train: 2.27097], [Test: 2.47460],
#           Effect: [ate-q], [train: 0.03062], [test: 0.03122]
# ********************************************************************************
# epoch: 36 / 100, time cost: 42.52 sec,
#           Loss: [Train: 2.26636], [Test: 2.48111],
#           Effect: [ate-q], [train: 0.11569], [test: 0.11657]
# ********************************************************************************
# epoch: 37 / 100, time cost: 42.79 sec,
#           Loss: [Train: 2.26155], [Test: 2.48225],
#           Effect: [ate-q], [train: 0.05881], [test: 0.05959]
# ********************************************************************************
# epoch: 38 / 100, time cost: 42.64 sec,
#           Loss: [Train: 2.25660], [Test: 2.48809],
#           Effect: [ate-q], [train: 0.05284], [test: 0.05357]
# ********************************************************************************
# epoch: 39 / 100, time cost: 42.94 sec,
#           Loss: [Train: 2.25247], [Test: 2.49517],
#           Effect: [ate-q], [train: 0.04617], [test: 0.04692]
# ********************************************************************************
# epoch: 40 / 100, time cost: 42.36 sec,
#           Loss: [Train: 2.24758], [Test: 2.50465],
#           Effect: [ate-q], [train: 0.10090], [test: 0.10181]
# ********************************************************************************
# epoch: 41 / 100, time cost: 42.49 sec,
#           Loss: [Train: 2.24299], [Test: 2.50409],
#           Effect: [ate-q], [train: 0.06699], [test: 0.06776]
# ********************************************************************************
# epoch: 42 / 100, time cost: 42.39 sec,
#           Loss: [Train: 2.23805], [Test: 2.50968],
#           Effect: [ate-q], [train: 0.08708], [test: 0.08781]
# ********************************************************************************
# epoch: 43 / 100, time cost: 42.33 sec,
#           Loss: [Train: 2.23385], [Test: 2.51553],
#           Effect: [ate-q], [train: 0.06240], [test: 0.06318]
# ********************************************************************************
# epoch: 44 / 100, time cost: 42.82 sec,
#           Loss: [Train: 2.22909], [Test: 2.52176],
#           Effect: [ate-q], [train: 0.09981], [test: 0.10059]
# ********************************************************************************
# epoch: 45 / 100, time cost: 42.31 sec,
#           Loss: [Train: 2.22540], [Test: 2.52804],
#           Effect: [ate-q], [train: 0.08734], [test: 0.08821]
# ********************************************************************************
# epoch: 46 / 100, time cost: 42.43 sec,
#           Loss: [Train: 2.22082], [Test: 2.53248],
#           Effect: [ate-q], [train: 0.06402], [test: 0.06472]
# ********************************************************************************
# epoch: 47 / 100, time cost: 42.03 sec,
#           Loss: [Train: 2.21677], [Test: 2.53941],
#           Effect: [ate-q], [train: 0.03889], [test: 0.03962]
# ********************************************************************************
# epoch: 48 / 100, time cost: 40.85 sec,
#           Loss: [Train: 2.21236], [Test: 2.54432],
#           Effect: [ate-q], [train: 0.07155], [test: 0.07225]
# ********************************************************************************
# epoch: 49 / 100, time cost: 41.86 sec,
#           Loss: [Train: 2.20913], [Test: 2.55071],
#           Effect: [ate-q], [train: 0.08805], [test: 0.08876]
# ********************************************************************************
# epoch: 50 / 100, time cost: 42.43 sec,
#           Loss: [Train: 2.20477], [Test: 2.55770],
#           Effect: [ate-q], [train: 0.09989], [test: 0.10063]
# ********************************************************************************
# epoch: 51 / 100, time cost: 42.37 sec,
#           Loss: [Train: 2.20161], [Test: 2.56132],
#           Effect: [ate-q], [train: 0.05735], [test: 0.05804]
# ********************************************************************************
# epoch: 52 / 100, time cost: 42.23 sec,
#           Loss: [Train: 2.19738], [Test: 2.56770],
#           Effect: [ate-q], [train: 0.06024], [test: 0.06087]
# ********************************************************************************
# epoch: 53 / 100, time cost: 42.32 sec,
#           Loss: [Train: 2.19451], [Test: 2.57279],
#           Effect: [ate-q], [train: 0.04474], [test: 0.04528]
# ********************************************************************************
# epoch: 54 / 100, time cost: 42.19 sec,
#           Loss: [Train: 2.19095], [Test: 2.57649],
#           Effect: [ate-q], [train: 0.07983], [test: 0.08048]
# ********************************************************************************
# epoch: 55 / 100, time cost: 42.11 sec,
#           Loss: [Train: 2.18748], [Test: 2.58588],
#           Effect: [ate-q], [train: 0.07101], [test: 0.07159]
# ********************************************************************************
# epoch: 56 / 100, time cost: 42.12 sec,
#           Loss: [Train: 2.18488], [Test: 2.59028],
#           Effect: [ate-q], [train: 0.11575], [test: 0.11646]
# ********************************************************************************
# epoch: 57 / 100, time cost: 42.58 sec,
#           Loss: [Train: 2.18124], [Test: 2.59311],
#           Effect: [ate-q], [train: 0.05086], [test: 0.05138]
# ********************************************************************************
# epoch: 58 / 100, time cost: 42.16 sec,
#           Loss: [Train: 2.17881], [Test: 2.60465],
#           Effect: [ate-q], [train: 0.09338], [test: 0.09421]
# ********************************************************************************
# epoch: 59 / 100, time cost: 42.52 sec,
#           Loss: [Train: 2.17574], [Test: 2.60307],
#           Effect: [ate-q], [train: 0.06968], [test: 0.07010]
# ********************************************************************************
# epoch: 60 / 100, time cost: 42.14 sec,
#           Loss: [Train: 2.17233], [Test: 2.60712],
#           Effect: [ate-q], [train: 0.07664], [test: 0.07714]
# ********************************************************************************
# epoch: 61 / 100, time cost: 42.18 sec,
#           Loss: [Train: 2.17032], [Test: 2.61234],
#           Effect: [ate-q], [train: 0.05305], [test: 0.05354]
# ********************************************************************************
# epoch: 62 / 100, time cost: 42.32 sec,
#           Loss: [Train: 2.16704], [Test: 2.61756],
#           Effect: [ate-q], [train: 0.04124], [test: 0.04162]
# ********************************************************************************
# epoch: 63 / 100, time cost: 42.49 sec,
#           Loss: [Train: 2.16397], [Test: 2.62319],
#           Effect: [ate-q], [train: 0.03266], [test: 0.03314]
# ********************************************************************************
# epoch: 64 / 100, time cost: 42.43 sec,
#           Loss: [Train: 2.16189], [Test: 2.62674],
#           Effect: [ate-q], [train: 0.08340], [test: 0.08396]
# ********************************************************************************
# epoch: 65 / 100, time cost: 42.02 sec,
#           Loss: [Train: 2.15953], [Test: 2.63349],
#           Effect: [ate-q], [train: 0.08933], [test: 0.08994]
# ********************************************************************************
# epoch: 66 / 100, time cost: 42.57 sec,
#           Loss: [Train: 2.15698], [Test: 2.63480],
#           Effect: [ate-q], [train: 0.07038], [test: 0.07083]
# ********************************************************************************
# epoch: 67 / 100, time cost: 42.79 sec,
#           Loss: [Train: 2.15441], [Test: 2.64518],
#           Effect: [ate-q], [train: 0.11337], [test: 0.11402]
# ********************************************************************************
# epoch: 68 / 100, time cost: 42.33 sec,
#           Loss: [Train: 2.15250], [Test: 2.64471],
#           Effect: [ate-q], [train: 0.08699], [test: 0.08759]
# ********************************************************************************
# epoch: 69 / 100, time cost: 42.55 sec,
#           Loss: [Train: 2.15120], [Test: 2.64944],
#           Effect: [ate-q], [train: 0.08511], [test: 0.08570]
# ********************************************************************************
# epoch: 70 / 100, time cost: 42.78 sec,
#           Loss: [Train: 2.14813], [Test: 2.65180],
#           Effect: [ate-q], [train: 0.05468], [test: 0.05510]
# ********************************************************************************
# epoch: 71 / 100, time cost: 42.46 sec,
#           Loss: [Train: 2.14650], [Test: 2.65885],
#           Effect: [ate-q], [train: 0.10599], [test: 0.10673]
# ********************************************************************************
# epoch: 72 / 100, time cost: 42.32 sec,
#           Loss: [Train: 2.14345], [Test: 2.65841],
#           Effect: [ate-q], [train: 0.06439], [test: 0.06484]
# ********************************************************************************
# epoch: 73 / 100, time cost: 42.51 sec,
#           Loss: [Train: 2.14232], [Test: 2.66296],
#           Effect: [ate-q], [train: 0.06295], [test: 0.06339]
# ********************************************************************************
# epoch: 74 / 100, time cost: 42.54 sec,
#           Loss: [Train: 2.14061], [Test: 2.66976],
#           Effect: [ate-q], [train: 0.01741], [test: 0.01765]
# ********************************************************************************
# epoch: 75 / 100, time cost: 42.24 sec,
#           Loss: [Train: 2.13838], [Test: 2.66973],
#           Effect: [ate-q], [train: 0.05505], [test: 0.05554]
# ********************************************************************************
# epoch: 76 / 100, time cost: 42.62 sec,
#           Loss: [Train: 2.13662], [Test: 2.67312],
#           Effect: [ate-q], [train: 0.06138], [test: 0.06179]
# ********************************************************************************
# epoch: 77 / 100, time cost: 42.65 sec,
#           Loss: [Train: 2.13556], [Test: 2.67702],
#           Effect: [ate-q], [train: 0.09934], [test: 0.09994]
# ********************************************************************************
# epoch: 78 / 100, time cost: 42.66 sec,
#           Loss: [Train: 2.13342], [Test: 2.67897],
#           Effect: [ate-q], [train: 0.08282], [test: 0.08342]
# ********************************************************************************
# epoch: 79 / 100, time cost: 42.68 sec,
#           Loss: [Train: 2.13261], [Test: 2.68089],
#           Effect: [ate-q], [train: 0.05515], [test: 0.05566]
# ********************************************************************************
# epoch: 80 / 100, time cost: 42.35 sec,
#           Loss: [Train: 2.13044], [Test: 2.68426],
#           Effect: [ate-q], [train: 0.05284], [test: 0.05327]
# ********************************************************************************
# epoch: 81 / 100, time cost: 42.32 sec,
#           Loss: [Train: 2.12995], [Test: 2.68913],
#           Effect: [ate-q], [train: 0.05636], [test: 0.05682]
# ********************************************************************************
# epoch: 82 / 100, time cost: 42.33 sec,
#           Loss: [Train: 2.12732], [Test: 2.69010],
#           Effect: [ate-q], [train: 0.08353], [test: 0.08404]
# ********************************************************************************
# epoch: 83 / 100, time cost: 42.53 sec,
#           Loss: [Train: 2.12674], [Test: 2.69221],
#           Effect: [ate-q], [train: 0.07198], [test: 0.07252]
# ********************************************************************************
# epoch: 84 / 100, time cost: 42.80 sec,
#           Loss: [Train: 2.12490], [Test: 2.69607],
#           Effect: [ate-q], [train: 0.04589], [test: 0.04630]
# ********************************************************************************
# epoch: 85 / 100, time cost: 42.75 sec,
#           Loss: [Train: 2.12395], [Test: 2.70089],
#           Effect: [ate-q], [train: 0.03411], [test: 0.03445]
# ********************************************************************************
# epoch: 86 / 100, time cost: 43.05 sec,
#           Loss: [Train: 2.12309], [Test: 2.70292],
#           Effect: [ate-q], [train: 0.05390], [test: 0.05440]
# ********************************************************************************
# epoch: 87 / 100, time cost: 42.80 sec,
#           Loss: [Train: 2.12208], [Test: 2.70655],
#           Effect: [ate-q], [train: 0.04391], [test: 0.04434]
# ********************************************************************************
# epoch: 88 / 100, time cost: 42.59 sec,
#           Loss: [Train: 2.12118], [Test: 2.70728],
#           Effect: [ate-q], [train: 0.07544], [test: 0.07604]
# ********************************************************************************
# epoch: 89 / 100, time cost: 42.84 sec,
#           Loss: [Train: 2.11978], [Test: 2.71048],
#           Effect: [ate-q], [train: 0.06386], [test: 0.06443]
# ********************************************************************************
# epoch: 90 / 100, time cost: 42.03 sec,
#           Loss: [Train: 2.11934], [Test: 2.70965],
#           Effect: [ate-q], [train: 0.06631], [test: 0.06696]
# ********************************************************************************
# epoch: 91 / 100, time cost: 42.53 sec,
#           Loss: [Train: 2.11828], [Test: 2.71088],
#           Effect: [ate-q], [train: 0.06505], [test: 0.06560]
# ********************************************************************************
# epoch: 92 / 100, time cost: 42.25 sec,
#           Loss: [Train: 2.11758], [Test: 2.71282],
#           Effect: [ate-q], [train: 0.06699], [test: 0.06758]
# ********************************************************************************
# epoch: 93 / 100, time cost: 42.63 sec,
#           Loss: [Train: 2.11669], [Test: 2.71488],
#           Effect: [ate-q], [train: 0.03852], [test: 0.03889]
# ********************************************************************************
# epoch: 94 / 100, time cost: 42.09 sec,
#           Loss: [Train: 2.11606], [Test: 2.71426],
#           Effect: [ate-q], [train: 0.07240], [test: 0.07293]
# ********************************************************************************
# epoch: 95 / 100, time cost: 42.17 sec,
#           Loss: [Train: 2.11525], [Test: 2.71550],
#           Effect: [ate-q], [train: 0.05327], [test: 0.05372]
# ********************************************************************************
# epoch: 96 / 100, time cost: 42.10 sec,
#           Loss: [Train: 2.11492], [Test: 2.71682],
#           Effect: [ate-q], [train: 0.04534], [test: 0.04579]
# ********************************************************************************
# epoch: 97 / 100, time cost: 42.43 sec,
#           Loss: [Train: 2.11415], [Test: 2.71703],
#           Effect: [ate-q], [train: 0.07208], [test: 0.07268]
# ********************************************************************************
# epoch: 98 / 100, time cost: 42.36 sec,
#           Loss: [Train: 2.11410], [Test: 2.71819],
#           Effect: [ate-q], [train: 0.06798], [test: 0.06856]
# ********************************************************************************
# epoch: 99 / 100, time cost: 42.62 sec,
#           Loss: [Train: 2.11313], [Test: 2.71958],
#           Effect: [ate-q], [train: 0.06239], [test: 0.06287]
# ********************************************************************************
# epoch: 100 / 100, time cost: 42.50 sec,
#           Loss: [Train: 2.11329], [Test: 2.71969],
#           Effect: [ate-q], [train: 0.06239], [test: 0.06291]
# ********************************************************************************
# Finish training...

# %%
real = true_casual_effect(test_loader)
unadjust = (testset.response[testset.treatment == 1].mean() - testset.response[testset.treatment == 0].mean()).item()
show_result(train_loss_hist, test_loss_hist, est_effect, real, unadjust, epoch)

# %% [markdown]
# # Med

# %%
vocab = create_vocab(merged=True, uni_diag=True)
tokenizer = WordLevelBertTokenizer(vocab)

alpha = 0.25
beta = 5.
c = 0.2
i = 0.

# %%
start = time.time()
trainset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                             alpha=alpha, beta=beta, c=c, i=i, 
                             group=list(range(1)), max_length=512, min_length=10,
                             truncate_method='first', device=device, seed=1)

print(f'Load training set in {(time.time() - start):.2f} sec')

start = time.time()
testset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                            alpha=alpha, beta=beta, c=c, i=i, 
                            group=[9], max_length=512, min_length=10,
                            truncate_method='first', device=device)

print(f'Load validation set in {(time.time() - start):.2f} sec')
# Out:
# Load training set in 70.11 sec
# Load validation set in 66.88 sec

# %%
train_loader = DataLoader(trainset, batch_size=bsz, drop_last=True, shuffle=True)
test_loader = DataLoader(testset, batch_size=2048, drop_last=True, shuffle=True)

# %%
real_att_q = true_casual_effect(test_loader)

print(f'Real: [effect: ate], [estimation: q], [value: {real_att_q:.5f}]')
print(f'Unadjusted: [value: {(testset.response[testset.treatment == 1].mean() - testset.response[testset.treatment == 0].mean()).item():.4f}]')
# Out:
# Real: [effect: ate], [estimation: q], [value: 0.06024]
# Unadjusted: [value: 0.1403]

# %%
trained_bert = '/nfs/turbo/lsa-regier/bert-results/results/behrt/MLM/merged/unidiag/checkpoint-6018425/'
# trained_bert = '/home/liutianc/emr/bert/results/behrt/MLM/merged/unidiag/checkpoint-6018425/'

model = BertForMaskedLM.from_pretrained(trained_bert)
token_embed = model.get_input_embeddings()
model = CausalBOW(token_embed, learnable_docu_embed=False, hidden_size=hidden_size, prop_is_logit=True).to(device)

pos_portion = trainset.treatment.mean()
pos_weight = (1 - pos_portion) / pos_portion

# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
epoch_iter = len(train_loader)
total_steps = epoch * epoch_iter

optimizer = AdamW(model.parameters(), lr=1e-4, eps=1e-8)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

q_loss = nn.BCELoss()
# prop_score_loss = nn.BCELoss()
prop_score_loss = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# Please specify the effect and estimation we want to use here.
effect = 'ate'
estimation = 'q'

effect = effect.lower()
estimation = estimation.lower()
assert effect in ['att', 'ate'], f'Wrong effect: {effect}...'
assert estimation in ['q', 'plugin'], f'Wrong estimation: {estimation}...'

# %%
rs_loss, rq1_loss, rq0_loss = [0.] * 3

train_loss_hist, test_loss_hist, est_effect = [], [], []
for e in range(1, epoch + 1):
    model.train()
    start = time.time()
    run_loss = 0.
    for idx, (tokens, treatment, response) in enumerate(train_loader):
        optimizer.zero_grad()
        prop_score, q1, q0 = model(tokens)
        
        loss = prop_score_loss(prop_score, treatment)
        if len(response[treatment == 1]) > 0:
            loss += q_loss(q1[treatment==1], response[treatment==1])# * pos_weight
            
        if len(response[treatment == 0]) > 0:
            loss += q_loss(q0[treatment==0], response[treatment==0])
            
        loss.backward()
        
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)    
        optimizer.step()
        scheduler.step()

        run_loss += loss.item()
        
    run_idx = idx

    # Evaluation.
    train_loss = run_loss / (run_idx + 1)
    train_effect, _, _, _ = est_casual_effect(train_loader, model, effect, estimation, eval_loss=False)
    test_effect, g_loss_test, q1_loss_test, q0_loss_test = est_casual_effect(test_loader, model, effect, estimation, g_loss=prop_score_loss, q_loss=q_loss)
    test_loss = q1_loss_test + q0_loss_test
    test_loss += g_loss_test
    
    train_loss_hist.append(train_loss)
    test_loss_hist.append(test_loss)
    est_effect.append(test_effect)
    print(f'''epoch: {e} / {epoch}, time cost: {(time.time() - start):.2f} sec, 
          Loss: [Train: {train_loss:.5f}], [Test: {test_loss:.5f}],
          Effect: [{effect}-{estimation}], [train: {train_effect:.5f}], [test: {test_effect:.5f}]''')
    print('*'* 80)
    start = time.time()
    run_loss = 0.

print('Finish training...')

# With only 1 group(s) to train.
# Out:
# epoch: 1 / 100, time cost: 36.81 sec,
#           Loss: [Train: 2.39876], [Test: 2.40095],
#           Effect: [ate-q], [train: 0.13645], [test: 0.13643]
# ********************************************************************************
# epoch: 2 / 100, time cost: 41.82 sec,
#           Loss: [Train: 2.39181], [Test: 2.39478],
#           Effect: [ate-q], [train: 0.12066], [test: 0.12065]
# ********************************************************************************
# epoch: 3 / 100, time cost: 40.80 sec,
#           Loss: [Train: 2.38090], [Test: 2.38051],
#           Effect: [ate-q], [train: 0.12523], [test: 0.12527]
# ********************************************************************************
# epoch: 4 / 100, time cost: 41.04 sec,
#           Loss: [Train: 2.36359], [Test: 2.36729],
#           Effect: [ate-q], [train: 0.11795], [test: 0.11813]
# ********************************************************************************
# epoch: 5 / 100, time cost: 41.13 sec,
#           Loss: [Train: 2.35116], [Test: 2.36130],
#           Effect: [ate-q], [train: 0.11575], [test: 0.11599]
# ********************************************************************************
# epoch: 6 / 100, time cost: 39.81 sec,
#           Loss: [Train: 2.34360], [Test: 2.35737],
#           Effect: [ate-q], [train: 0.10922], [test: 0.10949]
# ********************************************************************************
# epoch: 7 / 100, time cost: 40.09 sec,
#           Loss: [Train: 2.33652], [Test: 2.35412],
#           Effect: [ate-q], [train: 0.09690], [test: 0.09719]
# ********************************************************************************
# epoch: 8 / 100, time cost: 40.31 sec,
#           Loss: [Train: 2.32975], [Test: 2.35121],
#           Effect: [ate-q], [train: 0.12291], [test: 0.12329]
# ********************************************************************************
# epoch: 9 / 100, time cost: 39.67 sec,
#           Loss: [Train: 2.32433], [Test: 2.34933],
#           Effect: [ate-q], [train: 0.08838], [test: 0.08879]
# ********************************************************************************
# epoch: 10 / 100, time cost: 39.85 sec,
#           Loss: [Train: 2.31795], [Test: 2.34975],
#           Effect: [ate-q], [train: 0.06519], [test: 0.06569]
# ********************************************************************************
# epoch: 11 / 100, time cost: 39.79 sec,
#           Loss: [Train: 2.31200], [Test: 2.34806],
#           Effect: [ate-q], [train: 0.12423], [test: 0.12475]
# ********************************************************************************
# epoch: 12 / 100, time cost: 39.65 sec,
#           Loss: [Train: 2.30561], [Test: 2.34526],
#           Effect: [ate-q], [train: 0.09207], [test: 0.09270]
# ********************************************************************************
# epoch: 13 / 100, time cost: 40.47 sec,
#           Loss: [Train: 2.29983], [Test: 2.34624],
#           Effect: [ate-q], [train: 0.10221], [test: 0.10297]
# ********************************************************************************
# epoch: 14 / 100, time cost: 39.38 sec,
#           Loss: [Train: 2.29397], [Test: 2.34950],
#           Effect: [ate-q], [train: 0.12361], [test: 0.12449]
# ********************************************************************************
# epoch: 15 / 100, time cost: 39.51 sec,
#           Loss: [Train: 2.28767], [Test: 2.34765],
#           Effect: [ate-q], [train: 0.07292], [test: 0.07389]
# ********************************************************************************
# epoch: 16 / 100, time cost: 39.48 sec,
#           Loss: [Train: 2.28132], [Test: 2.34709],
#           Effect: [ate-q], [train: 0.09619], [test: 0.09725]
# ********************************************************************************
# epoch: 17 / 100, time cost: 39.51 sec,
#           Loss: [Train: 2.27430], [Test: 2.34920],
#           Effect: [ate-q], [train: 0.09352], [test: 0.09475]
# ********************************************************************************
# epoch: 18 / 100, time cost: 39.61 sec,
#           Loss: [Train: 2.26779], [Test: 2.35200],
#           Effect: [ate-q], [train: 0.06447], [test: 0.06570]
# ********************************************************************************
# epoch: 19 / 100, time cost: 39.22 sec,
#           Loss: [Train: 2.26198], [Test: 2.35258],
#           Effect: [ate-q], [train: 0.08181], [test: 0.08316]
# ********************************************************************************
# epoch: 20 / 100, time cost: 39.20 sec,
#           Loss: [Train: 2.25490], [Test: 2.35901],
#           Effect: [ate-q], [train: 0.04405], [test: 0.04551]
# ********************************************************************************
# epoch: 21 / 100, time cost: 39.39 sec,
#           Loss: [Train: 2.24866], [Test: 2.35879],
#           Effect: [ate-q], [train: 0.07693], [test: 0.07854]
# ********************************************************************************
# epoch: 22 / 100, time cost: 39.41 sec,
#           Loss: [Train: 2.24238], [Test: 2.36555],
#           Effect: [ate-q], [train: 0.03583], [test: 0.03744]
# ********************************************************************************
# epoch: 23 / 100, time cost: 39.36 sec,
#           Loss: [Train: 2.23661], [Test: 2.36726],
#           Effect: [ate-q], [train: 0.04841], [test: 0.05012]
# ********************************************************************************
# epoch: 24 / 100, time cost: 39.33 sec,
#           Loss: [Train: 2.22989], [Test: 2.36899],
#           Effect: [ate-q], [train: 0.05006], [test: 0.05185]
# ********************************************************************************
# epoch: 25 / 100, time cost: 39.24 sec,
#           Loss: [Train: 2.22404], [Test: 2.37498],
#           Effect: [ate-q], [train: 0.04344], [test: 0.04530]
# ********************************************************************************
# epoch: 26 / 100, time cost: 39.24 sec,
#           Loss: [Train: 2.21815], [Test: 2.37599],
#           Effect: [ate-q], [train: 0.12241], [test: 0.12469]
# ********************************************************************************
# epoch: 27 / 100, time cost: 39.33 sec,
#           Loss: [Train: 2.21197], [Test: 2.37967],
#           Effect: [ate-q], [train: 0.05901], [test: 0.06112]
# ********************************************************************************
# epoch: 28 / 100, time cost: 39.31 sec,
#           Loss: [Train: 2.20687], [Test: 2.38612],
#           Effect: [ate-q], [train: 0.04933], [test: 0.05149]
# ********************************************************************************
# epoch: 29 / 100, time cost: 39.43 sec,
#           Loss: [Train: 2.20142], [Test: 2.38956],
#           Effect: [ate-q], [train: 0.05145], [test: 0.05361]
# ********************************************************************************
# epoch: 30 / 100, time cost: 39.42 sec,
#           Loss: [Train: 2.19517], [Test: 2.39488],
#           Effect: [ate-q], [train: 0.10961], [test: 0.11204]
# ********************************************************************************
# epoch: 31 / 100, time cost: 39.54 sec,
#           Loss: [Train: 2.19061], [Test: 2.39796],
#           Effect: [ate-q], [train: 0.04275], [test: 0.04501]
# ********************************************************************************
# epoch: 32 / 100, time cost: 39.24 sec,
#           Loss: [Train: 2.18565], [Test: 2.40102],
#           Effect: [ate-q], [train: 0.08431], [test: 0.08674]
# ********************************************************************************
# epoch: 33 / 100, time cost: 39.09 sec,
#           Loss: [Train: 2.18222], [Test: 2.40656],
#           Effect: [ate-q], [train: 0.09029], [test: 0.09277]
# ********************************************************************************
# epoch: 34 / 100, time cost: 39.05 sec,
#           Loss: [Train: 2.17851], [Test: 2.41028],
#           Effect: [ate-q], [train: 0.05153], [test: 0.05396]
# ********************************************************************************
# epoch: 35 / 100, time cost: 39.12 sec,
#           Loss: [Train: 2.17296], [Test: 2.41901],
#           Effect: [ate-q], [train: 0.02542], [test: 0.02778]
# ********************************************************************************
# epoch: 36 / 100, time cost: 39.34 sec,
#           Loss: [Train: 2.16874], [Test: 2.41992],
#           Effect: [ate-q], [train: 0.10251], [test: 0.10522]
# ********************************************************************************
# epoch: 37 / 100, time cost: 39.18 sec,
#           Loss: [Train: 2.16538], [Test: 2.42467],
#           Effect: [ate-q], [train: 0.03833], [test: 0.04073]
# ********************************************************************************
# epoch: 38 / 100, time cost: 40.34 sec,
#           Loss: [Train: 2.16030], [Test: 2.42676],
#           Effect: [ate-q], [train: 0.05540], [test: 0.05792]
# ********************************************************************************
# epoch: 39 / 100, time cost: 39.41 sec,
#           Loss: [Train: 2.15649], [Test: 2.43512],
#           Effect: [ate-q], [train: 0.06483], [test: 0.06740]
# ********************************************************************************
# epoch: 40 / 100, time cost: 39.47 sec,
#           Loss: [Train: 2.15205], [Test: 2.43877],
#           Effect: [ate-q], [train: 0.10591], [test: 0.10863]
# ********************************************************************************
# epoch: 41 / 100, time cost: 39.68 sec,
#           Loss: [Train: 2.14781], [Test: 2.44149],
#           Effect: [ate-q], [train: 0.05141], [test: 0.05394]
# ********************************************************************************
# epoch: 42 / 100, time cost: 40.77 sec,
#           Loss: [Train: 2.14403], [Test: 2.44460],
#           Effect: [ate-q], [train: 0.07215], [test: 0.07459]
# ********************************************************************************
# epoch: 43 / 100, time cost: 40.91 sec,
#           Loss: [Train: 2.14000], [Test: 2.44878],
#           Effect: [ate-q], [train: 0.04040], [test: 0.04297]
# ********************************************************************************
# epoch: 44 / 100, time cost: 40.79 sec,
#           Loss: [Train: 2.13554], [Test: 2.45248],
#           Effect: [ate-q], [train: 0.09299], [test: 0.09564]
# ********************************************************************************
# epoch: 45 / 100, time cost: 41.08 sec,
#           Loss: [Train: 2.13183], [Test: 2.45851],
#           Effect: [ate-q], [train: 0.06212], [test: 0.06468]
# ********************************************************************************
# epoch: 46 / 100, time cost: 39.99 sec,
#           Loss: [Train: 2.12838], [Test: 2.46230],
#           Effect: [ate-q], [train: 0.04412], [test: 0.04666]
# ********************************************************************************
# epoch: 47 / 100, time cost: 40.29 sec,
#           Loss: [Train: 2.12433], [Test: 2.46852],
#           Effect: [ate-q], [train: 0.01831], [test: 0.02079]
# ********************************************************************************
# epoch: 48 / 100, time cost: 40.31 sec,
#           Loss: [Train: 2.12048], [Test: 2.46825],
#           Effect: [ate-q], [train: 0.08206], [test: 0.08470]
# ********************************************************************************
# epoch: 49 / 100, time cost: 40.76 sec,
#           Loss: [Train: 2.11734], [Test: 2.47153],
#           Effect: [ate-q], [train: 0.07433], [test: 0.07684]
# ********************************************************************************
# epoch: 50 / 100, time cost: 40.64 sec,
#           Loss: [Train: 2.11341], [Test: 2.47982],
#           Effect: [ate-q], [train: 0.08954], [test: 0.09205]
# ********************************************************************************
# epoch: 51 / 100, time cost: 40.66 sec,
#           Loss: [Train: 2.11002], [Test: 2.48014],
#           Effect: [ate-q], [train: 0.05132], [test: 0.05390]
# ********************************************************************************
# epoch: 52 / 100, time cost: 40.59 sec,
#           Loss: [Train: 2.10664], [Test: 2.49041],
#           Effect: [ate-q], [train: 0.03807], [test: 0.04035]
# ********************************************************************************
# epoch: 53 / 100, time cost: 40.47 sec,
#           Loss: [Train: 2.10394], [Test: 2.49426],
#           Effect: [ate-q], [train: 0.02150], [test: 0.02374]
# ********************************************************************************
# epoch: 54 / 100, time cost: 40.12 sec,
#           Loss: [Train: 2.09762], [Test: 2.49218],
#           Effect: [ate-q], [train: 0.05235], [test: 0.05489]
# ********************************************************************************
# epoch: 55 / 100, time cost: 40.87 sec,
#           Loss: [Train: 2.09650], [Test: 2.49883],
#           Effect: [ate-q], [train: 0.07534], [test: 0.07777]
# ********************************************************************************
# epoch: 56 / 100, time cost: 40.83 sec,
#           Loss: [Train: 2.09243], [Test: 2.50237],
#           Effect: [ate-q], [train: 0.10094], [test: 0.10355]
# ********************************************************************************
# epoch: 57 / 100, time cost: 41.05 sec,
#           Loss: [Train: 2.08900], [Test: 2.50518],
#           Effect: [ate-q], [train: 0.05273], [test: 0.05517]
# ********************************************************************************
# epoch: 58 / 100, time cost: 41.18 sec,
#           Loss: [Train: 2.08651], [Test: 2.51210],
#           Effect: [ate-q], [train: 0.07660], [test: 0.07920]
# ********************************************************************************
# epoch: 59 / 100, time cost: 40.82 sec,
#           Loss: [Train: 2.08359], [Test: 2.51170],
#           Effect: [ate-q], [train: 0.06247], [test: 0.06477]
# ********************************************************************************
# epoch: 60 / 100, time cost: 40.93 sec,
#           Loss: [Train: 2.08020], [Test: 2.51790],
#           Effect: [ate-q], [train: 0.05677], [test: 0.05897]
# ********************************************************************************
# epoch: 61 / 100, time cost: 40.97 sec,
#           Loss: [Train: 2.07804], [Test: 2.52019],
#           Effect: [ate-q], [train: 0.04485], [test: 0.04707]
# ********************************************************************************
# epoch: 62 / 100, time cost: 41.13 sec,
#           Loss: [Train: 2.07568], [Test: 2.52476],
#           Effect: [ate-q], [train: 0.01547], [test: 0.01755]
# ********************************************************************************
# epoch: 63 / 100, time cost: 41.06 sec,
#           Loss: [Train: 2.07303], [Test: 2.53124],
#           Effect: [ate-q], [train: 0.01308], [test: 0.01532]
# ********************************************************************************
# epoch: 64 / 100, time cost: 41.03 sec,
#           Loss: [Train: 2.07000], [Test: 2.53519],
#           Effect: [ate-q], [train: 0.05406], [test: 0.05644]
# ********************************************************************************
# epoch: 65 / 100, time cost: 41.57 sec,
#           Loss: [Train: 2.06832], [Test: 2.53173],
#           Effect: [ate-q], [train: 0.06248], [test: 0.06491]
# ********************************************************************************
# epoch: 66 / 100, time cost: 41.06 sec,
#           Loss: [Train: 2.06551], [Test: 2.53522],
#           Effect: [ate-q], [train: 0.06601], [test: 0.06836]
# ********************************************************************************
# epoch: 67 / 100, time cost: 41.38 sec,
#           Loss: [Train: 2.06318], [Test: 2.54021],
#           Effect: [ate-q], [train: 0.10678], [test: 0.10929]
# ********************************************************************************
# epoch: 68 / 100, time cost: 41.78 sec,
#           Loss: [Train: 2.06148], [Test: 2.54658],
#           Effect: [ate-q], [train: 0.05178], [test: 0.05412]
# ********************************************************************************
# epoch: 69 / 100, time cost: 39.36 sec,
#           Loss: [Train: 2.05983], [Test: 2.54774],
#           Effect: [ate-q], [train: 0.06827], [test: 0.07082]
# ********************************************************************************
# epoch: 70 / 100, time cost: 41.03 sec,
#           Loss: [Train: 2.05714], [Test: 2.55041],
#           Effect: [ate-q], [train: 0.04427], [test: 0.04653]
# ********************************************************************************
# epoch: 71 / 100, time cost: 40.59 sec,
#           Loss: [Train: 2.05541], [Test: 2.55397],
#           Effect: [ate-q], [train: 0.11267], [test: 0.11537]
# ********************************************************************************
# epoch: 72 / 100, time cost: 40.65 sec,
#           Loss: [Train: 2.05266], [Test: 2.55838],
#           Effect: [ate-q], [train: 0.03570], [test: 0.03791]
# ********************************************************************************
# epoch: 73 / 100, time cost: 40.99 sec,
#           Loss: [Train: 2.05110], [Test: 2.56273],
#           Effect: [ate-q], [train: 0.02608], [test: 0.02823]
# ********************************************************************************
# epoch: 74 / 100, time cost: 41.15 sec,
#           Loss: [Train: 2.04951], [Test: 2.56650],
#           Effect: [ate-q], [train: 0.01473], [test: 0.01684]
# ********************************************************************************
# epoch: 75 / 100, time cost: 41.12 sec,
#           Loss: [Train: 2.04772], [Test: 2.56544],
#           Effect: [ate-q], [train: 0.03910], [test: 0.04141]
# ********************************************************************************
# epoch: 76 / 100, time cost: 40.88 sec,
#           Loss: [Train: 2.04667], [Test: 2.56870],
#           Effect: [ate-q], [train: 0.03697], [test: 0.03919]
# ********************************************************************************
# epoch: 77 / 100, time cost: 40.88 sec,
#           Loss: [Train: 2.04539], [Test: 2.57208],
#           Effect: [ate-q], [train: 0.07090], [test: 0.07331]
# ********************************************************************************
# epoch: 78 / 100, time cost: 41.21 sec,
#           Loss: [Train: 2.04374], [Test: 2.57362],
#           Effect: [ate-q], [train: 0.06011], [test: 0.06254]
# ********************************************************************************
# epoch: 79 / 100, time cost: 41.19 sec,
#           Loss: [Train: 2.04248], [Test: 2.57774],
#           Effect: [ate-q], [train: 0.03202], [test: 0.03437]
# ********************************************************************************
# epoch: 80 / 100, time cost: 41.22 sec,
#           Loss: [Train: 2.04041], [Test: 2.57811],
#           Effect: [ate-q], [train: 0.04445], [test: 0.04683]
# ********************************************************************************
# epoch: 81 / 100, time cost: 41.42 sec,
#           Loss: [Train: 2.03994], [Test: 2.58246],
#           Effect: [ate-q], [train: 0.05428], [test: 0.05672]
# ********************************************************************************
# epoch: 82 / 100, time cost: 41.02 sec,
#           Loss: [Train: 2.03780], [Test: 2.58452],
#           Effect: [ate-q], [train: 0.06624], [test: 0.06871]
# ********************************************************************************
# epoch: 83 / 100, time cost: 40.93 sec,
#           Loss: [Train: 2.03756], [Test: 2.58660],
#           Effect: [ate-q], [train: 0.03949], [test: 0.04186]
# ********************************************************************************
# epoch: 84 / 100, time cost: 41.00 sec,
#           Loss: [Train: 2.03580], [Test: 2.58909],
#           Effect: [ate-q], [train: 0.02800], [test: 0.03026]
# ********************************************************************************
# epoch: 85 / 100, time cost: 41.18 sec,
#           Loss: [Train: 2.03539], [Test: 2.59490],
#           Effect: [ate-q], [train: 0.02115], [test: 0.02342]
# ********************************************************************************
# epoch: 86 / 100, time cost: 41.10 sec,
#           Loss: [Train: 2.03431], [Test: 2.59358],
#           Effect: [ate-q], [train: 0.02956], [test: 0.03191]
# ********************************************************************************
# epoch: 87 / 100, time cost: 41.09 sec,
#           Loss: [Train: 2.03325], [Test: 2.59771],
#           Effect: [ate-q], [train: 0.02350], [test: 0.02580]
# ********************************************************************************
# epoch: 88 / 100, time cost: 40.92 sec,
#           Loss: [Train: 2.03272], [Test: 2.59513],
#           Effect: [ate-q], [train: 0.05981], [test: 0.06240]
# ********************************************************************************
# epoch: 89 / 100, time cost: 41.03 sec,
#           Loss: [Train: 2.03120], [Test: 2.59792],
#           Effect: [ate-q], [train: 0.03971], [test: 0.04215]
# ********************************************************************************
# epoch: 90 / 100, time cost: 41.20 sec,
#           Loss: [Train: 2.03093], [Test: 2.59821],
#           Effect: [ate-q], [train: 0.05777], [test: 0.06038]
# ********************************************************************************
# epoch: 91 / 100, time cost: 41.23 sec,
#           Loss: [Train: 2.03032], [Test: 2.59951],
#           Effect: [ate-q], [train: 0.03769], [test: 0.04019]
# ********************************************************************************
# epoch: 92 / 100, time cost: 41.20 sec,
#           Loss: [Train: 2.02846], [Test: 2.60112],
#           Effect: [ate-q], [train: 0.05176], [test: 0.05428]
# ********************************************************************************
# epoch: 93 / 100, time cost: 41.37 sec,
#           Loss: [Train: 2.02858], [Test: 2.60365],
#           Effect: [ate-q], [train: 0.02898], [test: 0.03129]
# ********************************************************************************
# epoch: 94 / 100, time cost: 41.10 sec,
#           Loss: [Train: 2.02802], [Test: 2.60150],
#           Effect: [ate-q], [train: 0.05559], [test: 0.05803]
# ********************************************************************************
# epoch: 95 / 100, time cost: 40.86 sec,
#           Loss: [Train: 2.02669], [Test: 2.60534],
#           Effect: [ate-q], [train: 0.03393], [test: 0.03624]
# ********************************************************************************
# epoch: 96 / 100, time cost: 40.55 sec,
#           Loss: [Train: 2.02670], [Test: 2.60576],
#           Effect: [ate-q], [train: 0.03044], [test: 0.03283]
# ********************************************************************************
# epoch: 97 / 100, time cost: 40.80 sec,
#           Loss: [Train: 2.02566], [Test: 2.60322],
#           Effect: [ate-q], [train: 0.04717], [test: 0.04967]
# ********************************************************************************
# epoch: 98 / 100, time cost: 40.66 sec,
#           Loss: [Train: 2.02551], [Test: 2.60493],
#           Effect: [ate-q], [train: 0.04392], [test: 0.04638]
# ********************************************************************************
# epoch: 99 / 100, time cost: 40.86 sec,
#           Loss: [Train: 2.02521], [Test: 2.60521],
#           Effect: [ate-q], [train: 0.04521], [test: 0.04760]
# ********************************************************************************
# epoch: 100 / 100, time cost: 40.31 sec,
#           Loss: [Train: 2.02528], [Test: 2.60611],
#           Effect: [ate-q], [train: 0.04467], [test: 0.04713]
# ********************************************************************************
# Finish training...

# %%
real = true_casual_effect(test_loader)
unadjust = (testset.response[testset.treatment == 1].mean() - testset.response[testset.treatment == 0].mean()).item()
show_result(train_loss_hist, test_loss_hist, est_effect, real, unadjust, epoch)

# %% [markdown]
# # High

# %%
vocab = create_vocab(merged=True, uni_diag=True)
tokenizer = WordLevelBertTokenizer(vocab)

alpha = 0.75
beta = 25.
c = 0.2
i = 0.

# %%
start = time.time()
trainset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                             alpha=alpha, beta=beta, c=c, i=i, 
                             group=list(range(1)), max_length=512, min_length=10,
                             truncate_method='first', device=device, seed=1)

print(f'Load training set in {(time.time() - start):.2f} sec')

start = time.time()
testset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                            alpha=alpha, beta=beta, c=c, i=i, 
                            group=[9], max_length=512, min_length=10,
                            truncate_method='first', device=device)

print(f'Load validation set in {(time.time() - start):.2f} sec')
# Out:
# Load training set in 69.31 sec
# Load validation set in 64.14 sec

# %%
train_loader = DataLoader(trainset, batch_size=bsz, drop_last=True, shuffle=True)
test_loader = DataLoader(testset, batch_size=2048, drop_last=True, shuffle=True)

# %%
real_att_q = true_casual_effect(test_loader)

print(f'Real: [effect: ate], [estimation: q], [value: {real_att_q:.5f}]')
print(f'Unadjusted: [value: {(testset.response[testset.treatment == 1].mean() - testset.response[testset.treatment == 0].mean()).item():.4f}]')
# Out:
# Real: [effect: ate], [estimation: q], [value: 0.16917]
# Unadjusted: [value: 0.2379]

# %%
trained_bert = '/nfs/turbo/lsa-regier/bert-results/results/behrt/MLM/merged/unidiag/checkpoint-6018425/'
# trained_bert = '/home/liutianc/emr/bert/results/behrt/MLM/merged/unidiag/checkpoint-6018425/'

model = BertForMaskedLM.from_pretrained(trained_bert)
token_embed = model.get_input_embeddings()
model = CausalBOW(token_embed, learnable_docu_embed=False, hidden_size=hidden_size, prop_is_logit=True).to(device)

pos_portion = trainset.treatment.mean()
pos_weight = (1 - pos_portion) / pos_portion

# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
epoch_iter = len(train_loader)
total_steps = epoch * epoch_iter

optimizer = AdamW(model.parameters(), lr=1e-4, eps=1e-8)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

q_loss = nn.BCELoss()
# prop_score_loss = nn.BCELoss()
prop_score_loss = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# Please specify the effect and estimation we want to use here.
effect = 'ate'
estimation = 'q'

effect = effect.lower()
estimation = estimation.lower()
assert effect in ['att', 'ate'], f'Wrong effect: {effect}...'
assert estimation in ['q', 'plugin'], f'Wrong estimation: {estimation}...'

# %%
rs_loss, rq1_loss, rq0_loss = [0.] * 3

train_loss_hist, test_loss_hist, est_effect = [], [], []
for e in range(1, epoch + 1):
    model.train()
    start = time.time()
    run_loss = 0.
    for idx, (tokens, treatment, response) in enumerate(train_loader):
        optimizer.zero_grad()
        prop_score, q1, q0 = model(tokens)
        
        loss = prop_score_loss(prop_score, treatment)
        if len(response[treatment == 1]) > 0:
            loss += q_loss(q1[treatment==1], response[treatment==1])# * pos_weight
            
        if len(response[treatment == 0]) > 0:
            loss += q_loss(q0[treatment==0], response[treatment==0])
            
        loss.backward()
        
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)    
        optimizer.step()
        scheduler.step()

        run_loss += loss.item()
        
    run_idx = idx

    # Evaluation.
    train_loss = run_loss / (run_idx + 1)
    train_effect, _, _, _ = est_casual_effect(train_loader, model, effect, estimation, eval_loss=False)
    test_effect, g_loss_test, q1_loss_test, q0_loss_test = est_casual_effect(test_loader, model, effect, estimation, g_loss=prop_score_loss, q_loss=q_loss)
    test_loss = q1_loss_test + q0_loss_test
    test_loss += g_loss_test
    
    train_loss_hist.append(train_loss)
    test_loss_hist.append(test_loss)
    est_effect.append(test_effect)
    print(f'''epoch: {e} / {epoch}, time cost: {(time.time() - start):.2f} sec, 
          Loss: [Train: {train_loss:.5f}], [Test: {test_loss:.5f}],
          Effect: [{effect}-{estimation}], [train: {train_effect:.5f}], [test: {test_effect:.5f}]''')
    print('*'* 80)
    start = time.time()
    run_loss = 0.

print('Finish training...')

# With only 1 group(s) to train.
# Out:
# epoch: 1 / 100, time cost: 36.64 sec,
#           Loss: [Train: 2.32170], [Test: 2.31951],
#           Effect: [ate-q], [train: 0.24161], [test: 0.24159]
# ********************************************************************************
# epoch: 2 / 100, time cost: 41.57 sec,
#           Loss: [Train: 2.30688], [Test: 2.31427],
#           Effect: [ate-q], [train: 0.22971], [test: 0.22969]
# ********************************************************************************
# epoch: 3 / 100, time cost: 41.85 sec,
#           Loss: [Train: 2.29955], [Test: 2.30659],
#           Effect: [ate-q], [train: 0.23868], [test: 0.23868]
# ********************************************************************************
# epoch: 4 / 100, time cost: 41.71 sec,
#           Loss: [Train: 2.28929], [Test: 2.29601],
#           Effect: [ate-q], [train: 0.22799], [test: 0.22805]
# ********************************************************************************
# epoch: 5 / 100, time cost: 40.09 sec,
#           Loss: [Train: 2.27666], [Test: 2.28729],
#           Effect: [ate-q], [train: 0.23160], [test: 0.23171]
# ********************************************************************************
# epoch: 6 / 100, time cost: 39.79 sec,
#           Loss: [Train: 2.26757], [Test: 2.28225],
#           Effect: [ate-q], [train: 0.21640], [test: 0.21654]
# ********************************************************************************
# epoch: 7 / 100, time cost: 39.70 sec,
#           Loss: [Train: 2.26049], [Test: 2.27845],
#           Effect: [ate-q], [train: 0.20813], [test: 0.20828]
# ********************************************************************************
# epoch: 8 / 100, time cost: 39.58 sec,
#           Loss: [Train: 2.25370], [Test: 2.27530],
#           Effect: [ate-q], [train: 0.22424], [test: 0.22444]
# ********************************************************************************
# epoch: 9 / 100, time cost: 39.62 sec,
#           Loss: [Train: 2.24854], [Test: 2.27298],
#           Effect: [ate-q], [train: 0.21398], [test: 0.21422]
# ********************************************************************************
# epoch: 10 / 100, time cost: 39.63 sec,
#           Loss: [Train: 2.24293], [Test: 2.27193],
#           Effect: [ate-q], [train: 0.18407], [test: 0.18440]
# ********************************************************************************
# epoch: 11 / 100, time cost: 39.59 sec,
#           Loss: [Train: 2.23731], [Test: 2.26913],
#           Effect: [ate-q], [train: 0.19835], [test: 0.19870]
# ********************************************************************************
# epoch: 12 / 100, time cost: 39.47 sec,
#           Loss: [Train: 2.23164], [Test: 2.26739],
#           Effect: [ate-q], [train: 0.19963], [test: 0.20005]
# ********************************************************************************
# epoch: 13 / 100, time cost: 39.92 sec,
#           Loss: [Train: 2.22650], [Test: 2.26815],
#           Effect: [ate-q], [train: 0.21988], [test: 0.22040]
# ********************************************************************************
# epoch: 14 / 100, time cost: 39.92 sec,
#           Loss: [Train: 2.22136], [Test: 2.26887],
#           Effect: [ate-q], [train: 0.21053], [test: 0.21111]
# ********************************************************************************
# epoch: 15 / 100, time cost: 41.08 sec,
#           Loss: [Train: 2.21562], [Test: 2.26629],
#           Effect: [ate-q], [train: 0.20549], [test: 0.20621]
# ********************************************************************************
# epoch: 16 / 100, time cost: 41.33 sec,
#           Loss: [Train: 2.20997], [Test: 2.26697],
#           Effect: [ate-q], [train: 0.20701], [test: 0.20777]
# ********************************************************************************
# epoch: 17 / 100, time cost: 41.48 sec,
#           Loss: [Train: 2.20319], [Test: 2.26781],
#           Effect: [ate-q], [train: 0.19816], [test: 0.19906]
# ********************************************************************************
# epoch: 18 / 100, time cost: 41.41 sec,
#           Loss: [Train: 2.19703], [Test: 2.26764],
#           Effect: [ate-q], [train: 0.18688], [test: 0.18784]
# ********************************************************************************
# epoch: 19 / 100, time cost: 41.24 sec,
#           Loss: [Train: 2.19121], [Test: 2.26893],
#           Effect: [ate-q], [train: 0.19632], [test: 0.19736]
# ********************************************************************************
# epoch: 20 / 100, time cost: 41.22 sec,
#           Loss: [Train: 2.18463], [Test: 2.27105],
#           Effect: [ate-q], [train: 0.17372], [test: 0.17493]
# ********************************************************************************
# epoch: 21 / 100, time cost: 41.65 sec,
#           Loss: [Train: 2.17809], [Test: 2.27283],
#           Effect: [ate-q], [train: 0.17024], [test: 0.17155]
# ********************************************************************************
# epoch: 22 / 100, time cost: 41.70 sec,
#           Loss: [Train: 2.17182], [Test: 2.27764],
#           Effect: [ate-q], [train: 0.14548], [test: 0.14685]
# ********************************************************************************
# epoch: 23 / 100, time cost: 41.98 sec,
#           Loss: [Train: 2.16585], [Test: 2.27714],
#           Effect: [ate-q], [train: 0.16823], [test: 0.16975]
# ********************************************************************************
# epoch: 24 / 100, time cost: 42.27 sec,
#           Loss: [Train: 2.15873], [Test: 2.27887],
#           Effect: [ate-q], [train: 0.17458], [test: 0.17622]
# ********************************************************************************
# epoch: 25 / 100, time cost: 42.36 sec,
#           Loss: [Train: 2.15234], [Test: 2.28172],
#           Effect: [ate-q], [train: 0.19258], [test: 0.19438]
# ********************************************************************************
# epoch: 26 / 100, time cost: 42.02 sec,
#           Loss: [Train: 2.14624], [Test: 2.28567],
#           Effect: [ate-q], [train: 0.20640], [test: 0.20843]
# ********************************************************************************
# epoch: 27 / 100, time cost: 41.36 sec,
#           Loss: [Train: 2.13922], [Test: 2.28801],
#           Effect: [ate-q], [train: 0.16878], [test: 0.17082]
# ********************************************************************************
# epoch: 28 / 100, time cost: 41.59 sec,
#           Loss: [Train: 2.13271], [Test: 2.29253],
#           Effect: [ate-q], [train: 0.18017], [test: 0.18239]
# ********************************************************************************
# epoch: 29 / 100, time cost: 40.93 sec,
#           Loss: [Train: 2.12639], [Test: 2.29398],
#           Effect: [ate-q], [train: 0.16358], [test: 0.16586]
# ********************************************************************************
# epoch: 30 / 100, time cost: 40.34 sec,
#           Loss: [Train: 2.11960], [Test: 2.30571],
#           Effect: [ate-q], [train: 0.21793], [test: 0.22026]
# ********************************************************************************
# epoch: 31 / 100, time cost: 40.18 sec,
#           Loss: [Train: 2.11298], [Test: 2.30514],
#           Effect: [ate-q], [train: 0.17025], [test: 0.17264]
# ********************************************************************************
# epoch: 32 / 100, time cost: 40.53 sec,
#           Loss: [Train: 2.10661], [Test: 2.31367],
#           Effect: [ate-q], [train: 0.20552], [test: 0.20807]
# ********************************************************************************
# epoch: 33 / 100, time cost: 39.85 sec,
#           Loss: [Train: 2.10065], [Test: 2.31426],
#           Effect: [ate-q], [train: 0.19694], [test: 0.19956]
# ********************************************************************************
# epoch: 34 / 100, time cost: 39.68 sec,
#           Loss: [Train: 2.09488], [Test: 2.32091],
#           Effect: [ate-q], [train: 0.16761], [test: 0.17030]
# ********************************************************************************
# epoch: 35 / 100, time cost: 40.21 sec,
#           Loss: [Train: 2.08876], [Test: 2.32145],
#           Effect: [ate-q], [train: 0.15995], [test: 0.16279]
# ********************************************************************************
# epoch: 36 / 100, time cost: 40.05 sec,
#           Loss: [Train: 2.08314], [Test: 2.33705],
#           Effect: [ate-q], [train: 0.20850], [test: 0.21140]
# ********************************************************************************
# epoch: 37 / 100, time cost: 40.13 sec,
#           Loss: [Train: 2.07776], [Test: 2.33424],
#           Effect: [ate-q], [train: 0.14748], [test: 0.15030]
# ********************************************************************************
# epoch: 38 / 100, time cost: 39.90 sec,
#           Loss: [Train: 2.07189], [Test: 2.33932],
#           Effect: [ate-q], [train: 0.16561], [test: 0.16855]
# ********************************************************************************
# epoch: 39 / 100, time cost: 40.84 sec,
#           Loss: [Train: 2.06758], [Test: 2.35238],
#           Effect: [ate-q], [train: 0.17313], [test: 0.17600]
# ********************************************************************************
# epoch: 40 / 100, time cost: 39.78 sec,
#           Loss: [Train: 2.06195], [Test: 2.35343],
#           Effect: [ate-q], [train: 0.18337], [test: 0.18632]
# ********************************************************************************
# epoch: 41 / 100, time cost: 39.85 sec,
#           Loss: [Train: 2.05679], [Test: 2.35239],
#           Effect: [ate-q], [train: 0.16669], [test: 0.16991]
# ********************************************************************************
# epoch: 42 / 100, time cost: 39.74 sec,
#           Loss: [Train: 2.05182], [Test: 2.36120],
#           Effect: [ate-q], [train: 0.18630], [test: 0.18935]
# ********************************************************************************
# epoch: 43 / 100, time cost: 39.82 sec,
#           Loss: [Train: 2.04734], [Test: 2.37326],
#           Effect: [ate-q], [train: 0.08973], [test: 0.09271]
# ********************************************************************************
# epoch: 44 / 100, time cost: 39.79 sec,
#           Loss: [Train: 2.04295], [Test: 2.37428],
#           Effect: [ate-q], [train: 0.20365], [test: 0.20685]
# ********************************************************************************
# epoch: 45 / 100, time cost: 39.76 sec,
#           Loss: [Train: 2.03864], [Test: 2.37903],
#           Effect: [ate-q], [train: 0.14966], [test: 0.15270]
# ********************************************************************************
# epoch: 46 / 100, time cost: 40.04 sec,
#           Loss: [Train: 2.03556], [Test: 2.38441],
#           Effect: [ate-q], [train: 0.17667], [test: 0.17978]
# ********************************************************************************
# epoch: 47 / 100, time cost: 40.03 sec,
#           Loss: [Train: 2.03073], [Test: 2.39071],
#           Effect: [ate-q], [train: 0.11959], [test: 0.12271]
# ********************************************************************************
# epoch: 48 / 100, time cost: 40.06 sec,
#           Loss: [Train: 2.02612], [Test: 2.39892],
#           Effect: [ate-q], [train: 0.17928], [test: 0.18242]
# ********************************************************************************
# epoch: 49 / 100, time cost: 39.89 sec,
#           Loss: [Train: 2.02328], [Test: 2.40301],
#           Effect: [ate-q], [train: 0.17723], [test: 0.18040]
# ********************************************************************************
# epoch: 50 / 100, time cost: 39.97 sec,
#           Loss: [Train: 2.01925], [Test: 2.41005],
#           Effect: [ate-q], [train: 0.19210], [test: 0.19514]
# ********************************************************************************
# epoch: 51 / 100, time cost: 40.79 sec,
#           Loss: [Train: 2.01577], [Test: 2.41396],
#           Effect: [ate-q], [train: 0.16711], [test: 0.17033]
# ********************************************************************************
# epoch: 52 / 100, time cost: 39.91 sec,
#           Loss: [Train: 2.01240], [Test: 2.41991],
#           Effect: [ate-q], [train: 0.12963], [test: 0.13273]
# ********************************************************************************
# epoch: 53 / 100, time cost: 39.92 sec,
#           Loss: [Train: 2.00992], [Test: 2.42570],
#           Effect: [ate-q], [train: 0.12392], [test: 0.12695]
# ********************************************************************************
# epoch: 54 / 100, time cost: 41.41 sec,
#           Loss: [Train: 2.00561], [Test: 2.42710],
#           Effect: [ate-q], [train: 0.14722], [test: 0.15054]
# ********************************************************************************
# epoch: 55 / 100, time cost: 41.15 sec,
#           Loss: [Train: 2.00250], [Test: 2.44244],
#           Effect: [ate-q], [train: 0.20475], [test: 0.20796]
# ********************************************************************************
# epoch: 56 / 100, time cost: 41.12 sec,
#           Loss: [Train: 2.00020], [Test: 2.44159],
#           Effect: [ate-q], [train: 0.19069], [test: 0.19407]
# ********************************************************************************
# epoch: 57 / 100, time cost: 41.15 sec,
#           Loss: [Train: 1.99732], [Test: 2.45292],
#           Effect: [ate-q], [train: 0.16613], [test: 0.16905]
# ********************************************************************************
# epoch: 58 / 100, time cost: 41.32 sec,
#           Loss: [Train: 1.99430], [Test: 2.45648],
#           Effect: [ate-q], [train: 0.16261], [test: 0.16580]
# ********************************************************************************
# epoch: 59 / 100, time cost: 39.91 sec,
#           Loss: [Train: 1.99177], [Test: 2.45875],
#           Effect: [ate-q], [train: 0.17679], [test: 0.18000]
# ********************************************************************************
# epoch: 60 / 100, time cost: 40.37 sec,
#           Loss: [Train: 1.98899], [Test: 2.46136],
#           Effect: [ate-q], [train: 0.15557], [test: 0.15867]
# ********************************************************************************
# epoch: 61 / 100, time cost: 40.66 sec,
#           Loss: [Train: 1.98690], [Test: 2.46986],
#           Effect: [ate-q], [train: 0.13639], [test: 0.13948]
# ********************************************************************************
# epoch: 62 / 100, time cost: 39.81 sec,
#           Loss: [Train: 1.98372], [Test: 2.47843],
#           Effect: [ate-q], [train: 0.14631], [test: 0.14932]
# ********************************************************************************
# epoch: 63 / 100, time cost: 39.77 sec,
#           Loss: [Train: 1.98145], [Test: 2.47810],
#           Effect: [ate-q], [train: 0.13319], [test: 0.13637]
# ********************************************************************************
# epoch: 64 / 100, time cost: 39.85 sec,
#           Loss: [Train: 1.97921], [Test: 2.48501],
#           Effect: [ate-q], [train: 0.13588], [test: 0.13924]
# ********************************************************************************
# epoch: 65 / 100, time cost: 39.51 sec,
#           Loss: [Train: 1.97680], [Test: 2.48943],
#           Effect: [ate-q], [train: 0.16206], [test: 0.16530]
# ********************************************************************************
# epoch: 66 / 100, time cost: 39.70 sec,
#           Loss: [Train: 1.97545], [Test: 2.49529],
#           Effect: [ate-q], [train: 0.17513], [test: 0.17818]
# ********************************************************************************
# epoch: 67 / 100, time cost: 39.74 sec,
#           Loss: [Train: 1.97231], [Test: 2.50132],
#           Effect: [ate-q], [train: 0.18534], [test: 0.18857]
# ********************************************************************************
# epoch: 68 / 100, time cost: 39.69 sec,
#           Loss: [Train: 1.97036], [Test: 2.50264],
#           Effect: [ate-q], [train: 0.18031], [test: 0.18346]
# ********************************************************************************
# epoch: 69 / 100, time cost: 39.65 sec,
#           Loss: [Train: 1.96903], [Test: 2.50581],
#           Effect: [ate-q], [train: 0.15973], [test: 0.16308]
# ********************************************************************************
# epoch: 70 / 100, time cost: 40.49 sec,
#           Loss: [Train: 1.96671], [Test: 2.51090],
#           Effect: [ate-q], [train: 0.14502], [test: 0.14803]
# ********************************************************************************
# epoch: 71 / 100, time cost: 41.61 sec,
#           Loss: [Train: 1.96483], [Test: 2.51684],
#           Effect: [ate-q], [train: 0.18951], [test: 0.19278]
# ********************************************************************************
# epoch: 72 / 100, time cost: 41.64 sec,
#           Loss: [Train: 1.96242], [Test: 2.51748],
#           Effect: [ate-q], [train: 0.12855], [test: 0.13162]
# ********************************************************************************
# epoch: 73 / 100, time cost: 41.65 sec,
#           Loss: [Train: 1.96149], [Test: 2.52355],
#           Effect: [ate-q], [train: 0.13223], [test: 0.13528]
# ********************************************************************************
# epoch: 74 / 100, time cost: 41.03 sec,
#           Loss: [Train: 1.96011], [Test: 2.52768],
#           Effect: [ate-q], [train: 0.11730], [test: 0.12032]
# ********************************************************************************
# epoch: 75 / 100, time cost: 41.20 sec,
#           Loss: [Train: 1.95760], [Test: 2.53257],
#           Effect: [ate-q], [train: 0.16331], [test: 0.16652]
# ********************************************************************************
# epoch: 76 / 100, time cost: 39.79 sec,
#           Loss: [Train: 1.95662], [Test: 2.53701],
#           Effect: [ate-q], [train: 0.15150], [test: 0.15454]
# ********************************************************************************
# epoch: 77 / 100, time cost: 39.78 sec,
#           Loss: [Train: 1.95519], [Test: 2.53790],
#           Effect: [ate-q], [train: 0.17443], [test: 0.17768]
# ********************************************************************************
# epoch: 78 / 100, time cost: 39.59 sec,
#           Loss: [Train: 1.95321], [Test: 2.54934],
#           Effect: [ate-q], [train: 0.17749], [test: 0.18066]
# ********************************************************************************
# epoch: 79 / 100, time cost: 39.85 sec,
#           Loss: [Train: 1.95246], [Test: 2.54900],
#           Effect: [ate-q], [train: 0.15150], [test: 0.15479]
# ********************************************************************************
# epoch: 80 / 100, time cost: 41.27 sec,
#           Loss: [Train: 1.95056], [Test: 2.55440],
#           Effect: [ate-q], [train: 0.15164], [test: 0.15491]
# ********************************************************************************
# epoch: 81 / 100, time cost: 41.30 sec,
#           Loss: [Train: 1.94986], [Test: 2.56098],
#           Effect: [ate-q], [train: 0.17424], [test: 0.17758]
# ********************************************************************************
# epoch: 82 / 100, time cost: 41.42 sec,
#           Loss: [Train: 1.94768], [Test: 2.56315],
#           Effect: [ate-q], [train: 0.17995], [test: 0.18322]
# ********************************************************************************
# epoch: 83 / 100, time cost: 41.55 sec,
#           Loss: [Train: 1.94707], [Test: 2.56376],
#           Effect: [ate-q], [train: 0.14080], [test: 0.14406]
# ********************************************************************************
# epoch: 84 / 100, time cost: 41.61 sec,
#           Loss: [Train: 1.94565], [Test: 2.56925],
#           Effect: [ate-q], [train: 0.14121], [test: 0.14427]
# ********************************************************************************
# epoch: 85 / 100, time cost: 41.73 sec,
#           Loss: [Train: 1.94476], [Test: 2.57704],
#           Effect: [ate-q], [train: 0.14557], [test: 0.14873]
# ********************************************************************************
# epoch: 86 / 100, time cost: 41.80 sec,
#           Loss: [Train: 1.94375], [Test: 2.57795],
#           Effect: [ate-q], [train: 0.12361], [test: 0.12668]
# ********************************************************************************
# epoch: 87 / 100, time cost: 41.61 sec,
#           Loss: [Train: 1.94294], [Test: 2.58335],
#           Effect: [ate-q], [train: 0.13155], [test: 0.13455]
# ********************************************************************************
# epoch: 88 / 100, time cost: 41.45 sec,
#           Loss: [Train: 1.94228], [Test: 2.58165],
#           Effect: [ate-q], [train: 0.16931], [test: 0.17255]
# ********************************************************************************
# epoch: 89 / 100, time cost: 41.46 sec,
#           Loss: [Train: 1.94120], [Test: 2.58727],
#           Effect: [ate-q], [train: 0.14039], [test: 0.14356]
# ********************************************************************************
# epoch: 90 / 100, time cost: 41.55 sec,
#           Loss: [Train: 1.94046], [Test: 2.58463],
#           Effect: [ate-q], [train: 0.15099], [test: 0.15430]
# ********************************************************************************
# epoch: 91 / 100, time cost: 41.35 sec,
#           Loss: [Train: 1.93999], [Test: 2.58697],
#           Effect: [ate-q], [train: 0.15138], [test: 0.15460]
# ********************************************************************************
# epoch: 92 / 100, time cost: 41.18 sec,
#           Loss: [Train: 1.93910], [Test: 2.58615],
#           Effect: [ate-q], [train: 0.14603], [test: 0.14931]
# ********************************************************************************
# epoch: 93 / 100, time cost: 41.25 sec,
#           Loss: [Train: 1.93800], [Test: 2.59070],
#           Effect: [ate-q], [train: 0.12884], [test: 0.13194]
# ********************************************************************************
# epoch: 94 / 100, time cost: 41.26 sec,
#           Loss: [Train: 1.93731], [Test: 2.59379],
#           Effect: [ate-q], [train: 0.16734], [test: 0.17042]
# ********************************************************************************
# epoch: 95 / 100, time cost: 41.19 sec,
#           Loss: [Train: 1.93693], [Test: 2.59165],
#           Effect: [ate-q], [train: 0.14233], [test: 0.14553]
# ********************************************************************************
# epoch: 96 / 100, time cost: 41.45 sec,
#           Loss: [Train: 1.93620], [Test: 2.59513],
#           Effect: [ate-q], [train: 0.13789], [test: 0.14108]
# ********************************************************************************
# epoch: 97 / 100, time cost: 41.30 sec,
#           Loss: [Train: 1.93567], [Test: 2.59428],
#           Effect: [ate-q], [train: 0.15350], [test: 0.15672]
# ********************************************************************************
# epoch: 98 / 100, time cost: 41.32 sec,
#           Loss: [Train: 1.93529], [Test: 2.59410],
#           Effect: [ate-q], [train: 0.14929], [test: 0.15253]
# ********************************************************************************
# epoch: 99 / 100, time cost: 41.08 sec,
#           Loss: [Train: 1.93461], [Test: 2.59491],
#           Effect: [ate-q], [train: 0.15695], [test: 0.16009]
# ********************************************************************************
# epoch: 100 / 100, time cost: 41.09 sec,
#           Loss: [Train: 1.93490], [Test: 2.59758],
#           Effect: [ate-q], [train: 0.15206], [test: 0.15534]
# ********************************************************************************
# Finish training...

# %%
real = true_casual_effect(test_loader)
unadjust = (testset.response[testset.treatment == 1].mean() - testset.response[testset.treatment == 0].mean()).item()
show_result(train_loss_hist, test_loss_hist, est_effect, real, unadjust, epoch)
