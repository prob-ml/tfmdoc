# %%
import os
import time
import random
import math

import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt

from torch.distributions.binomial import Binomial
from torch.distributions.bernoulli import Bernoulli
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader 

from transformers import DataCollatorForLanguageModeling, BertForMaskedLM
from transformers import Trainer, TrainingArguments
from transformers import get_linear_schedule_with_warmup, AdamW

from causal_bert import load_data, load_model
from causal_bert import true_casual_effect, est_casual_effect, show_result

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '7'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
effect = 'ate'
estimation = 'q'

effect = effect.lower()
estimation = estimation.lower()
assert effect in ['att', 'ate'], f'Wrong effect: {effect}...'
assert estimation in ['q', 'plugin'], f'Wrong estimation: {estimation}...'

# %%
bsz = 256
epoch = 50
hidden_size = 64
lr = 5e-6

# %%
alpha = 0.75
beta = 25.
c = 0.2
i = 0.

train_loader, test_loader = load_data(alpha, beta, c, i, bsz, device=device)
# Out:
# Load training set in 69.09 sec
# Load validation set in 65.60 sec

# %%
real_att_q = true_casual_effect(test_loader)

print(f'Real: [effect: ate], [estimation: q], [value: {real_att_q:.5f}]')
print(f'Unadjusted: [value: {(test_loader.dataset.response[test_loader.dataset.treatment == 1].mean() - test_loader.dataset.response[test_loader.dataset.treatment == 0].mean()).item():.4f}]')
# Out:
# Real: [effect: ate], [estimation: q], [value: 0.16917]
# Unadjusted: [value: 0.2379]

# %%
model = load_model(model='bow', hidden_size=hidden_size, device=device)

pos_portion = train_loader.dataset.treatment.mean()
pos_weight = (1 - pos_portion) / pos_portion

epoch_iter = len(train_loader)
total_steps = epoch * epoch_iter

# optimizer = torch.optim.Adam(model.parameters(), lr=lr)
optimizer = AdamW(model.parameters(), lr=lr, eps=1e-8)

q_loss = nn.BCELoss()
prop_score_loss = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# %%
train_loss_hist_p, train_loss_hist_q1, train_loss_hist_q0 = [], [], []
test_loss_hist_p, test_loss_hist_q1, test_loss_hist_q0 = [], [], []
est_effect, prop_score_hist = [], []

for e in range(1, epoch + 1):
    model.train()
    start = time.time()
        
    p_loss_train, q1_loss_train, q0_loss_train  = [], [], []
    for idx, (tokens, treatment, response, _) in enumerate(train_loader):
        optimizer.zero_grad()
        prop_score, q1, q0 = model(tokens)
        
        loss_p = prop_score_loss(prop_score, treatment)
        loss = loss_p
        
        p_loss_train.append(loss_p.item())
        if len(response[treatment == 1]) > 0:
            loss_q1 = q_loss(q1[treatment==1], response[treatment==1])
            loss += loss_q1
            q1_loss_train.append(loss_q1.item())
            
        if len(response[treatment == 0]) > 0:
            loss_q0 = q_loss(q1[treatment==0], response[treatment==0])
            loss += loss_q0
            q0_loss_train.append(loss_q0.item())
                        
        loss.backward()
        optimizer.step()

    run_idx = idx

    # Evaluation.
    p_loss_train = np.array(p_loss_train).mean()
    q1_loss_train = np.array(q1_loss_train).mean()
    q0_loss_train = np.array(q0_loss_train).mean()
    
    train_effect, _, _, _, _, _, _ = est_casual_effect(train_loader, model, effect, estimation, evaluate=False)
    test_effect, p_loss_test, q1_loss_test, q0_loss_test, prop_accu_test, q1_accu_test, q0_accu_test = est_casual_effect(test_loader, model, effect, estimation, evaluate=True, g_loss=prop_score_loss, q_loss=q_loss)
    
    train_loss_hist_p.append(p_loss_train)
    train_loss_hist_q1.append(q1_loss_train)
    train_loss_hist_q0.append(q0_loss_train)
    
    test_loss_hist_p.append(p_loss_test)
    test_loss_hist_q1.append(q1_loss_test)
    test_loss_hist_q0.append(q0_loss_test)

    est_effect.append(test_effect)
    
    
    print(f'''epoch: {e} / {epoch}, time cost: {(time.time() - start):.2f} sec, 
          Loss: [Train: p = {p_loss_train:.5f}, q = {(q1_loss_train + q0_loss_train):.5f}], 
          Loss: [Test: p = {p_loss_test:.5f}, q = {(q1_loss_test + q0_loss_test):.5f}],
          Effect: [{effect}-{estimation}], [train: {train_effect:.5f}], [test: {test_effect:.5f}]''')
    print('*'* 80)
    start = time.time()

train_loss_hist = dict(p=train_loss_hist_p, q1=train_loss_hist_q1, q0=train_loss_hist_q1)
test_loss_hist = dict(p=test_loss_hist_p, q1=test_loss_hist_q1, q0=test_loss_hist_q0)

print('Finish training...')
# Out:
# epoch: 1 / 50, time cost: 43.21 sec,
#           Loss: [Train: p = 1.05714, q = 1.34647],
#           Loss: [Test: p = 1.06037, q = 1.33368],
#           Effect: [ate-q], [train: 0.07465], [test: 0.07464]
# ********************************************************************************
# epoch: 2 / 50, time cost: 40.73 sec,
#           Loss: [Train: p = 1.05686, q = 1.33148],
#           Loss: [Test: p = 1.06008, q = 1.31328],
#           Effect: [ate-q], [train: 0.10389], [test: 0.10387]
# ********************************************************************************
# epoch: 3 / 50, time cost: 40.34 sec,
#           Loss: [Train: p = 1.05642, q = 1.32285],
#           Loss: [Test: p = 1.05983, q = 1.29983],
#           Effect: [ate-q], [train: 0.12674], [test: 0.12671]
# ********************************************************************************
# epoch: 4 / 50, time cost: 41.00 sec,
#           Loss: [Train: p = 1.05632, q = 1.32049],
#           Loss: [Test: p = 1.05964, q = 1.29440],
#           Effect: [ate-q], [train: 0.13629], [test: 0.13625]
# ********************************************************************************
# epoch: 5 / 50, time cost: 43.59 sec,
#           Loss: [Train: p = 1.05609, q = 1.32008],
#           Loss: [Test: p = 1.05943, q = 1.29307],
#           Effect: [ate-q], [train: 0.13910], [test: 0.13906]
# ********************************************************************************
# epoch: 6 / 50, time cost: 40.18 sec,
#           Loss: [Train: p = 1.05585, q = 1.31994],
#           Loss: [Test: p = 1.05925, q = 1.29243],
#           Effect: [ate-q], [train: 0.14023], [test: 0.14019]
# ********************************************************************************
# epoch: 7 / 50, time cost: 40.82 sec,
#           Loss: [Train: p = 1.05562, q = 1.31984],
#           Loss: [Test: p = 1.05908, q = 1.29241],
#           Effect: [ate-q], [train: 0.14013], [test: 0.14009]
# ********************************************************************************
# epoch: 8 / 50, time cost: 40.58 sec,
#           Loss: [Train: p = 1.05551, q = 1.31980],
#           Loss: [Test: p = 1.05895, q = 1.29254],
#           Effect: [ate-q], [train: 0.13992], [test: 0.13988]
# ********************************************************************************
# epoch: 9 / 50, time cost: 39.88 sec,
#           Loss: [Train: p = 1.05538, q = 1.32000],
#           Loss: [Test: p = 1.05878, q = 1.29205],
#           Effect: [ate-q], [train: 0.14043], [test: 0.14039]
# ********************************************************************************
# epoch: 10 / 50, time cost: 42.62 sec,
#           Loss: [Train: p = 1.05520, q = 1.31995],
#           Loss: [Test: p = 1.05862, q = 1.29197],
#           Effect: [ate-q], [train: 0.14086], [test: 0.14081]
# ********************************************************************************
# epoch: 11 / 50, time cost: 40.59 sec,
#           Loss: [Train: p = 1.05500, q = 1.31989],
#           Loss: [Test: p = 1.05852, q = 1.29242],
#           Effect: [ate-q], [train: 0.13976], [test: 0.13971]
# ********************************************************************************
# epoch: 12 / 50, time cost: 40.22 sec,
#           Loss: [Train: p = 1.05491, q = 1.31956],
#           Loss: [Test: p = 1.05836, q = 1.29273],
#           Effect: [ate-q], [train: 0.13941], [test: 0.13936]
# ********************************************************************************
# epoch: 13 / 50, time cost: 41.05 sec,
#           Loss: [Train: p = 1.05467, q = 1.31981],
#           Loss: [Test: p = 1.05822, q = 1.29270],
#           Effect: [ate-q], [train: 0.13924], [test: 0.13919]
# ********************************************************************************
# epoch: 14 / 50, time cost: 39.82 sec,
#           Loss: [Train: p = 1.05454, q = 1.31974],
#           Loss: [Test: p = 1.05808, q = 1.29237],
#           Effect: [ate-q], [train: 0.13989], [test: 0.13984]
# ********************************************************************************
# epoch: 15 / 50, time cost: 42.25 sec,
#           Loss: [Train: p = 1.05421, q = 1.31938],
#           Loss: [Test: p = 1.05794, q = 1.29231],
#           Effect: [ate-q], [train: 0.13971], [test: 0.13966]
# ********************************************************************************
# epoch: 16 / 50, time cost: 39.79 sec,
#           Loss: [Train: p = 1.05417, q = 1.31952],
#           Loss: [Test: p = 1.05775, q = 1.29201],
#           Effect: [ate-q], [train: 0.14003], [test: 0.13998]
# ********************************************************************************
# epoch: 17 / 50, time cost: 39.53 sec,
#           Loss: [Train: p = 1.05407, q = 1.31938],
#           Loss: [Test: p = 1.05767, q = 1.29153],
#           Effect: [ate-q], [train: 0.14093], [test: 0.14087]
# ********************************************************************************
# epoch: 18 / 50, time cost: 45.76 sec,
#           Loss: [Train: p = 1.05394, q = 1.31926],
#           Loss: [Test: p = 1.05747, q = 1.29114],
#           Effect: [ate-q], [train: 0.14153], [test: 0.14147]
# ********************************************************************************
# epoch: 19 / 50, time cost: 41.59 sec,
#           Loss: [Train: p = 1.05373, q = 1.31905],
#           Loss: [Test: p = 1.05736, q = 1.29134],
#           Effect: [ate-q], [train: 0.14128], [test: 0.14122]
# ********************************************************************************
# epoch: 20 / 50, time cost: 44.91 sec,
#           Loss: [Train: p = 1.05356, q = 1.31912],
#           Loss: [Test: p = 1.05719, q = 1.29164],
#           Effect: [ate-q], [train: 0.14017], [test: 0.14011]
# ********************************************************************************
# epoch: 21 / 50, time cost: 39.86 sec,
#           Loss: [Train: p = 1.05343, q = 1.31861],
#           Loss: [Test: p = 1.05706, q = 1.29123],
#           Effect: [ate-q], [train: 0.14103], [test: 0.14097]
# ********************************************************************************
# epoch: 22 / 50, time cost: 41.10 sec,
#           Loss: [Train: p = 1.05327, q = 1.31868],
#           Loss: [Test: p = 1.05691, q = 1.29164],
#           Effect: [ate-q], [train: 0.13955], [test: 0.13948]
# ********************************************************************************
# epoch: 23 / 50, time cost: 40.98 sec,
#           Loss: [Train: p = 1.05306, q = 1.31863],
#           Loss: [Test: p = 1.05674, q = 1.29154],
#           Effect: [ate-q], [train: 0.13986], [test: 0.13980]
# ********************************************************************************
# epoch: 24 / 50, time cost: 42.08 sec,
#           Loss: [Train: p = 1.05280, q = 1.31846],
#           Loss: [Test: p = 1.05661, q = 1.29067],
#           Effect: [ate-q], [train: 0.14117], [test: 0.14110]
# ********************************************************************************
# epoch: 25 / 50, time cost: 44.29 sec,
#           Loss: [Train: p = 1.05275, q = 1.31835],
#           Loss: [Test: p = 1.05644, q = 1.29095],
#           Effect: [ate-q], [train: 0.14042], [test: 0.14035]
# ********************************************************************************
# epoch: 26 / 50, time cost: 41.22 sec,
#           Loss: [Train: p = 1.05256, q = 1.31810],
#           Loss: [Test: p = 1.05628, q = 1.29145],
#           Effect: [ate-q], [train: 0.13917], [test: 0.13910]
# ********************************************************************************
# epoch: 27 / 50, time cost: 39.93 sec,
#           Loss: [Train: p = 1.05238, q = 1.31789],
#           Loss: [Test: p = 1.05610, q = 1.29063],
#           Effect: [ate-q], [train: 0.14092], [test: 0.14085]
# ********************************************************************************
# epoch: 28 / 50, time cost: 40.67 sec,
#           Loss: [Train: p = 1.05214, q = 1.31791],
#           Loss: [Test: p = 1.05598, q = 1.29105],
#           Effect: [ate-q], [train: 0.13964], [test: 0.13957]
# ********************************************************************************
# epoch: 29 / 50, time cost: 40.10 sec,
#           Loss: [Train: p = 1.05184, q = 1.31726],
#           Loss: [Test: p = 1.05580, q = 1.29108],
#           Effect: [ate-q], [train: 0.13916], [test: 0.13909]
# ********************************************************************************
# epoch: 30 / 50, time cost: 43.52 sec,
#           Loss: [Train: p = 1.05172, q = 1.31739],
#           Loss: [Test: p = 1.05564, q = 1.29102],
#           Effect: [ate-q], [train: 0.13881], [test: 0.13873]
# ********************************************************************************
# epoch: 31 / 50, time cost: 41.71 sec,
#           Loss: [Train: p = 1.05156, q = 1.31733],
#           Loss: [Test: p = 1.05547, q = 1.29110],
#           Effect: [ate-q], [train: 0.13817], [test: 0.13809]
# ********************************************************************************
# epoch: 32 / 50, time cost: 40.79 sec,
#           Loss: [Train: p = 1.05138, q = 1.31678],
#           Loss: [Test: p = 1.05524, q = 1.29050],
#           Effect: [ate-q], [train: 0.13872], [test: 0.13864]
# ********************************************************************************
# epoch: 33 / 50, time cost: 42.72 sec,
#           Loss: [Train: p = 1.05113, q = 1.31661],
#           Loss: [Test: p = 1.05509, q = 1.28961],
#           Effect: [ate-q], [train: 0.14043], [test: 0.14036]
# ********************************************************************************
# epoch: 34 / 50, time cost: 42.45 sec,
#           Loss: [Train: p = 1.05104, q = 1.31618],
#           Loss: [Test: p = 1.05494, q = 1.28934],
#           Effect: [ate-q], [train: 0.14027], [test: 0.14019]
# ********************************************************************************

# %%
real = true_casual_effect(test_loader)
unadjust = (test_loader.dataset.response[test_loader.dataset.treatment == 1].mean() - test_loader.dataset.response[test_loader.dataset.treatment == 0].mean()).item()
show_result(train_loss_hist, test_loss_hist, est_effect, real, unadjust, epoch)
