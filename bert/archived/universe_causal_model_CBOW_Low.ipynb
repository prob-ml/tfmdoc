# %%
import os
import time
import random
import math

import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt

from torch.distributions.binomial import Binomial
from torch.distributions.bernoulli import Bernoulli
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader 

from transformers import DataCollatorForLanguageModeling, BertForMaskedLM
from transformers import Trainer, TrainingArguments
from transformers import get_linear_schedule_with_warmup, AdamW

from causal_bert import load_data, load_model
from causal_bert import true_casual_effect, est_casual_effect, show_result

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '7'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
effect = 'ate'
estimation = 'q'

effect = effect.lower()
estimation = estimation.lower()
assert effect in ['att', 'ate'], f'Wrong effect: {effect}...'
assert estimation in ['q', 'plugin'], f'Wrong estimation: {estimation}...'

# %%
bsz = 256
epoch = 50
hidden_size = 64
lr = 5e-6

# %%
alpha = 0.25
beta = 1
c = 0.2
i = 0.

train_loader, test_loader = load_data(alpha, beta, c, i, bsz, device=device)
# Out:
# Load training set in 93.27 sec
# Load validation set in 84.67 sec

# %%
real_att_q = true_casual_effect(test_loader)

print(f'Real: [effect: ate], [estimation: q], [value: {real_att_q:.5f}]')
print(f'Unadjusted: [value: {(test_loader.dataset.response[test_loader.dataset.treatment == 1].mean() - test_loader.dataset.response[test_loader.dataset.treatment == 0].mean()).item():.4f}]')
# Out:
# Real: [effect: ate], [estimation: q], [value: 0.06317]
# Unadjusted: [value: 0.0919]

# %%
model = load_model(model='bow', hidden_size=hidden_size, device=device)

pos_portion = train_loader.dataset.treatment.mean()
pos_weight = (1 - pos_portion) / pos_portion

epoch_iter = len(train_loader)
total_steps = epoch * epoch_iter

# optimizer = torch.optim.Adam(model.parameters(), lr=lr)
optimizer = AdamW(model.parameters(), lr=lr, eps=1e-8)

q_loss = nn.BCELoss()
prop_score_loss = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# %%
train_loss_hist_p, train_loss_hist_q1, train_loss_hist_q0 = [], [], []
test_loss_hist_p, test_loss_hist_q1, test_loss_hist_q0 = [], [], []
est_effect, prop_score_hist = [], []

for e in range(1, epoch + 1):
    model.train()
    start = time.time()
        
    p_loss_train, q1_loss_train, q0_loss_train  = [], [], []
    for idx, (tokens, treatment, response, _) in enumerate(train_loader):
        optimizer.zero_grad()
        prop_score, q1, q0 = model(tokens)
        
        loss_p = prop_score_loss(prop_score, treatment)
        loss = loss_p
        
        p_loss_train.append(loss_p.item())
        if len(response[treatment == 1]) > 0:
            loss_q1 = q_loss(q1[treatment==1], response[treatment==1])
            loss += loss_q1
            q1_loss_train.append(loss_q1.item())
            
        if len(response[treatment == 0]) > 0:
            loss_q0 = q_loss(q1[treatment==0], response[treatment==0])
            loss += loss_q0
            q0_loss_train.append(loss_q0.item())
                        
        loss.backward()
        optimizer.step()

    run_idx = idx

    # Evaluation.
    p_loss_train = np.array(p_loss_train).mean()
    q1_loss_train = np.array(q1_loss_train).mean()
    q0_loss_train = np.array(q0_loss_train).mean()
    
    train_effect, _, _, _, _, _, _ = est_casual_effect(train_loader, model, effect, estimation, evaluate=False)
    test_effect, p_loss_test, q1_loss_test, q0_loss_test, prop_accu_test, q1_accu_test, q0_accu_test = est_casual_effect(test_loader, model, effect, estimation, evaluate=True, g_loss=prop_score_loss, q_loss=q_loss)
    
    train_loss_hist_p.append(p_loss_train)
    train_loss_hist_q1.append(q1_loss_train)
    train_loss_hist_q0.append(q0_loss_train)
    
    test_loss_hist_p.append(p_loss_test)
    test_loss_hist_q1.append(q1_loss_test)
    test_loss_hist_q0.append(q0_loss_test)

    est_effect.append(test_effect)
    
    
    print(f'''epoch: {e} / {epoch}, time cost: {(time.time() - start):.2f} sec, 
          Loss: [Train: p = {p_loss_train:.5f}, q = {(q1_loss_train + q0_loss_train):.5f}], 
          Loss: [Test: p = {p_loss_test:.5f}, q = {(q1_loss_test + q0_loss_test):.5f}],
          Effect: [{effect}-{estimation}], [train: {train_effect:.5f}], [test: {test_effect:.5f}]''')
    print('*'* 80)
    start = time.time()

train_loss_hist = dict(p=train_loss_hist_p, q1=train_loss_hist_q1, q0=train_loss_hist_q1)
test_loss_hist = dict(p=test_loss_hist_p, q1=test_loss_hist_q1, q0=test_loss_hist_q0)

print('Finish training...')
# Out:
# epoch: 1 / 50, time cost: 37.62 sec,
#           Loss: [Train: p = 1.05686, q = 1.37774],
#           Loss: [Test: p = 1.06012, q = 1.37485],
#           Effect: [ate-q], [train: 0.05456], [test: 0.05456]
# ********************************************************************************
# epoch: 2 / 50, time cost: 38.64 sec,
#           Loss: [Train: p = 1.05656, q = 1.37748],
#           Loss: [Test: p = 1.05986, q = 1.37418],
#           Effect: [ate-q], [train: 0.05752], [test: 0.05752]
# ********************************************************************************
# epoch: 3 / 50, time cost: 39.75 sec,
#           Loss: [Train: p = 1.05617, q = 1.37740],
#           Loss: [Test: p = 1.05964, q = 1.37394],
#           Effect: [ate-q], [train: 0.05907], [test: 0.05907]
# ********************************************************************************
# epoch: 4 / 50, time cost: 41.63 sec,
#           Loss: [Train: p = 1.05611, q = 1.37737],
#           Loss: [Test: p = 1.05949, q = 1.37389],
#           Effect: [ate-q], [train: 0.05914], [test: 0.05914]
# ********************************************************************************
# epoch: 5 / 50, time cost: 39.09 sec,
#           Loss: [Train: p = 1.05591, q = 1.37731],
#           Loss: [Test: p = 1.05929, q = 1.37379],
#           Effect: [ate-q], [train: 0.05976], [test: 0.05975]
# ********************************************************************************
# epoch: 6 / 50, time cost: 44.19 sec,
#           Loss: [Train: p = 1.05569, q = 1.37735],
#           Loss: [Test: p = 1.05914, q = 1.37377],
#           Effect: [ate-q], [train: 0.05995], [test: 0.05994]
# ********************************************************************************
# epoch: 7 / 50, time cost: 46.89 sec,
#           Loss: [Train: p = 1.05549, q = 1.37734],
#           Loss: [Test: p = 1.05898, q = 1.37372],
#           Effect: [ate-q], [train: 0.05994], [test: 0.05994]
# ********************************************************************************
# epoch: 8 / 50, time cost: 45.72 sec,
#           Loss: [Train: p = 1.05539, q = 1.37740],
#           Loss: [Test: p = 1.05886, q = 1.37372],
#           Effect: [ate-q], [train: 0.05976], [test: 0.05975]
# ********************************************************************************
# epoch: 9 / 50, time cost: 39.55 sec,
#           Loss: [Train: p = 1.05527, q = 1.37737],
#           Loss: [Test: p = 1.05869, q = 1.37364],
#           Effect: [ate-q], [train: 0.06023], [test: 0.06023]
# ********************************************************************************
# epoch: 10 / 50, time cost: 39.36 sec,
#           Loss: [Train: p = 1.05510, q = 1.37729],
#           Loss: [Test: p = 1.05853, q = 1.37359],
#           Effect: [ate-q], [train: 0.06058], [test: 0.06058]
# ********************************************************************************
# epoch: 11 / 50, time cost: 39.56 sec,
#           Loss: [Train: p = 1.05490, q = 1.37739],
#           Loss: [Test: p = 1.05844, q = 1.37365],
#           Effect: [ate-q], [train: 0.06009], [test: 0.06009]
# ********************************************************************************
# epoch: 12 / 50, time cost: 41.17 sec,
#           Loss: [Train: p = 1.05482, q = 1.37722],
#           Loss: [Test: p = 1.05828, q = 1.37375],
#           Effect: [ate-q], [train: 0.06008], [test: 0.06007]
# ********************************************************************************
# epoch: 13 / 50, time cost: 39.71 sec,
#           Loss: [Train: p = 1.05457, q = 1.37737],
#           Loss: [Test: p = 1.05815, q = 1.37374],
#           Effect: [ate-q], [train: 0.05976], [test: 0.05975]
# ********************************************************************************
# epoch: 14 / 50, time cost: 39.02 sec,
#           Loss: [Train: p = 1.05444, q = 1.37735],
#           Loss: [Test: p = 1.05800, q = 1.37383],
#           Effect: [ate-q], [train: 0.05951], [test: 0.05951]
# ********************************************************************************
# epoch: 15 / 50, time cost: 38.99 sec,
#           Loss: [Train: p = 1.05412, q = 1.37726],
#           Loss: [Test: p = 1.05787, q = 1.37364],
#           Effect: [ate-q], [train: 0.05985], [test: 0.05984]
# ********************************************************************************
# epoch: 16 / 50, time cost: 41.86 sec,
#           Loss: [Train: p = 1.05408, q = 1.37727],
#           Loss: [Test: p = 1.05768, q = 1.37367],
#           Effect: [ate-q], [train: 0.06013], [test: 0.06012]
# ********************************************************************************
# epoch: 17 / 50, time cost: 40.93 sec,
#           Loss: [Train: p = 1.05398, q = 1.37725],
#           Loss: [Test: p = 1.05759, q = 1.37354],
#           Effect: [ate-q], [train: 0.06076], [test: 0.06074]
# ********************************************************************************
# epoch: 18 / 50, time cost: 39.64 sec,
#           Loss: [Train: p = 1.05385, q = 1.37722],
#           Loss: [Test: p = 1.05740, q = 1.37352],
#           Effect: [ate-q], [train: 0.06088], [test: 0.06086]
# ********************************************************************************
# epoch: 19 / 50, time cost: 39.91 sec,
#           Loss: [Train: p = 1.05364, q = 1.37714],
#           Loss: [Test: p = 1.05728, q = 1.37354],
#           Effect: [ate-q], [train: 0.06096], [test: 0.06095]
# ********************************************************************************
# epoch: 20 / 50, time cost: 41.59 sec,
#           Loss: [Train: p = 1.05347, q = 1.37724],
#           Loss: [Test: p = 1.05712, q = 1.37362],
#           Effect: [ate-q], [train: 0.06006], [test: 0.06004]
# ********************************************************************************
# epoch: 21 / 50, time cost: 38.72 sec,
#           Loss: [Train: p = 1.05334, q = 1.37709],
#           Loss: [Test: p = 1.05699, q = 1.37362],
#           Effect: [ate-q], [train: 0.06036], [test: 0.06035]
# ********************************************************************************
# epoch: 22 / 50, time cost: 39.15 sec,
#           Loss: [Train: p = 1.05319, q = 1.37716],
#           Loss: [Test: p = 1.05684, q = 1.37366],
#           Effect: [ate-q], [train: 0.05954], [test: 0.05952]
# ********************************************************************************
# epoch: 23 / 50, time cost: 39.00 sec,
#           Loss: [Train: p = 1.05297, q = 1.37711],
#           Loss: [Test: p = 1.05667, q = 1.37358],
#           Effect: [ate-q], [train: 0.06007], [test: 0.06005]
# ********************************************************************************
# epoch: 24 / 50, time cost: 40.01 sec,
#           Loss: [Train: p = 1.05272, q = 1.37719],
#           Loss: [Test: p = 1.05654, q = 1.37351],
#           Effect: [ate-q], [train: 0.06036], [test: 0.06035]
# ********************************************************************************
# epoch: 25 / 50, time cost: 41.47 sec,
#           Loss: [Train: p = 1.05266, q = 1.37711],
#           Loss: [Test: p = 1.05638, q = 1.37355],
#           Effect: [ate-q], [train: 0.06059], [test: 0.06057]
# ********************************************************************************
# epoch: 26 / 50, time cost: 39.29 sec,
#           Loss: [Train: p = 1.05248, q = 1.37709],
#           Loss: [Test: p = 1.05622, q = 1.37360],
#           Effect: [ate-q], [train: 0.05979], [test: 0.05977]
# ********************************************************************************
# epoch: 27 / 50, time cost: 39.01 sec,
#           Loss: [Train: p = 1.05230, q = 1.37705],
#           Loss: [Test: p = 1.05605, q = 1.37359],
#           Effect: [ate-q], [train: 0.06009], [test: 0.06007]
# ********************************************************************************
# epoch: 28 / 50, time cost: 39.20 sec,
#           Loss: [Train: p = 1.05207, q = 1.37709],
#           Loss: [Test: p = 1.05593, q = 1.37357],
#           Effect: [ate-q], [train: 0.06018], [test: 0.06015]
# ********************************************************************************
# epoch: 29 / 50, time cost: 45.93 sec,
#           Loss: [Train: p = 1.05177, q = 1.37688],
#           Loss: [Test: p = 1.05575, q = 1.37353],
#           Effect: [ate-q], [train: 0.06024], [test: 0.06022]
# ********************************************************************************
# epoch: 30 / 50, time cost: 39.42 sec,
#           Loss: [Train: p = 1.05165, q = 1.37705],
#           Loss: [Test: p = 1.05560, q = 1.37354],
#           Effect: [ate-q], [train: 0.05986], [test: 0.05983]
# ********************************************************************************
# epoch: 31 / 50, time cost: 39.42 sec,
#           Loss: [Train: p = 1.05150, q = 1.37703],
#           Loss: [Test: p = 1.05544, q = 1.37362],
#           Effect: [ate-q], [train: 0.05919], [test: 0.05917]
# ********************************************************************************
# epoch: 32 / 50, time cost: 40.11 sec,
#           Loss: [Train: p = 1.05132, q = 1.37698],
#           Loss: [Test: p = 1.05522, q = 1.37361],
#           Effect: [ate-q], [train: 0.05907], [test: 0.05904]
# ********************************************************************************
# epoch: 33 / 50, time cost: 41.05 sec,
#           Loss: [Train: p = 1.05108, q = 1.37687],
#           Loss: [Test: p = 1.05507, q = 1.37338],
#           Effect: [ate-q], [train: 0.06051], [test: 0.06048]
# ********************************************************************************
# epoch: 34 / 50, time cost: 39.06 sec,
#           Loss: [Train: p = 1.05100, q = 1.37685],
#           Loss: [Test: p = 1.05493, q = 1.37327],
#           Effect: [ate-q], [train: 0.06065], [test: 0.06062]
# ********************************************************************************
# epoch: 35 / 50, time cost: 38.71 sec,
#           Loss: [Train: p = 1.05070, q = 1.37687],
#           Loss: [Test: p = 1.05476, q = 1.37334],
#           Effect: [ate-q], [train: 0.06003], [test: 0.06001]
# ********************************************************************************
# epoch: 36 / 50, time cost: 39.56 sec,
#           Loss: [Train: p = 1.05048, q = 1.37679],
#           Loss: [Test: p = 1.05457, q = 1.37317],
#           Effect: [ate-q], [train: 0.06088], [test: 0.06086]
# ********************************************************************************
# epoch: 37 / 50, time cost: 41.69 sec,
#           Loss: [Train: p = 1.05037, q = 1.37674],
#           Loss: [Test: p = 1.05439, q = 1.37333],
#           Effect: [ate-q], [train: 0.05995], [test: 0.05992]
# ********************************************************************************
# epoch: 38 / 50, time cost: 39.74 sec,
#           Loss: [Train: p = 1.05001, q = 1.37679],
#           Loss: [Test: p = 1.05423, q = 1.37334],
#           Effect: [ate-q], [train: 0.06010], [test: 0.06007]
# ********************************************************************************
# epoch: 39 / 50, time cost: 39.87 sec,
#           Loss: [Train: p = 1.04992, q = 1.37662],
#           Loss: [Test: p = 1.05402, q = 1.37322],
#           Effect: [ate-q], [train: 0.06021], [test: 0.06018]
# ********************************************************************************
# epoch: 40 / 50, time cost: 40.46 sec,
#           Loss: [Train: p = 1.04964, q = 1.37677],
#           Loss: [Test: p = 1.05387, q = 1.37322],
#           Effect: [ate-q], [train: 0.05991], [test: 0.05988]
# ********************************************************************************
# epoch: 41 / 50, time cost: 41.79 sec,
#           Loss: [Train: p = 1.04950, q = 1.37659],
#           Loss: [Test: p = 1.05364, q = 1.37330],
#           Effect: [ate-q], [train: 0.05908], [test: 0.05905]
# ********************************************************************************
# epoch: 42 / 50, time cost: 39.36 sec,
#           Loss: [Train: p = 1.04942, q = 1.37655],
#           Loss: [Test: p = 1.05352, q = 1.37321],
#           Effect: [ate-q], [train: 0.05948], [test: 0.05945]
# ********************************************************************************
# epoch: 43 / 50, time cost: 38.95 sec,
#           Loss: [Train: p = 1.04904, q = 1.37656],
#           Loss: [Test: p = 1.05336, q = 1.37296],
#           Effect: [ate-q], [train: 0.06093], [test: 0.06090]
# ********************************************************************************
# epoch: 44 / 50, time cost: 39.34 sec,
#           Loss: [Train: p = 1.04884, q = 1.37639],
#           Loss: [Test: p = 1.05313, q = 1.37323],
#           Effect: [ate-q], [train: 0.05930], [test: 0.05927]
# ********************************************************************************
# epoch: 45 / 50, time cost: 38.97 sec,
#           Loss: [Train: p = 1.04868, q = 1.37644],
#           Loss: [Test: p = 1.05293, q = 1.37300],
#           Effect: [ate-q], [train: 0.05982], [test: 0.05978]
# ********************************************************************************
# epoch: 46 / 50, time cost: 41.64 sec,
#           Loss: [Train: p = 1.04834, q = 1.37633],
#           Loss: [Test: p = 1.05276, q = 1.37315],
#           Effect: [ate-q], [train: 0.05936], [test: 0.05933]
# ********************************************************************************
# epoch: 47 / 50, time cost: 38.93 sec,
#           Loss: [Train: p = 1.04824, q = 1.37630],
#           Loss: [Test: p = 1.05258, q = 1.37301],
#           Effect: [ate-q], [train: 0.05927], [test: 0.05924]
# ********************************************************************************
# epoch: 48 / 50, time cost: 39.30 sec,
#           Loss: [Train: p = 1.04793, q = 1.37618],
#           Loss: [Test: p = 1.05236, q = 1.37292],
#           Effect: [ate-q], [train: 0.05983], [test: 0.05980]
# ********************************************************************************
# epoch: 49 / 50, time cost: 39.58 sec,
#           Loss: [Train: p = 1.04785, q = 1.37618],
#           Loss: [Test: p = 1.05222, q = 1.37285],
#           Effect: [ate-q], [train: 0.06008], [test: 0.06004]
# ********************************************************************************
# epoch: 50 / 50, time cost: 41.64 sec,
#           Loss: [Train: p = 1.04754, q = 1.37610],
#           Loss: [Test: p = 1.05198, q = 1.37293],
#           Effect: [ate-q], [train: 0.05897], [test: 0.05893]
# ********************************************************************************
# Finish training...

# %%
real = true_casual_effect(test_loader)
unadjust = (test_loader.dataset.response[test_loader.dataset.treatment == 1].mean() - test_loader.dataset.response[test_loader.dataset.treatment == 0].mean()).item()
show_result(train_loss_hist, test_loss_hist, est_effect, real, unadjust, epoch)
