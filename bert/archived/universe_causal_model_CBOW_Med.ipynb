# %%
import os
import time
import random
import math

import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt

from torch.distributions.binomial import Binomial
from torch.distributions.bernoulli import Bernoulli
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader 

from transformers import DataCollatorForLanguageModeling, BertForMaskedLM
from transformers import Trainer, TrainingArguments
from transformers import get_linear_schedule_with_warmup, AdamW

from causal_bert import load_data, load_model
from causal_bert import true_casual_effect, est_casual_effect, show_result

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '7'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
effect = 'ate'
estimation = 'q'

effect = effect.lower()
estimation = estimation.lower()
assert effect in ['att', 'ate'], f'Wrong effect: {effect}...'
assert estimation in ['q', 'plugin'], f'Wrong estimation: {estimation}...'

# %%
bsz = 256
epoch = 50
hidden_size = 64
lr = 5e-6

# %%
alpha = 0.5
beta = 5.
c = 0.2
i = 0.

train_loader, test_loader = load_data(alpha, beta, c, i, bsz, device=device)
# Out:
# Load training set in 131.70 sec
# Load validation set in 99.45 sec

# %%
real_att_q = true_casual_effect(test_loader)

print(f'Real: [effect: ate], [estimation: q], [value: {real_att_q:.5f}]')
print(f'Unadjusted: [value: {(test_loader.dataset.response[test_loader.dataset.treatment == 1].mean() - test_loader.dataset.response[test_loader.dataset.treatment == 0].mean()).item():.4f}]')
# Out:
# Real: [effect: ate], [estimation: q], [value: 0.11704]
# Unadjusted: [value: 0.1880]

# %%
model = load_model(model='bow', hidden_size=hidden_size, device=device)

pos_portion = train_loader.dataset.treatment.mean()
pos_weight = (1 - pos_portion) / pos_portion

epoch_iter = len(train_loader)
total_steps = epoch * epoch_iter

# optimizer = torch.optim.Adam(model.parameters(), lr=lr)
optimizer = AdamW(model.parameters(), lr=lr, eps=1e-8)

q_loss = nn.BCELoss()
prop_score_loss = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# %%
train_loss_hist_p, train_loss_hist_q1, train_loss_hist_q0 = [], [], []
test_loss_hist_p, test_loss_hist_q1, test_loss_hist_q0 = [], [], []
est_effect, prop_score_hist = [], []

for e in range(1, epoch + 1):
    model.train()
    start = time.time()
        
    p_loss_train, q1_loss_train, q0_loss_train  = [], [], []
    for idx, (tokens, treatment, response, _) in enumerate(train_loader):
        optimizer.zero_grad()
        prop_score, q1, q0 = model(tokens)
        
        loss_p = prop_score_loss(prop_score, treatment)
        loss = loss_p
        
        p_loss_train.append(loss_p.item())
        if len(response[treatment == 1]) > 0:
            loss_q1 = q_loss(q1[treatment==1], response[treatment==1])
            loss += loss_q1
            q1_loss_train.append(loss_q1.item())
            
        if len(response[treatment == 0]) > 0:
            loss_q0 = q_loss(q1[treatment==0], response[treatment==0])
            loss += loss_q0
            q0_loss_train.append(loss_q0.item())
                        
        loss.backward()
        optimizer.step()

    run_idx = idx

    # Evaluation.
    p_loss_train = np.array(p_loss_train).mean()
    q1_loss_train = np.array(q1_loss_train).mean()
    q0_loss_train = np.array(q0_loss_train).mean()
    
    train_effect, _, _, _, _, _, _ = est_casual_effect(train_loader, model, effect, estimation, evaluate=False)
    test_effect, p_loss_test, q1_loss_test, q0_loss_test, prop_accu_test, q1_accu_test, q0_accu_test = est_casual_effect(test_loader, model, effect, estimation, evaluate=True, g_loss=prop_score_loss, q_loss=q_loss)
    
    train_loss_hist_p.append(p_loss_train)
    train_loss_hist_q1.append(q1_loss_train)
    train_loss_hist_q0.append(q0_loss_train)
    
    test_loss_hist_p.append(p_loss_test)
    test_loss_hist_q1.append(q1_loss_test)
    test_loss_hist_q0.append(q0_loss_test)

    est_effect.append(test_effect)
    
    
    print(f'''epoch: {e} / {epoch}, time cost: {(time.time() - start):.2f} sec, 
          Loss: [Train: p = {p_loss_train:.5f}, q = {(q1_loss_train + q0_loss_train):.5f}], 
          Loss: [Test: p = {p_loss_test:.5f}, q = {(q1_loss_test + q0_loss_test):.5f}],
          Effect: [{effect}-{estimation}], [train: {train_effect:.5f}], [test: {test_effect:.5f}]''')
    print('*'* 80)
    start = time.time()

train_loss_hist = dict(p=train_loss_hist_p, q1=train_loss_hist_q1, q0=train_loss_hist_q1)
test_loss_hist = dict(p=test_loss_hist_p, q1=test_loss_hist_q1, q0=test_loss_hist_q0)

print('Finish training...')
# Out:
# epoch: 1 / 50, time cost: 36.19 sec,
#           Loss: [Train: p = 1.05686, q = 1.35700],
#           Loss: [Test: p = 1.06013, q = 1.34827],
#           Effect: [ate-q], [train: 0.07216], [test: 0.07216]
# ********************************************************************************
# epoch: 2 / 50, time cost: 39.05 sec,
#           Loss: [Train: p = 1.05657, q = 1.34905],
#           Loss: [Test: p = 1.05986, q = 1.33719],
#           Effect: [ate-q], [train: 0.09397], [test: 0.09398]
# ********************************************************************************
# epoch: 3 / 50, time cost: 38.01 sec,
#           Loss: [Train: p = 1.05618, q = 1.34556],
#           Loss: [Test: p = 1.05965, q = 1.33112],
#           Effect: [ate-q], [train: 0.10804], [test: 0.10804]
# ********************************************************************************
# epoch: 4 / 50, time cost: 40.38 sec,
#           Loss: [Train: p = 1.05612, q = 1.34470],
#           Loss: [Test: p = 1.05950, q = 1.32925],
#           Effect: [ate-q], [train: 0.11212], [test: 0.11213]
# ********************************************************************************
# epoch: 5 / 50, time cost: 38.22 sec,
#           Loss: [Train: p = 1.05592, q = 1.34451],
#           Loss: [Test: p = 1.05931, q = 1.32863],
#           Effect: [ate-q], [train: 0.11381], [test: 0.11381]
# ********************************************************************************
# epoch: 6 / 50, time cost: 38.46 sec,
#           Loss: [Train: p = 1.05571, q = 1.34446],
#           Loss: [Test: p = 1.05916, q = 1.32834],
#           Effect: [ate-q], [train: 0.11447], [test: 0.11447]
# ********************************************************************************
# epoch: 7 / 50, time cost: 38.39 sec,
#           Loss: [Train: p = 1.05551, q = 1.34437],
#           Loss: [Test: p = 1.05900, q = 1.32835],
#           Effect: [ate-q], [train: 0.11431], [test: 0.11430]
# ********************************************************************************
# epoch: 8 / 50, time cost: 40.05 sec,
#           Loss: [Train: p = 1.05541, q = 1.34436],
#           Loss: [Test: p = 1.05888, q = 1.32834],
#           Effect: [ate-q], [train: 0.11430], [test: 0.11430]
# ********************************************************************************
# epoch: 9 / 50, time cost: 37.31 sec,
#           Loss: [Train: p = 1.05530, q = 1.34448],
#           Loss: [Test: p = 1.05872, q = 1.32799],
#           Effect: [ate-q], [train: 0.11469], [test: 0.11468]
# ********************************************************************************
# epoch: 10 / 50, time cost: 38.01 sec,
#           Loss: [Train: p = 1.05513, q = 1.34434],
#           Loss: [Test: p = 1.05856, q = 1.32779],
#           Effect: [ate-q], [train: 0.11520], [test: 0.11519]
# ********************************************************************************
# epoch: 11 / 50, time cost: 38.49 sec,
#           Loss: [Train: p = 1.05493, q = 1.34428],
#           Loss: [Test: p = 1.05847, q = 1.32802],
#           Effect: [ate-q], [train: 0.11426], [test: 0.11425]
# ********************************************************************************
# epoch: 12 / 50, time cost: 40.16 sec,
#           Loss: [Train: p = 1.05485, q = 1.34395],
#           Loss: [Test: p = 1.05831, q = 1.32808],
#           Effect: [ate-q], [train: 0.11436], [test: 0.11434]
# ********************************************************************************
# epoch: 13 / 50, time cost: 38.72 sec,
#           Loss: [Train: p = 1.05461, q = 1.34411],
#           Loss: [Test: p = 1.05818, q = 1.32805],
#           Effect: [ate-q], [train: 0.11394], [test: 0.11392]
# ********************************************************************************
# epoch: 14 / 50, time cost: 37.82 sec,
#           Loss: [Train: p = 1.05449, q = 1.34406],
#           Loss: [Test: p = 1.05804, q = 1.32808],
#           Effect: [ate-q], [train: 0.11415], [test: 0.11413]
# ********************************************************************************
# epoch: 15 / 50, time cost: 38.66 sec,
#           Loss: [Train: p = 1.05417, q = 1.34370],
#           Loss: [Test: p = 1.05791, q = 1.32785],
#           Effect: [ate-q], [train: 0.11405], [test: 0.11402]
# ********************************************************************************
# epoch: 16 / 50, time cost: 40.88 sec,
#           Loss: [Train: p = 1.05413, q = 1.34369],
#           Loss: [Test: p = 1.05772, q = 1.32769],
#           Effect: [ate-q], [train: 0.11449], [test: 0.11446]
# ********************************************************************************
# epoch: 17 / 50, time cost: 38.38 sec,
#           Loss: [Train: p = 1.05403, q = 1.34359],
#           Loss: [Test: p = 1.05764, q = 1.32699],
#           Effect: [ate-q], [train: 0.11580], [test: 0.11577]
# ********************************************************************************
# epoch: 18 / 50, time cost: 38.02 sec,
#           Loss: [Train: p = 1.05390, q = 1.34341],
#           Loss: [Test: p = 1.05744, q = 1.32675],
#           Effect: [ate-q], [train: 0.11621], [test: 0.11618]
# ********************************************************************************
# epoch: 19 / 50, time cost: 37.88 sec,
#           Loss: [Train: p = 1.05369, q = 1.34315],
#           Loss: [Test: p = 1.05733, q = 1.32691],
#           Effect: [ate-q], [train: 0.11588], [test: 0.11584]
# ********************************************************************************
# epoch: 20 / 50, time cost: 40.30 sec,
#           Loss: [Train: p = 1.05354, q = 1.34324],
#           Loss: [Test: p = 1.05717, q = 1.32729],
#           Effect: [ate-q], [train: 0.11416], [test: 0.11412]
# ********************************************************************************
# epoch: 21 / 50, time cost: 38.17 sec,
#           Loss: [Train: p = 1.05340, q = 1.34278],
#           Loss: [Test: p = 1.05704, q = 1.32684],
#           Effect: [ate-q], [train: 0.11543], [test: 0.11538]
# ********************************************************************************
# epoch: 22 / 50, time cost: 37.98 sec,
#           Loss: [Train: p = 1.05325, q = 1.34279],
#           Loss: [Test: p = 1.05689, q = 1.32708],
#           Effect: [ate-q], [train: 0.11402], [test: 0.11397]
# ********************************************************************************
# epoch: 23 / 50, time cost: 37.74 sec,
#           Loss: [Train: p = 1.05304, q = 1.34263],
#           Loss: [Test: p = 1.05672, q = 1.32677],
#           Effect: [ate-q], [train: 0.11459], [test: 0.11454]
# ********************************************************************************
# epoch: 24 / 50, time cost: 38.11 sec,
#           Loss: [Train: p = 1.05279, q = 1.34242],
#           Loss: [Test: p = 1.05660, q = 1.32596],
#           Effect: [ate-q], [train: 0.11644], [test: 0.11638]
# ********************************************************************************
# epoch: 25 / 50, time cost: 39.87 sec,
#           Loss: [Train: p = 1.05273, q = 1.34230],
#           Loss: [Test: p = 1.05643, q = 1.32612],
#           Effect: [ate-q], [train: 0.11559], [test: 0.11553]
# ********************************************************************************
# epoch: 26 / 50, time cost: 37.79 sec,
#           Loss: [Train: p = 1.05255, q = 1.34199],
#           Loss: [Test: p = 1.05627, q = 1.32660],
#           Effect: [ate-q], [train: 0.11376], [test: 0.11370]
# ********************************************************************************
# epoch: 27 / 50, time cost: 37.89 sec,
#           Loss: [Train: p = 1.05238, q = 1.34186],
#           Loss: [Test: p = 1.05610, q = 1.32594],
#           Effect: [ate-q], [train: 0.11544], [test: 0.11538]
# ********************************************************************************
# epoch: 28 / 50, time cost: 38.35 sec,
#           Loss: [Train: p = 1.05214, q = 1.34170],
#           Loss: [Test: p = 1.05598, q = 1.32611],
#           Effect: [ate-q], [train: 0.11444], [test: 0.11437]
# ********************************************************************************
# epoch: 29 / 50, time cost: 40.07 sec,
#           Loss: [Train: p = 1.05185, q = 1.34117],
#           Loss: [Test: p = 1.05580, q = 1.32589],
#           Effect: [ate-q], [train: 0.11428], [test: 0.11420]
# ********************************************************************************
# epoch: 30 / 50, time cost: 38.09 sec,
#           Loss: [Train: p = 1.05173, q = 1.34116],
#           Loss: [Test: p = 1.05565, q = 1.32580],
#           Effect: [ate-q], [train: 0.11401], [test: 0.11394]
# ********************************************************************************
# epoch: 31 / 50, time cost: 37.94 sec,
#           Loss: [Train: p = 1.05158, q = 1.34108],
#           Loss: [Test: p = 1.05548, q = 1.32577],
#           Effect: [ate-q], [train: 0.11339], [test: 0.11332]
# ********************************************************************************
# epoch: 32 / 50, time cost: 38.06 sec,
#           Loss: [Train: p = 1.05140, q = 1.34066],
#           Loss: [Test: p = 1.05526, q = 1.32583],
#           Effect: [ate-q], [train: 0.11245], [test: 0.11237]
# ********************************************************************************
# epoch: 33 / 50, time cost: 39.64 sec,
#           Loss: [Train: p = 1.05116, q = 1.34035],
#           Loss: [Test: p = 1.05510, q = 1.32458],
#           Effect: [ate-q], [train: 0.11550], [test: 0.11542]
# ********************************************************************************
# epoch: 34 / 50, time cost: 37.99 sec,
#           Loss: [Train: p = 1.05108, q = 1.33991],
#           Loss: [Test: p = 1.05497, q = 1.32394],
#           Effect: [ate-q], [train: 0.11588], [test: 0.11579]
# ********************************************************************************
# epoch: 35 / 50, time cost: 37.94 sec,
#           Loss: [Train: p = 1.05078, q = 1.33966],
#           Loss: [Test: p = 1.05478, q = 1.32410],
#           Effect: [ate-q], [train: 0.11500], [test: 0.11491]
# ********************************************************************************
# epoch: 36 / 50, time cost: 38.07 sec,
#           Loss: [Train: p = 1.05055, q = 1.33917],
#           Loss: [Test: p = 1.05459, q = 1.32338],
#           Effect: [ate-q], [train: 0.11593], [test: 0.11585]
# ********************************************************************************
# epoch: 37 / 50, time cost: 39.33 sec,
#           Loss: [Train: p = 1.05045, q = 1.33889],
#           Loss: [Test: p = 1.05440, q = 1.32408],
#           Effect: [ate-q], [train: 0.11330], [test: 0.11322]
# ********************************************************************************
# epoch: 38 / 50, time cost: 38.04 sec,
#           Loss: [Train: p = 1.05008, q = 1.33870],
#           Loss: [Test: p = 1.05424, q = 1.32311],
#           Effect: [ate-q], [train: 0.11585], [test: 0.11576]
# ********************************************************************************
# epoch: 39 / 50, time cost: 38.01 sec,
#           Loss: [Train: p = 1.04999, q = 1.33810],
#           Loss: [Test: p = 1.05403, q = 1.32297],
#           Effect: [ate-q], [train: 0.11469], [test: 0.11460]
# ********************************************************************************
# epoch: 40 / 50, time cost: 38.20 sec,
#           Loss: [Train: p = 1.04971, q = 1.33782],
#           Loss: [Test: p = 1.05386, q = 1.32246],
#           Effect: [ate-q], [train: 0.11505], [test: 0.11496]
# ********************************************************************************
# epoch: 41 / 50, time cost: 40.14 sec,
#           Loss: [Train: p = 1.04956, q = 1.33711],
#           Loss: [Test: p = 1.05363, q = 1.32254],
#           Effect: [ate-q], [train: 0.11310], [test: 0.11301]
# ********************************************************************************
# epoch: 42 / 50, time cost: 38.39 sec,
#           Loss: [Train: p = 1.04949, q = 1.33663],
#           Loss: [Test: p = 1.05350, q = 1.32280],
#           Effect: [ate-q], [train: 0.11194], [test: 0.11185]
# ********************************************************************************
# epoch: 43 / 50, time cost: 37.97 sec,
#           Loss: [Train: p = 1.04910, q = 1.33624],
#           Loss: [Test: p = 1.05333, q = 1.32052],
#           Effect: [ate-q], [train: 0.11637], [test: 0.11628]
# ********************************************************************************
# epoch: 44 / 50, time cost: 37.39 sec,
#           Loss: [Train: p = 1.04891, q = 1.33533],
#           Loss: [Test: p = 1.05310, q = 1.32195],
#           Effect: [ate-q], [train: 0.11182], [test: 0.11173]
# ********************************************************************************
# epoch: 45 / 50, time cost: 38.04 sec,
#           Loss: [Train: p = 1.04874, q = 1.33491],
#           Loss: [Test: p = 1.05290, q = 1.32101],
#           Effect: [ate-q], [train: 0.11246], [test: 0.11237]
# ********************************************************************************
# epoch: 46 / 50, time cost: 39.86 sec,
#           Loss: [Train: p = 1.04841, q = 1.33439],
#           Loss: [Test: p = 1.05272, q = 1.32016],
#           Effect: [ate-q], [train: 0.11388], [test: 0.11379]
# ********************************************************************************
# epoch: 47 / 50, time cost: 38.27 sec,
#           Loss: [Train: p = 1.04831, q = 1.33371],
#           Loss: [Test: p = 1.05253, q = 1.32016],
#           Effect: [ate-q], [train: 0.11236], [test: 0.11227]
# ********************************************************************************
# epoch: 48 / 50, time cost: 37.74 sec,
#           Loss: [Train: p = 1.04800, q = 1.33295],
#           Loss: [Test: p = 1.05231, q = 1.31967],
#           Effect: [ate-q], [train: 0.11217], [test: 0.11209]
# ********************************************************************************
# epoch: 49 / 50, time cost: 38.29 sec,
#           Loss: [Train: p = 1.04792, q = 1.33244],
#           Loss: [Test: p = 1.05216, q = 1.31903],
#           Effect: [ate-q], [train: 0.11234], [test: 0.11226]
# ********************************************************************************
# epoch: 50 / 50, time cost: 40.11 sec,
#           Loss: [Train: p = 1.04762, q = 1.33162],
#           Loss: [Test: p = 1.05192, q = 1.31878],
#           Effect: [ate-q], [train: 0.11151], [test: 0.11142]
# ********************************************************************************
# Finish training...

# %%
real = true_casual_effect(test_loader)
unadjust = (test_loader.dataset.response[test_loader.dataset.treatment == 1].mean() - test_loader.dataset.response[test_loader.dataset.treatment == 0].mean()).item()
show_result(train_loss_hist, test_loss_hist, est_effect, real, unadjust, epoch)
