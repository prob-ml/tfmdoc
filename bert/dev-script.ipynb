# %%
import os
import sys
import argparse

import torch
from transformers import DataCollatorForLanguageModeling, BertForMaskedLM
from transformers import Trainer, TrainingArguments

from data import LineByLineTextDataset
from tokens import WordLevelBertTokenizer
from vocab import create_vocab
from utils import DATA_PATH, make_dirs

# %%
vocab = create_vocab(merged=True)
vocab
# Out:
# '/nfs/turbo/lsa-regier/emr-data/vocabs/vocab_merged.json'

# %%
tokenizer = WordLevelBertTokenizer(vocab)
    
len(tokenizer)

# %%
user_group = [str(i) for i in range(10)]

vocab, size = {}, 0
for group in user_group:
    read = os.path.join(DATA_PATH, f'group_{group}_merged.csv')

    with open(read, 'r') as raw:
        for line in raw:
            line = line.replace('\n', '')
            user, tokens = line.split(',')
            tokens = tokens.strip()
            token_list = tokens.split(' ')

            for token in token_list:
                if token not in ['[SEP]', 'document', '']:
                    if token in vocab:
                        # If a token is existed, don't do anything.
                        pass
                    else:
                        # A new token: tokens value will start from 0
                        vocab[token] = size
                        size += 1

for j, v in enumerate(['[UNK]', '[SEP]', '[CLS]']):
    vocab[v] = size + j

# %%
vocab
# Out:
# {'SIMVASTATIN': 0,
#  'METOPROLOL_SUCCINATE': 1,
#  'LISINOPRIL': 2,
#  'ESCITALOPRAM_OXALATE': 3,
#  'METFORMIN_HCL': 4,
#  'SITAGLIPTIN_PHOSPHATE': 5,
#  'INSULIN_GLARGINE_HUM.REC.ANLOG': 6,
#  'LEVOTHYROXINE_SODIUM': 7,
#  'icd:9.0_diag:25000': 8,
#  'icd:9.0_diag:4011': 9,
#  'icd:9.0_diag:4659': 10,
#  'icd:9.0_diag:7862': 11,
#  'AZITHROMYCIN': 12,
#  'HYDROCODONE/CHLORPHEN_P-STIREX': 13,
#  'icd:9.0_diag:2724': 14,
#  'icd:9.0_diag:V5869': 15,
#  'icd:9.0_diag:41401': 16,
#  'ERGOCALCIFEROL_(VITAMIN_D2)': 17,
#  'OXYCODONE_HCL/ACETAMINOPHEN': 18,
#  'INSULIN_LISPRO': 19,
#  'NEEDLES__INSULIN_DISPOSABLE': 20,
#  'AMOXICILLIN': 21,
#  'METHYLPREDNISOLONE': 22,
#  'BLOOD_SUGAR_DIAGNOSTIC': 23,
#  'LANCETS': 24,
#  'icd:9_diag:2724': 25,
#  'icd:9_diag:25000': 26,
#  'icd:9_diag:41401': 27,
#  'icd:9_diag:78652': 28,
#  'icd:9_diag:7904': 29,
#  'icd:9_diag:V4581': 30,
#  'icd:9_diag:412': 31,
#  'icd:9_diag:79439': 32,
#  'PEN_NEEDLE__DIABETIC': 33,
#  'icd:10_diag:J029': 34,
#  'icd:10_diag:J309': 35,
#  'icd:10_diag:J320': 36,
#  'CEFUROXIME_AXETIL': 37,
#  'icd:10_diag:E039': 38,
#  'icd:10_diag:E119': 39,
#  'icd:10_diag:E559': 40,
#  'icd:10_diag:E784': 41,
#  'icd:10_diag:I10': 42,
#  'icd:10_diag:Z79891': 43,
#  'icd:10_diag:E785': 44,
#  'icd:10_diag:I2510': 45,
#  'icd:10_diag:R0789': 46,
#  'icd:10_diag:R945': 47,
#  'icd:10_diag:E1165': 48,
#  'icd:10_diag:Z79899': 49,
#  'icd:10_diag:Z944': 50,
#  'icd:10_diag:F329': 51,
#  'icd:10_diag:Z23': 52,
#  'BLOOD-GLUCOSE_METER': 53,
#  'icd:10_diag:H02834': 54,
#  'icd:10_diag:H524': 55,
#  'icd:10_diag:Z1211': 56,
#  'icd:10_diag:Z1212': 57,
#  'icd:10_diag:Z794': 58,
#  'icd:10_diag:E7800': 59,
#  'icd:10_diag:R931': 60,
#  'icd:10_diag:Z951': 61,
#  'icd:10_diag:M7989': 62,
#  'icd:10_diag:S99912A': 63,
#  'icd:10_diag:R799': 64,
#  'icd:10_diag:Z1231': 65,
#  'icd:10_diag:Z209': 66,
#  'EMPAGLIFLOZIN': 67,
#  'icd:10_diag:R7989': 68,
#  'icd:9_diag:7822': 69,
#  'icd:9.0_diag:V700': 70,
#  'icd:9_diag:59972': 71,
#  'icd:9_diag:V700': 72,
#  'icd:9_diag:60889': 73,
#  'icd:9_diag:6039': 74,
#  'icd:10_diag:Z0000': 75,
#  'icd:10_diag:E782': 76,
#  'icd:10_diag:R7309': 77,
#  'icd:10_diag:M545': 78,
#  'icd:10_diag:Z130': 79,
#  'icd:10_diag:Z13220': 80,
#  'icd:10_diag:Z1329': 81,
#  'icd:10_diag:R7301': 82,
#  'icd:10_diag:M7051': 83,
#  'icd:10_diag:M7052': 84,
#  'icd:9.0_diag:V7612': 85,
#  'icd:9.0_diag:25002': 86,
#  'icd:9.0_diag:6279': 87,
#  'icd:9.0_diag:73300': 88,
#  'icd:9.0_diag:V4981': 89,
#  'icd:9.0_diag:V8281': 90,
#  'icd:9.0_diag:36511': 91,
#  'icd:9.0_diag:36573': 92,
#  'icd:9.0_diag:5569': 93,
#  'icd:9.0_diag:9190': 94,
#  'icd:9.0_diag:4019': 95,
#  'icd:9.0_diag:36619': 96,
#  'icd:9.0_diag:37921': 97,
#  'icd:9.0_diag:37924': 98,
#  'icd:9.0_diag:3569': 99,
#  'icd:9.0_diag:42789': 100,
#  'icd:9.0_diag:59970': 101,
#  'icd:9.0_diag:30000': 102,
#  'icd:9_diag:25002': 103,
#  'icd:9_diag:2722': 104,
#  'icd:9_diag:4019': 105,
#  'icd:9_diag:78079': 106,
#  'icd:9_diag:4011': 107,
#  'icd:9_diag:36511': 108,
#  'icd:9_diag:36573': 109,
#  'icd:9_diag:36619': 110,
#  'icd:9_diag:71944': 111,
#  'icd:9_diag:78650': 112,
#  'icd:9_diag:4240': 113,
#  'icd:9_diag:4293': 114,
#  'icd:9_diag:5559': 115,
#  'icd:9_diag:78659': 116,
#  'icd:9_diag:4010': 117,
#  'icd:9_diag:79431': 118,
#  'icd:9_diag:72704': 119,
#  'icd:9_diag:7295': 120,
#  'icd:9_diag:71594': 121,
#  'icd:9_diag:5569': 122,
#  'icd:9_diag:38900': 123,
#  'icd:9_diag:7823': 124,
#  'icd:10_diag:R5383': 125,
#  'icd:10_diag:H4011X3': 126,
#  'AMLODIPINE_BESYLATE': 127,
#  'SITAGLIPTIN_PHOS/METFORMIN_HCL': 128,
#  'icd:10_diag:R197': 129,
#  'GLIMEPIRIDE': 130,
#  'icd:10_diag:H2512': 131,
#  'icd:10_diag:M2550': 132,
#  'icd:10_diag:M7072': 133,
#  'icd:10_diag:R51': 134,
#  'GABAPENTIN': 135,
#  'icd:10_diag:M7551': 136,
#  'BENZONATATE': 137,
#  'icd:10_diag:M899': 138,
#  'icd:10_diag:M810': 139,
#  'icd:10_diag:M8580': 140,
#  'TRIAMCINOLONE_ACETONIDE': 141,
#  'icd:10_diag:M4722': 142,
#  'icd:10_diag:M542': 143,
#  'icd:10_diag:S335XXA': 144,
#  'icd:10_diag:K51818': 145,
#  'icd:10_diag:M5412': 146,
#  'TIZANIDINE_HCL': 147,
#  'NAPROXEN': 148,
#  'TRAMADOL_HCL/ACETAMINOPHEN': 149,
#  'MESALAMINE': 150,
#  'icd:10_diag:H401133': 151,
#  'icd:10_diag:N644': 152,
#  'icd:10_diag:R21': 153,
#  'GUAIFENESIN/CODEINE_PHOSPHATE': 154,
#  'icd:10_diag:E781': 155,
#  'icd:10_diag:R0600': 156,
#  'icd:10_diag:N390': 157,
#  'icd:10_diag:R531': 158,
#  'NITROFURANTOIN_MONOHYD/M-CRYST': 159,
#  'icd:10_diag:M4604': 160,
#  'NAPROXEN_SODIUM': 161,
#  'CHOLESTYRAMINE_(WITH_SUGAR)': 162,
#  'icd:10_diag:K5090': 163,
#  'icd:10_diag:E1140': 164,
#  'PEG3350/SOD_SUL/NACL/ASB/C/KCL': 165,
#  'icd:10_diag:K529': 166,
#  'icd:10_diag:K635': 167,
#  'icd:10_diag:K648': 168,
#  'icd:10_diag:K5730': 169,
#  'icd:10_diag:K640': 170,
#  'icd:10_diag:R194': 171,
#  'icd:10_diag:H401113': 172,
#  'icd:10_diag:H401122': 173,
#  'LATANOPROST': 174,
#  'icd:10_diag:R634': 175,
#  'icd:10_diag:M65331': 176,
#  'icd:10_diag:K5100': 177,
#  'icd:10_diag:G609': 178,
#  'icd:10_diag:Z961': 179,
#  'icd:10_diag:L988': 180,
#  'icd:10_diag:M65332': 181,
#  'icd:10_diag:K5790': 182,
#  'COLESTIPOL_HCL': 183,
#  'POLYMYXIN_B_SULF/TRIMETHOPRIM': 184,
#  'PREDNISOLONE_ACETATE': 185,
#  'KETOROLAC_TROMETHAMINE': 186,
#  'icd:10_diag:K51911': 187,
#  'icd:10_diag:K5180': 188,
#  'icd:10_diag:R601': 189,
#  'icd:9_diag:5246': 190,
#  'icd:9_diag:83901': 191,
#  'icd:9_diag:V0489': 192,
#  'icd:9_diag:V2509': 193,
#  'icd:9_diag:V7231': 194,
#  'icd:9_diag:30781': 195,
#  'ALPRAZOLAM': 196,
#  'icd:9_diag:4619': 197,
#  'icd:9_diag:6929': 198,
#  'BETAMET_DIPROP/PROP_GLY': 199,
#  'PROMETHAZINE_HCL': 200,
#  'AMOX_TR/POTASSIUM_CLAVULANATE': 201,
#  'IBUPROFEN': 202,
#  'HYDROCODONE_BIT/ACETAMINOPHEN': 203,
#  'CHLORHEXIDINE_GLUCONATE': 204,
#  'FLUCONAZOLE': 205,
#  'TERCONAZOLE': 206,
#  'icd:9_diag:7048': 207,
#  'CIPROFLOXACIN_HCL': 208,
#  'icd:9_diag:1330': 209,
#  'HYDROXYZINE_HCL': 210,
#  'PERMETHRIN': 211,
#  'icd:9_diag:7821': 212,
#  'PREDNISONE': 213,
#  'icd:9_diag:462': 214,
#  'icd:9_diag:4659': 215,
#  'icd:9_diag:5282': 216,
#  'icd:9_diag:61172': 217,
#  'icd:9_diag:5950': 218,
#  'SULFAMETHOXAZOLE/TRIMETHOPRIM': 219,
#  'icd:9_diag:4610': 220,
#  'FLUTICASONE_PROPIONATE': 221,
#  'OLOPATADINE_HCL': 222,
#  'icd:9_diag:3804': 223,
#  'icd:9_diag:5641': 224,
#  'icd:9_diag:7827': 225,
#  'icd:9_diag:5693': 226,
#  'HYDROCORTISONE/PRAMOXINE': 227,
#  'NORGESTREL-ETHINYL_ESTRADIOL': 228,
#  'icd:9_diag:V2511': 229,
#  'icd:9_diag:V2542': 230,
#  'icd:9.0_diag:V7231': 231,
#  'icd:9.0_diag:7061': 232,
#  'CLINDAMYCIN_PHOS/BENZOYL_PEROX': 233,
#  'icd:9.0_diag:6829': 234,
#  'icd:9.0_diag:V8289': 235,
#  'icd:9.0_diag:V0389': 236,
#  'icd:9.0_diag:V061': 237,
#  'icd:9.0_diag:V741': 238,
#  'icd:9.0_diag:V0481': 239,
#  'icd:9.0_diag:30002': 240,
#  'icd:9_diag:6169': 241,
#  'icd:9_diag:V741': 242,
#  'icd:9_diag:V0481': 243,
#  'icd:9_diag:30742': 244,
#  'ZOLPIDEM_TARTRATE': 245,
#  'icd:10_diag:S01512A': 246,
#  'icd:10_diag:W503XXA': 247,
#  'ACETAMINOPHEN_WITH_CODEINE': 248,
#  'SUCRALFATE': 249,
#  'icd:10_diag:H5005': 250,
#  'icd:10_diag:F411': 251,
#  'ESZOPICLONE': 252,
#  'icd:10_diag:Z01419': 253,
#  'icd:10_diag:Z1272': 254,
#  'icd:10_diag:Z3009': 255,
#  'icd:10_diag:H50011': 256,
#  'AMOXICILLIN/POTASSIUM_CLAV': 257,
#  'MOXIFLOXACIN_HCL': 258,
#  'icd:10_diag:H509': 259,
#  'icd:10_diag:H5000': 260,
#  'icd:10_diag:Z9889': 261,
#  'icd:10_diag:Z30430': 262,
#  'icd:10_diag:Z30431': 263,
#  'icd:10_diag:Z30432': 264,
#  'icd:10_diag:R10814': 265,
#  'icd:10_diag:R109': 266,
#  'METRONIDAZOLE': 267,
#  'icd:10_diag:R635': 268,
#  'icd:10_diag:Z6826': 269,
#  'icd:10_diag:Z713': 270,
#  'icd:10_diag:Z6825': 271,
#  'icd:10_diag:J069': 272,
#  'icd:9.0_diag:6851': 273,
#  'icd:9.0_diag:49390': 274,
#  'icd:9.0_diag:V202': 275,
#  'icd:9.0_diag:V703': 276,
#  'NYSTATIN': 277,
#  'icd:9_diag:6850': 278,
#  'icd:9_diag:6851': 279,
#  'CEPHALEXIN': 280,
#  'HYDROCODONE/ACETAMINOPHEN': 281,
#  'icd:9_diag:99883': 282,
#  'icd:9_diag:27800': 283,
#  'icd:9_diag:V202': 284,
#  'icd:10_diag:L98419': 285,
#  'icd:10_diag:T8189XD': 286,
#  'icd:10_diag:T8189XA': 287,
#  'icd:10_diag:Z5189': 288,
#  'icd:10_diag:L700': 289,
#  'icd:10_diag:L720': 290,
#  'icd:10_diag:E669': 291,
#  'icd:10_diag:Z00129': 292,
#  'icd:10_diag:H66002': 293,
#  'icd:10_diag:H1132': 294,
#  'icd:10_diag:H66003': 295,
#  'icd:10_diag:J208': 296,
#  'ALBUTEROL_SULFATE': 297,
#  'PROMETHAZINE/DEXTROMETHORPHAN': 298,
#  'icd:10_diag:J111': 299,
#  'icd:10_diag:J4520': 300,
#  'icd:10_diag:R509': 301,
#  'OSELTAMIVIR_PHOSPHATE': 302,
#  'icd:10_diag:L219': 303,
#  'icd:10_diag:Z6836': 304,
#  'KETOCONAZOLE': 305,
#  'ETHYNODIOL_D-ETHINYL_ESTRADIOL': 306,
#  'icd:10_diag:R5382': 307,
#  'icd:10_diag:Z7689': 308,
#  'icd:9_diag:515': 309,
#  'icd:9_diag:5180': 310,
#  'icd:9_diag:55090': 311,
#  'icd:9_diag:5781': 312,
#  'icd:9_diag:59970': 313,
#  'icd:9_diag:60000': 314,
#  'icd:9_diag:2558': 315,
#  'icd:9_diag:5939': 316,
#  'icd:9_diag:59971': 317,
#  'icd:9_diag:V0382': 318,
#  'icd:9_diag:2720': 319,
#  'icd:9_diag:41400': 320,
#  'icd:9_diag:56400': 321,
#  'ATORVASTATIN_CALCIUM': 322,
#  'SODIUM_POTASSIUM_&MAG_SULFATES': 323,
#  'icd:9_diag:2113': 324,
#  'icd:9_diag:V7651': 325,
#  'icd:10_diag:Q6100': 326,
#  'icd:10_diag:R319': 327,
#  'icd:10_diag:Z87891': 328,
#  'icd:10_diag:I259': 329,
#  'icd:10_diag:I440': 330,
#  'icd:10_diag:H538': 331,
#  'icd:10_diag:Z7984': 332,
#  'icd:9.0_diag:07999': 333,
#  'icd:9.0_diag:37230': 334,
#  'icd:9.0_diag:3829': 335,
#  'icd:9.0_diag:3789': 336,
#  'icd:9.0_diag:37820': 337,
#  'icd:9.0_diag:0578': 338,
#  'icd:9.0_diag:37835': 339,
#  'icd:9.0_diag:5589': 340,
#  'icd:9.0_diag:78060': 341,
#  'icd:9_diag:5531': 342,
#  'icd:9_diag:3829': 343,
#  'CEFDINIR': 344,
#  'icd:9_diag:37820': 345,
#  'icd:10_diag:Z2821': 346,
#  'icd:10_diag:H5043': 347,
#  'icd:10_diag:H65192': 348,
#  'icd:10_diag:H5030': 349,
#  'icd:10_diag:J020': 350,
#  'icd:10_diag:H6692': 351,
#  'icd:10_diag:J050': 352,
#  'icd:10_diag:Z00121': 353,
#  'icd:10_diag:H5203': 354,
#  'icd:10_diag:B9789': 355,
#  'icd:10_diag:J310': 356,
#  'icd:10_diag:L0100': 357,
#  'icd:9.0_diag:5990': 358,
#  'icd:9.0_diag:7242': 359,
#  'icd:9.0_diag:V7240': 360,
#  'icd:9.0_diag:7241': 361,
#  'icd:9.0_diag:75612': 362,
#  'CYCLOBENZAPRINE_HCL': 363,
#  'icd:9.0_diag:7384': 364,
#  'icd:9.0_diag:7393': 365,
#  'icd:9.0_diag:7394': 366,
#  'icd:9.0_diag:7395': 367,
#  'DIAZEPAM': 368,
#  'icd:10_diag:N751': 369,
#  'icd:10_diag:R102': 370,
#  'icd:10_diag:O2690': 371,
#  'icd:10_diag:O4691': 372,
#  'icd:10_diag:Z3A01': 373,
#  'icd:10_diag:N926': 374,
#  'icd:10_diag:Z1151': 375,
#  'icd:10_diag:Z124': 376,
#  'icd:10_diag:Z331': 377,
#  'icd:10_diag:O200': 378,
#  'DOXYCYCLINE_HYCLATE': 379,
#  'icd:10_diag:O021': 380,
#  'icd:10_diag:N912': 381,
#  'icd:10_diag:N910': 382,
#  'icd:10_diag:E030': 383,
#  'icd:10_diag:O24911': 384,
#  'icd:10_diag:O99281': 385,
#  'icd:10_diag:O208': 386,
#  'icd:10_diag:Z31430': 387,
#  'icd:10_diag:Z3490': 388,
#  'icd:10_diag:O99282': 389,
#  'icd:10_diag:Z820': 390,
#  'icd:10_diag:Z36': 391,
#  'icd:10_diag:O351XX0': 392,
#  'icd:10_diag:Z3A23': 393,
#  'icd:10_diag:O24912': 394,
#  'icd:10_diag:O99283': 395,
#  'icd:10_diag:O3662X0': 396,
#  'icd:10_diag:Z3A35': 397,
#  'icd:10_diag:O4703': 398,
#  'icd:10_diag:Z3A36': 399,
#  'icd:10_diag:O923': 400,
#  'icd:10_diag:O9279': 401,
#  'icd:10_diag:Z3400': 402,
#  'icd:10_diag:O76': 403,
#  'icd:10_diag:Z370': 404,
#  'icd:10_diag:Z3A38': 405,
#  'icd:10_diag:O80': 406,
#  'icd:10_diag:O6981X0': 407,
#  'icd:10_diag:O701': 408,
#  'icd:10_diag:O99284': 409,
#  'icd:10.0_proc:0KQM0ZZ': 410,
#  'icd:10.0_proc:10D07Z6': 411,
#  'icd:10_diag:O219': 412,
#  'icd:10_diag:O99285': 413,
#  'icd:10_diag:O9989': 414,
#  'icd:10_diag:Z392': 415,
#  'icd:10_diag:O99810': 416,
#  'icd:10_diag:Z719': 417,
#  'icd:10_diag:J209': 418,
#  'icd:9.0_diag:29590': 419,
#  'icd:9.0_diag:2689': 420,
#  'icd:9.0_diag:59972': 421,
#  'icd:9.0_diag:V6540': 422,
#  'QUETIAPINE_FUMARATE': 423,
#  'DIVALPROEX_SODIUM': 424,
#  'icd:9.0_diag:29530': 425,
#  'icd:9.0_diag:2989': 426,
#  'icd:9.0_diag:29570': 427,
#  'icd:9.0_diag:V1552': 428,
#  'icd:9.0_diag:V6109': 429,
#  'icd:9.0_diag:78650': 430,
#  'icd:9.0_diag:29534': 431,
#  'icd:9.0_diag:V170': 432,
#  'icd:9.0_diag:V620': 433,
#  'icd:9_proc:9439': 434,
#  'icd:9_proc:9449': 435,
#  'RISPERIDONE': 436,
#  'BENZTROPINE_MESYLATE': 437,
#  'icd:9.0_diag:2165': 438,
#  'icd:9.0_diag:4481': 439,
#  'icd:9.0_diag:V9999': 440,
#  'icd:10.0_diag:F250': 441,
#  'icd:9.0_diag:4589': 442,
#  'icd:9.0_diag:V7651': 443,
#  'icd:9_diag:29590': 444,
#  'icd:9_diag:29570': 445,
#  'icd:9_diag:V759': 446,
#  'icd:9_diag:V771': 447,
#  'icd:9_diag:V7791': 448,
#  'icd:9_diag:2689': 449,
#  'icd:9_diag:V6540': 450,
#  'icd:10_diag:F250': 451,
#  'icd:10_diag:Z119': 452,
#  'icd:10_diag:Z131': 453,
#  'icd:10_diag:K4020': 454,
#  'icd:10_diag:Z419': 455,
#  'icd:10_diag:S90822A': 456,
#  'LORAZEPAM': 457,
#  'ACETAZOLAMIDE': 458,
#  'icd:10_diag:U997003': 459,
#  'icd:10_diag:D485': 460,
#  'icd:10_diag:L719': 461,
#  'icd:10_diag:C44311': 462,
#  'icd:10_diag:C4491': 463,
#  'icd:10_diag:F259': 464,
#  'SERTRALINE_HCL': 465,
#  'icd:10_diag:M79671': 466,
#  'icd:10_diag:S20211A': 467,
#  'icd:10_diag:S23420A': 468,
#  'icd:9.0_diag:71944': 469,
#  'icd:9.0_diag:7295': 470,
#  'icd:9.0_diag:84213': 471,
#  'icd:9_diag:71945': 472,
#  'icd:9_diag:78901': 473,
#  'icd:9_diag:78907': 474,
#  'icd:9_diag:78963': 475,
#  'icd:9_diag:78900': 476,
#  'icd:10_diag:Z1389': 477,
#  'icd:10_diag:Z6852': 478,
#  'icd:10_diag:Z7189': 479,
#  'icd:10_diag:I861': 480,
#  'icd:10_diag:J9801': 481,
#  'LISINOPRIL/HYDROCHLOROTHIAZIDE': 482,
#  'icd:9.0_diag:4660': 483,
#  'icd:10_diag:J40': 484,
#  'icd:10_diag:R05': 485,
#  'icd:10_diag:L02612': 486,
#  'icd:10_diag:L03032': 487,
#  'icd:10_diag:L600': 488,
#  'icd:10_diag:M79675': 489,
#  'icd:10_diag:N429': 490,
#  'icd:10_diag:R0683': 491,
#  'icd:10_diag:G2581': 492,
#  'icd:10_diag:G4710': 493,
#  'icd:10_diag:G4733': 494,
#  'icd:10_diag:R0902': 495,
#  'icd:10_diag:Z114': 496,
#  'icd:10_diag:Z1159': 497,
#  'icd:10_diag:B9689': 498,
#  'icd:10_diag:J0190': 499,
#  'NEOMYCIN/POLYMYXIN_B/HYDROCORT': 500,
#  'icd:10_diag:H66009': 501,
#  'icd:10_diag:H60332': 502,
#  'icd:10_diag:H6982': 503,
#  'icd:9.0_diag:7820': 504,
#  'icd:9.0_diag:7835': 505,
#  'icd:9.0_diag:78841': 506,
#  'icd:9.0_diag:27802': 507,
#  'icd:9.0_diag:7964': 508,
#  'icd:9_diag:61610': 509,
#  'icd:9_diag:V7241': 510,
#  'icd:9_diag:3051': 511,
#  'icd:9_diag:460': 512,
#  'icd:9_diag:7862': 513,
#  'icd:9_diag:6235': 514,
#  'icd:9_diag:7808': 515,
#  'icd:9_diag:7881': 516,
#  'icd:9_diag:V7381': 517,
#  'icd:9_diag:V762': 518,
#  'icd:9_diag:5990': 519,
#  'icd:10_diag:F17210': 520,
#  'icd:10_diag:H10023': 521,
#  'icd:10_diag:H1032': 522,
#  'icd:10_diag:H5713': 523,
#  'icd:10_diag:L299': 524,
#  'TOBRAMYCIN/DEXAMETHASONE': 525,
#  'icd:10_diag:N898': 526,
#  'icd:10_diag:N760': 527,
#  'icd:10_diag:F419': 528,
#  'BUPROPION_HCL': 529,
#  'icd:10_diag:N393': 530,
#  'icd:10_diag:Z202': 531,
#  'CLINDAMYCIN_HCL': 532,
#  'icd:10_diag:Z711': 533,
#  'icd:10_diag:R110': 534,
#  'icd:10_diag:R140': 535,
#  'icd:10_diag:F418': 536,
#  'icd:10_diag:F5105': 537,
#  'icd:10_diag:Z566': 538,
#  'PANTOPRAZOLE_SODIUM': 539,
#  'icd:10_diag:M25569': 540,
#  'icd:10_diag:M25562': 541,
#  'icd:10_diag:Z720': 542,
#  'icd:10_diag:Z723': 543,
#  'icd:10_diag:F17200': 544,
#  'icd:10_diag:G8929': 545,
#  'icd:10_diag:R300': 546,
#  'icd:10_diag:E639': 547,
#  'icd:10_diag:A084': 548,
#  'icd:10_diag:R1031': 549,
#  'icd:10_diag:R112': 550,
#  'icd:10_diag:R1030': 551,
#  'icd:10_diag:R1110': 552,
#  'icd:10_diag:S0993XA': 553,
#  'icd:10_diag:G500': 554,
#  'icd:10_diag:F17219': 555,
#  'icd:10_diag:R3915': 556,
#  'TOPIRAMATE': 557,
#  'FLUOXETINE_HCL': 558,
#  'icd:10_diag:R350': 559,
#  'icd:10_diag:Z113': 560,
#  'icd:10_diag:O2342': 561,
#  'icd:10_diag:Z3A14': 562,
#  'icd:10_diag:O209': 563,
#  'icd:10_diag:O364XX0': 564,
#  'icd:10_diag:O3121X0': 565,
#  'icd:10_diag:D573': 566,
#  'icd:10_diag:O034': 567,
#  'icd:10_diag:O132': 568,
#  'icd:10_diag:O364XX1': 569,
#  'icd:10_diag:O99112': 570,
#  'icd:10_diag:Z3A15': 571,
#  'icd:10_diag:Z8249': 572,
#  'icd:10_diag:Z3480': 573,
#  'icd:10_diag:Z3201': 574,
#  'icd:10_diag:Z3481': 575,
#  'icd:10_diag:F1920': 576,
#  'icd:10_diag:Z5181': 577,
#  'icd:10_diag:O323XX1': 578,
#  'icd:10_diag:O4693': 579,
#  'icd:10_diag:O629': 580,
#  'icd:10_diag:Z3A34': 581,
#  'icd:10_diag:Z3A37': 582,
#  'icd:10_diag:O26893': 583,
#  'icd:10_diag:Z3689': 584,
#  'icd:10_diag:Z3A33': 585,
#  'icd:10_diag:O34211': 586,
#  'icd:10_diag:O82': 587,
#  'icd:10.0_proc:10D00Z1': 588,
#  'TRIAMTERENE/HYDROCHLOROTHIAZID': 589,
#  'icd:9.0_diag:7840': 590,
#  'icd:9.0_diag:78906': 591,
#  'icd:9.0_diag:3688': 592,
#  'icd:9.0_diag:V171': 593,
#  'icd:9.0_diag:V7189': 594,
#  'FENOFIBRATE': 595,
#  'icd:10_diag:L03113': 596,
#  'icd:10_diag:Z760': 597,
#  'icd:10_diag:E7801': 598,
#  'icd:10_diag:B349': 599,
#  'icd:10_diag:E860': 600,
#  'icd:10_diag:K2970': 601,
#  'DICYCLOMINE_HCL': 602,
#  'icd:10_diag:J1189': 603,
#  'icd:10_diag:N63': 604,
#  'icd:10_diag:D241': 605,
#  'DOXYCYCLINE_MONOHYDRATE': 606,
#  'icd:10_diag:B9681': 607,
#  'icd:10_diag:Z0001': 608,
#  'icd:10_diag:J0390': 609,
#  'icd:10_diag:J0110': 610,
#  'BROMPHENIRAMINE/PSEUDOEPHED/DM': 611,
#  'icd:10_diag:Z833': 612,
#  'icd:9.0_diag:53550': 613,
#  'icd:9.0_diag:7871': 614,
#  'icd:9.0_diag:7873': 615,
#  'icd:9.0_diag:7934': 616,
#  'icd:9.0_diag:7062': 617,
#  'icd:9.0_diag:53540': 618,
#  'icd:9.0_diag:78909': 619,
#  'icd:9.0_diag:53500': 620,
#  'ONDANSETRON_HCL': 621,
#  'icd:9.0_diag:53510': 622,
#  'icd:9.0_diag:V220': 623,
#  'icd:9.0_diag:64313': 624,
#  'icd:9.0_diag:6202': 625,
#  'icd:9.0_diag:65443': 626,
#  'icd:9.0_diag:V2881': 627,
#  'METOCLOPRAMIDE_HCL': 628,
#  'DOXYLAMINE/PYRIDOXINE_HCL': 629,
#  'icd:9.0_diag:V2889': 630,
#  'HYDROCORTISONE': 631,
#  'icd:9.0_diag:64403': 632,
#  'icd:9.0_diag:64893': 633,
#  'icd:9.0_diag:78900': 634,
#  'icd:9.0_diag:7881': 635,
#  'icd:9.0_diag:65973': 636,
#  'icd:9.0_diag:64963': 637,
#  'icd:9.0_diag:V286': 638,
#  'icd:9.0_diag:V241': 639,
#  'icd:9.0_diag:64301': 640,
#  'icd:9.0_diag:65441': 641,
#  'icd:9.0_diag:65811': 642,
#  'icd:9.0_diag:66331': 643,
#  'icd:9.0_diag:66411': 644,
#  'icd:9.0_diag:78321': 645,
#  'icd:9.0_diag:V270': 646,
#  'icd:9.0_diag:V8521': 647,
#  'icd:9.0_diag:650': 648,
#  'icd:9_proc:7569': 649,
#  'icd:9_diag:37214': 650,
#  'icd:9_diag:4779': 651,
#  'icd:9_diag:4780': 652,
#  'icd:9_diag:70400': 653,
#  'icd:9_diag:71949': 654,
#  'icd:9_diag:72982': 655,
#  'icd:9_diag:38200': 656,
#  'icd:9_diag:5110': 657,
#  'DICLOFENAC_SODIUM': 658,
#  'icd:9_diag:38181': 659,
#  'icd:9_diag:38870': 660,
#  'icd:9_diag:4738': 661,
#  'icd:9_diag:61171': 662,
#  'icd:9_diag:6259': 663,
#  'icd:9_diag:7241': 664,
#  'icd:10_diag:G44209': 665,
#  'icd:10_diag:N8320': 666,
#  'icd:10_diag:S61011A': 667,
#  'icd:10_diag:W458XXA': 668,
#  'icd:10_diag:L738': 669,
#  'icd:10_diag:Q828': 670,
#  'icd:10_diag:D2239': 671,
#  'icd:10_diag:D224': 672,
#  'icd:10_diag:D2262': 673,
#  'icd:10_diag:D2271': 674,
#  'icd:10_diag:J329': 675,
#  'icd:10_diag:J351': 676,
#  'icd:10_diag:R55': 677,
#  'icd:10_diag:M436': 678,
#  'icd:10_diag:G43109': 679,
#  'icd:10_diag:R42': 680,
#  'icd:10_diag:F410': 681,
#  'TRAZODONE_HCL': 682,
#  'icd:10_diag:R922': 683,
#  'IPRATROPIUM_BROMIDE': 684,
#  'ONDANSETRON': 685,
#  'icd:10_diag:H6992': 686,
#  'icd:10_diag:O99519': 687,
#  'icd:10_diag:O09521': 688,
#  'icd:10_diag:O210': 689,
#  'icd:10_diag:Z3A12': 690,
#  'icd:10_diag:Z3482': 691,
#  'icd:10_diag:R7302': 692,
#  'icd:10_diag:Z3685': 693,
#  'icd:10_diag:O09523': 694,
#  'icd:10_diag:Z0374': 695,
#  'icd:10_diag:Z3A39': 696,
#  'icd:10_diag:O99824': 697,
#  'icd:10.0_proc:10907ZC': 698,
#  'icd:10.0_proc:10E0XZZ': 699,
#  'icd:9.0_diag:311': 700,
#  'icd:9.0_diag:V6549': 701,
#  'TADALAFIL': 702,
#  'icd:9.0_diag:7821': 703,
#  'icd:9_diag:79671': 704,
#  'icd:9_diag:9953': 705,
#  'icd:10_diag:Z09': 706,
#  'icd:10_diag:Z86010': 707,
#  'icd:10_diag:F5221': 708,
#  'SILDENAFIL_CITRATE': 709,
#  'icd:10_diag:J342': 710,
#  'AZELASTINE_HCL': 711,
#  'CODEINE_PHOSPHATE/GUAIFENESIN': 712,
#  'icd:10_diag:Z7252': 713,
#  'EMTRICITABINE/TENOFOVIR_(TDF)': 714,
#  'icd:10_diag:Z0189': 715,
#  'icd:10_diag:J322': 716,
#  'icd:10_diag:D2330': 717,
#  'icd:9.0_diag:25003': 718,
#  'MOMETASONE_FUROATE': 719,
#  'NPH__HUMAN_INSULIN_ISOPHANE': 720,
#  'INSULIN_ASPART': 721,
#  'icd:9.0_diag:49300': 722,
#  'PREDNISOLONE_SOD_PHOSPHATE': 723,
#  'icd:9.0_diag:25001': 724,
#  'SYRINGE_&_NEEDLE_INSULIN_1_ML': 725,
#  'icd:9_diag:25080': 726,
#  'icd:9_diag:79021': 727,
#  'icd:9_diag:79029': 728,
#  'icd:9_diag:25003': 729,
#  'URINE_ACETONE_TEST_STRIPS': 730,
#  'INSULIN_NPH_HUMAN_ISOPHANE': 731,
#  'SYR_W-NDL_INS_0.3_ML_HALF_MARK': 732,
#  'icd:9_diag:49390': 733,
#  'icd:9_diag:V5867': 734,
#  'icd:9_diag:25081': 735,
#  'icd:9_diag:2512': 736,
#  'icd:9_diag:25001': 737,
#  'icd:9_diag:37200': 738,
#  'icd:9_diag:V653': 739,
#  'icd:9_diag:V8552': 740,
#  'icd:10_diag:J45909': 741,
#  'icd:10_diag:E109': 742,
#  'BLOOD-GLUCOSE_SENSOR': 743,
#  'BLOOD-GLUCOSE_TRANSMITTER': 744,
#  'BLOOD-GLUCOSE_METER_CONTINUOUS': 745,
#  'icd:10_diag:R0981': 746,
#  'icd:10_diag:R1111': 747,
#  'icd:10_diag:E1065': 748,
#  'icd:10_diag:E139': 749,
#  'SYRGE-NDL_INS_0.3_ML_HALF_MARK': 750,
#  'icd:10_diag:E663': 751,
#  'icd:10_diag:L2082': 752,
#  'icd:10_diag:J00': 753,
#  'icd:10_diag:R1084': 754,
#  'INSULIN_DETEMIR': 755,
#  'icd:10_diag:H00013': 756,
#  'icd:10_diag:H0013': 757,
#  'icd:10_diag:H44001': 758,
#  'icd:10_diag:H1031': 759,
#  'icd:10_diag:Z87898': 760,
#  'icd:10_diag:J45901': 761,
#  'PREDNISOLONE': 762,
#  'icd:10_diag:E10649': 763,
#  'icd:10_diag:E162': 764,
#  'icd:10_diag:K920': 765,
#  'INSULIN_PUMP_CARTRIDGE': 766,
#  'icd:10_diag:J4531': 767,
#  'icd:10_diag:Z7182': 768,
#  'icd:10_diag:Z6853': 769,
#  'icd:9.0_diag:2449': 770,
#  'icd:9.0_diag:2720': 771,
#  'icd:9.0_diag:V7644': 772,
#  'icd:9.0_diag:60000': 773,
#  'CITALOPRAM_HYDROBROMIDE': 774,
#  'icd:9.0_diag:53011': 775,
#  'icd:9.0_diag:79093': 776,
#  'icd:9_diag:2449': 777,
#  'icd:9_diag:2382': 778,
#  'icd:9_diag:79093': 779,
#  'icd:9_diag:2572': 780,
#  'icd:10_diag:E018': 781,
#  'icd:10_diag:E291': 782,
#  'icd:10_diag:N400': 783,
#  'icd:10_diag:E568': 784,
#  'icd:10_diag:M25572': 785,
#  'icd:10_diag:N5314': 786,
#  'icd:10_diag:D3131': 787,
#  'icd:10_diag:M47817': 788,
#  'icd:10_diag:M5136': 789,
#  'icd:10_diag:M25571': 790,
#  'icd:10_diag:M5416': 791,
#  'icd:10_diag:M791': 792,
#  'TAMSULOSIN_HCL': 793,
#  'icd:10_diag:R9720': 794,
#  'icd:10_diag:N401': 795,
#  'icd:10_diag:S61411A': 796,
#  'icd:9.0_diag:4779': 797,
#  'icd:9.0_diag:36803': 798,
#  'icd:9.0_diag:36831': 799,
#  'icd:9.0_diag:74357': 800,
#  'icd:9.0_diag:37841': 801,
#  'icd:9.0_diag:5950': 802,
#  'icd:9.0_diag:78821': 803,
#  'icd:9_diag:36803': 804,
#  'icd:9_diag:36831': 805,
#  'icd:9_diag:36830': 806,
#  'icd:9_diag:37841': 807,
#  'icd:10_diag:B083': 808,
#  'icd:10_diag:H5051': 809,
#  'icd:10_diag:H5334': 810,
#  'icd:10_diag:J45902': 811,
#  'INHALER__ASSIST_DEVICES': 812,
#  'icd:10_diag:H5052': 813,
#  'icd:10_diag:H5330': 814,
#  'icd:10_diag:S0181XA': 815,
#  'icd:10_diag:Z0110': 816,
#  'icd:10_diag:D229': 817,
#  'icd:10_diag:H1044': 818,
#  'icd:10_diag:H47333': 819,
#  'icd:10_diag:Z418': 820,
#  'icd:9.0_diag:V3000': 821,
#  'icd:9.0_diag:V502': 822,
#  'icd:9.0_diag:76719': 823,
#  'icd:9.0_diag:V2031': 824,
#  'icd:9.0_diag:V653': 825,
#  'icd:9.0_diag:78607': 826,
#  'icd:9.0_diag:6929': 827,
#  'BUDESONIDE': 828,
#  'icd:9.0_diag:V1269': 829,
#  'icd:9_diag:V1269': 830,
#  'icd:9_diag:78607': 831,
#  'icd:9_diag:78060': 832,
#  'icd:9_diag:4829': 833,
#  'icd:9_diag:49392': 834,
#  'icd:9_diag:7830': 835,
#  'icd:9_diag:7850': 836,
#  'icd:9_diag:V5869': 837,
#  'icd:9_diag:486': 838,
#  'icd:9_diag:5198': 839,
#  'icd:9_diag:38101': 840,
#  'icd:10_diag:M79672': 841,
#  'icd:10_diag:S99922A': 842,
#  'icd:10_diag:Z792': 843,
#  'icd:10_diag:B354': 844,
#  'GRISEOFULVIN__MICROSIZE': 845,
#  'icd:10_diag:B350': 846,
#  'icd:10_diag:L739': 847,
#  'MUPIROCIN': 848,
#  'icd:10_diag:L309': 849,
#  'ECONAZOLE_NITRATE': 850,
#  'icd:10_diag:R062': 851,
#  'icd:10_diag:L0291': 852,
#  'icd:10_diag:L0390': 853,
#  'icd:10_diag:J398': 854,
#  'icd:10_diag:J4521': 855,
#  'icd:10_diag:Z7722': 856,
#  'icd:10_diag:H6693': 857,
#  'icd:10_diag:L259': 858,
#  'icd:10_diag:J45998': 859,
#  'icd:10_diag:H6993': 860,
#  'icd:10_diag:J343': 861,
#  'icd:10_diag:J3489': 862,
#  'icd:10_diag:R0989': 863,
#  'icd:10_diag:J4530': 864,
#  'icd:10_diag:H66001': 865,
#  'AMLODIPINE/VALSARTAN/HCTHIAZID': 866,
#  'icd:10_diag:R5381': 867,
#  'icd:10_diag:Z6821': 868,
#  'icd:10_diag:Z1321': 869,
#  'icd:10_diag:Z13818': 870,
#  'icd:10_diag:Z139': 871,
#  'icd:10_diag:Z13228': 872,
#  'icd:10_diag:Z136': 873,
#  'icd:10_diag:Z1371': 874,
#  'VALSARTAN/HYDROCHLOROTHIAZIDE': 875,
#  'icd:10_diag:Z1239': 876,
#  'icd:10_diag:Z8742': 877,
#  'icd:10_diag:Z6820': 878,
#  'icd:10_diag:R1013': 879,
#  'icd:10_diag:R718': 880,
#  'TERBINAFINE_HCL': 881,
#  'icd:10_diag:D751': 882,
#  'icd:10_diag:B001': 883,
#  'icd:10_diag:G43909': 884,
#  'icd:10_diag:H8110': 885,
#  'icd:10_diag:K259': 886,
#  'icd:10_diag:L989': 887,
#  'icd:10_diag:N289': 888,
#  'icd:10_diag:Z87440': 889,
#  'icd:10_diag:E1169': 890,
#  'icd:10_diag:F17218': 891,
#  'icd:10_diag:M1009': 892,
#  'icd:10_diag:M189': 893,
#  'icd:10_diag:R7303': 894,
#  'icd:10_diag:Z780': 895,
#  'LOSARTAN/HYDROCHLOROTHIAZIDE': 896,
#  'icd:10_diag:M19041': 897,
#  'icd:10_diag:M19042': 898,
#  'icd:10_diag:M19031': 899,
#  'icd:10_diag:M19032': 900,
#  'icd:10_diag:M79631': 901,
#  'icd:10_diag:M79641': 902,
#  'icd:10_diag:M1811': 903,
#  'icd:10_diag:M1711': 904,
#  'icd:10_diag:Z9189': 905,
#  'icd:10_diag:Z13820': 906,
#  'icd:10_diag:B373': 907,
#  'CLOTRIMAZOLE/BETAMETHASONE_DIP': 908,
#  'icd:10_diag:H16291': 909,
#  'icd:10_diag:H25813': 910,
#  'NEOMYCIN/POLYMYXIN_B/DEXAMETHA': 911,
#  'icd:10_diag:H52223': 912,
#  'VALSARTAN': 913,
#  'icd:9.0_diag:2168': 914,
#  'icd:9.0_diag:69274': 915,
#  'icd:9.0_diag:70219': 916,
#  'icd:9.0_diag:V1083': 917,
#  'icd:9.0_diag:7175': 918,
#  'icd:9.0_diag:7851': 919,
#  'icd:9.0_diag:79029': 920,
#  'icd:9.0_diag:32723': 921,
#  'icd:9.0_diag:7177': 922,
#  'icd:9.0_diag:78057': 923,
#  'icd:9.0_diag:8360': 924,
#  'icd:9.0_diag:V5866': 925,
#  'icd:9.0_diag:71740': 926,
#  'icd:9.0_diag:8362': 927,
#  'icd:9.0_diag:V5878': 928,
#  'icd:9.0_diag:41519': 929,
#  'icd:9.0_diag:486': 930,
#  'icd:9.0_diag:34620': 931,
#  'icd:9.0_diag:4264': 932,
#  'icd:9.0_diag:45342': 933,
#  'icd:9.0_diag:78053': 934,
#  'icd:9.0_diag:79431': 935,
#  'icd:9.0_diag:4536': 936,
#  'RIVAROXABAN': 937,
#  'icd:9.0_diag:7020': 938,
#  'icd:9_diag:2168': 939,
#  'icd:9_diag:7020': 940,
#  'icd:9_diag:70219': 941,
#  'icd:9_diag:7099': 942,
#  'icd:9_diag:V1083': 943,
#  'icd:9_diag:32723': 944,
#  'icd:9_diag:V7644': 945,
#  'icd:10_diag:D122': 946,
#  'icd:10_diag:D128': 947,
#  'icd:10_diag:Z800': 948,
#  'icd:10_diag:E780': 949,
#  'icd:10_diag:G4730': 950,
#  'icd:10_diag:K621': 951,
#  'icd:10_diag:Z86711': 952,
#  'icd:10_diag:D225': 953,
#  'icd:10_diag:L579': 954,
#  'icd:10_diag:L821': 955,
#  'icd:10_diag:Z85828': 956,
#  'icd:10_diag:E6609': 957,
#  'icd:10_diag:R739': 958,
#  'icd:10_diag:M1990': 959,
#  'MELOXICAM': 960,
#  'icd:10_diag:Z6834': 961,
#  'icd:10_diag:D2272': 962,
#  'icd:10_diag:Z6835': 963,
#  'icd:10_diag:L570': 964,
#  'icd:10_diag:L820': 965,
#  'icd:10_diag:X32XXXS': 966,
#  'IRBESARTAN': 967,
#  'icd:10_diag:C44222': 968,
#  'icd:10_diag:C44229': 969,
#  'icd:10_diag:M25551': 970,
#  'icd:10_diag:M25552': 971,
#  'icd:10_diag:M25561': 972,
#  'icd:10_diag:M1611': 973,
#  'LEVONORGESTREL-ETH_ESTRADIOL': 974,
#  'icd:9.0_diag:8483': 975,
#  'icd:9.0_diag:33819': 976,
#  'icd:9.0_diag:71947': 977,
#  'LEVONORGESTREL-ETHIN_ESTRADIOL': 978,
#  'icd:9.0_diag:84500': 979,
#  'icd:9.0_diag:E9289': 980,
#  'icd:9.0_diag:7392': 981,
#  'icd:9.0_diag:8471': 982,
#  'icd:9_diag:71947': 983,
#  'icd:9_diag:8470': 984,
#  'icd:9_diag:8471': 985,
#  'icd:9_diag:72672': 986,
#  'icd:9_diag:72709': 987,
#  'icd:9_diag:71946': 988,
#  'icd:9_diag:71906': 989,
#  'icd:9_diag:78096': 990,
#  'icd:9_diag:79095': 991,
#  'icd:9_diag:6960': 992,
#  'SULFASALAZINE': 993,
#  'CELECOXIB': 994,
#  'icd:10_diag:H6121': 995,
#  'TOBRAMYCIN': 996,
#  'icd:10_diag:H20011': 997,
#  'DIFLUPREDNATE': 998,
#  'icd:10_diag:L4050': 999,
#  ...}

# %%
dataset = LineByLineTextDataset(tokenizer=tokenizer, data_type='merged', max_length=max_length)

# %%
mlm_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=True, mlm_probability=0.15, )

# %%
from transformers import BertConfig
config = BertConfig(vocab_size=len(tokenizer), max_position_embeddings=max_length,
                    num_attention_heads=4,
                    num_hidden_layers=4,
                    hidden_size=128,
                    type_vocab_size=1, )

# %%
model = BertForMaskedLM(config=config)

# %%
model.num_parameters()

# %%
training_args = TrainingArguments(output_dir='./result-dev/MLM', overwrite_output_dir=True,
                              num_train_epochs=1,
                              per_device_train_batch_size=bsz,
                              save_steps=10_000,)

# %%
trainer = Trainer(model=model,
                  args=training_args,
                  data_collator=mlm_collator,
                  train_dataset=dataset,
                  prediction_loss_only=True, )

# %%
dataloader = trainer.get_train_dataloader()

# %%
trainer.train()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Epoch', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Iteration', max=31284.0, style=ProgressStyle(description_…
# /home/liutianc/.local/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:61: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/liutianc/.local/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:200: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)

# %%
for data in dataloader:
    print(data)
    break

# %%
data['labels'].shape
