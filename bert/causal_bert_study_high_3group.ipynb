# %%
import os
import time

import numpy as np
import torch
import pandas as pd
import random
from torch.distributions.binomial import Binomial
from torch.distributions.bernoulli import Bernoulli
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader 
from torch.nn.utils import clip_grad_norm_

from transformers import DataCollatorForLanguageModeling, BertModel
from transformers import Trainer, TrainingArguments
from transformers import get_linear_schedule_with_warmup, AdamW

from tokens import WordLevelBertTokenizer
from vocab import create_vocab
from data import CausalBertDataset, MLMDataset
from causal_bert import CausalBert

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '6'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def true_casual_effect(data_loader, effect='ate', estimation='Q'):
    dataset = data_loader.dataset
    
    Q1 = dataset.treatment * dataset.response + (1 - dataset.treatment) * dataset.pseudo_response
    Q1 = Q1.cpu().data.numpy().squeeze()

    Q0 = dataset.treatment * dataset.pseudo_response + (1 - dataset.treatment) * dataset.response
    Q0 = Q0.cpu().data.numpy().squeeze()

    treatment = dataset.treatment.cpu().data.numpy().squeeze()
    prop_scores = dataset.prop_score.cpu().data.numpy().squeeze()
    
    if estimation == 'q':
        if effect == 'att':
            phi = (treatment * (Q1 - Q0))
            return phi.sum() / treatment.sum()
        elif effect == 'ate':
            return (Q1 - Q0).mean()
        
    elif estimation == 'plugin':
        phi = (prop_scores * (Q1 - Q0)).mean()
        if effect == 'att':
            return phi / treatment.mean()
        elif effect == 'ate': 
            return phi

def est_casual_effect(data_loader, model, effect='ate', estimation='Q'):
    # We use `real_treatment` here to emphasize the estimations use real instead of estimated treatment.
    real_response, real_treatment = [], []
    prop_scores, Q1, Q0 = [], [], []

    model.eval()
    with torch.no_grad():
        for idx, (tokens, treatment, response) in enumerate(data_loader):
            real_response.append(response.cpu().data.numpy().squeeze())
            real_treatment.append(treatment.cpu().data.numpy().squeeze())

            prop_score, q1, q0 = model(tokens)

            prop_scores.append(prop_score.cpu().data.numpy().squeeze())
            Q1.append(q1.cpu().data.numpy().squeeze())
            Q0.append(q0.cpu().data.numpy().squeeze())

        real_response = np.concatenate(real_response, axis=0)
        real_treatment = np.concatenate(real_treatment, axis=0)

        Q1 = np.concatenate(Q1, axis=0)
        Q0 = np.concatenate(Q0, axis=0)
        prop_scores = np.concatenate(prop_scores, axis=0)
    
    model.train()
    
    if estimation == 'q':
        if effect == 'att':
            phi = (real_treatment * (Q1 - Q0))
            return phi.sum() / real_treatment.sum()            
        elif effect == 'ate':
            return (Q1 - Q0).mean()
        
    elif estimation == 'plugin':
        phi = (prop_scores * (Q1 - Q0)).mean()
        if effect == 'att':
            return phi / real_treatment.mean()
        elif effect == 'ate':
            return phi

# %% [markdown]
# # Prepare data

# %%
vocab = create_vocab(merged=True, uni_diag=True)

tokenizer = WordLevelBertTokenizer(vocab)

alpha = 0.75
beta = 1.
c = 0.5
i = 0

# %%
start = time.time()
trainset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                             alpha=alpha, beta=beta, c=c, i=i, 
                             group=list(range(3)), max_length=512, min_length=10,
                             truncate_method='first', device=device)

print(f'Load training set in {(time.time() - start):.2f} sec')
# Out:
# Load training set in 220.47 sec

# %%
start = time.time()
testset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                            alpha=alpha, beta=beta, c=c, i=i, 
                            group=[9], max_length=512, min_length=10,
                            truncate_method='first', device=device)

print(f'Load training set in {(time.time() - start):.2f} sec')
# Out:
# Load training set in 56.26 sec

# %%
train_loader = DataLoader(trainset, batch_size=20, drop_last=True, shuffle=True)
test_loader = DataLoader(testset, batch_size=20, drop_last=True, shuffle=True)

# %% [markdown]
# # Create and train a Causal-Bert

# %%
trained_bert = '/nfs/turbo/lsa-regier/bert-results/results/behrt/MLM/merged/unidiag/checkpoint-4574003/'
bert = BertModel.from_pretrained(trained_bert).to(device)
model = CausalBert(bert, learnable_docu_embed=False, hidden_size=64).to(device)

epoch = 5
epoch_iter = len(train_loader)
total_steps = epoch * epoch_iter
optimizer = AdamW(model.parameters(),
                  lr = 2e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )

scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)

# optimizer = torch.optim.Adam(causal_bert.parameters(), lr=5e-5)

q_loss = nn.BCELoss()
prop_score_loss = nn.BCELoss()

# Please specify the effect and estimation we want to use here.
effect = 'ate'
estimation = 'Q'

effect = effect.lower()
estimation = estimation.lower()
assert effect in ['att', 'ate'], f'Wrong effect: {effect}...'
assert estimation in ['q', 'plugin'], f'Wrong estimation: {estimation}...'

# %%
real_att_q = true_casual_effect(test_loader, effect, estimation)
est_att_q = est_casual_effect(test_loader, causal_bert, effect, estimation)

print(f'Real: [effect: {effect}], [estimation: {estimation}], [value: {real_att_q:.5f}]')
print(f'Estimated: [effect: {effect}], [estimation: {estimation}], [value: {est_att_q:.5f}]')
# Out:
# Real: [effect: ate], [estimation: q], [value: 0.18590]
# Estimated: [effect: ate], [estimation: q], [value: 0.77961]

# %%
for e in range(1, epoch + 1):
    model.train()
    start = time.time()
    
    rg_loss, rq1_loss, rq0_loss = [], [], []
    for idx, (tokens, treatment, response) in enumerate(train_loader):
        optimizer.zero_grad()
        prop_score, q1, q0 = model(tokens)
        
        g_loss  = prop_score_loss(prop_score, treatment)
        rg_loss.append(g_loss.item())

        g_loss.backward(retain_graph=True)
        
        if len(response[treatment == 1]) > 0:
            q1_loss = q_loss(q1[treatment==1], response[treatment==1])
            rq1_loss.append(q1_loss.item())
            
            q1_loss.backward(retain_graph=True)

        if len(response[treatment == 0]) > 0:
            q0_loss = q_loss(q0[treatment==0], response[treatment==0])
            rq0_loss.append(q0_loss.item())
            
            q0_loss.backward()
        
        torch.nn.utils.clip_grad_norm_(causal_bert.parameters(), 1.0)    
            
        optimizer.step()
        scheduler.step()
        
        if not idx % 2000 and idx > 0: 
            rg_loss = np.array(rg_loss)
            rq1_loss = np.array(rq1_loss)
            rq0_loss = np.array(rq0_loss)

            print(f'''epoch: {e}/{epoch}, iteration: {idx + 1}/{epoch_iter}, time: {(time.time() - start):.2f} sec, 
                  g_loss: {(rg_loss.mean()) :.5f}, q1_loss: {(rq1_loss.mean()):.5f}/{rq1_loss.shape[0]}, q0_loss: {(rq0_loss.mean()) :.5f}/{rq0_loss.shape[0]}, 
                  ''')
            rg_loss, rq1_loss, rq0_loss = [], [], []

    run_idx = idx
    
    # Evaluation.
#     train_est_att_q = est_casual_effect(train_loader, causal_bert, effect, estimation)
    test_est_att_q = est_casual_effect(test_loader, model, effect, estimation)
    print(f'''epoch: {e} / {epoch}, 
          time cost: {(time.time() - start):.2f} sec,
          Testing set effect: [effect: {effect}], [estimation: {estimation}], [value: {test_est_att_q:.5f}]''')
    start = time.time()

print('Finish training...')

# With only 3 groups to train.
# Out:
# epoch: 1/5, iteration: 2001/28859, time: 607.86 sec,
#                   g_loss: 23.85582, q1_loss: 1.94897/1995, q0_loss: 1.85235/2001,
#
# epoch: 1/5, iteration: 4001/28859, time: 1227.68 sec,
#                   g_loss: 23.60750, q1_loss: 0.78999/1992, q0_loss: 0.74502/2000,
#
# epoch: 1/5, iteration: 6001/28859, time: 1846.23 sec,
#                   g_loss: 24.03500, q1_loss: 0.72872/1991, q0_loss: 0.72491/2000,
#
# epoch: 1/5, iteration: 8001/28859, time: 2472.44 sec,
#                   g_loss: 23.69500, q1_loss: 0.72984/1996, q0_loss: 0.70803/2000,
#
# epoch: 1/5, iteration: 10001/28859, time: 3102.43 sec,
#                   g_loss: 24.03500, q1_loss: 0.72619/1991, q0_loss: 0.70184/2000,
#
# epoch: 1/5, iteration: 12001/28859, time: 3723.87 sec,
#                   g_loss: 23.48750, q1_loss: 0.73026/1996, q0_loss: 0.69985/2000,
#
# epoch: 1/5, iteration: 14001/28859, time: 4345.06 sec,
#                   g_loss: 23.54750, q1_loss: 0.69226/1993, q0_loss: 0.69686/2000,
#
# epoch: 1/5, iteration: 16001/28859, time: 4963.98 sec,
#                   g_loss: 23.56250, q1_loss: 0.68133/1987, q0_loss: 0.69242/2000,
#
# epoch: 1/5, iteration: 18001/28859, time: 5583.97 sec,
#                   g_loss: 23.89000, q1_loss: 0.66782/1989, q0_loss: 0.72118/2000,
#
# epoch: 1/5, iteration: 20001/28859, time: 6200.41 sec,
#                   g_loss: 24.14000, q1_loss: 0.66347/1990, q0_loss: 0.70688/2000,
#
# epoch: 1/5, iteration: 22001/28859, time: 6820.39 sec,
#                   g_loss: 23.18750, q1_loss: 0.67167/1993, q0_loss: 0.69453/2000,
#
# epoch: 1/5, iteration: 24001/28859, time: 7441.26 sec,
#                   g_loss: 23.79750, q1_loss: 0.65985/1990, q0_loss: 0.69774/2000,
#
# epoch: 1/5, iteration: 26001/28859, time: 8062.18 sec,
#                   g_loss: 24.12250, q1_loss: 0.65643/1995, q0_loss: 0.69682/2000,
#
# epoch: 1/5, iteration: 28001/28859, time: 8683.99 sec,
#                   g_loss: 23.68500, q1_loss: 0.65621/1987, q0_loss: 0.69475/2000,
#
# epoch: 1 / 5,
#           time cost: 9374.78 sec,
#           Testing set effect: [effect: ate], [estimation: q], [value: 0.15093]
# epoch: 2/5, iteration: 2001/28859, time: 616.51 sec,
#                   g_loss: 24.01549, q1_loss: 0.66022/1995, q0_loss: 0.68636/2001,
#
# epoch: 2/5, iteration: 4001/28859, time: 1238.16 sec,
#                   g_loss: 23.93250, q1_loss: 0.65377/1990, q0_loss: 0.68810/2000,
#
# epoch: 2/5, iteration: 6001/28859, time: 1860.29 sec,
#                   g_loss: 23.59250, q1_loss: 0.66465/1989, q0_loss: 0.69150/2000,
#
# epoch: 2/5, iteration: 8001/28859, time: 2485.31 sec,
#                   g_loss: 24.06000, q1_loss: 0.65980/1992, q0_loss: 0.68646/2000,
#
# epoch: 2/5, iteration: 10001/28859, time: 3108.52 sec,
#                   g_loss: 23.92250, q1_loss: 0.67216/1995, q0_loss: 0.68499/2000,
#
# epoch: 2/5, iteration: 12001/28859, time: 3716.32 sec,
#                   g_loss: 23.51750, q1_loss: 0.67199/1987, q0_loss: 0.68445/2000,
#
# epoch: 2/5, iteration: 14001/28859, time: 4337.07 sec,
#                   g_loss: 23.55500, q1_loss: 0.66987/1986, q0_loss: 0.68359/2000,
#
# epoch: 2/5, iteration: 16001/28859, time: 4958.12 sec,
#                   g_loss: 23.83500, q1_loss: 0.67009/1992, q0_loss: 0.68488/2000,
#
# epoch: 2/5, iteration: 18001/28859, time: 5584.73 sec,
#                   g_loss: 23.48000, q1_loss: 0.69375/1990, q0_loss: 0.68536/2000,
#
# epoch: 2/5, iteration: 20001/28859, time: 6208.12 sec,
#                   g_loss: 23.76250, q1_loss: 0.70150/1994, q0_loss: 0.68300/2000,
#
# epoch: 2/5, iteration: 22001/28859, time: 6828.37 sec,
#                   g_loss: 23.72750, q1_loss: 0.70425/1992, q0_loss: 0.68266/2000,
#
# epoch: 2/5, iteration: 24001/28859, time: 7448.39 sec,
#                   g_loss: 23.93750, q1_loss: 0.70890/1991, q0_loss: 0.68225/2000,
#
# epoch: 2/5, iteration: 26001/28859, time: 8068.84 sec,
#                   g_loss: 23.40750, q1_loss: 0.70468/1991, q0_loss: 0.68083/2000,
#
# epoch: 2/5, iteration: 28001/28859, time: 8690.14 sec,
#                   g_loss: 23.70500, q1_loss: 0.70166/1993, q0_loss: 0.68285/2000,
#
# epoch: 2 / 5,
#           time cost: 9380.83 sec,
#           Testing set effect: [effect: ate], [estimation: q], [value: 0.14662]
# epoch: 3/5, iteration: 2001/28859, time: 620.58 sec,
#                   g_loss: 23.86307, q1_loss: 0.69849/1995, q0_loss: 0.68215/2001,
#
# epoch: 3/5, iteration: 4001/28859, time: 1240.33 sec,
#                   g_loss: 23.74250, q1_loss: 0.70185/1987, q0_loss: 0.68332/2000,
#
# epoch: 3/5, iteration: 6001/28859, time: 1865.32 sec,
#                   g_loss: 24.05250, q1_loss: 0.69264/1988, q0_loss: 0.68216/2000,
#
# epoch: 3/5, iteration: 8001/28859, time: 2484.88 sec,
#                   g_loss: 24.00250, q1_loss: 0.69089/1986, q0_loss: 0.68319/2000,
#
# epoch: 3/5, iteration: 10001/28859, time: 3113.08 sec,
#                   g_loss: 24.12750, q1_loss: 0.69102/1993, q0_loss: 0.68323/2000,
#
# epoch: 3/5, iteration: 12001/28859, time: 3747.35 sec,
#                   g_loss: 23.36250, q1_loss: 0.68934/1990, q0_loss: 0.68305/2000,
#
# epoch: 3/5, iteration: 14001/28859, time: 4368.27 sec,
#                   g_loss: 23.88750, q1_loss: 0.69038/1985, q0_loss: 0.68334/2000,
#
# epoch: 3/5, iteration: 16001/28859, time: 4995.35 sec,
#                   g_loss: 23.80750, q1_loss: 0.69365/1985, q0_loss: 0.68220/2000,
#
# epoch: 3/5, iteration: 18001/28859, time: 5615.72 sec,
#                   g_loss: 23.72750, q1_loss: 0.68048/1994, q0_loss: 0.68308/2000,
#
# epoch: 3/5, iteration: 20001/28859, time: 6239.11 sec,
#                   g_loss: 23.96750, q1_loss: 0.67685/1987, q0_loss: 0.68338/2000,
#
# epoch: 3/5, iteration: 22001/28859, time: 6859.67 sec,
#                   g_loss: 23.23750, q1_loss: 0.67176/1993, q0_loss: 0.68304/2000,
#
# epoch: 3/5, iteration: 24001/28859, time: 7480.52 sec,
#                   g_loss: 23.79250, q1_loss: 0.68741/1996, q0_loss: 0.68317/2000,
#
# epoch: 3/5, iteration: 26001/28859, time: 8112.28 sec,
#                   g_loss: 23.72750, q1_loss: 0.68312/1991, q0_loss: 0.68313/2000,
#
# epoch: 3/5, iteration: 28001/28859, time: 8734.18 sec,
#                   g_loss: 23.50250, q1_loss: 0.68935/1988, q0_loss: 0.68176/2000,
#
# epoch: 3 / 5,
#           time cost: 9424.49 sec,
#           Testing set effect: [effect: ate], [estimation: q], [value: 0.18130]
# epoch: 4/5, iteration: 2001/28859, time: 609.85 sec,
#                   g_loss: 23.88306, q1_loss: 0.69452/1994, q0_loss: 0.68321/2001,
#
# epoch: 4/5, iteration: 4001/28859, time: 1227.46 sec,
#                   g_loss: 23.65250, q1_loss: 0.68980/1991, q0_loss: 0.68336/2000,
#
# epoch: 4/5, iteration: 6001/28859, time: 1856.70 sec,
#                   g_loss: 23.69750, q1_loss: 0.68633/1993, q0_loss: 0.68199/2000,
#
# epoch: 4/5, iteration: 8001/28859, time: 2482.88 sec,
#                   g_loss: 24.05500, q1_loss: 0.68472/1992, q0_loss: 0.68045/2000,
#
# epoch: 4/5, iteration: 10001/28859, time: 3106.27 sec,
#                   g_loss: 23.70250, q1_loss: 0.68899/1992, q0_loss: 0.68183/2000,
#
# epoch: 4/5, iteration: 12001/28859, time: 3726.53 sec,
#                   g_loss: 23.81750, q1_loss: 0.69546/1991, q0_loss: 0.68402/2000,
#
# epoch: 4/5, iteration: 14001/28859, time: 4346.98 sec,
#                   g_loss: 23.76000, q1_loss: 0.69003/1993, q0_loss: 0.68323/2000,
#
# epoch: 4/5, iteration: 16001/28859, time: 4967.36 sec,
#                   g_loss: 23.34500, q1_loss: 0.68451/1990, q0_loss: 0.68355/2000,
#
# epoch: 4/5, iteration: 18001/28859, time: 5587.41 sec,
#                   g_loss: 23.69000, q1_loss: 0.69238/1990, q0_loss: 0.68304/2000,
#
# epoch: 4/5, iteration: 20001/28859, time: 6211.85 sec,
#                   g_loss: 23.88250, q1_loss: 0.69486/1989, q0_loss: 0.68296/2000,
#
# epoch: 4/5, iteration: 22001/28859, time: 6832.11 sec,
#                   g_loss: 23.92750, q1_loss: 0.67812/1989, q0_loss: 0.68124/2000,
#
# epoch: 4/5, iteration: 24001/28859, time: 7456.53 sec,
#                   g_loss: 23.87250, q1_loss: 0.69240/1993, q0_loss: 0.68317/2000,
#
# epoch: 4/5, iteration: 26001/28859, time: 8078.15 sec,
#                   g_loss: 23.50000, q1_loss: 0.68332/1989, q0_loss: 0.68257/2000,
#
# epoch: 4/5, iteration: 28001/28859, time: 8704.65 sec,
#                   g_loss: 23.95750, q1_loss: 0.68675/1989, q0_loss: 0.68285/2000,
#
# epoch: 4 / 5,
#           time cost: 9395.18 sec,
#           Testing set effect: [effect: ate], [estimation: q], [value: 0.16713]
# epoch: 5/5, iteration: 2001/28859, time: 611.18 sec,
#                   g_loss: 23.68316, q1_loss: 0.70309/1990, q0_loss: 0.68157/2001,
#
# epoch: 5/5, iteration: 4001/28859, time: 1228.78 sec,
#                   g_loss: 23.78500, q1_loss: 0.68835/1989, q0_loss: 0.68179/2000,
#
# epoch: 5/5, iteration: 6001/28859, time: 1858.94 sec,
#                   g_loss: 23.95250, q1_loss: 0.68090/1987, q0_loss: 0.68163/2000,
#
# epoch: 5/5, iteration: 8001/28859, time: 2478.99 sec,
#                   g_loss: 23.60750, q1_loss: 0.68370/1991, q0_loss: 0.68312/2000,
#
# epoch: 5/5, iteration: 10001/28859, time: 3097.94 sec,
#                   g_loss: 23.87250, q1_loss: 0.67278/1995, q0_loss: 0.68388/2000,
#
# epoch: 5/5, iteration: 12001/28859, time: 3723.87 sec,
#                   g_loss: 23.74500, q1_loss: 0.68495/1990, q0_loss: 0.68347/2000,
#
# epoch: 5/5, iteration: 14001/28859, time: 4342.32 sec,
#                   g_loss: 24.09750, q1_loss: 0.69346/1992, q0_loss: 0.68231/2000,
#
# epoch: 5/5, iteration: 16001/28859, time: 4960.54 sec,
#                   g_loss: 23.60500, q1_loss: 0.69098/1994, q0_loss: 0.68103/2000,
#
# epoch: 5/5, iteration: 18001/28859, time: 5578.72 sec,
#                   g_loss: 23.86750, q1_loss: 0.69177/1990, q0_loss: 0.68247/2000,
#
# epoch: 5/5, iteration: 20001/28859, time: 6199.09 sec,
#                   g_loss: 23.73000, q1_loss: 0.69299/1991, q0_loss: 0.68244/2000,
#
# epoch: 5/5, iteration: 22001/28859, time: 6818.20 sec,
#                   g_loss: 23.79250, q1_loss: 0.69205/1996, q0_loss: 0.68210/2000,
#
# epoch: 5/5, iteration: 24001/28859, time: 7441.56 sec,
#                   g_loss: 23.65500, q1_loss: 0.69188/1992, q0_loss: 0.68183/2000,
#
# epoch: 5/5, iteration: 26001/28859, time: 8059.16 sec,
#                   g_loss: 23.55500, q1_loss: 0.69075/1989, q0_loss: 0.68109/2000,
#
# epoch: 5/5, iteration: 28001/28859, time: 8677.43 sec,
#                   g_loss: 23.59000, q1_loss: 0.69765/1990, q0_loss: 0.68076/2000,
#
# epoch: 5 / 5,
#           time cost: 9367.67 sec,
#           Testing set effect: [effect: ate], [estimation: q], [value: 0.19717]
# Finish training...

# %%
train_est_att_q = est_casual_effect(train_loader, causal_bert, effect, estimation)
test_est_att_q = est_casual_effect(test_loader, causal_bert, effect, estimation)
print(f'''epoch: {e} / {epoch}, 
      time cost: {(time.time() - start):.2f} sec,
      Trainning set effect: [effect: {effect}], [estimation: {estimation}], [value: {train_est_att_q:.5f}],
      Testing set effect: [effect: {effect}], [estimation: {estimation}], [value: {test_est_att_q:.5f}]''')
# Out:
# epoch: 5 / 5,
#       time cost: 2872.02 sec,
#       Trainning set effect: [effect: ate], [estimation: q], [value: 0.19705],
#       Testing set effect: [effect: ate], [estimation: q], [value: 0.19716]

# %%
train_est = est_casual_effect(train_loader, causal_bert, effect, 'plugin')
test_est = est_casual_effect(test_loader, causal_bert, effect, 'plugin')
print(f'''epoch: {e} / {epoch}, 
      time cost: {(time.time() - start):.2f} sec,
      Trainning set effect: [effect: {effect}], [estimation: 'plugin'], [value: {train_est:.5f}],
      Testing set effect: [effect: {effect}], [estimation: 'plugin'], [value: {test_est:.5f}]''')

# %%
# train_est_att_q = est_casual_effect(train_loader, causal_bert, effect, 'plugin')
test_est = est_casual_effect(test_loader, causal_bert, effect, 'plugin')
print(f'''epoch: {e} / {epoch}, 
      time cost: {(time.time() - start):.2f} sec,
      Testing set effect: [effect: {effect}], [estimation: plugin], [value: {test_est:.5f}]''')
# Out:
# epoch: 5 / 5,
#       time cost: 745.45 sec,
#       Testing set effect: [effect: ate], [estimation: q], [value: 0.00000]
