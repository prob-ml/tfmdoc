# %%
import os
import time
import random
import math

import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt

from torch.distributions.binomial import Binomial
from torch.distributions.bernoulli import Bernoulli
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader 

from transformers import DataCollatorForLanguageModeling, BertForMaskedLM
from transformers import Trainer, TrainingArguments
from transformers import get_linear_schedule_with_warmup, AdamW

from causal_bert import load_data, load_model
from causal_bert import true_casual_effect, est_casual_effect, show_result

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '7'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
effect = 'ate'
estimation = 'q'

effect = effect.lower()
estimation = estimation.lower()
assert effect in ['att', 'ate'], f'Wrong effect: {effect}...'
assert estimation in ['q', 'plugin'], f'Wrong estimation: {estimation}...'

# %%
bsz = 256
epoch = 50
hidden_size = 64
lr = 5e-6

# %%
alpha = 0.75
beta = 25.
c = 0.2
i = 0.

train_loader, test_loader = load_data(alpha, beta, c, i, bsz, device=device)

# %%
real_att_q = true_casual_effect(test_loader)

print(f'Real: [effect: ate], [estimation: q], [value: {real_att_q:.5f}]')
print(f'Unadjusted: [value: {(test_loader.dataset.response[test_loader.dataset.treatment == 1].mean() - test_loader.dataset.response[test_loader.dataset.treatment == 0].mean()).item():.4f}]')

# %%
model = load_model(model='bow', hidden_size=hidden_size, device=device)

pos_portion = train_loader.dataset.treatment.mean()
pos_weight = (1 - pos_portion) / pos_portion

epoch_iter = len(train_loader)
total_steps = epoch * epoch_iter

# optimizer = torch.optim.Adam(model.parameters(), lr=lr)
optimizer = AdamW(model.parameters(), lr=lr, eps=1e-8)

q_loss = nn.BCELoss()
prop_score_loss = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# %%
train_loss_hist_p, train_loss_hist_q1, train_loss_hist_q0 = [], [], []
test_loss_hist_p, test_loss_hist_q1, test_loss_hist_q0 = [], [], []
est_effect, prop_score_hist = [], []

for e in range(1, epoch + 1):
    model.train()
    start = time.time()
        
    p_loss_train, q1_loss_train, q0_loss_train  = [], [], []
    for idx, (tokens, treatment, response, _) in enumerate(train_loader):
        optimizer.zero_grad()
        prop_score, q1, q0 = model(tokens)
        
        loss_p = prop_score_loss(prop_score, treatment)
        loss = loss_p
        
        p_loss_train.append(loss_p.item())
        if len(response[treatment == 1]) > 0:
            loss_q1 = q_loss(q1[treatment==1], response[treatment==1])
            loss += loss_q1
            q1_loss_train.append(loss_q1.item())
            
        if len(response[treatment == 0]) > 0:
            loss_q0 = q_loss(q0[treatment==0], response[treatment==0])
            loss += loss_q0
            q0_loss_train.append(loss_q0.item())
                        
        loss.backward()
        optimizer.step()

    run_idx = idx

    # Evaluation.
    p_loss_train = np.array(p_loss_train).mean()
    q1_loss_train = np.array(q1_loss_train).mean()
    q0_loss_train = np.array(q0_loss_train).mean()
    
    train_effect, _, _, _, _, _, _ = est_casual_effect(train_loader, model, effect, estimation, evaluate=False)
    test_effect, p_loss_test, q1_loss_test, q0_loss_test, prop_accu_test, q1_accu_test, q0_accu_test = est_casual_effect(test_loader, model, effect, estimation, evaluate=True, g_loss=prop_score_loss, q_loss=q_loss)
    
    train_loss_hist_p.append(p_loss_train)
    train_loss_hist_q1.append(q1_loss_train)
    train_loss_hist_q0.append(q0_loss_train)
    
    test_loss_hist_p.append(p_loss_test)
    test_loss_hist_q1.append(q1_loss_test)
    test_loss_hist_q0.append(q0_loss_test)

    est_effect.append(test_effect)
    
    
    print(f'''epoch: {e} / {epoch}, time cost: {(time.time() - start):.2f} sec, 
          Loss: [Train: p = {p_loss_train:.5f}, q = {(q1_loss_train + q0_loss_train):.5f}], 
          Loss: [Test: p = {p_loss_test:.5f}, q = {(q1_loss_test + q0_loss_test):.5f}],
          Effect: [{effect}-{estimation}], [train: {train_effect:.5f}], [test: {test_effect:.5f}]''')
    print('*'* 80)
    start = time.time()

train_loss_hist = dict(p=train_loss_hist_p, q1=train_loss_hist_q1, q0=train_loss_hist_q1)
test_loss_hist = dict(p=test_loss_hist_p, q1=test_loss_hist_q1, q0=test_loss_hist_q0)

print('Finish training...')
# Out:
# epoch: 1 / 50, time cost: 36.41 sec,
#           Loss: [Train: p = 1.05687, q = 1.34656],
#           Loss: [Test: p = 1.06013, q = 1.33412],
#           Effect: [ate-q], [train: 0.07516], [test: 0.07516]
# ********************************************************************************
# epoch: 2 / 50, time cost: 39.70 sec,
#           Loss: [Train: p = 1.05657, q = 1.33196],
#           Loss: [Test: p = 1.05987, q = 1.31335],
#           Effect: [ate-q], [train: 0.10532], [test: 0.10533]
# ********************************************************************************
# epoch: 3 / 50, time cost: 39.88 sec,
#           Loss: [Train: p = 1.05618, q = 1.32333],
#           Loss: [Test: p = 1.05965, q = 1.30002],
#           Effect: [ate-q], [train: 0.12832], [test: 0.12833]
# ********************************************************************************
# epoch: 4 / 50, time cost: 41.28 sec,
#           Loss: [Train: p = 1.05613, q = 1.32123],
#           Loss: [Test: p = 1.05951, q = 1.29521],
#           Effect: [ate-q], [train: 0.13678], [test: 0.13680]
# ********************************************************************************
# epoch: 5 / 50, time cost: 39.31 sec,
#           Loss: [Train: p = 1.05593, q = 1.32086],
#           Loss: [Test: p = 1.05932, q = 1.29408],
#           Effect: [ate-q], [train: 0.13919], [test: 0.13920]
# ********************************************************************************
# epoch: 6 / 50, time cost: 39.97 sec,
#           Loss: [Train: p = 1.05572, q = 1.32067],
#           Loss: [Test: p = 1.05917, q = 1.29351],
#           Effect: [ate-q], [train: 0.14015], [test: 0.14015]
# ********************************************************************************
# epoch: 7 / 50, time cost: 40.40 sec,
#           Loss: [Train: p = 1.05552, q = 1.32055],
#           Loss: [Test: p = 1.05901, q = 1.29352],
#           Effect: [ate-q], [train: 0.13989], [test: 0.13990]
# ********************************************************************************
# epoch: 8 / 50, time cost: 41.41 sec,
#           Loss: [Train: p = 1.05543, q = 1.32044],
#           Loss: [Test: p = 1.05889, q = 1.29354],
#           Effect: [ate-q], [train: 0.13988], [test: 0.13988]
# ********************************************************************************
# epoch: 9 / 50, time cost: 38.61 sec,
#           Loss: [Train: p = 1.05532, q = 1.32058],
#           Loss: [Test: p = 1.05874, q = 1.29289],
#           Effect: [ate-q], [train: 0.14062], [test: 0.14061]
# ********************************************************************************
# epoch: 10 / 50, time cost: 38.92 sec,
#           Loss: [Train: p = 1.05515, q = 1.32048],
#           Loss: [Test: p = 1.05858, q = 1.29289],
#           Effect: [ate-q], [train: 0.14086], [test: 0.14086]
# ********************************************************************************
# epoch: 11 / 50, time cost: 38.25 sec,
#           Loss: [Train: p = 1.05495, q = 1.32039],
#           Loss: [Test: p = 1.05849, q = 1.29330],
#           Effect: [ate-q], [train: 0.13976], [test: 0.13975]
# ********************************************************************************
# epoch: 12 / 50, time cost: 40.64 sec,
#           Loss: [Train: p = 1.05488, q = 1.31998],
#           Loss: [Test: p = 1.05833, q = 1.29352],
#           Effect: [ate-q], [train: 0.13948], [test: 0.13947]
# ********************************************************************************
# epoch: 13 / 50, time cost: 38.23 sec,
#           Loss: [Train: p = 1.05464, q = 1.32018],
#           Loss: [Test: p = 1.05820, q = 1.29353],
#           Effect: [ate-q], [train: 0.13914], [test: 0.13912]
# ********************************************************************************
# epoch: 14 / 50, time cost: 38.22 sec,
#           Loss: [Train: p = 1.05451, q = 1.32004],
#           Loss: [Test: p = 1.05806, q = 1.29298],
#           Effect: [ate-q], [train: 0.14016], [test: 0.14014]
# ********************************************************************************
# epoch: 15 / 50, time cost: 38.25 sec,
#           Loss: [Train: p = 1.05419, q = 1.31963],
#           Loss: [Test: p = 1.05793, q = 1.29292],
#           Effect: [ate-q], [train: 0.13991], [test: 0.13988]
# ********************************************************************************
# epoch: 16 / 50, time cost: 40.52 sec,
#           Loss: [Train: p = 1.05416, q = 1.31971],
#           Loss: [Test: p = 1.05774, q = 1.29249],
#           Effect: [ate-q], [train: 0.14038], [test: 0.14036]
# ********************************************************************************
# epoch: 17 / 50, time cost: 38.21 sec,
#           Loss: [Train: p = 1.05406, q = 1.31953],
#           Loss: [Test: p = 1.05766, q = 1.29188],
#           Effect: [ate-q], [train: 0.14148], [test: 0.14144]
# ********************************************************************************
# epoch: 18 / 50, time cost: 37.92 sec,
#           Loss: [Train: p = 1.05394, q = 1.31935],
#           Loss: [Test: p = 1.05747, q = 1.29133],
#           Effect: [ate-q], [train: 0.14234], [test: 0.14230]
# ********************************************************************************
# epoch: 19 / 50, time cost: 38.63 sec,
#           Loss: [Train: p = 1.05373, q = 1.31910],
#           Loss: [Test: p = 1.05736, q = 1.29166],
#           Effect: [ate-q], [train: 0.14175], [test: 0.14171]
# ********************************************************************************
# epoch: 20 / 50, time cost: 40.59 sec,
#           Loss: [Train: p = 1.05357, q = 1.31912],
#           Loss: [Test: p = 1.05720, q = 1.29206],
#           Effect: [ate-q], [train: 0.14032], [test: 0.14028]
# ********************************************************************************
# epoch: 21 / 50, time cost: 38.07 sec,
#           Loss: [Train: p = 1.05344, q = 1.31855],
#           Loss: [Test: p = 1.05707, q = 1.29135],
#           Effect: [ate-q], [train: 0.14172], [test: 0.14167]
# ********************************************************************************
# epoch: 22 / 50, time cost: 37.86 sec,
#           Loss: [Train: p = 1.05329, q = 1.31856],
#           Loss: [Test: p = 1.05692, q = 1.29201],
#           Effect: [ate-q], [train: 0.13965], [test: 0.13960]
# ********************************************************************************
# epoch: 23 / 50, time cost: 38.16 sec,
#           Loss: [Train: p = 1.05308, q = 1.31847],
#           Loss: [Test: p = 1.05675, q = 1.29173],
#           Effect: [ate-q], [train: 0.14023], [test: 0.14018]
# ********************************************************************************
# epoch: 24 / 50, time cost: 38.11 sec,
#           Loss: [Train: p = 1.05283, q = 1.31824],
#           Loss: [Test: p = 1.05663, q = 1.29061],
#           Effect: [ate-q], [train: 0.14198], [test: 0.14193]
# ********************************************************************************
# epoch: 25 / 50, time cost: 40.06 sec,
#           Loss: [Train: p = 1.05278, q = 1.31809],
#           Loss: [Test: p = 1.05646, q = 1.29103],
#           Effect: [ate-q], [train: 0.14084], [test: 0.14078]
# ********************************************************************************
# epoch: 26 / 50, time cost: 38.34 sec,
#           Loss: [Train: p = 1.05259, q = 1.31778],
#           Loss: [Test: p = 1.05631, q = 1.29166],
#           Effect: [ate-q], [train: 0.13924], [test: 0.13918]
# ********************************************************************************
# epoch: 27 / 50, time cost: 38.09 sec,
#           Loss: [Train: p = 1.05242, q = 1.31753],
#           Loss: [Test: p = 1.05613, q = 1.29056],
#           Effect: [ate-q], [train: 0.14148], [test: 0.14142]
# ********************************************************************************
# epoch: 28 / 50, time cost: 38.38 sec,
#           Loss: [Train: p = 1.05219, q = 1.31751],
#           Loss: [Test: p = 1.05602, q = 1.29118],
#           Effect: [ate-q], [train: 0.13975], [test: 0.13968]
# ********************************************************************************
# epoch: 29 / 50, time cost: 40.58 sec,
#           Loss: [Train: p = 1.05190, q = 1.31683],
#           Loss: [Test: p = 1.05584, q = 1.29113],
#           Effect: [ate-q], [train: 0.13934], [test: 0.13927]
# ********************************************************************************
# epoch: 30 / 50, time cost: 38.00 sec,
#           Loss: [Train: p = 1.05178, q = 1.31692],
#           Loss: [Test: p = 1.05569, q = 1.29102],
#           Effect: [ate-q], [train: 0.13902], [test: 0.13895]
# ********************************************************************************
# epoch: 31 / 50, time cost: 38.12 sec,
#           Loss: [Train: p = 1.05162, q = 1.31683],
#           Loss: [Test: p = 1.05552, q = 1.29109],
#           Effect: [ate-q], [train: 0.13837], [test: 0.13829]
# ********************************************************************************
# epoch: 32 / 50, time cost: 38.31 sec,
#           Loss: [Train: p = 1.05145, q = 1.31625],
#           Loss: [Test: p = 1.05529, q = 1.29041],
#           Effect: [ate-q], [train: 0.13900], [test: 0.13892]
# ********************************************************************************
# epoch: 33 / 50, time cost: 40.29 sec,
#           Loss: [Train: p = 1.05121, q = 1.31606],
#           Loss: [Test: p = 1.05514, q = 1.28926],
#           Effect: [ate-q], [train: 0.14121], [test: 0.14113]
# ********************************************************************************
# epoch: 34 / 50, time cost: 38.42 sec,
#           Loss: [Train: p = 1.05112, q = 1.31560],
#           Loss: [Test: p = 1.05500, q = 1.28902],
#           Effect: [ate-q], [train: 0.14093], [test: 0.14085]
# ********************************************************************************
# epoch: 35 / 50, time cost: 38.19 sec,
#           Loss: [Train: p = 1.05082, q = 1.31523],
#           Loss: [Test: p = 1.05482, q = 1.28877],
#           Effect: [ate-q], [train: 0.14072], [test: 0.14064]
# ********************************************************************************
# epoch: 36 / 50, time cost: 38.03 sec,
#           Loss: [Train: p = 1.05060, q = 1.31476],
#           Loss: [Test: p = 1.05462, q = 1.28793],
#           Effect: [ate-q], [train: 0.14173], [test: 0.14165]
# ********************************************************************************
# epoch: 37 / 50, time cost: 40.25 sec,
#           Loss: [Train: p = 1.05049, q = 1.31448],
#           Loss: [Test: p = 1.05443, q = 1.28944],
#           Effect: [ate-q], [train: 0.13825], [test: 0.13816]
# ********************************************************************************
# epoch: 38 / 50, time cost: 38.29 sec,
#           Loss: [Train: p = 1.05012, q = 1.31430],
#           Loss: [Test: p = 1.05427, q = 1.28754],
#           Effect: [ate-q], [train: 0.14177], [test: 0.14168]
# ********************************************************************************
# epoch: 39 / 50, time cost: 38.22 sec,
#           Loss: [Train: p = 1.05003, q = 1.31374],
#           Loss: [Test: p = 1.05405, q = 1.28779],
#           Effect: [ate-q], [train: 0.14031], [test: 0.14022]
# ********************************************************************************
# epoch: 40 / 50, time cost: 37.40 sec,
#           Loss: [Train: p = 1.04974, q = 1.31336],
#           Loss: [Test: p = 1.05389, q = 1.28728],
#           Effect: [ate-q], [train: 0.14059], [test: 0.14050]
# ********************************************************************************
# epoch: 41 / 50, time cost: 39.10 sec,
#           Loss: [Train: p = 1.04960, q = 1.31278],
#           Loss: [Test: p = 1.05365, q = 1.28777],
#           Effect: [ate-q], [train: 0.13824], [test: 0.13815]
# ********************************************************************************
# epoch: 42 / 50, time cost: 37.37 sec,
#           Loss: [Train: p = 1.04952, q = 1.31231],
#           Loss: [Test: p = 1.05353, q = 1.28833],
#           Effect: [ate-q], [train: 0.13663], [test: 0.13655]
# ********************************************************************************
# epoch: 43 / 50, time cost: 37.23 sec,
#           Loss: [Train: p = 1.04913, q = 1.31192],
#           Loss: [Test: p = 1.05335, q = 1.28563],
#           Effect: [ate-q], [train: 0.14086], [test: 0.14078]
# ********************************************************************************
# epoch: 44 / 50, time cost: 37.43 sec,
#           Loss: [Train: p = 1.04894, q = 1.31091],
#           Loss: [Test: p = 1.05311, q = 1.28700],
#           Effect: [ate-q], [train: 0.13765], [test: 0.13757]
# ********************************************************************************
# epoch: 45 / 50, time cost: 37.17 sec,
#           Loss: [Train: p = 1.04877, q = 1.31047],
#           Loss: [Test: p = 1.05291, q = 1.28577],
#           Effect: [ate-q], [train: 0.13889], [test: 0.13880]
# ********************************************************************************
# epoch: 46 / 50, time cost: 39.03 sec,
#           Loss: [Train: p = 1.04843, q = 1.30995],
#           Loss: [Test: p = 1.05273, q = 1.28526],
#           Effect: [ate-q], [train: 0.13927], [test: 0.13919]
# ********************************************************************************
# epoch: 47 / 50, time cost: 38.04 sec,
#           Loss: [Train: p = 1.04833, q = 1.30925],
#           Loss: [Test: p = 1.05254, q = 1.28505],
#           Effect: [ate-q], [train: 0.13839], [test: 0.13830]
# ********************************************************************************
# epoch: 48 / 50, time cost: 37.61 sec,
#           Loss: [Train: p = 1.04801, q = 1.30858],
#           Loss: [Test: p = 1.05232, q = 1.28513],
#           Effect: [ate-q], [train: 0.13723], [test: 0.13715]
# ********************************************************************************
# epoch: 49 / 50, time cost: 38.25 sec,
#           Loss: [Train: p = 1.04794, q = 1.30799],
#           Loss: [Test: p = 1.05216, q = 1.28381],
#           Effect: [ate-q], [train: 0.13855], [test: 0.13847]
# ********************************************************************************
# epoch: 50 / 50, time cost: 39.39 sec,
#           Loss: [Train: p = 1.04763, q = 1.30709],
#           Loss: [Test: p = 1.05192, q = 1.28328],
#           Effect: [ate-q], [train: 0.13864], [test: 0.13856]
# ********************************************************************************
# Finish training...

# %%
real = true_casual_effect(test_loader)
unadjust = (test_loader.dataset.response[test_loader.dataset.treatment == 1].mean() - test_loader.dataset.response[test_loader.dataset.treatment == 0].mean()).item()
show_result(train_loss_hist, test_loss_hist, est_effect, real, unadjust, epoch)
