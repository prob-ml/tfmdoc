# %%
import os
import csv
import sys
import argparse
import json

import pandas as pd
import numpy as np

import torch
from transformers import DataCollatorForLanguageModeling, BertForMaskedLM
from transformers import Trainer, TrainingArguments

from data import LineByLineTextDataset
from tokens import WordLevelBertTokenizer
from vocab import create_vocab
from utils import DATA_PATH, make_dirs

# %% [markdown]
# # Convert Diag code

# %%
diagmap_path = os.path.join('/home/liutianc/emr/data/', 'diag_9to10.csv')
icd_csv = csv.reader(open(diagmap_path), delimiter='|')

# %%
icd_map = []
for code in open(diagmap_path).readlines():
    code=code.strip()
    if code.split("|")[1] == 'Flags':
        header = code.split("|")
        print(code)
    else:
        icd_map.append(code.split("|"))
        
icd_map_df = pd.DataFrame(icd_map).loc[:,:1]
icd_map_df.columns = ['icd9', 'icd10']

# Drop some outlier characters.
icd_map_df['icd9'] = icd_map_df['icd9'].str.replace("'", "", regex=False)
icd_map_df['icd10'] = icd_map_df['icd10'].str.replace("'", "", regex=False)

# Only keep rows with defined mapping relationships: coverage rate is 14,660 / 15,086 = 95.85%
icd_map_df = icd_map_df.loc[icd_map_df['icd10'] != '']

# Only keep rows with UNIQUE mapping relationships: coverage rate is 13,516 / 14,660 = 92.20%
icd9_mapnum = icd_map_df.groupby('icd9').count().reset_index()
icd9_unimap = set(list(icd9_mapnum.loc[icd9_mapnum['icd10'] == 1, 'icd9']))
icd_map_df = icd_map_df.loc[icd_map_df['icd9'].apply(lambda x: x in icd9_unimap)]

# Cast icd10 encode to our data version: coverage rate is 9261 / 9802 = 94.48%
icd_map_df['icd10'] = icd_map_df['icd10'].str.replace('.', '', regex=False).str.upper()

icd_map_df.shape
# Out:
# (13516, 2)

# %%
icd_map_df = icd_map_df.set_index('icd9')
icd_map_raw = icd_map_df.to_dict(orient='index')

# %%
icd_map = {}
for idx, icd9 in enumerate(icd_map_raw):
    value = test[icd9]['icd10']
    
    _icd9 = icd9.replace('.', '')
    keys = [_icd9]
    # Add zero: We only add 0 to the end.
    keys += [_icd9 + '0']
    # If the last two chars are not 00, then we will add double 00 to the end.
    if _icd9[-2:] != '00':
        keys += [_icd9 + '00']

    # Strip ALL 0.
    keys += [_icd9.strip('0')]

    for key in set(keys):
        if key in icd_map:
            icd_map[key] = None
        else:
            icd_map[key] = [value, icd9]

# %%
icd9 = set(diag_icd9)

vc = [k for k in icd_map if icd_map[k] is not None]
ivc = [k for k in icd_map if icd_map[k] is None]

print(f'''
Total icd9 diag we have: {len(icd9)},
Caught by valid mapping: {len(icd9.difference(set(vc)))},
Caught by invalid mapping: {len(icd9.intersection(ivc))},
Not caught: {len(icd9.difference(set(icd_map)))}
''')
# Out:
# Total icd9 diag we have: 26963,
# Caught by valid mapping: 11962,
# Caught by invalid mapping: 976,
# Not caught: 10986

# %%
icd9 = set(diag_icd9)
icd10 = set(diag_icd10)

vc = [k for k in icd_map if icd_map[k] is not None]
ivc = [k for k in icd_map if icd_map[k] is None]

fail, success = [], []
for t in icd9:
    is_succ = 0
    if t in vc:
        success.append(t)
        is_succ = 1
    
    # Since we didn't add 0 to the beginning, removing possible extra 0 is done here.
    while t[0] == '0':
        t = t[1:]
        if t in vc:
            success.append(t)
            is_succ = 1
            continue
    if is_succ == 0:
        fail.append(t)

fail = set(fail)

print(f'''
Total icd9 diag we have: {len(icd9)},
Caught by invalid mapping: {len(success)},
Caught by invalid mapping: {len(fail.intersection(ivc))},
Not caught: {len(fail.difference(set(icd_map)))}
Actually ICD10: {len(fail.intersection(icd10))}
''')
# Out:
# 15659
# 11729

# %%
# real_miss = fail.difference(set(icd_map)).difference(icd10)

# %%
# user_group = [str(i) for i in range(10)]

# for group in user_group:
#     read = os.path.join(DATA_PATH, f'group_{group}.csv')

#     with open(read, 'r') as raw:
#         for line in raw:
#             for token in icd10_9:
#                 if f'icd:9_diag:{token}' in line:
#                     print(line)
#                     break
    
#     print(f'Checked: {group}')
# Out:
# 560499201141940,2014-10-02,icd:9_diag:25000
#
# 560499201141940,2014-10-28,icd:9_diag:25000 icd:9_diag:4011 icd:9_diag:4659 icd:9_diag:7862 AZITHROMYCIN HYDROCODONE/CHLORPHEN_P-STIREX
#
# 560499201141940,2014-11-06,icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:4011 icd:9_diag:V5869
#
# 560499201141940,2014-11-11,icd:9_diag:25000 icd:9_diag:4011 icd:9_diag:41401 icd:9_diag:4659 AZITHROMYCIN METFORMIN_HCL ERGOCALCIFEROL_(VITAMIN_D2)
#
# 560499201141940,2014-12-09,icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:4011 icd:9_diag:41401
#
# 560499201141940,2015-06-02,icd:9_diag:25000 icd:9_diag:41401 icd:9_diag:78652 icd:9_diag:7904 INSULIN_LISPRO NEEDLES__INSULIN_DISPOSABLE
#
# 560499201141940,2015-07-20,icd:9_diag:41401 icd:9_diag:412 icd:9_diag:79439 icd:9_diag:V4581
#
# 560499201299620,2010-09-27,icd:9_diag:V700 icd:9_diag:V700 icd:9_diag:V700
#
# 560499201299620,2014-02-20,icd:9_diag:V700 icd:9_diag:V700 icd:9_diag:V700
#
# 560499201299620,2015-04-30,icd:9_diag:59972 icd:9_diag:V700 icd:9_diag:V700
#
# 560499201299620,2015-05-01,icd:9_diag:V700 icd:9_diag:V700
#
# 560499202033740,2014-07-17,icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:4011 icd:9_diag:9190 icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:4011 icd:9_diag:9190
#
# 560499202033740,2014-07-18,icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:4019 icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:4019 icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:4019 icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:4019
#
# 560499202033740,2014-11-03,icd:9_diag:25002 icd:9_diag:4011 icd:9_diag:42789 icd:9_diag:59970
#
# 560499202033740,2014-11-04,icd:9_diag:25002 icd:9_diag:25002 icd:9_diag:4019 icd:9_diag:59970 icd:9_diag:25002 icd:9_diag:4019 icd:9_diag:59970
#
# 560499202033740,2015-04-14,icd:9_diag:25000 icd:9_diag:4011 icd:9_diag:71944
#
# 560499202033740,2015-05-30,icd:9_diag:78650 icd:9_diag:25000 icd:9_diag:4019 icd:9_diag:78650 icd:9_diag:78650 icd:9_diag:4240 icd:9_diag:4293 icd:9_diag:78650 icd:9_diag:25000 icd:9_diag:4019 icd:9_diag:5559 icd:9_diag:78659
#
# 560499202033740,2015-05-31,icd:9_diag:4240 icd:9_diag:4293 icd:9_diag:78650 icd:9_diag:25000 icd:9_diag:4019 icd:9_diag:5559 icd:9_diag:78659
#
# 560499202033740,2015-06-02,icd:9_diag:25000 icd:9_diag:4010 icd:9_diag:78659 icd:9_diag:79431
#
# 560499202033740,2015-06-11,icd:9_diag:25000 icd:9_diag:4010 icd:9_diag:78659 icd:9_diag:79431 icd:9_diag:7295 icd:9_diag:25000 icd:9_diag:4010 icd:9_diag:78659 icd:9_diag:79431 icd:9_diag:71594 icd:9_diag:7295
#
# 560499202033740,2015-06-25,icd:9_diag:25000 icd:9_diag:2722 icd:9_diag:4010
#
# 560499202033740,2015-08-12,icd:9_diag:25000 icd:9_diag:4011 icd:9_diag:5569
#
# 560499202037510,2010-06-09,icd:9_diag:5246 icd:9_diag:83901
#
# 560499202037510,2010-06-18,icd:9_diag:5246 icd:9_diag:83901
#
# 560499202037510,2011-01-24,icd:9_diag:V0489 icd:9_diag:V2509 icd:9_diag:V7231 icd:9_diag:V0489 icd:9_diag:V2509 icd:9_diag:V7231 icd:9_diag:V0489 icd:9_diag:V2509 icd:9_diag:V7231 icd:9_diag:V7231
#
# 560499202037510,2011-02-09,icd:9_diag:4619 icd:9_diag:6929 AZITHROMYCIN BETAMET_DIPROP/PROP_GLY
#
# 560499202037510,2011-03-11,icd:9_diag:V700 icd:9_diag:V700
#
# 560499202037510,2011-05-13,icd:9_diag:V0489
#
# 560499202037510,2011-07-07,icd:9_diag:V0489 icd:9_diag:V0489
#
# 560499202037510,2011-12-14,icd:9_diag:5950 SULFAMETHOXAZOLE/TRIMETHOPRIM NAPROXEN
#
# 560499202037510,2012-10-30,icd:9_diag:5641 icd:9_diag:7827 icd:9_diag:V700
#
# 560499202037510,2012-11-07,icd:9_diag:5693 HYDROCORTISONE/PRAMOXINE
#
# 560499202037510,2012-11-13,icd:9_diag:V700
#
# 560499202037510,2013-07-12,icd:9_diag:V2511 icd:9_diag:V2511 icd:9_diag:V2511
#
# 560499202037510,2014-02-24,icd:9_diag:7061 icd:9_diag:V700 CLINDAMYCIN_PHOS/BENZOYL_PEROX
#
# 560499202037510,2014-08-25,icd:9_diag:V0481
#
# 560499202037510,2015-08-14,icd:9_diag:V0481
#
# 560499202037510,2015-08-21,icd:9_diag:30742 icd:9_diag:V700 ESCITALOPRAM_OXALATE ALPRAZOLAM ZOLPIDEM_TARTRATE
#
# 560499202052920,2015-08-10,icd:9_diag:27800 icd:9_diag:V0489 icd:9_diag:V202 icd:9_diag:27800 icd:9_diag:V0489 icd:9_diag:V202 icd:9_diag:99883
#
# 560499202054390,2015-03-13,icd:9_diag:59970 icd:9_diag:V4582 icd:9_diag:59970
#
# 560499202054390,2015-03-15,icd:9_diag:25000 icd:9_diag:4019 icd:9_diag:515 icd:9_diag:5180 icd:9_diag:55090 icd:9_diag:5781 icd:9_diag:59970 icd:9_diag:60000 icd:9_diag:2558 icd:9_diag:5939 icd:9_diag:59970 icd:9_diag:60000 icd:9_diag:25000 icd:9_diag:4019 icd:9_diag:5781 icd:9_diag:59970
#
# 560499202054390,2015-03-20,icd:9_diag:59971 icd:9_diag:59972 icd:9_diag:59971
#
# 560499202054390,2015-04-01,icd:9_diag:V0382 icd:9_diag:25000 icd:9_diag:2720 icd:9_diag:4011 icd:9_diag:41400 icd:9_diag:56400 icd:9_diag:59970 icd:9_diag:V0382 icd:9_diag:25000 icd:9_diag:2720 icd:9_diag:4011 icd:9_diag:41400 LISINOPRIL
#
# 560499202054390,2015-08-19,icd:9_diag:2113 icd:9_diag:V7651 icd:9_diag:2113 icd:9_diag:V7651 icd:9_diag:2113 icd:9_diag:V7651 icd:9_diag:2113 icd:9_diag:27800 icd:9_diag:4019 icd:9_diag:V7651
#
# 560499202130060,2014-08-22,icd:9_diag:5990 icd:9_diag:7242
#
# 560499202130060,2014-09-08,icd:9_diag:5990 icd:9_diag:7242 icd:9_diag:V7240 icd:9_diag:5990
#
# 560499202131330,2014-02-18,icd:9_diag:2689 icd:9_diag:59972 icd:9_diag:V6540 QUETIAPINE_FUMARATE
#
# 560499202131330,2014-08-31,icd:9_diag:V9999
#
# 560499202131330,2014-09-14,icd:9_diag:V9999
#
# 560499202131330,2014-09-28,icd:9_diag:V9999 icd:10_diag:F250
#
# 560499202131330,2014-10-12,icd:9_diag:V9999
#
# 560499202131330,2014-10-26,icd:9_diag:V9999
#
# 560499202131330,2014-11-09,icd:9_diag:V9999
#
# 560499202131330,2014-11-23,icd:9_diag:V9999
#
# 560499202131330,2015-03-26,icd:9_diag:V700 icd:9_diag:V759 icd:9_diag:V771 icd:9_diag:V7791 icd:9_diag:V700 icd:9_diag:V759 icd:9_diag:V771 icd:9_diag:V7791 icd:9_diag:V700 icd:9_diag:V759 icd:9_diag:V771 icd:9_diag:V7791 icd:9_diag:V700 icd:9_diag:V759 icd:9_diag:V771 icd:9_diag:V7791 icd:9_diag:V700 icd:9_diag:V759 icd:9_diag:V771 icd:9_diag:V7791 icd:9_diag:V700 icd:9_diag:V759 icd:9_diag:V771 icd:9_diag:V7791 icd:9_diag:V700 icd:9_diag:V759 icd:9_diag:V771 icd:9_diag:V7791 icd:9_diag:V700 icd:9_diag:V759 icd:9_diag:V771 icd:9_diag:V7791 icd:9_diag:V700 icd:9_diag:V759 icd:9_diag:V771 icd:9_diag:V7791 icd:9_diag:2689 icd:9_diag:59972 icd:9_diag:V6540 icd:9_diag:V700
#
# 560499202131330,2015-04-06,icd:9_diag:2689 icd:9_diag:59972
#
# 560499202131330,2015-05-14,icd:9_diag:2689 icd:9_diag:59972 icd:9_diag:V6540
#
# 560499202168430,2015-08-11,icd:9_diag:V0389 icd:9_diag:V0489 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0389 icd:9_diag:V0489 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0389 icd:9_diag:V0489 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0389 icd:9_diag:V0489 icd:9_diag:V061 icd:9_diag:V202
#
# 560499202185210,2014-03-26,icd:9_diag:V700
#
# 560499202200400,2015-06-25,icd:9_diag:6235 icd:9_diag:7808 icd:9_diag:78659 icd:9_diag:7881 icd:9_diag:6235 icd:9_diag:7808 icd:9_diag:78659 icd:9_diag:7881 icd:9_diag:61610 icd:9_diag:7881 icd:9_diag:V7381 icd:9_diag:V762 icd:9_diag:61610 icd:9_diag:7881 icd:9_diag:V7381 icd:9_diag:V762 icd:9_diag:5693 icd:9_diag:5990 icd:9_diag:78659 icd:9_diag:78900
#
# 560499202200400,2015-07-23,icd:9_diag:27800 icd:9_diag:3051 icd:9_diag:7808 icd:9_diag:78659 icd:9_diag:27800 icd:9_diag:3051 icd:9_diag:7808 icd:9_diag:78659 icd:9_diag:78659
#
# 560499202212380,2014-03-05,icd:9_diag:53550 icd:9_diag:78650 icd:9_diag:7871 icd:9_diag:7873 icd:9_diag:7934 icd:9_diag:7062 icd:9_diag:53540 icd:9_diag:78650 icd:9_diag:7871 icd:9_diag:78909 icd:9_diag:7871 icd:9_diag:53500 icd:9_diag:7871 icd:9_diag:7873
#
# 560499202212380,2014-09-23,icd:9_diag:64403 icd:9_diag:7881 icd:9_diag:V0481
#
# 560499202212380,2015-04-23,icd:9_diag:38200 icd:9_diag:460 icd:9_diag:4619 AMOXICILLIN/POTASSIUM_CLAV GUAIFENESIN/CODEINE_PHOSPHATE
#
# 560499202213980,2014-03-06,icd:9_diag:311
#
# 560499202213980,2014-03-20,icd:9_diag:311
#
# 560499202213980,2014-03-27,icd:9_diag:311
#
# 560499202213980,2014-04-10,icd:9_diag:311
#
# 560499202213980,2014-05-08,icd:9_diag:311
#
# 560499202213980,2014-05-22,icd:9_diag:311
#
# 560499202213980,2014-06-05,icd:9_diag:311
#
# 560499202213980,2014-06-19,icd:9_diag:311
#
# 560499202213980,2014-07-23,icd:9_diag:311
#
# 560499202213980,2014-08-07,icd:9_diag:311
#
# 560499202213980,2014-08-13,icd:9_diag:311
#
# 560499202213980,2014-08-27,icd:9_diag:311
#
# 560499202213980,2014-09-18,icd:9_diag:311
#
# 560499202213980,2014-10-02,icd:9_diag:311
#
# 560499202213980,2014-10-16,icd:9_diag:311
#
# 560499202213980,2014-10-29,icd:9_diag:311 TADALAFIL
#
# 560499202213980,2014-11-18,icd:9_diag:311
#
# 560499202213980,2014-12-04,icd:9_diag:311
#
# 560499202213980,2014-12-18,icd:9_diag:311
#
# 560499202213980,2015-05-05,icd:9_diag:79671 icd:9_diag:9953 icd:9_diag:V700 TADALAFIL
#
# 560499202215620,2014-06-05,icd:9_diag:2449 icd:9_diag:2720 icd:9_diag:311 icd:9_diag:60000
#
# 560499202215620,2014-08-07,icd:9_diag:2449 icd:9_diag:2720 icd:9_diag:53011 icd:9_diag:60000 icd:9_diag:V700 icd:9_diag:2449 icd:9_diag:2720 icd:9_diag:53011 icd:9_diag:60000 icd:9_diag:V700 FLUTICASONE_PROPIONATE
#
# 560499202215620,2015-08-13,icd:9_diag:2449 icd:9_diag:2572 icd:9_diag:2722 icd:9_diag:60000 icd:9_diag:V700
#
# 560499202218280,2014-09-25,icd:9_diag:V0481 icd:9_diag:V202
#
# 560499202218280,2014-11-01,icd:9_diag:5990 icd:9_diag:5950 icd:9_diag:59970 icd:9_diag:78821 SULFAMETHOXAZOLE/TRIMETHOPRIM
#
# 560499202218280,2014-11-04,icd:9_diag:5950 icd:9_diag:59970
#
# 560499202218280,2015-09-29,icd:9_diag:V0481 icd:9_diag:V202 icd:9_diag:V0481 icd:9_diag:V202
#
# 560499202220340,2014-10-20,icd:9_diag:V0481 icd:9_diag:V1269 icd:9_diag:V202 icd:9_diag:V653 icd:9_diag:V0481 icd:9_diag:V1269 icd:9_diag:V202 icd:9_diag:V653
#
# 560499202223440,2014-05-30,icd:9_diag:2724 icd:9_diag:7851 icd:9_diag:79029 icd:9_diag:2724 icd:9_diag:4011 icd:9_diag:7851 icd:9_diag:79029 icd:9_diag:V700
#
# 560499202223440,2015-06-04,icd:9_diag:27800 icd:9_diag:32723 icd:9_diag:4019
#
# 560499202223440,2015-09-04,icd:9_diag:2724 icd:9_diag:4011 icd:9_diag:79029 icd:9_diag:V7644 icd:9_diag:2724 icd:9_diag:4011 icd:9_diag:79029 icd:9_diag:V700 icd:9_diag:2724 icd:9_diag:4011 icd:9_diag:79029 icd:9_diag:V7644 ATORVASTATIN_CALCIUM VALSARTAN
#
# 560499202223710,2014-08-29,icd:9_diag:84500 icd:9_diag:E9289 icd:9_diag:84500 icd:9_diag:E9289
#
# 560499202225130,2014-06-19,icd:9_diag:56400 icd:9_diag:7580 icd:9_diag:56400 icd:9_diag:7580 icd:9_diag:56400 icd:9_diag:7580
#
# 560499202225130,2015-07-28,icd:9_diag:3077 icd:9_diag:56400 icd:9_diag:5693 icd:9_diag:V140 icd:9_diag:V1851
#
# 560499202225130,2015-09-24,icd:9_diag:56400 icd:9_diag:7580 icd:9_diag:56400 icd:9_diag:7580
#
# 560499202225130,2015-09-25,icd:9_diag:56400 icd:9_diag:56400 icd:9_diag:7580 icd:9_diag:56400 icd:9_diag:7580 icd:9_diag:56400 icd:9_diag:7580
#
# 560499202227660,2010-03-10,icd:9_diag:2449 icd:9_diag:59970 icd:9_diag:78651 icd:9_diag:2449 icd:9_diag:2449 icd:9_diag:2449 icd:9_diag:2449 THYROID_PORK
#
# 560499202227660,2010-04-14,icd:9_diag:2452 icd:9_diag:59970
#
# 560499202227660,2010-04-19,icd:9_diag:2452 icd:9_diag:59970 icd:9_diag:2452 icd:9_diag:59970 icd:9_diag:2452 icd:9_diag:59970 icd:9_diag:2452 icd:9_diag:59970 icd:9_diag:2452 icd:9_diag:2452
#
# 560499202227660,2010-04-27,icd:9_diag:4619 AZITHROMYCIN
#
# 560499202227660,2010-05-27,icd:9_diag:2449 icd:9_diag:2452 icd:9_diag:59970 icd:9_diag:78651
#
# 560499202227660,2010-11-12,icd:9_diag:V0481 ALBUTEROL_SULFATE ALBUTEROL_SULFATE MONTELUKAST_SODIUM BECLOMETHASONE_DIPROPIONATE
#
# 560499202227660,2010-11-15,icd:9_diag:29665 icd:9_diag:29689 icd:9_diag:29665 icd:9_diag:29689 icd:9_diag:V0481
#
# 560499202227660,2011-10-05,icd:9_diag:4619 icd:9_diag:49390 AZITHROMYCIN BUDESONIDE
#
# 560499202227660,2011-11-15,icd:9_diag:V0481
#
# 560499202227660,2012-10-26,icd:9_diag:2449 icd:9_diag:2689 icd:9_diag:3051 icd:9_diag:4254 icd:9_diag:4580 icd:9_diag:4739 icd:9_diag:486 icd:9_diag:490 icd:9_diag:49392 icd:9_diag:490 icd:9_diag:49390 icd:9_diag:78609 icd:9_diag:78650 icd:9_diag:4659 icd:9_diag:49392 icd:9_diag:78605 icd:9_diag:79902 icd:9_diag:78605
#
# 560499202227660,2012-11-12,icd:9_diag:V0481
#
# 560499202227660,2013-04-08,icd:9_diag:2724 icd:9_diag:29660 icd:9_diag:3051 icd:9_diag:41401 icd:9_diag:4254 icd:9_diag:4280 icd:9_diag:49320 icd:9_diag:53081 icd:9_diag:V6284 icd:9_diag:78721 icd:9_diag:311 icd:9_diag:V6284 icd:9_proc:4292 icd:9_proc:4516 CLONAZEPAM BECLOMETHASONE_DIPROPIONATE FLUTICASONE/SALMETEROL
#
# 560499202227660,2013-04-09,icd:9_diag:2449 icd:9_diag:53081 icd:9_diag:78721 icd:9_diag:V6284 icd:9_diag:49390 icd:9_diag:29650 icd:9_diag:311 icd:9_diag:V6284 MONTELUKAST_SODIUM
#
# 560499202227660,2013-04-10,icd:9_diag:53550 icd:9_diag:78720 icd:9_diag:V6284 icd:9_diag:29650 icd:9_diag:311 icd:9_diag:V6284
#
# 560499202227660,2013-04-11,icd:9_diag:29650 icd:9_diag:311 icd:9_diag:V6284
#
# 560499202227660,2013-04-12,icd:9_diag:29650 icd:9_diag:311 icd:9_diag:V6284
#
# 560499202227660,2013-04-15,icd:9_diag:2724 icd:9_diag:29660 icd:9_diag:3051 icd:9_diag:41401 icd:9_diag:4254 icd:9_diag:4280 icd:9_diag:49320 icd:9_diag:53081 icd:9_diag:V6284 icd:9_diag:29650 icd:9_diag:311 icd:9_diag:V6284 icd:9_proc:4292 icd:9_proc:4516 DIVALPROEX_SODIUM
#
# 560499202227660,2013-07-01,icd:9_diag:9999 icd:9_diag:29640
#
# 560499202227660,2013-08-26,icd:9_diag:7851 icd:9_diag:78650 icd:9_diag:42682 icd:9_diag:42789 icd:9_diag:78659 icd:9_diag:311 icd:9_diag:49390 icd:9_diag:53081 icd:9_diag:78659 SUCRALFATE
#
# 560499202227660,2013-09-03,icd:9_diag:2729 icd:9_diag:311 icd:9_diag:4254 icd:9_diag:49390
#
# 560499202227660,2013-09-18,icd:9_diag:6227 icd:9_diag:6261 icd:9_diag:V7231 icd:9_diag:496 icd:9_diag:29653 icd:9_diag:29660 icd:9_diag:311 icd:9_diag:49390 icd:9_diag:V6284 LURASIDONE_HCL
#
# 560499202227660,2013-09-24,icd:9_diag:29660 icd:9_diag:311 icd:9_diag:4019
#
# 560499202227660,2013-10-22,icd:9_diag:2449 icd:9_diag:27800 icd:9_diag:29650 icd:9_diag:3090 icd:9_diag:49320 icd:9_diag:5641 icd:9_diag:V6284 icd:9_proc:9427
#
# 560499202227660,2013-10-28,icd:9_diag:311 icd:9_diag:29633 icd:9_diag:29653
#
# 560499202227660,2013-11-04,icd:9_diag:29653 icd:9_diag:311
#
# 560499202228140,2014-01-21,icd:9_diag:83908 icd:9_diag:83920 icd:9_diag:83921 icd:9_diag:83969
#
# 560499202228140,2014-03-14,icd:9_diag:2722 icd:9_diag:V700 icd:9_diag:V7644 icd:9_diag:2722 icd:9_diag:V700 icd:9_diag:V7644 icd:9_diag:2722 icd:9_diag:V700 icd:9_diag:V7644 icd:9_diag:2722 icd:9_diag:V700 icd:9_diag:V7644
#
# 560499202228140,2014-03-26,icd:9_diag:27800 icd:9_diag:V653 icd:9_diag:V700 icd:9_diag:V8530
#
# 560499202228140,2014-03-31,icd:9_diag:83908 icd:9_diag:83920 icd:9_diag:83921 icd:9_diag:83942 icd:9_diag:83969
#
# 560499202228140,2014-11-07,icd:9_diag:83908 icd:9_diag:83920 icd:9_diag:83921 icd:9_diag:83942 icd:9_diag:83969
#
# 560499202228140,2015-02-13,icd:9_diag:83908 icd:9_diag:83920 icd:9_diag:83921 icd:9_diag:83942 icd:9_diag:83969
#
# 560499202228140,2015-02-26,icd:9_diag:V700 icd:9_diag:V7644 icd:9_diag:V700 icd:9_diag:V7644 icd:9_diag:V700 icd:9_diag:V7644
#
# 560499202228140,2015-03-10,icd:9_diag:2720 icd:9_diag:V700 icd:9_diag:V8525 icd:9_diag:2720 icd:9_diag:V700 icd:9_diag:V8525
#
# 560499202228920,2014-11-06,icd:9_diag:V0481
#
# 560499202228920,2015-09-11,icd:9_diag:0743 icd:9_diag:684 icd:9_diag:78031 MUPIROCIN
#
# 560499202230270,2014-06-17,icd:9_diag:2449 icd:9_diag:2689 icd:9_diag:V700 icd:9_diag:2449 icd:9_diag:2689 icd:9_diag:V700 icd:9_diag:2449 icd:9_diag:2449 icd:9_diag:2689 icd:9_diag:4549 icd:9_diag:5990 icd:9_diag:V700 icd:9_diag:2449 icd:9_diag:2689 icd:9_diag:4549 icd:9_diag:5990 icd:9_diag:V700
#
# 560499202230270,2015-01-26,icd:9_diag:5990 icd:9_diag:V7381 icd:9_diag:V762
#
# 560499202230270,2015-02-23,icd:9_diag:V0489 icd:9_diag:V0489
#
# 560499202230270,2015-03-26,icd:9_diag:V0489 icd:9_diag:V0489 LEVOTHYROXINE_SODIUM
#
# 560499202234550,2014-10-08,icd:9_diag:V0481 icd:9_diag:V202 icd:9_diag:V0481 icd:9_diag:V202
#
# 560499202235750,2014-02-12,icd:9_diag:V700
#
# 560499202235750,2014-09-05,icd:9_diag:53789 icd:9_diag:56210 icd:9_diag:7873
#
# 560499202235750,2014-11-21,icd:9_diag:V0481
#
# 560499202235750,2014-12-30,icd:9_diag:V700
#
# 560499202235750,2015-01-16,icd:9_diag:V700 icd:9_diag:V700 icd:9_diag:V700 icd:9_diag:07811 icd:9_diag:6929 icd:9_diag:70219
#
# 560499202235750,2015-05-06,icd:9_diag:53789 icd:9_diag:56210 icd:9_diag:5693 icd:9_diag:7873
#
# 560499202235750,2015-07-24,icd:9_diag:53081 icd:9_diag:V700 OMEPRAZOLE
#
# 560499202238070,2014-10-02,icd:9_diag:V0481 icd:9_diag:2689 icd:9_diag:2724 icd:9_diag:4019 icd:9_diag:53011 SIMVASTATIN SIMVASTATIN
#
# 560499202238070,2015-07-07,icd:9_diag:4619 AMOXICILLIN AMOXICILLIN
#
# 560499202240200,2014-05-09,icd:9_diag:34290 icd:9_diag:7812 icd:9_diag:V571
#
# 560499202240200,2014-06-10,icd:9_diag:34290 icd:9_diag:7812 icd:9_diag:V571
#
# 560499202240200,2014-07-03,icd:9_diag:34290 icd:9_diag:7812 icd:9_diag:V571
#
# 560499202240200,2014-07-28,icd:9_diag:34290 icd:9_diag:43491 icd:9_diag:7810 icd:9_diag:7812
#
# 560499202240200,2014-08-13,icd:9_diag:34290 icd:9_diag:7812 icd:9_diag:V571
#
# 560499202240200,2014-10-15,icd:9_diag:33818 icd:9_diag:4589 icd:9_diag:78039 icd:9_diag:78603 icd:9_diag:99670 icd:9_diag:43411 icd:9_diag:V5861 icd:9_diag:4294 icd:9_diag:43820 icd:9_diag:74689 icd:9_diag:74731 icd:9_diag:78039 icd:9_diag:V1369 icd:9_diag:V441 icd:9_diag:33818 icd:9_diag:79989 icd:9_diag:V7285 icd:9_diag:7453 icd:9_diag:74731 icd:9_diag:V151 icd:9_diag:51289 icd:9_proc:3594 icd:9_proc:3885 icd:9_proc:3957 icd:9_proc:3961
#
# 560499202240200,2014-10-16,icd:9_diag:34590 icd:9_diag:7453 icd:9_diag:V151 icd:9_diag:33818 icd:9_diag:4589 icd:9_diag:78039 icd:9_diag:78603 icd:9_diag:99670 icd:9_diag:43411 icd:9_diag:V5861 icd:9_diag:42789 icd:9_diag:4293 icd:9_diag:79431 icd:9_diag:V5849 icd:9_diag:78039 icd:9_diag:V6709
#
# 560499202240200,2014-10-17,icd:9_diag:7453 icd:9_diag:V151 icd:9_diag:33818 icd:9_diag:7461 icd:9_diag:78039 icd:9_diag:78603 icd:9_diag:99670 icd:9_diag:43411 icd:9_diag:V5861 icd:9_diag:V6709
#
# 560499202240200,2014-10-18,icd:9_diag:33818 icd:9_diag:7461 icd:9_diag:78039 icd:9_diag:78603 icd:9_diag:99670 icd:9_diag:42789 icd:9_diag:4293 icd:9_diag:7469 icd:9_diag:V151
#
# 560499202240200,2014-10-19,icd:9_diag:33818 icd:9_diag:4589 icd:9_diag:78039 icd:9_diag:78603 icd:9_diag:99670 icd:9_diag:4294 icd:9_diag:43820 icd:9_diag:74689 icd:9_diag:74731 icd:9_diag:78039 icd:9_diag:V1369 icd:9_diag:V441 icd:9_diag:7461 icd:9_diag:V151 icd:9_proc:3594 icd:9_proc:3885 icd:9_proc:3957 icd:9_proc:3961
#
# 560499202240200,2014-10-20,icd:9_diag:7461 icd:9_diag:78039 icd:9_diag:78720 icd:9_diag:99670 icd:9_diag:7469 icd:9_diag:78039 icd:9_diag:V5861 icd:9_diag:51882 icd:9_diag:7825 icd:9_diag:43491 icd:9_diag:74689 icd:9_diag:78039 icd:9_diag:78079 icd:9_diag:V6759
#
# 560499202240200,2014-10-21,icd:9_diag:43411 icd:9_diag:V5861 icd:9_diag:51882 icd:9_diag:7825 icd:9_diag:43491 icd:9_diag:74689 icd:9_diag:78039 icd:9_diag:78079
#
# 560499202240200,2014-10-22,icd:9_diag:43411 icd:9_diag:V5861 icd:9_diag:7453 icd:9_diag:7825 icd:9_diag:V151 icd:9_diag:43491 icd:9_diag:74689 icd:9_diag:78039 icd:9_diag:78079
#
# 560499202240200,2014-10-23,icd:9_diag:74689 icd:9_diag:78039 icd:9_diag:78079 icd:9_diag:78720 icd:9_diag:7453 icd:9_diag:74731 icd:9_diag:7825 icd:9_diag:V151 icd:9_diag:4294 icd:9_diag:43820 icd:9_diag:74689 icd:9_diag:74731 icd:9_diag:78039 icd:9_diag:V1369 icd:9_diag:V441 icd:9_proc:3594 icd:9_proc:3885 icd:9_proc:3957 icd:9_proc:3961
#
# 560499202240200,2014-10-24,icd:9_diag:79902 icd:9_diag:7469 icd:9_diag:78039 icd:9_diag:V5861 icd:9_diag:74689 icd:9_diag:78039 icd:9_diag:78079 icd:9_diag:78720 icd:9_diag:7453 icd:9_diag:74731 icd:9_diag:7825 icd:9_diag:V151 icd:9_diag:79902 ENOXAPARIN_SODIUM LEVETIRACETAM FUROSEMIDE POLYETHYLENE_GLYCOL_3350
#
# 560499202240200,2014-10-30,icd:9_diag:41000 icd:9_diag:4280 icd:9_diag:74684 icd:9_diag:78039
#
# 560499202240200,2014-11-24,icd:9_diag:79902 icd:9_diag:79902 icd:9_diag:79902 WARFARIN_SODIUM WARFARIN_SODIUM
#
# 560499202240200,2014-12-11,icd:9_diag:43491 icd:9_diag:78039 icd:9_diag:7469 icd:9_diag:E9342 icd:9_diag:V5861
#
# 560499202240200,2014-12-24,icd:9_diag:79902 icd:9_diag:79902 icd:9_diag:79902
#
# 560499202240200,2015-01-24,icd:9_diag:79902 icd:9_diag:79902 icd:9_diag:79902
#
# 560499202240200,2015-02-24,icd:9_diag:79902 icd:9_diag:79902 icd:9_diag:79902
#
# 560499202240200,2015-03-24,icd:9_diag:79902 icd:9_diag:79902 icd:9_diag:79902
#
# 560499202240200,2015-04-24,icd:9_diag:79902 icd:9_diag:79902 icd:9_diag:79902 icd:9_diag:79902
#
# 560499202240200,2015-05-24,icd:9_diag:79902 icd:9_diag:79902 icd:9_diag:79902
#
# 560499202240200,2015-06-24,icd:9_diag:79902
#
# 560499202240200,2015-07-21,icd:9_diag:43491 icd:9_diag:78039
#
# 560499202240200,2015-07-24,icd:9_diag:79902 icd:9_diag:79902
#
# 560499202241450,2015-01-22,icd:9_diag:56400 icd:9_diag:5650 POLYETHYLENE_GLYCOL_3350
#
# 560499202241450,2015-02-10,icd:9_diag:3829 icd:9_diag:56400 icd:9_diag:78607 AMOXICILLIN
#
# 560499202242060,2014-02-04,icd:9_diag:V239
#
# 560499202242060,2014-03-12,icd:9_diag:V239
#
# 560499202242060,2014-04-26,icd:9_diag:V239
#
# 560499202242060,2014-05-02,icd:9_diag:V239
#
# 560499202242060,2014-06-11,icd:9_diag:V239
#
# 560499202242060,2014-06-16,icd:9_diag:V239
#
# 560499202242060,2014-07-08,icd:9_diag:65421 icd:9_diag:V7260 icd:9_diag:65421 icd:9_diag:V270 icd:9_diag:65421 icd:9_diag:V252 icd:9_diag:V270 icd:9_diag:65421 icd:9_diag:V239 icd:9_diag:V252 icd:9_diag:V252 icd:9_proc:6632 icd:9_proc:741
#
# 560499202245100,2014-08-06,icd:9_diag:V700
#
# 560499202245100,2015-08-17,icd:9_diag:V700
#
# 560499202247180,2014-03-06,icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V068 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V068 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V068 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V068 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V068 icd:9_diag:V202
#
# 560499202247180,2014-05-08,icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V068 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V068 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V068 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V068 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V068 icd:9_diag:V202
#
# 560499202247180,2014-11-03,icd:9_diag:3829 icd:9_diag:V0481 icd:9_diag:3829 icd:9_diag:V0481
#
# 560499202247180,2014-12-01,icd:9_diag:V0481
#
# 560499202248530,2014-10-15,icd:9_diag:V0481
#
# 560499202249140,2014-10-23,icd:9_diag:V0481
#
# 560499202250510,2015-04-30,icd:9_diag:4619
#
# 560499202253910,2015-02-25,icd:9_diag:81400 icd:9_diag:E0008 icd:9_diag:E0032 icd:9_diag:E8494 icd:9_diag:E8853 icd:9_diag:81341
#
# 560499202254840,2014-04-16,icd:9_diag:36501 icd:9_diag:3671 icd:9_diag:36720 icd:9_diag:37515 icd:9_diag:V720
#
# 560499202254840,2014-04-23,icd:9_diag:38870 icd:9_diag:V771 icd:9_diag:V7791 icd:9_diag:38870 icd:9_diag:V771 icd:9_diag:V7791 icd:9_diag:V1819 icd:9_diag:3540 icd:9_diag:38870 icd:9_diag:V700 icd:9_diag:V771 icd:9_diag:V7791
#
# 560499202254840,2015-06-04,icd:9_diag:V771 icd:9_diag:V7791 icd:9_diag:V1819 icd:9_diag:78052 icd:9_diag:7820 icd:9_diag:V700 icd:9_diag:V771 icd:9_diag:V7791 TRAZODONE_HCL
#
# 560499202254840,2015-07-29,icd:9_diag:36500 icd:9_diag:3671 icd:9_diag:V720
#
# 560499202257230,2015-06-16,icd:9_diag:V700 icd:9_diag:V700 icd:9_diag:V700 icd:9_diag:V700
#
# 560499202260520,2014-02-26,icd:9_diag:4619 icd:9_diag:4779 icd:9_diag:7245 icd:9_diag:78079 icd:9_diag:4619 icd:9_diag:4779 icd:9_diag:7245 icd:9_diag:78079 icd:9_diag:78499 LEVOCETIRIZINE_DIHYDROCHLORIDE CEPHALEXIN METHYLPREDNISOLONE
#
# 560499202260520,2014-10-30,icd:9_diag:V0481
#
# 560499202260520,2015-09-29,icd:9_diag:V0481
#
# 560499202260610,2014-02-27,icd:9_diag:V700 icd:9_diag:25000 icd:9_diag:2689 icd:9_diag:2724 icd:9_diag:4019 icd:9_diag:V700
#
# 560499202260610,2014-03-06,icd:9_diag:V700
#
# 560499202260610,2015-04-15,icd:9_diag:25000 icd:9_diag:2689 icd:9_diag:2724 icd:9_diag:4019 icd:9_diag:25000 icd:9_diag:2689 icd:9_diag:2724 icd:9_diag:4019
#
# 560499202260610,2015-04-22,icd:9_diag:V700 TRAMADOL_HCL
#
# 560499202260610,2015-08-24,icd:9_diag:25000 icd:9_diag:25000 icd:9_diag:27800 icd:9_diag:4019 icd:9_diag:71590 TRAMADOL_HCL EMPAGLIFLOZIN
#
# 560499202261660,2014-07-30,icd:9_diag:V0489 icd:9_diag:V202 icd:9_diag:V720 icd:9_diag:V0489 icd:9_diag:V202 icd:9_diag:V720
#
# 560499202261660,2014-11-07,icd:9_diag:V0481 icd:9_diag:V0489 icd:9_diag:V0481 icd:9_diag:V0489
#
# 560499202261710,2014-10-09,icd:9_diag:2724 icd:9_diag:311 icd:9_diag:71690 icd:9_diag:V0382 icd:9_diag:V7612 icd:9_diag:2724 icd:9_diag:311 icd:9_diag:71690 icd:9_diag:V0382 icd:9_diag:V7612 icd:9_diag:2724 icd:9_diag:311 icd:9_diag:71690 icd:9_diag:V0382 icd:9_diag:V7612 FLUTICASONE_PROPIONATE
#
# 560499202261710,2014-11-03,icd:9_diag:27800 icd:9_diag:V7651 PEG3350/SOD_SUL/NACL/ASB/C/KCL
#
# 560499202261710,2015-02-20,icd:9_diag:56210 icd:9_diag:V7651 icd:9_diag:27800 icd:9_diag:311 icd:9_diag:56210 icd:9_diag:V7651 icd:9_diag:V8532
#
# 560499202261710,2015-06-12,icd:9_diag:2724 icd:9_diag:311 icd:9_diag:71691 icd:9_diag:V1588 icd:9_diag:V7284
#
# 560499202261710,2015-06-19,icd:9_diag:2724 icd:9_diag:311 icd:9_diag:3899 icd:9_diag:71531 icd:9_diag:V169 icd:9_diag:V4361 icd:9_diag:V4364 icd:9_diag:V4369 icd:9_diag:71531 icd:9_diag:71531 icd:9_diag:33818 icd:9_diag:71591 icd:9_diag:71941 icd:9_diag:71591 icd:9_diag:71591 icd:9_proc:0481 icd:9_proc:8180
#
# 560499202266280,2014-02-21,icd:9_diag:V7231 icd:9_diag:V016 icd:9_diag:V700 icd:9_diag:2167 icd:9_diag:7354 icd:9_diag:V700 icd:9_diag:V7231 icd:9_diag:V016 icd:9_diag:V700
#
# 560499202266280,2014-03-14,icd:9_diag:2859 icd:9_diag:2859 icd:9_diag:4619 icd:9_diag:4779 icd:9_diag:5939 AMOXICILLIN
#
# 560499202266280,2014-04-03,icd:9_diag:56889 icd:9_diag:78933
#
# 560499202266280,2014-04-16,icd:9_diag:V700
#
# 560499202266280,2014-06-05,icd:9_diag:2390 icd:9_diag:57420 icd:9_diag:1580 icd:9_diag:57410 icd:9_diag:56738 icd:9_diag:57420 icd:9_diag:1580 icd:9_diag:33818 icd:9_diag:1580 icd:9_diag:2189 icd:9_diag:2859 icd:9_diag:33818 icd:9_diag:57410 icd:9_diag:6202 icd:9_diag:7533 icd:9_proc:5122 icd:9_proc:544
#
# 560499202271230,2015-01-08,icd:9_diag:7881 icd:9_diag:V700 icd:9_diag:7881 icd:9_diag:V700 icd:9_diag:7881 icd:9_diag:V700
#
# 560499202271230,2015-02-17,icd:9_diag:6273 icd:9_diag:78821 icd:9_diag:78834 icd:9_diag:79389 icd:9_diag:79389 icd:9_diag:61189 icd:9_diag:59970 icd:9_diag:78821
#
# 560499202271230,2015-02-18,icd:9_diag:59970
#
# 560499202271230,2015-03-02,icd:9_diag:59972 icd:9_diag:61801 icd:9_diag:61804 icd:9_diag:78831 icd:9_diag:59972 icd:9_diag:78831 icd:9_diag:59972 icd:9_diag:61801 icd:9_diag:61804 icd:9_diag:6182 icd:9_diag:78831 icd:9_diag:59972 icd:9_diag:78863
#
# 560499202276280,2014-01-04,icd:9_diag:2768 icd:9_diag:5990 icd:9_diag:78909 icd:9_diag:496 icd:9_diag:7862 icd:9_diag:2768 icd:9_diag:4019 icd:9_diag:5990
#
# 560499202276280,2014-01-08,icd:9_diag:2768 icd:9_diag:28860 icd:9_diag:5853 icd:9_diag:5990
#
# 560499202276280,2014-01-30,icd:9_diag:2768 icd:9_diag:28860 icd:9_diag:5990 icd:9_diag:2768 icd:9_diag:28860 icd:9_diag:5990
#
# 560499202276280,2014-04-01,icd:9_diag:5990 icd:9_diag:6929 icd:9_diag:71590 icd:9_diag:5990 icd:9_diag:71590 BETAMETHASONE_DIPROPIONATE
#
# 560499202276280,2014-06-04,icd:9_diag:40310 icd:9_diag:42731 icd:9_diag:4414 icd:9_diag:5853 icd:9_diag:40310 icd:9_diag:42731 icd:9_diag:4414 icd:9_diag:V0489 icd:9_diag:V700 icd:9_diag:40310 icd:9_diag:42731 icd:9_diag:4414 icd:9_diag:5853 ZOSTER_VACCINE_LIVE/PF
#
# 560499202280570,2014-10-10,icd:9_diag:37556 icd:9_diag:V0481 icd:9_diag:V202 icd:9_diag:37556 icd:9_diag:V0481 icd:9_diag:V202
#
# 560499202280570,2014-11-13,icd:9_diag:V0481
#
# 560499202280570,2015-08-27,icd:9_diag:0780 icd:9_diag:V0481 icd:9_diag:0780 icd:9_diag:V0481
#
# 560499202282580,2015-02-04,icd:9_diag:V700 VENLAFAXINE_HCL
#
# 560499202282580,2015-03-25,icd:9_diag:311 VENLAFAXINE_HCL
#
# 560499202282580,2015-07-08,icd:9_diag:311 BUPROPION_HCL
#
# 560499202284170,2015-09-17,icd:9_diag:7840 icd:9_diag:R51 icd:9_diag:7840
#
# 560499202284170,2015-10-19,icd:9_diag:7840 icd:9_diag:R51
#
# 560499202286320,2014-03-14,icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V0489 icd:9_diag:V061 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V061 icd:9_diag:V068
#
# 560499202286320,2014-05-14,icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V0489 icd:9_diag:V061 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V061 icd:9_diag:V068 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V040 icd:9_diag:V061 icd:9_diag:V202
#
# 560499202286320,2014-07-16,icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V061 icd:9_diag:V202 icd:9_diag:V0381 icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V061 icd:9_diag:V068
#
# 560499202290350,2015-08-25,icd:9_diag:2449 icd:9_diag:2724 icd:9_diag:56211 icd:9_diag:78060 icd:9_diag:78904 icd:9_diag:78060 icd:9_diag:78904 icd:9_diag:2449 icd:9_diag:2724 icd:9_diag:3051 icd:9_diag:56211 icd:9_diag:5718 icd:9_diag:5718 icd:9_diag:78900 icd:9_diag:56211 icd:9_diag:56983 icd:9_diag:78904 icd:9_diag:56211 icd:9_diag:56983 icd:9_diag:78904 icd:9_proc:9915
#
# 560499202290350,2015-08-26,icd:9_diag:56213
#
# 560499202290350,2015-08-27,icd:9_diag:2449 icd:9_diag:2724 icd:9_diag:56211 icd:9_diag:78060 icd:9_diag:78904 icd:9_diag:56213
#
# 560499202290350,2015-08-28,icd:9_diag:56213 icd:9_diag:7213 icd:9_diag:7873 icd:9_diag:78900
#
# 560499202290350,2015-08-29,icd:9_diag:56213 icd:9_diag:78900
#
# 560499202290350,2015-08-30,icd:9_diag:56213 icd:9_diag:78900 ATORVASTATIN_CALCIUM LEVOTHYROXINE_SODIUM
#
# 560499202290350,2015-08-31,icd:9_diag:56213
#
# 560499202290350,2015-09-01,icd:9_diag:56213 icd:9_diag:78900 LEVOFLOXACIN METRONIDAZOLE ACETAMINOPHEN_WITH_CODEINE
#
# 560499202290350,2015-09-08,icd:9_diag:56213
#
# 560499202292890,2014-12-08,icd:9_diag:2449 icd:9_diag:25000 icd:9_diag:2724 PRAVASTATIN_SODIUM
#
# 560499202292890,2015-03-03,icd:9_diag:2468 icd:9_diag:25000 icd:9_diag:2722 icd:9_diag:78079 icd:9_diag:2468 icd:9_diag:25000 icd:9_diag:2722 icd:9_diag:4611 icd:9_diag:78079 AMOXICILLIN/POTASSIUM_CLAV
#
# 560499202292890,2015-07-06,icd:9_diag:2468 icd:9_diag:25000 icd:9_diag:2722 icd:9_diag:4660 AZITHROMYCIN BENZONATATE LEVOTHYROXINE_SODIUM
#
# 560499202292890,2015-09-21,icd:9_diag:2468 icd:9_diag:25000 icd:9_diag:2722 icd:9_diag:71516 METFORMIN_HCL
#
# 560499202293890,2014-11-07,icd:9_diag:4779 icd:9_diag:V0481
#
# 560499202293890,2015-06-15,icd:9_diag:6918 icd:9_diag:V700
#
# 560499202294140,2014-10-28,icd:9_diag:V700 icd:9_diag:V700 icd:9_diag:V700
#
# 560499202294140,2014-11-05,icd:9_diag:2724 icd:9_diag:33394 icd:9_diag:49390 icd:9_diag:V700 icd:9_diag:2724 icd:9_diag:33394 icd:9_diag:49390 icd:9_diag:V700 ALBUTEROL_SULFATE MOMETASONE_FUROATE
#
# 560499202294480,2014-02-10,icd:9_diag:2449 icd:9_diag:30000 icd:9_diag:311 icd:9_diag:2449 icd:9_diag:2449
#
# 560499202308710,2010-01-05,icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:42731 icd:9_diag:V7644 icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:42731 icd:9_diag:V7644 icd:9_diag:3670 icd:9_diag:3670
#
# 560499202308710,2010-01-09,icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:25000 icd:9_diag:42731
#
# 560499202308710,2010-01-21,icd:9_diag:56210 icd:9_diag:78900 icd:9_diag:56211 icd:9_diag:78904 CIPROFLOXACIN_HCL METRONIDAZOLE
#
# 560499202308710,2010-02-17,icd:9_diag:4254 icd:9_diag:4111 icd:9_diag:42731 icd:9_diag:42823 icd:9_diag:5849
#
# 560499202308710,2010-03-16,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2010-03-26,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2010-04-06,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 WARFARIN_SODIUM
#
# 560499202308710,2010-04-19,icd:9_diag:5990 icd:9_diag:5990
#
# 560499202308710,2010-05-04,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2010-06-01,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2010-06-15,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2010-07-16,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2010-07-26,icd:9_diag:5990 icd:9_diag:5990 icd:9_diag:7881 LEVOFLOXACIN
#
# 560499202308710,2010-08-02,icd:9_diag:5990 NITROFURANTOIN/NITROFURAN_MAC
#
# 560499202308710,2010-08-09,icd:9_diag:5990 icd:9_diag:185 icd:9_diag:59970 icd:9_diag:185 icd:9_diag:59970 icd:9_diag:78841 icd:9_diag:185 icd:9_diag:59970 icd:9_diag:78841
#
# 560499202308710,2010-08-17,icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:4019 icd:9_diag:4254 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:42823 icd:9_diag:78079 icd:9_diag:78701 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:78605 icd:9_diag:78605 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:78605
#
# 560499202308710,2010-08-18,icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079
#
# 560499202308710,2010-08-19,icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079
#
# 560499202308710,2010-08-20,icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079
#
# 560499202308710,2010-08-21,icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079
#
# 560499202308710,2010-08-22,icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079
#
# 560499202308710,2010-08-23,icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78079
#
# 560499202308710,2010-09-10,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2010-09-20,icd:9_diag:59970 LISINOPRIL
#
# 560499202308710,2010-10-25,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25002 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2010-11-19,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25002 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2010-12-02,icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:V5861 icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:V5861
#
# 560499202308710,2010-12-06,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25002 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2011-01-07,icd:9_diag:V5861 icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:4011 icd:9_diag:4271 icd:9_diag:42731
#
# 560499202308710,2011-01-24,icd:9_diag:185 icd:9_diag:185 icd:9_diag:185 icd:9_diag:59971 SULFAMETHOXAZOLE/TRIMETHOPRIM
#
# 560499202308710,2011-01-27,icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:4254 icd:9_diag:4271 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:42823 icd:9_diag:78650 icd:9_diag:V4502 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78609 icd:9_diag:78650 icd:9_diag:3051 icd:9_diag:41090 icd:9_diag:4280 icd:9_diag:41091 icd:9_diag:4280 icd:9_diag:78609 icd:9_diag:78650 icd:9_diag:4280 icd:9_diag:41092 icd:9_diag:78605
#
# 560499202308710,2011-02-11,icd:9_diag:25002 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2011-03-02,icd:9_diag:25002 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2011-04-21,icd:9_diag:25000 icd:9_diag:4254 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:V4501 icd:9_diag:V5861 icd:9_diag:78605 icd:9_diag:25000 icd:9_diag:4254 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78605 icd:9_diag:25000 icd:9_diag:4254 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78605 icd:9_diag:78605
#
# 560499202308710,2011-04-22,icd:9_diag:25000 icd:9_diag:4254 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4254 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:4280 icd:9_diag:78605
#
# 560499202308710,2011-04-23,icd:9_diag:25000 icd:9_diag:4254 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4254 icd:9_diag:42731 icd:9_diag:4280
#
# 560499202308710,2011-05-06,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2011-06-01,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2011-06-10,icd:9_diag:25000 icd:9_diag:4019 icd:9_diag:5990 icd:9_diag:75319 icd:9_diag:78900 icd:9_diag:V4501 icd:9_diag:5990 icd:9_diag:78900 icd:9_diag:5932 icd:9_diag:78650
#
# 560499202308710,2011-07-28,icd:9_diag:25000 icd:9_diag:4011 icd:9_diag:4280 icd:9_diag:49121
#
# 560499202308710,2011-08-03,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2011-09-06,icd:9_diag:185 icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:4019 icd:9_diag:41401 icd:9_diag:4254 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:79902 icd:9_diag:42731 icd:9_diag:4279 icd:9_diag:4280 icd:9_diag:78609 icd:9_diag:78605 icd:9_diag:42731 icd:9_diag:4279 icd:9_diag:4280 icd:9_diag:78609
#
# 560499202308710,2011-09-18,icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78609 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:5119 icd:9_diag:78609 icd:9_diag:78605 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:5119 icd:9_diag:78609
#
# 560499202308710,2011-09-19,icd:9_diag:25000 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:78609 WARFARIN_SODIUM DILTIAZEM_HCL
#
# 560499202308710,2011-10-07,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280
#
# 560499202308710,2011-12-09,icd:9_diag:25000 icd:9_diag:3688 icd:9_diag:25000 icd:9_diag:3688 icd:9_diag:25000 icd:9_diag:36811 icd:9_diag:4271 icd:9_diag:V5861 icd:9_diag:25000 icd:9_diag:36811 icd:9_diag:4271 icd:9_diag:V5861
#
# 560499202308710,2012-01-04,icd:9_diag:185 icd:9_diag:25000 icd:9_diag:2724 icd:9_diag:27651 icd:9_diag:41401 icd:9_diag:4254 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:79092 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:27651 icd:9_diag:4280 icd:9_diag:4589 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:27651 icd:9_diag:4280 icd:9_diag:4589 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:27651 icd:9_diag:4280 icd:9_diag:4589
#
# 560499202308710,2012-01-05,icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 LISINOPRIL
#
# 560499202308710,2012-01-06,icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280
#
# 560499202308710,2012-01-07,icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280
#
# 560499202308710,2012-01-08,icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280
#
# 560499202308710,2012-01-09,icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:41091 icd:9_diag:42731 icd:9_diag:4280 LEVOFLOXACIN FLUCONAZOLE
#
# 560499202308710,2012-02-01,icd:9_diag:36615 icd:9_diag:25000 icd:9_diag:4011 icd:9_diag:4270 icd:9_diag:4280 icd:9_diag:V5861 PAROXETINE_HCL
#
# 560499202308710,2012-03-02,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:V5861
#
# 560499202308710,2012-04-03,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:V5861
#
# 560499202308710,2012-04-17,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:V5861
#
# 560499202308710,2012-05-08,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:V5861
#
# 560499202308710,2012-06-05,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:V5861
#
# 560499202308710,2012-07-03,icd:9_diag:25000 icd:9_diag:4280 icd:9_diag:25000 icd:9_diag:4280
#
# 560499202308710,2012-07-06,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:V5861 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:V5861
#
# 560499202308710,2012-09-07,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:V5861
#
# 560499202308710,2012-11-09,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:V5861
#
# 560499202308710,2013-01-11,icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:V5861 icd:9_diag:25000 icd:9_diag:4271 icd:9_diag:4280 icd:9_diag:V5861
#
# 560499202308710,2013-03-23,icd:9_diag:25000 icd:9_diag:4279 icd:9_diag:78650 icd:9_diag:78650 icd:9_diag:25000 icd:9_diag:4279 icd:9_diag:78650
#
# 560499202308710,2013-08-04,icd:9_diag:5990 icd:9_diag:78909 icd:9_diag:5990 icd:9_diag:78900 SULFAMETHOXAZOLE/TRIMETHOPRIM
#
# 560499202308710,2013-08-17,icd:9_diag:4280 icd:9_diag:5990 icd:9_diag:78959 icd:9_diag:4280 icd:9_diag:5990 icd:9_diag:78959 icd:9_diag:78900 icd:9_diag:78650 icd:9_diag:4280 icd:9_diag:5990 icd:9_diag:78959
#
# 560499202308710,2013-08-18,icd:9_diag:2763 icd:9_diag:78959 icd:9_diag:2763 icd:9_diag:78959 icd:9_diag:78959 icd:9_diag:2763 icd:9_diag:78959 icd:9_diag:2763 icd:9_diag:78959 icd:9_diag:78959 icd:9_diag:78959 icd:9_diag:4280 icd:9_diag:5990 icd:9_diag:78959
#
# 560499202308710,2013-08-20,icd:9_diag:586 icd:9_diag:4111 icd:9_diag:78609 icd:9_diag:78650 icd:9_diag:7873 icd:9_diag:586 icd:9_diag:78650 icd:9_diag:78650 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:586 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:586 icd:9_diag:586 icd:9_diag:78650 BUMETANIDE
#
# 560499202308710,2013-08-21,icd:9_diag:4111 icd:9_diag:2113 icd:9_diag:4550 icd:9_diag:56210 icd:9_diag:7905 icd:9_diag:V7651 icd:9_diag:78609 icd:9_diag:2762 icd:9_diag:4149 icd:9_diag:42823 icd:9_diag:5849 icd:9_diag:78650 icd:9_diag:42731 icd:9_diag:4280
#
# 560499202308710,2013-08-22,icd:9_diag:4111 icd:9_diag:2113 icd:9_diag:4550 icd:9_diag:56210 icd:9_diag:7905 icd:9_diag:V7651 icd:9_diag:78609 icd:9_diag:2762 icd:9_diag:4149 icd:9_diag:42823 icd:9_diag:5849 icd:9_diag:5119 icd:9_diag:514 icd:9_diag:5715 icd:9_diag:78650 icd:9_diag:42731 icd:9_diag:4280
#
# 560499202308710,2013-08-23,icd:9_diag:4280 icd:9_diag:2113 icd:9_diag:4550 icd:9_diag:56210 icd:9_diag:7905 icd:9_diag:V7651 icd:9_diag:78609 icd:9_diag:2762 icd:9_diag:4149 icd:9_diag:42823 icd:9_diag:5849 icd:9_diag:42731 icd:9_diag:4280
#
# 560499202308710,2013-08-24,icd:9_diag:2113 icd:9_diag:4550 icd:9_diag:56210 icd:9_diag:7905 icd:9_diag:V7651 icd:9_diag:78609 icd:9_diag:2768 icd:9_diag:4280 icd:9_diag:5849 icd:9_diag:42731 icd:9_diag:4280
#
# 560499202308710,2013-08-25,icd:9_diag:2113 icd:9_diag:4550 icd:9_diag:56210 icd:9_diag:7905 icd:9_diag:V7651 icd:9_diag:78609 icd:9_diag:5119 icd:9_diag:514 icd:9_diag:5715 icd:9_diag:78650 icd:9_diag:2768 icd:9_diag:4280 icd:9_diag:5849 icd:9_diag:42731 icd:9_diag:4280
#
# 560499202308710,2013-08-26,icd:9_diag:2113 icd:9_diag:4550 icd:9_diag:56210 icd:9_diag:7905 icd:9_diag:V7651 icd:9_diag:78609 icd:9_diag:5119 icd:9_diag:514 icd:9_diag:5715 icd:9_diag:78650 icd:9_diag:2762 icd:9_diag:4149 icd:9_diag:42823 icd:9_diag:5849 icd:9_diag:42731 icd:9_diag:4280
#
# 560499202308710,2013-08-27,icd:9_diag:2113 icd:9_diag:4550 icd:9_diag:56210 icd:9_diag:7905 icd:9_diag:V7651 icd:9_diag:78609 icd:9_diag:2762 icd:9_diag:4149 icd:9_diag:42823 icd:9_diag:5849
#
# 560499202308710,2013-11-01,icd:9_diag:4280 icd:9_diag:4400 icd:9_diag:5180 icd:9_diag:V5881 icd:9_diag:5180 icd:9_diag:V5881 icd:9_diag:V5882 icd:9_diag:2762 icd:9_diag:42731 icd:9_diag:5849 icd:9_diag:99592 icd:9_diag:0389 icd:9_diag:2762 icd:9_diag:2767 icd:9_diag:5849 icd:9_diag:0389 icd:9_diag:2762 icd:9_diag:34982 icd:9_diag:4254 icd:9_diag:51881 icd:9_diag:5849 icd:9_diag:5856 icd:9_diag:5990 icd:9_diag:78552 icd:9_diag:42731 icd:9_diag:4280 icd:9_diag:4589 icd:9_diag:5849 icd:9_diag:42731 icd:9_diag:4280 icd:9_proc:3895 icd:9_proc:3995 icd:9_proc:9390 icd:9_proc:9604 icd:9_proc:9672 icd:9_proc:9960
#
# 560499202313770,2014-11-25,icd:9_diag:V700 icd:9_diag:V700 icd:9_diag:6253 icd:9_diag:V1301 icd:9_diag:V700
#
# 560499202313770,2014-11-26,icd:9_diag:2189 icd:9_diag:V700
#
# 560499202313770,2015-02-05,icd:9_diag:56400 icd:9_diag:78605 icd:9_diag:V1301 ALBUTEROL_SULFATE
#
# 560499202313770,2015-04-30,icd:9_diag:7291 icd:9_diag:7391 icd:9_diag:7393 icd:9_diag:84500
#
# 560499202313770,2015-05-08,icd:9_diag:V700 icd:9_diag:V700 icd:9_diag:79380 icd:9_diag:V1301
#
# 560499202315610,2011-06-29,icd:9_diag:311 icd:9_diag:311 PAROXETINE_HCL
#
# 560499202315610,2013-01-11,icd:9_diag:V7260 icd:9_diag:V7260 icd:9_diag:V7260 icd:9_diag:V7260 icd:9_diag:V0481
#
# 560499202315610,2014-01-09,icd:9_diag:V700 icd:9_diag:311 icd:9_diag:V700 icd:9_diag:311 icd:9_diag:V700 icd:9_diag:311 icd:9_diag:V700 icd:9_diag:311 icd:9_diag:V700
#
# 560499202378810,2014-04-21,icd:9_diag:72741 icd:9_diag:V700
#
# 560499202384380,2015-04-07,icd:9_diag:V2382 icd:9_diag:V2385 icd:9_diag:V2389 icd:9_diag:V2382 icd:9_diag:V2385 icd:9_diag:V2389 icd:9_diag:V2382 icd:9_diag:V2385 icd:9_diag:V2389
#
# 560499202384380,2015-05-26,icd:9_diag:V2382 icd:9_diag:V2385 icd:9_diag:V2389 icd:9_diag:V221 icd:9_diag:V221 icd:9_diag:V221 icd:9_diag:V221 icd:9_diag:V221 icd:9_diag:V221 icd:9_diag:V221 icd:9_diag:V221 icd:9_diag:V2382 icd:9_diag:V2385 icd:9_diag:V2389
#
# 560499202384380,2015-06-04,icd:9_diag:7965 icd:9_diag:V2382 icd:9_diag:V2385 icd:9_diag:V2389 icd:9_diag:7965 icd:9_diag:V2382 icd:9_diag:V2389
#
# 560499202384380,2015-06-23,icd:9_diag:V2385 icd:9_diag:V2389
#
# 560499202384380,2015-07-21,icd:9_diag:V2389 icd:9_diag:V2389
#
# 560499202384380,2015-08-18,icd:9_diag:64110 icd:9_diag:64113 icd:9_diag:V2385 icd:9_diag:V2389
#
# 560499202384380,2015-09-01,icd:9_diag:V2385 icd:9_diag:V2389
#
# 560499202384380,2015-09-22,icd:9_diag:V221 icd:9_diag:V2385 icd:9_diag:V221 icd:9_diag:V2385 icd:9_diag:V221 icd:9_diag:V2385
#
# 560499202384380,2015-09-28,icd:9_diag:V2385 icd:9_diag:V2389 icd:9_diag:V2385 icd:9_diag:V2389
#
# 560499202386570,2014-04-21,icd:9_diag:5368 icd:9_diag:56409 icd:9_diag:78906
#
# 560499202386570,2015-03-20,icd:9_diag:4619 icd:9_diag:78079 icd:9_diag:7862 AZITHROMYCIN PROMETHAZINE_HCL/CODEINE
#
# ...
#
# 560499208324380,2015-04-21,icd:9_diag:V7231 icd:9_diag:2410 icd:9_diag:69279 icd:9_diag:V700 icd:9_diag:V7231
#
# 560499208324720,2014-01-08,icd:9_diag:1539 icd:9_diag:4019 icd:9_diag:7852 icd:9_diag:V700 icd:9_diag:1539 icd:9_diag:4019 icd:9_diag:7852 icd:9_diag:V700 LISINOPRIL/HYDROCHLOROTHIAZIDE
#
# 560499208324720,2015-01-13,icd:9_diag:2724 icd:9_diag:2724 icd:9_diag:7179 icd:9_diag:7852 icd:9_diag:V700 icd:9_diag:2724 icd:9_diag:7179 icd:9_diag:7852 icd:9_diag:V700 icd:9_diag:2724 icd:9_diag:4019 icd:9_diag:7179 icd:9_diag:7852 icd:9_diag:V700 icd:9_diag:V1005 ATORVASTATIN_CALCIUM
#
# 560499208324720,2015-01-14,icd:9_diag:2724 icd:9_diag:4019 icd:9_diag:7179 icd:9_diag:7852 icd:9_diag:V700
#
# 560499208324720,2015-01-17,icd:9_diag:78650 icd:9_diag:78650 icd:9_diag:78650 icd:9_diag:78651 icd:9_diag:4111 icd:9_diag:78650
#
# 560499208325570,2014-02-08,icd:9_diag:25000 icd:9_diag:5990 icd:9_diag:V7231 icd:9_diag:5990 icd:9_diag:61610 icd:9_diag:V745 icd:9_diag:V7231
#
# 560499208325570,2015-03-24,icd:9_diag:V700
#
# 560499208325570,2015-08-12,icd:9_diag:5990 icd:9_diag:5990 icd:9_diag:7242 icd:9_diag:V8535
#
# 560499208325570,2015-08-18,icd:9_diag:4019 icd:9_diag:5990 icd:9_diag:7242 icd:9_diag:72885
#
# 560499208325570,2015-08-22,icd:9_diag:5990
#
# 560499208325920,2015-03-09,icd:9_diag:4619
#
# 560499208326070,2014-03-05,icd:9_diag:78605 icd:9_diag:78605 icd:9_diag:27800 icd:9_diag:29636 icd:9_diag:4011 icd:9_diag:4553 LISINOPRIL
#
# 560499208326070,2015-02-27,icd:9_diag:311 icd:9_diag:4019 icd:9_diag:78906 icd:9_diag:78650 icd:9_diag:78659 icd:9_diag:78909 icd:9_diag:8471
#
# 560499208326170,2014-01-29,icd:9_diag:7291 icd:9_diag:V0481 icd:9_diag:V1005 icd:9_diag:V700
#
# 560499208326170,2014-01-30,icd:9_diag:V700 ETODOLAC
#
# 560499208326170,2014-07-23,icd:9_diag:2722 icd:9_diag:4400 icd:9_diag:V1005 icd:9_diag:V700 icd:9_diag:2689 icd:9_diag:5852 icd:9_diag:79029
#
# 560499208326170,2014-09-10,icd:9_diag:2689 icd:9_diag:5852 icd:9_diag:V1005 icd:9_diag:V700 icd:9_diag:V7231
#
# 560499208326170,2015-01-20,icd:9_diag:2722 icd:9_diag:78930 icd:9_diag:V700
#
# 560499208326170,2015-08-13,icd:9_diag:3670 icd:9_diag:3674 icd:9_diag:V720
#
# 560499208326260,2014-05-01,icd:9_diag:25000 icd:9_diag:36615 icd:9_diag:36616 icd:9_diag:V431
#
# 560499208326260,2014-08-14,icd:9_diag:25000 icd:9_diag:36250 icd:9_diag:36616 icd:9_diag:36650 ALLOPURINOL
#
# 560499208326260,2015-07-16,icd:9_diag:36250 icd:9_diag:36650 icd:9_diag:25000 icd:9_diag:36250 icd:9_diag:36616 icd:9_diag:37924 icd:9_diag:36250 icd:9_diag:36650 icd:9_diag:25000 icd:9_diag:36250 icd:9_diag:36616 icd:9_diag:37924 PREDNISOLONE_ACETATE
#
# 560499208326260,2015-07-21,icd:9_diag:25000 icd:9_diag:2722 icd:9_diag:4011
#
# 560499208326400,2014-03-28,icd:9_diag:25000 icd:9_diag:36615 icd:9_diag:37515 icd:9_diag:V801
#
# 560499208326400,2014-05-05,icd:9_diag:25080 icd:9_diag:2724 icd:9_diag:2875 icd:9_diag:59970 icd:9_diag:2875 icd:9_diag:59970 icd:9_diag:7245 icd:9_diag:2875 icd:9_diag:59970
#
# 560499208326400,2014-05-09,icd:9_diag:7245 icd:9_diag:36721 icd:9_diag:V720
#
# 560499208326400,2015-03-04,icd:9_diag:4439 icd:9_diag:56400 icd:9_diag:7821 icd:9_diag:V7651 icd:9_diag:V801 icd:9_diag:V700 TRIAMCINOLONE_ACETONIDE
#
# 560499208326400,2015-06-03,icd:9_diag:1121 icd:9_diag:2875 icd:9_diag:5990 icd:9_diag:V7651 icd:9_diag:25080 icd:9_diag:5990 SULFAMETHOXAZOLE/TRIMETHOPRIM
#
# 560499208326400,2015-08-04,icd:9_diag:5990 icd:9_diag:5990 CIPROFLOXACIN_HCL
#
# 560499208326400,2015-08-12,icd:9_diag:5990
#
# 560499208326400,2015-09-29,icd:9_diag:25080 icd:9_diag:2724 icd:9_diag:2875 icd:9_diag:5999 icd:9_diag:V700 icd:9_diag:25080 icd:9_diag:2875 icd:9_diag:5999 icd:9_diag:25080 icd:9_diag:2875
#
# 560499208326500,2014-03-14,icd:9_diag:V700 icd:9_diag:V700
#
# 560499208326500,2014-03-28,icd:9_diag:4549 icd:9_diag:6253 icd:9_diag:7821 icd:9_diag:V700
#
# 560499208326640,2014-02-14,icd:9_diag:25000 icd:9_diag:78093
#
# 560499208326640,2014-02-17,icd:9_diag:25000 icd:9_diag:V7791 icd:9_diag:25000 icd:9_diag:V700
#
# 560499208326640,2014-04-24,icd:9_diag:2724 icd:9_diag:V7791 icd:9_diag:2724
#
# 560499208326640,2014-08-14,icd:9_diag:25000
#
# 560499208326640,2014-09-08,icd:9_diag:25000 icd:9_diag:4019
#
# 560499208326640,2014-10-03,icd:9_diag:25050 icd:9_diag:25060 icd:9_diag:3572 icd:9_diag:V700 icd:9_diag:V851
#
# 560499208326640,2014-10-27,icd:9_diag:25000
#
# 560499208326640,2014-12-27,icd:9_diag:25000
#
# 560499208326640,2015-01-16,icd:9_diag:2449 icd:9_diag:25000 icd:9_diag:2720 icd:9_diag:2449 icd:9_diag:25000 icd:9_diag:2720
#
# 560499208326640,2015-04-22,icd:9_diag:25000 icd:9_diag:25000 icd:9_diag:25080 icd:9_diag:2724 icd:9_diag:73300 icd:9_diag:V851
#
# 560499208326640,2015-05-14,icd:9_diag:25000 icd:9_diag:73300 NYSTATIN IBANDRONATE_SODIUM NYSTATIN IBANDRONATE_SODIUM
#
# 560499208326640,2015-06-04,icd:9_diag:25000 icd:9_diag:25000
#
# 560499208326640,2015-07-01,icd:9_diag:25000 icd:9_diag:53081 icd:9_diag:5368
#
# 560499208326640,2015-09-04,icd:9_diag:25000
#
# 560499208326640,2015-09-10,icd:9_diag:4400 icd:9_diag:7862 icd:9_diag:25000 icd:9_diag:4659 icd:9_diag:7804 icd:9_diag:25000 icd:9_diag:4400 icd:9_diag:4659 icd:9_diag:7804 icd:9_diag:V0481
#
# 560499208326640,2015-09-17,icd:9_diag:2449 icd:9_diag:25000 icd:9_diag:2720 icd:9_diag:30411
#
# 560499208326950,2014-03-12,icd:9_diag:30000 icd:9_diag:30981 icd:9_diag:311 icd:9_diag:4019 icd:9_diag:53081 icd:9_diag:7140 icd:9_diag:72210 icd:9_diag:75612 icd:9_diag:V454 icd:9_diag:V7283 icd:9_proc:7869 icd:9_proc:8051 icd:9_proc:8107 icd:9_proc:8163 OXYCODONE_HCL/ACETAMINOPHEN
#
# 560499208326950,2014-10-24,icd:9_diag:25000 icd:9_diag:4019 icd:9_diag:72252 OXYCODONE_HCL/ACETAMINOPHEN
#
# 560499208326950,2015-03-31,icd:9_diag:25000 icd:9_diag:4019 icd:9_diag:72252 icd:9_diag:7243
#
# 560499208326950,2015-05-26,icd:9_diag:7244 icd:9_diag:73710 icd:9_diag:7378 icd:9_diag:V454 icd:9_diag:7244 icd:9_diag:73710 icd:9_diag:7378 icd:9_diag:V454 icd:9_diag:07070 icd:9_diag:53081 icd:9_diag:72252 icd:9_diag:73710 icd:9_diag:99649 icd:9_diag:7244 icd:9_diag:7245 icd:9_diag:73382 icd:9_diag:7242 icd:9_diag:7244 icd:9_diag:07070 icd:9_diag:30981 icd:9_diag:4019 icd:9_diag:49390 icd:9_diag:53081 icd:9_diag:56400 icd:9_diag:72252 icd:9_diag:73710 icd:9_diag:99649 icd:9_diag:4011 icd:9_diag:49390 icd:9_diag:7226 icd:9_diag:79902 icd:9_diag:07070 icd:9_diag:30981 icd:9_diag:4019 icd:9_diag:49390 icd:9_diag:53081 icd:9_diag:56400 icd:9_diag:72252 icd:9_diag:73710 icd:9_diag:99649 icd:9_diag:4011 icd:9_diag:49390 icd:9_diag:7226 icd:9_diag:79902 icd:9_proc:3932 icd:9_proc:7859 icd:9_proc:8106 icd:9_proc:8137 icd:9_proc:9904 icd:9_proc:3932 icd:9_proc:7859 icd:9_proc:8106 icd:9_proc:8137 icd:9_proc:9904
#
# 560499208326950,2015-05-27,icd:9_diag:4011 icd:9_diag:49390 icd:9_diag:7226 icd:9_diag:79902 icd:9_diag:4011 icd:9_diag:49390 icd:9_diag:7226 icd:9_diag:79902
#
# 560499208326950,2015-05-30,icd:9_diag:4011 icd:9_diag:49390 icd:9_diag:7226 icd:9_diag:79902
#
# 560499208326950,2015-05-31,icd:9_diag:72210 icd:9_diag:4011 icd:9_diag:49390 icd:9_diag:7226 icd:9_diag:79902 icd:9_diag:4011 icd:9_diag:49390 icd:9_diag:7226 icd:9_diag:79902
#
# 560499208327440,2014-05-16,icd:9_diag:56211 CIPROFLOXACIN_HCL METRONIDAZOLE
#
# 560499208327440,2014-05-29,icd:9_diag:3051 icd:9_diag:4019 icd:9_diag:4409 icd:9_diag:56211 icd:9_diag:71595
#
# 560499208327440,2014-06-02,icd:9_diag:56211
#
# 560499208327440,2014-08-18,icd:9_diag:5990 icd:9_diag:5990 icd:9_diag:71595 LEVOFLOXACIN
#
# 560499208327440,2014-10-29,icd:9_diag:7812 icd:9_diag:V571
#
# 560499208327440,2014-11-12,icd:9_diag:3670 icd:9_diag:36721 icd:9_diag:3674 icd:9_diag:V720 icd:9_diag:3670 icd:9_diag:36721 icd:9_diag:3674
#
# 560499208327440,2015-06-04,icd:9_diag:2724 icd:9_diag:3051 icd:9_diag:4019 icd:9_diag:V0382 icd:9_diag:V700
#
# 560499208327440,2015-08-31,icd:9_diag:33819 icd:9_diag:4019 icd:9_diag:56211 icd:9_diag:7271 icd:9_diag:78904 CIPROFLOXACIN_HCL METRONIDAZOLE
#
# 560499208328060,2014-02-24,icd:9_diag:V7260 icd:9_diag:V7231 icd:9_diag:V762 icd:9_diag:V700 icd:9_diag:V762
#
# 560499208328280,2014-05-01,icd:9_diag:V6541 icd:9_diag:V700 icd:9_diag:V811 icd:9_diag:V8289 icd:9_diag:V8532 icd:9_diag:V700 icd:9_diag:V7610 icd:9_diag:V7641 icd:9_diag:V7644 icd:9_diag:V811 icd:9_diag:27802 icd:9_diag:42781
#
# 560499208328280,2014-12-01,icd:9_diag:41010 icd:9_diag:4111
#
# 560499208328280,2014-12-02,icd:9_diag:41010 icd:9_diag:4111
#
# 560499208328280,2014-12-03,icd:9_diag:41010 icd:9_diag:4111
#
# 560499208328280,2014-12-04,icd:9_diag:41010 icd:9_diag:4111
#
# 560499208328280,2014-12-18,icd:9_diag:412 icd:9_diag:41400 SPIRONOLACTONE
#
# 560499208328280,2015-02-09,icd:9_diag:41400 PRASUGREL_HCL
#
# 560499208328280,2015-02-19,icd:9_diag:412 icd:9_diag:41400 icd:9_diag:42731 icd:9_diag:42822 SIMVASTATIN
#
# 560499208328280,2015-06-18,icd:9_diag:V6541 icd:9_diag:V700 icd:9_diag:V811 icd:9_diag:V8289 icd:9_diag:V8532 icd:9_diag:412 icd:9_diag:4139 icd:9_diag:4160 icd:9_diag:42731 icd:9_diag:4400 icd:9_diag:4019 icd:9_diag:4259 icd:9_diag:60784 icd:9_diag:71945 icd:9_diag:72252 icd:9_diag:27802 icd:9_diag:4139 icd:9_diag:4439 icd:9_diag:60091
#
# 560499208328880,2014-06-30,icd:9_diag:1104 icd:9_diag:25040 icd:9_diag:2749 icd:9_diag:40310 icd:9_diag:4549 icd:9_diag:V7285 icd:9_diag:V8525 KETOCONAZOLE
#
# 560499208328880,2014-08-18,icd:9_diag:1101 icd:9_diag:25000 icd:9_diag:7295
#
# 560499208328880,2014-09-08,icd:9_diag:25000 icd:9_diag:4011 icd:9_diag:5718 icd:9_diag:5920 icd:9_diag:72982 DICLOFENAC_SODIUM
#
# 560499208328880,2015-03-04,icd:9_diag:78650 icd:9_diag:3319 icd:9_diag:7804 icd:9_diag:95901 icd:9_diag:E8889 icd:9_diag:4139 icd:9_diag:78650 icd:9_diag:56210 icd:9_diag:5778 icd:9_diag:75319 icd:9_diag:78900
#
# 560499208328880,2015-03-05,icd:9_diag:27651 icd:9_diag:7804 icd:9_diag:78650 icd:9_diag:78791 icd:9_diag:25000 icd:9_diag:4019 icd:9_diag:78650
#
# 560499208328880,2015-05-05,icd:9_diag:25000 icd:9_diag:2749
#
# 560499208328880,2015-05-20,icd:9_diag:V700
#
# 560499208328880,2015-05-27,icd:9_diag:2449 icd:9_diag:25000 LEVOTHYROXINE_SODIUM
#
# 560499208328880,2015-08-12,icd:9_diag:25000 icd:9_diag:7038 icd:9_diag:7039 icd:9_diag:7295
#
# 560499208328880,2015-08-19,icd:9_diag:25000 icd:9_diag:2749
#
# 560499208328880,2015-08-26,icd:9_diag:2449 icd:9_diag:25000
#
# 560499208329130,2014-04-01,icd:9_diag:5569 icd:9_diag:5693 icd:9_diag:78791 PEG3350/SOD_SUL/NACL/ASB/C/KCL
#
# 560499208329130,2014-04-17,icd:9_diag:56210 icd:9_diag:78900 icd:9_diag:78799
#
# 560499208329130,2014-07-10,icd:9_diag:5990 icd:9_diag:5990 icd:9_diag:7881 icd:9_diag:5990 CIPROFLOXACIN_HCL
#
# 560499208329130,2014-08-06,icd:9_diag:5990 icd:9_diag:5990 icd:9_diag:5990 NITROFURANTOIN_MONOHYD/M-CRYST
#
# 560499208329130,2014-08-26,icd:9_diag:5568 icd:9_diag:5990 icd:9_diag:72610 icd:9_diag:73390 IPRATROPIUM_BROMIDE RISEDRONATE_SODIUM
#
# 560499208329130,2014-10-08,icd:9_diag:V0481 icd:9_diag:71941 icd:9_diag:V0481 ACYCLOVIR GABAPENTIN
#
# 560499208329130,2015-02-04,icd:9_diag:4011 icd:9_diag:5990 icd:9_diag:7881 icd:9_diag:5990 icd:9_diag:5990 CIPROFLOXACIN_HCL
#
# 560499208329130,2015-03-11,icd:9_diag:30000 icd:9_diag:4659 icd:9_diag:5990 icd:9_diag:78052 AZITHROMYCIN
#
# 560499208329130,2015-03-27,icd:9_diag:311 icd:9_diag:34670 icd:9_diag:7231 icd:9_diag:78052
#
# 560499208329130,2015-06-17,icd:9_diag:311 icd:9_diag:34670 icd:9_diag:4429 icd:9_diag:7231 icd:9_diag:78052
#
# 560499208329130,2015-09-16,icd:9_diag:311 icd:9_diag:34670 icd:9_diag:4373 icd:9_diag:7231 icd:9_diag:34690 icd:9_diag:V5873 ZOLMITRIPTAN
#
# 560499208329200,2014-12-16,icd:9_diag:V720
#
# 560499208329200,2015-01-08,icd:9_diag:V720 ATORVASTATIN_CALCIUM VENLAFAXINE_HCL CHLORTHALIDONE
#
# 560499208329380,2014-11-12,icd:9_diag:V0481 icd:9_diag:2724 icd:9_diag:V0481
#
# 560499208329590,2014-09-15,icd:9_diag:1103
#
# 560499208329590,2014-09-25,icd:9_diag:1101 icd:9_diag:60001 icd:9_diag:78650 icd:9_diag:V0481 icd:9_diag:V700
#
# 560499208329590,2014-10-28,icd:9_diag:1101
#
# 560499208329590,2014-11-26,icd:9_diag:1101
#
# 560499208329590,2015-08-12,icd:9_diag:4019 icd:9_diag:5990 icd:9_diag:5990
#
# 560499208329590,2015-09-29,icd:9_diag:53081 icd:9_diag:60001 icd:9_diag:7295 icd:9_diag:V0481 icd:9_diag:V700 icd:9_diag:V8525
#
# 560499208329640,2014-03-27,icd:9_diag:2449 icd:9_diag:2859 icd:9_diag:496 icd:9_diag:V700 icd:9_diag:V0489 LEVOTHYROXINE_SODIUM ZOSTER_VACCINE_LIVE/PF CLOTRIMAZOLE/BETAMETHASONE_DIP
#
# 560499208329640,2014-07-18,icd:9_diag:2113 icd:9_diag:56989 icd:9_diag:V7651 icd:9_diag:2113 icd:9_diag:4550 icd:9_diag:4553 icd:9_diag:56210 icd:9_diag:V7651 icd:9_diag:2113 icd:9_diag:4550 icd:9_diag:56210 icd:9_diag:V7651
#
# 560499208329640,2014-10-15,icd:9_diag:2449 icd:9_diag:5277 icd:9_diag:78321 icd:9_diag:7859 icd:9_diag:V0481
#
# 560499208329640,2014-12-19,icd:9_diag:07810 icd:9_diag:1104 LEVOTHYROXINE_SODIUM NYSTATIN
#
# 560499208329640,2015-02-12,icd:9_diag:1103 icd:9_diag:4439 icd:9_diag:496 ECONAZOLE_NITRATE
#
# 560499208329640,2015-03-02,icd:9_diag:1103 FLUCONAZOLE
#
# 560499208329810,2014-02-28,icd:9_diag:41400 LEVOCETIRIZINE_DIHYDROCHLORIDE HYDROXYCHLOROQUINE_SULFATE ALFUZOSIN_HCL ATORVASTATIN_CALCIUM CIMETIDINE FINASTERIDE
#
# 560499208329810,2014-03-27,icd:9_diag:2724 icd:9_diag:41400 ATORVASTATIN_CALCIUM
#
# 560499208329810,2015-04-17,icd:9_diag:27801 icd:9_diag:33829 icd:9_diag:412 icd:9_diag:49392 icd:9_diag:V8535 HYDROCODONE/ACETAMINOPHEN
#
# 560499208329810,2015-07-17,icd:9_diag:49392 icd:9_diag:78605 icd:9_diag:2724 icd:9_diag:3559 icd:9_diag:4019 icd:9_diag:412 icd:9_diag:41400 icd:9_diag:49392 icd:9_diag:53081 icd:9_diag:60000 icd:9_diag:7140
#
# 560499208329810,2015-07-18,icd:9_diag:2724 icd:9_diag:3559 icd:9_diag:4019 icd:9_diag:412 icd:9_diag:41400 icd:9_diag:49392 icd:9_diag:53081 icd:9_diag:60000 icd:9_diag:7140
#
# 560499208342920,2014-10-17,icd:9_diag:V0481
#
# 560499208342920,2015-01-22,icd:9_diag:V0382 icd:9_diag:V0489 icd:9_diag:V1201 icd:9_diag:V700 icd:9_diag:V7791
#
# 560499208342920,2015-02-19,icd:9_diag:30000 icd:9_diag:311 icd:9_diag:4019 icd:9_diag:78052 icd:9_diag:7862
#
# 560499208342920,2015-03-20,icd:9_diag:30000 icd:9_diag:311 icd:9_diag:4019 icd:9_diag:7862 icd:9_diag:V829 ALBUTEROL_SULFATE TRAZODONE_HCL
#
# 560499208342920,2015-06-11,icd:9_diag:311 icd:9_diag:3899 icd:9_diag:40599 icd:9_diag:78052 icd:9_diag:7862
#
# 560499208342920,2015-09-22,icd:9_diag:5738 icd:9_diag:5779 icd:9_diag:7243 icd:9_diag:V700
#
# 560499208342930,2015-05-04,icd:9_diag:1869 icd:9_diag:7245 icd:9_diag:78901 icd:9_diag:V700 icd:9_diag:1869 icd:9_diag:7245 icd:9_diag:78901 icd:9_diag:V700 NAPROXEN
#
# 560499208342930,2015-05-13,icd:9_diag:V700
#
# 560499208344040,2015-04-09,icd:9_diag:V700
#
# 560499208344040,2015-04-15,icd:9_diag:V700
#
# 560499208344140,2014-12-24,icd:9_diag:311 icd:9_diag:319 icd:9_diag:4019 icd:9_diag:7422
#
# 560499208344140,2015-03-16,icd:9_diag:27801 icd:9_diag:29900 icd:9_diag:4019 icd:9_diag:7422 icd:9_diag:V700
#
# 560499208344140,2015-09-16,icd:9_diag:V0481
#
# 560499208344190,2014-02-06,icd:9_diag:60000 icd:9_diag:2724 icd:9_diag:60000 icd:9_diag:7905 icd:9_diag:V7260 icd:9_diag:V0481 icd:9_diag:V8521
#
# 560499208344190,2014-06-18,icd:9_diag:7231 icd:9_diag:7245 icd:9_diag:7231 icd:9_diag:7245 icd:9_diag:78052 icd:9_diag:V700 icd:9_diag:V709 TEMAZEPAM
#
# 560499208344210,2014-02-14,icd:9_diag:2720 icd:9_diag:311 icd:9_diag:4011 icd:9_diag:60000 icd:9_diag:7231
#
# 560499208344210,2014-07-16,icd:9_diag:2720 icd:9_diag:5789 icd:9_diag:7242 icd:9_diag:79029 icd:9_diag:V700
#
# 560499208344210,2014-10-27,icd:9_diag:311 icd:9_diag:4011 icd:9_diag:70219 icd:9_diag:7231 icd:9_diag:V0481 icd:9_diag:2720 icd:9_diag:311 icd:9_diag:4011 icd:9_diag:7231 icd:9_diag:V8534 icd:9_diag:311 icd:9_diag:4011 icd:9_diag:70219 icd:9_diag:7231 icd:9_diag:V0481 HYDROCODONE/ACETAMINOPHEN
#
# 560499208344210,2015-03-27,icd:9_diag:4019 icd:9_diag:56400 icd:9_diag:7921 icd:9_diag:V7651 OMEPRAZOLE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-477-1a712fcebcf7> in <module>
#       7         for line in raw:
#       8             for token in icd10_9:
# ----> 9                 if f'icd:9_diag:{token}' in line:
#      10                     print(line)
#      11                     break
#
# KeyboardInterrupt:

# %%
icd10_9 = fail.intersection(icd10)

# %%
icd10_9
# Out:
# {'I4510',
#  'I482',
#  'C4440',
#  'H402211',
#  'H20013',
#  'L270',
#  'N870',
#  'L080',
#  'M84333A',
#  'D61818',
#  'S82402S',
#  'M25762',
#  'F0150',
#  'W260XXA',
#  'E0865',
#  'H01003',
#  'C786',
#  'S83206A',
#  'I479',
#  'I77819',
#  'R110',
#  'Z9225',
#  'R1031',
#  'K9420',
#  'S066X0A',
#  'J939',
#  'H401122',
#  'L089',
#  'I4949',
#  'N261',
#  'E11621',
#  '7390',
#  'S72002A',
#  'I517',
#  'Z3403',
#  'H353124',
#  'R2689',
#  'E889',
#  'W540XXA',
#  'S39013A',
#  'H179',
#  'L89310',
#  'S76812D',
#  'S4292XA',
#  'D0359',
#  'E1343',
#  'C8190',
#  'M5414',
#  'S0083XA',
#  'C8512',
#  'H5442',
#  'N186',
#  'S3314',
#  '84409',
#  'A4189',
#  'M94261',
#  'M9943',
#  'Z452',
#  'W19XXXA',
#  'I87323',
#  '5609',
#  'K269',
#  'M4316',
#  'Z96649',
#  'Z6835',
#  'M8589',
#  'J918',
#  'T792XXS',
#  'G301',
#  'C7802',
#  'H5710',
#  'M25461',
#  'M8710',
#  'T889XXD',
#  'F325',
#  'M24172',
#  'H04423',
#  'F1010',
#  'S61412A',
#  'S12101A',
#  'M2557',
#  'E440',
#  'M9904',
#  'S60511A',
#  'N6021',
#  'I213',
#  'M50222',
#  'G0491',
#  'I8390',
#  'M990',
#  'H10503',
#  'I69319',
#  'S065X9A',
#  'C132',
#  'Z6826',
#  'M9240',
#  'E2749',
#  'Z4802',
#  'R7981',
#  'K319',
#  'C20',
#  'M4603',
#  'Z9189',
#  'Z6822',
#  'I6522',
#  'R2681',
#  'I739',
#  'M9908',
#  'Z6842',
#  'I712',
#  'M5380',
#  'L232',
#  'K7040',
#  'G543',
#  'S7002XA',
#  'K9409',
#  'K8000',
#  'S01111A',
#  'T17908A',
#  'E43',
#  'B070',
#  'R412',
#  'K8580',
#  'R12',
#  'H02115',
#  'I1310',
#  'M87011',
#  'C888',
#  'R2780',
#  'S301XXA',
#  'T8542XD',
#  'Z62820',
#  'J9611',
#  'J984',
#  'R198',
#  'Z7983',
#  'R001',
#  'F209',
#  'I361',
#  'S63231A',
#  'Z96659',
#  'K900',
#  'R87615',
#  'H02403',
#  'P925',
#  'L539',
#  '83901',
#  'M11842',
#  'R6882',
#  'L308',
#  'H0012',
#  'R410',
#  'G9781',
#  'S73014A',
#  'I83012',
#  'N442',
#  'N858',
#  'H20011',
#  'H401311',
#  'S8010XA',
#  'S83281A',
#  'H35032',
#  'Z89611',
#  'M25651',
#  'M0609',
#  'M545',
#  'I350',
#  'H3522',
#  'H353221',
#  'N86',
#  'D630',
#  'S91012A',
#  'H547',
#  'C8319',
#  'F918',
#  'I511',
#  'R369',
#  'K7469',
#  'S50362A',
#  'H401432',
#  'M19019',
#  'Z89431',
#  'Q935',
#  'M5440',
#  'M25469',
#  'A084',
#  'R824',
#  'B370',
#  'L84',
#  'D3001',
#  'G43C0',
#  'R21',
#  'M751',
#  'L710',
#  'J158',
#  'M7710',
#  'M961',
#  'M179',
#  'R569',
#  'H35363',
#  'H11002',
#  'M20012',
#  'H40053',
#  'Z2821',
#  'C8590',
#  'D701',
#  'K130',
#  'T65223S',
#  'H65111',
#  'C672',
#  'H02401',
#  'M23221',
#  'S0012XA',
#  'D518',
#  'R489',
#  'R800',
#  'E113213',
#  'S82302D',
#  'K7200',
#  'I63512',
#  'M19071',
#  'L89320',
#  'I82531',
#  'S82832A',
#  'C7A8',
#  'I509',
#  'I77810',
#  'S4990XA',
#  'Z392',
#  'Y92410',
#  'I83028',
#  'H01006',
#  'H33302',
#  'I82442',
#  'Z7901',
#  'S82854D',
#  'E870',
#  'G4730',
#  'D4410',
#  'M84422S',
#  'S82141K',
#  'C170',
#  'H353120',
#  'Z231',
#  'M4047',
#  'H401390',
#  'H5371',
#  'E11331',
#  'D127',
#  'A9999',
#  'Q150',
#  'E1340',
#  'F5001',
#  'S83281D',
#  'V720',
#  'H47299',
#  'H539',
#  'E786',
#  'J1289',
#  'N2581',
#  'L739',
#  'R945',
#  'M24549',
#  'B450',
#  'J339',
#  'Z3481',
#  'M500',
#  'M25375',
#  'M4854XA',
#  'Z4509',
#  'H00022',
#  'D101',
#  'H11153',
#  'M25422',
#  'S82001D',
#  'Z8041',
#  'H5712',
#  'Z418',
#  'F329',
#  'R2989',
#  'N19',
#  'R5082',
#  'H2101',
#  'I495',
#  'E113511',
#  'R41840',
#  'M79642',
#  'H35033',
#  'R1312',
#  'C154',
#  'H353123',
#  'I70233',
#  'L820',
#  'S63591D',
#  'I6529',
#  'L859',
#  'K640',
#  'S71009A',
#  'M8588',
#  'F840',
#  'F330',
#  'M222X2',
#  'Z6839',
#  'S92512D',
#  'M4306',
#  'E749',
#  'M5415',
#  'E1159',
#  'K5732',
#  'S62001A',
#  'L03311',
#  'I69939',
#  'G44319',
#  'D352',
#  'Z87440',
#  'I25119',
#  'Y92009',
#  'M3131',
#  'S70369A',
#  'M2242',
#  'K648',
#  'S93491D',
#  'F89',
#  'M21949',
#  'M75120',
#  'E089',
#  'T50995A',
#  'M0569',
#  'I749',
#  'S0420XA',
#  'R683',
#  'R9900',
#  'Z955',
#  'D4101',
#  'B029',
#  'I63431',
#  'A480',
#  'R69',
#  'Z0000',
#  'H40831',
#  'O7582',
#  'I255',
#  'E874',
#  'M62831',
#  'D470',
#  'B964',
#  '7812',
#  '7803',
#  'Z7689',
#  'T82590A',
#  'S46001D',
#  'H02409',
#  'Z0001',
#  'Z01818',
#  'F340',
#  '82900',
#  'F0390',
#  'L97213',
#  'G44219',
#  'G9009',
#  'F334',
#  'L89152',
#  'H02005',
#  'E7800',
#  'S46092A',
#  'M41112',
#  'D839',
#  'H8001',
#  'C182',
#  'H5212',
#  'D569',
#  'A047',
#  'S902',
#  'G893',
#  'Z89512',
#  'J42',
#  'H25091',
#  'F422',
#  'S3210XA',
#  'S5292XA',
#  'M4640',
#  'M14672',
#  '4619',
#  'S069X9A',
#  'Z6379',
#  'C50219',
#  'E1321',
#  'I82401',
#  'H2640',
#  'M25519',
#  'H402233',
#  'M6520',
#  'H81393',
#  'O770',
#  'E9318',
#  'S63052D',
#  'Z411',
#  'G40909',
#  'N809',
#  'Z7984',
#  'D689',
#  'J690',
#  'H02052',
#  'Z8572',
#  'Z6828',
#  'T63301A',
#  'G43011',
#  'S20229A',
#  'D2272',
#  'M7592',
#  'E1021',
#  'S60222A',
#  'M71812',
#  'Z1389',
#  'K8062',
#  'D6959',
#  'Z1231',
#  'O09899',
#  'V9999',
#  'M7502',
#  'M542',
#  'E789',
#  'B9729',
#  'M5442',
#  'S62356A',
#  'D0439',
#  'J929',
#  'V899XXA',
#  'R278',
#  'S92002A',
#  'E113512',
#  'R499',
#  'S4381XA',
#  'A411',
#  'H401323',
#  'J4542',
#  'Z999',
#  'C181',
#  'S92352A',
#  'F1510',
#  'G450',
#  'S63509A',
#  'R718',
#  'M47896',
#  'T7840XA',
#  'M7541',
#  'K30',
#  'S72402B',
#  'R509',
#  'G64',
#  'S61432A',
#  'I69392',
#  'G40309',
#  'L97513',
#  'T84023A',
#  'N185',
#  'H401290',
#  'S5290XA',
#  'E8589',
#  'D3615',
#  'Z0130',
#  'I82629',
#  'L7211',
#  'O99810',
#  'R350',
#  'H35353',
#  'I70212',
#  'C8594',
#  'C9111',
#  'I70239',
#  'Z391',
#  'C210',
#  'S12401D',
#  'D369',
#  'M79673',
#  'D849',
#  'I493',
#  'Z515',
#  'I708',
#  'E11649',
#  'D069',
#  'M5417',
#  'F4321',
#  'Z45010',
#  'E860',
#  'Z4789',
#  'E0486',
#  'Z8249',
#  'Z8781',
#  'C9142',
#  'S83282D',
#  'I25810',
#  'Q381',
#  'M4697',
#  'N178',
#  'R7982',
#  'K859',
#  'S42301A',
#  'H02849',
#  'S99921A',
#  'G90512',
#  'N183',
#  'S66526A',
#  'H348112',
#  'K0253',
#  'S335',
#  'K429',
#  'N2889',
#  '8395',
#  'B340',
#  'F070',
#  'R229',
#  'M3320',
#  'D4620',
#  'S72402D',
#  'Z170',
#  'N528',
#  'E1140',
#  'T68XXXA',
#  'M19049',
#  'F09',
#  'C189',
#  'C029',
#  'S52532A',
#  'I779',
#  'E069',
#  'I5043',
#  'V4940XA',
#  'H526',
#  'E039',
#  'L97522',
#  'Z87891',
#  'D751',
#  'M2604',
#  'M3130',
#  'S43421D',
#  'S72031A',
#  'S72146A',
#  'K861',
#  'S86111A',
#  'Z5112',
#  'R40241',
#  'G40401',
#  'C6990',
#  'S9780XS',
#  'R0902',
#  'S8263XA',
#  '82525',
#  'M89312',
#  'M159',
#  'M79632',
#  'C4402',
#  'F05',
#  'M7510',
#  'Z008',
#  'M19211',
#  'I951',
#  'C4492',
#  'H538',
#  'S0590XA',
#  'R070',
#  'C009',
#  'S46012D',
#  'C9211',
#  'G40801',
#  'G8928',
#  'H029',
#  'W228XXA',
#  'K51511',
#  'S42002D',
#  'Z3400',
#  'I69398',
#  'G5690',
#  'Z302',
#  'R3129',
#  'K625',
#  'U9999',
#  'C44622',
#  'M79622',
#  'K8071',
#  'G609',
#  'M7652',
#  '412',
#  'S5011XS',
#  'R195',
#  'S86811A',
#  'T50904A',
#  'H2512',
#  'N393',
#  'M7981',
#  'L89323',
#  'C50211',
#  'T300',
#  'Z3141',
#  'H353112',
#  'E038',
#  'S81812D',
#  'G6281',
#  'M93271',
#  'Z8701',
#  'I491',
#  'Z96612',
#  'H401131',
#  'K5720',
#  'H02012',
#  'Z8742',
#  'R54',
#  'M21612',
#  'M629',
#  '25000',
#  'S70362A',
#  'I69359',
#  'H0289',
#  'D46C',
#  'C3411',
#  'G250',
#  'I6031',
#  'H59091',
#  'E282',
#  'M21379',
#  'M25621',
#  'H35373',
#  'Q612',
#  'M205X2',
#  'H35352',
#  'N3091',
#  'C8419',
#  'H353290',
#  'M8458XD',
#  'S7290XA',
#  'I5031',
#  'A6920',
#  'E103493',
#  'L02511',
#  'H401190',
#  'M79662',
#  'R202',
#  'M5489',
#  'E83118',
#  'L89211',
#  'Z136',
#  'M65841',
#  'R6511',
#  'R488',
#  'H35453',
#  'H6980',
#  'L89529',
#  'L906',
#  'R8279',
#  'B389',
#  'N4232',
#  'K5190',
#  'H25033',
#  'S199XXD',
#  'L97514',
#  'I159',
#  'Z87311',
#  'M069',
#  'Z9119',
#  'L7451',
#  'L851',
#  'G839',
#  'K7041',
#  'M85852',
#  'M4180',
#  'O368930',
#  'W101XXS',
#  'M25632',
#  'Z0100',
#  'C9110',
#  'Z1273',
#  'C155',
#  'S24114S',
#  'H43811',
#  'T162XXA',
#  'Z85841',
#  'Z973',
#  'S22009A',
#  'V877XXA',
#  'S3993XA',
#  'I63131',
#  'M25562',
#  'S52531S',
#  'B965',
#  'G5720',
#  'Q078',
#  'I70245',
#  'J986',
#  'S72091D',
#  'L03317',
#  'K222',
#  'Q761',
#  'M25429',
#  'M67911',
#  'I611',
#  'S0991XA',
#  'T86828',
#  'M533',
#  'S63437A',
#  'G5772',
#  'D1630',
#  'T8611',
#  'Z1383',
#  'V700',
#  'V4950XA',
#  'R312',
#  'N509',
#  'H6502',
#  'S83241D',
#  'M8088XA',
#  'O2621',
#  'S76002A',
#  'R251',
#  'H278',
#  'S8011XA',
#  'K0252',
#  'E113553',
#  'B379',
#  'S62666D',
#  'Q442',
#  'I5022',
#  'L814',
#  'G464',
#  'G621',
#  'P926',
#  'H2501',
#  'I82433',
#  'S22089A',
#  'B9620',
#  'Z9079',
#  'K047',
#  'M24851',
#  'R0000',
#  'L97221',
#  'G5620',
#  'H43399',
#  'H11159',
#  'M25551',
#  'Z8042',
#  'R29898',
#  'E2740',
#  'Z639',
#  'Z559',
#  'S52592D',
#  'Z3A36',
#  'B353',
#  'S52531A',
#  'L709',
#  'L569',
#  'R413',
#  'N9410',
#  'I099',
#  'E784',
#  'S62307A',
#  'C541',
#  'H353111',
#  'I82602',
#  'N390',
#  'H401133',
#  'T438X5S',
#  'S0101XA',
#  'D688',
#  'N4340',
#  'S72402A',
#  'G44229',
#  'T8131XD',
#  'H0014',
#  'S0993XD',
#  'D72829',
#  'S46912A',
#  'R402410',
#  'H40012',
#  'I38',
#  'R791',
#  'H16072',
#  'S62212D',
#  'H59031',
#  'L509',
#  'I158',
#  'M549',
#  'C44311',
#  'M25512',
#  'H33102',
#  'H60501',
#  'H01019',
#  'H2513',
#  'G5762',
#  'D693',
#  'F909',
#  'C44609',
#  'G589',
#  'N83299',
#  'I70243',
#  'R0982',
#  'C561',
#  'E230',
#  'S52325A',
#  'N938',
#  'H90A21',
#  'K1321',
#  'I69951',
#  'M278',
#  'S335X',
#  'M2550',
#  'N401',
#  'M1039',
#  'L89621',
#  'H5052',
#  'M659',
#  'N6012',
#  'M8708',
#  'Q758',
#  'H02106',
#  'R769',
#  'M7061',
#  'G5603',
#  'S42291A',
#  'D259',
#  'H520',
#  'M86179',
#  'R261',
#  'M5030',
#  'Z1151',
#  'D721',
#  'M26609',
#  'M25674',
#  'S70922A',
#  'S81811A',
#  'C4911',
#  'M21172',
#  'M869',
#  'L97222',
#  'I25111',
#  'Z5111',
#  'E790',
#  'F82',
#  'O99213',
#  'B079',
#  'M109',
#  'M9973',
#  'R531',
#  'M6283',
#  'D122',
#  'I871',
#  'H8110',
#  'M2041',
#  'H43819',
#  'Z853',
#  'K55069',
#  'J45909',
#  'C168',
#  'E1010',
#  'E113591',
#  'C73',
#  'C9000',
#  'R319',
#  'R938',
#  'C9030',
#  'H26493',
#  'Z951',
#  'D72820',
#  'N3080',
#  'D46Z',
#  'L03811',
#  'L272',
#  'M19039',
#  'B078',
#  'S63511A',
#  'G43109',
#  'D229',
#  '59500',
#  'H9193',
#  'S52615A',
#  'H5340',
#  'S20212A',
#  'M13862',
#  'H43813',
#  'W1839XD',
#  'C49A0',
#  'H401130',
#  'Z006',
#  'M25612',
#  'I5042',
#  'Z3A08',
#  'M50123',
#  'J310',
#  'H348320',
#  'H353110',
#  'M2392',
#  'Z9484',
#  'H9071',
#  'M7731',
#  'J9851',
#  'I1311',
#  'F902',
#  'K51219',
#  'G10',
#  'H5203',
#  'K090',
#  'S0181XA',
#  'Z791',
#  'G5601',
#  'C44519',
#  'J9610',
#  'I80209',
#  'S63502A',
#  'N059',
#  'R918',
#  'I82412',
#  'M3210',
#  'M729',
#  'H9190',
#  'M75111',
#  'M79603',
#  'N993',
#  'H401191',
#  'I87313',
#  'W57XXXA',
#  'H43391',
#  'I499',
#  'M4712',
#  'L910',
#  'Z8603',
#  'T887XXA',
#  'J343',
#  'Z049',
#  'E869',
#  'M7732',
#  'H40059',
#  'L03113',
#  'S91002D',
#  'N521',
#  'H6123',
#  'T63421A',
#  'I129',
#  'O321XX1',
#  'I25700',
#  'H3589',
#  'J3081',
#  'J80',
#  'G43709',
#  'I97190',
#  'T8452XA',
#  'J84112',
#  'L565',
#  'H66011',
#  'M84750A',
#  'E08319',
#  'M25552',
#  'T8092XA',
#  'K045',
#  'M25559',
#  'S46002D',
#  'H52203',
#  'M999',
#  'N135',
#  'K8070',
#  'A419',
#  'J312',
#  'I4891',
#  'I6930',
#  'K432',
#  'R471',
#  'G5602',
#  'C4491',
#  'C7801',
#  'C792',
#  'S239XXA',
#  'I25708',
#  'S43014S',
#  'Z01812',
#  'I82403',
#  'H359',
#  'K5669',
#  'I5041',
#  'S2243XA',
#  'F312',
#  'Z13220',
#  'X780XXA',
#  'S92403A',
#  'Z3A17',
#  'Z634',
#  'H40022',
#  'Z08',
#  'I6789',
#  'M5126',
#  'C44222',
#  'J1108',
#  'H3509',
#  'S86911A',
#  'S99911A',
#  'R8290',
#  'S93492A',
#  'Z1635',
#  'B351',
#  'H31021',
#  'M79674',
#  'N8111',
#  'M79671',
#  'M5127',
#  ...}

# %%
z = [t for t in diag_icd9 if t[0] == '0']
ext = [t.replace('.', '') for t in test]

# %%
# miss = []
# cat = 0
# for t in z:
#     if t in ext:
#         cat +=1 
#     else:
#         miss.append(t)

# miss

# %%
# import re

# result = []
# pattern = '^.*0{3}$'
# for diag in diag_icd9:
#     if re.search(pattern, diag):
#         result.append(diag)
# result

# %%
[token for token in diag_icd9 if '0350' in token]
# Out:
# ['80350', '40350', '03500']

# %%
# [token for token in diag_icd9 if len(token) > 5]

[token for token in diag_icd9 if '024' in token]
# Out:
# ['20240',
#  '90240',
#  'S0240CA',
#  '40240',
#  'H02403',
#  'H02409',
#  'H02401',
#  '30240',
#  '80240']

# %%
# [ key for key in icd_map if '.' not in key]

# %%
icd9 = icd_map_df['icd9']
icd9_points = icd9.str.split('.', expand=True)
icd9_p_len = icd9_points[1].apply(lambda x: len(x) if x else 0)

icd9_p_len.value_counts()
# Out:
# 2    9065
# 1    5201
# 0     394
# Name: 1, dtype: int64

# %%
mapping = {}
for icd9 in icd_map_df

# %%
icd_dict_path = os.path.join('/home/liutianc/emr/data/', 'ICD_9_10_d_v1.1.csv')
icd_csv = csv.reader(open(icd_dict_path), delimiter='|')

# %%
# icd_dict = []
# for code in open(icd_dict_path).readlines():
#     code=code.strip()
#     if code.split("|")[1] == 'Flags':
#         header = code.split("|")
#         print(code)
# #     else:
#     icd_dict[code.split("|")[1]] = code
# Out:
# TargetI9|Flags|I9Name

# %%
icd_map = []
for code in open(icd_dict_path).readlines():
    code=code.strip()
    if code.split("|")[1] == 'Flags':
        header = code.split("|")
        print(code)
    else:
        icd_map.append(code.split("|"))
        
icd_map_df = pd.DataFrame(icd_map)
icd_map_df.columns = ['icd10', 'icd9', 'i9name']
# Out:
# TargetI9|Flags|I9Name

# %%
vocabs['icd:9_diag:2860253']
# Out:
# 99960

# %%
icd10 = icd_map_df['icd10']
icd10_points = icd10.str.split('.', expand=True)
icd10_p_len = icd10_points[1].apply(lambda x: len(x) if x else 0)

icd10_p_len.value_counts()

# %%
# icd_map_df.loc[icd_map_df['icd9'] == '0010']

# %%
icd9 = icd_map_df['icd9']
icd9_points = icd9.str.split('.', expand=True)
icd9_p_len = icd9_points[1].apply(lambda x: len(x) if x else 0)

icd9_p_len.value_counts()
# Out:
# 0    108498
# 2     89130
# 1     63513
# Name: 1, dtype: int64

# %%
vocab_path = os.path.join(DATA_PATH, 'vocabs', 'vocab_merged.json')

with open(vocab_path, 'r') as file:
    vocabs = json.load(file)

# %%
diag_icd9, diag_icd10 = [], []
proc_icd9, proc_icd10 = [], []
for token in vocabs:
    if 'diag' in token:
        if 'icd:9_' in token:
            token = token.split('_')[1]
            token = token.split(':')[1]
            diag_icd9.append(token)
        elif 'icd:10_' in token:
            token = token.split('_')[1]
            token = token.split(':')[1]
            diag_icd10.append(token)   
    elif 'proc' in token:
        if 'icd:9_' in token:
            token = token.split('_')[1]
            token = token.split(':')[1]
            proc_icd9.append(token)
        elif 'icd:10_' in token:
            token = token.split('_')[1]
            token = token.split(':')[1]
            proc_icd10.append(token)   
            
diag_icd9 = [token.replace('-', '') for token in diag_icd9]
diag_icd10 = [token.replace('-', '') for token in diag_icd10]

# diag_icd9 = dict.fromkeys(diag_icd9, 1)
# diag10 = dict.fromkeys(diag_icd10, 1)

# %%
[t for t in vocabs if 'W260XXA' in t]
# Out:
# ['icd:10_diag:W260XXA', 'icd:9_diag:W260XXA']

# %%
map10 = icd_map_df['icd10']
map10 = [token.upper() for token in map10]
print(f'''
match: {len(set(diag_icd10).intersection(set(map10)))} / {len(set([token.upper() for token in map10]))} = \
{len(set(diag_icd10).intersection(set(map10))) / len(set([token.upper() for token in map10]))}, 
''')

# set(map10).difference(set(diag_icd10))?
# Out:
# match: 9261 / 9802 = 0.9448071822077128,

# %%
'05310'.strip('0')
# Out:
# '531'
