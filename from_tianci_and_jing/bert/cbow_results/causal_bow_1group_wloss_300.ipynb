# %%
import os
import time
import random

import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt

from torch.distributions.binomial import Binomial
from torch.distributions.bernoulli import Bernoulli
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader 

from transformers import DataCollatorForLanguageModeling, BertForMaskedLM
from transformers import Trainer, TrainingArguments
from transformers import get_linear_schedule_with_warmup, AdamW

from tokens import WordLevelBertTokenizer
from vocab import create_vocab
from data import CausalBertDataset, MLMDataset
from causal_bert import CausalBOW

# %%
bsz = 256
epoch = 300
hidden_size = 64

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '7'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def true_casual_effect(data_loader, effect='ate', estimation='q'):
    assert effect == 'ate' and estimation == 'q', f'unallowed effect/estimation: {effect}/{estimation}'
    
    dataset = data_loader.dataset
    
    Q1 = dataset.treatment * dataset.response + (1 - dataset.treatment) * dataset.pseudo_response
    Q1 = Q1.cpu().data.numpy().squeeze()

    Q0 = dataset.treatment * dataset.pseudo_response + (1 - dataset.treatment) * dataset.response
    Q0 = Q0.cpu().data.numpy().squeeze()

    treatment = dataset.treatment.cpu().data.numpy().squeeze()
    prop_scores = dataset.prop_score.cpu().data.numpy().squeeze()
    
    if estimation == 'q':
        if effect == 'att':
            phi = (treatment * (Q1 - Q0))
            return phi.sum() / treatment.sum()
        elif effect == 'ate':
            return (Q1 - Q0).mean()
        
    elif estimation == 'plugin':
        phi = (prop_scores * (Q1 - Q0)).mean()
        if effect == 'att':
            return phi / treatment.mean()
        elif effect == 'ate': 
            return phi
        
def est_casual_effect(data_loader, model, effect='ate', estimation='q', eval_loss=True, **kwargs):
    # We use `real_treatment` here to emphasize the estimations use real instead of estimated treatment.
    real_response, real_treatment = [], []
    prop_scores, Q1, Q0 = [], [], []

    if eval_loss:
        g_loss = kwargs.get('g_loss')
        q_loss = kwargs.get('q_loss')
        g_loss_test, q1_loss_test, q0_loss_test  = [], [], []
    model.eval()
    for idx, (tokens, treatment, response) in enumerate(data_loader):
        real_response.append(response.cpu().data.numpy().squeeze())
        real_treatment.append(treatment.cpu().data.numpy().squeeze())

        prop_score, q1, q0 = model(tokens)
        
        prop_scores.append(prop_score.cpu().data.numpy().squeeze())
        Q1.append(q1.cpu().data.numpy().squeeze())
        Q0.append(q0.cpu().data.numpy().squeeze())
        
        if eval_loss:
            g_loss_val  = g_loss(prop_score, treatment)
            q1_loss_val = q_loss(q1[treatment==1], response[treatment==1])
            q0_loss_val = q_loss(q0[treatment==0], response[treatment==0])
            
            g_loss_test.append(g_loss_val.item())
            q1_loss_test.append(q1_loss_val.item())
            q0_loss_test.append(q0_loss_val.item())
            
    real_response = np.concatenate(real_response, axis=0)
    real_treatment = np.concatenate(real_treatment, axis=0)

    Q1 = np.concatenate(Q1, axis=0)
    Q0 = np.concatenate(Q0, axis=0)
    prop_scores = np.concatenate(prop_scores, axis=0)
    
    
    g_loss = np.array(g_loss_test).mean() if eval_loss else None
    q1_loss = np.array(q1_loss_test).mean() if eval_loss else None
    q0_loss = np.array(q0_loss_test).mean() if eval_loss else None

    model.train()
    
    if estimation == 'q':
        if effect == 'att':
            phi = (real_treatment * (Q1 - Q0))
            return phi.sum() / real_treatment.sum(), g_loss, q1_loss, q0_loss
        elif effect == 'ate':
            return (Q1 - Q0).mean(), g_loss, q1_loss, q0_loss

    elif estimation == 'plugin':
        phi = (prop_scores * (Q1 - Q0)).mean()
        if effect == 'att':
            return phi / real_treatment.mean(), g_loss, q1_loss, q0_loss
        elif effect == 'ate':
            return phi, g_loss, q1_loss, q0_loss
        

def show_result(train_loss_hist, test_loss_hist, est_effect, real, unadjust, epoch):
    train_loss_hist = np.array(train_loss_hist)
    test_loss_hist = np.array(test_loss_hist)
    est_effect = np.array(est_effect)
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    lns1 = ax.plot(np.arange(epoch), test_loss_hist, label='test loss')

    ax_r = plt.twinx()
    lns2 = ax_r.plot(np.arange(epoch), est_effect, color='coral', label='estimate ATE')
    lns3 = ax_r.plot(np.arange(epoch), np.ones(epoch) * real, color='red', ls='--', label='real ATE')
    lns4 = ax_r.plot(np.arange(epoch), np.ones(epoch) * unadjust, color='green', ls='--', label='unadjusted ATE')

    lns = lns1+lns2+lns3+lns4
    labs = [l.get_label() for l in lns]
    ax_r.legend(lns, labs, loc=0)
    plt.show()

# %% [markdown]
# # LOW

# %%
vocab = create_vocab(merged=True, uni_diag=True)
tokenizer = WordLevelBertTokenizer(vocab)

alpha = 0.25
beta = 1.
c = 0.2
i = 0.

# %%
start = time.time()
trainset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                             alpha=alpha, beta=beta, c=c, i=i, 
                             group=list(range(1)), max_length=512, min_length=10,
                             truncate_method='first', device=device, seed=1)

print(f'Load training set in {(time.time() - start):.2f} sec')

start = time.time()
testset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                            alpha=alpha, beta=beta, c=c, i=i, 
                            group=[9], max_length=512, min_length=10,
                            truncate_method='first', device=device)

print(f'Load validation set in {(time.time() - start):.2f} sec')
# Out:
# Load training set in 70.60 sec
# Load validation set in 64.20 sec

# %%
train_loader = DataLoader(trainset, batch_size=bsz, drop_last=True, shuffle=True)
test_loader = DataLoader(testset, batch_size=2048, drop_last=True, shuffle=True)

# %%
real_att_q = true_casual_effect(test_loader)

print(f'Real: [effect: ate], [estimation: q], [value: {real_att_q:.5f}]')
print(f'Unadjusted: [value: {(testset.response[testset.treatment == 1].mean() - testset.response[testset.treatment == 0].mean()).item():.4f}]')
# Out:
# Real: [effect: ate], [estimation: q], [value: 0.06317]
# Unadjusted: [value: 0.0919]

# %%
trained_bert = '/nfs/turbo/lsa-regier/bert-results/results/behrt/MLM/merged/unidiag/checkpoint-6018425/'
# trained_bert = '/home/liutianc/emr/bert/results/behrt/MLM/merged/unidiag/checkpoint-6018425/'

model = BertForMaskedLM.from_pretrained(trained_bert)
token_embed = model.get_input_embeddings()
model = CausalBOW(token_embed, learnable_docu_embed=False, hidden_size=hidden_size, prop_is_logit=True).to(device)

pos_portion = trainset.treatment.mean()
pos_weight = (1 - pos_portion) / pos_portion

# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
epoch_iter = len(train_loader)
total_steps = epoch * epoch_iter

optimizer = AdamW(model.parameters(), lr=1e-4, eps=1e-8)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

q_loss = nn.BCELoss()
# prop_score_loss = nn.BCELoss()
prop_score_loss = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# Please specify the effect and estimation we want to use here.
effect = 'ate'
estimation = 'q'

effect = effect.lower()
estimation = estimation.lower()
assert effect in ['att', 'ate'], f'Wrong effect: {effect}...'
assert estimation in ['q', 'plugin'], f'Wrong estimation: {estimation}...'

# %%
rs_loss, rq1_loss, rq0_loss = [0.] * 3

train_loss_hist, test_loss_hist, est_effect = [], [], []
for e in range(1, epoch + 1):
    model.train()
    start = time.time()
    run_loss = 0.
    for idx, (tokens, treatment, response) in enumerate(train_loader):
        optimizer.zero_grad()
        prop_score, q1, q0 = model(tokens)
        
        loss = prop_score_loss(prop_score, treatment)
        if len(response[treatment == 1]) > 0:
            loss += q_loss(q1[treatment==1], response[treatment==1])# * pos_weight
            
        if len(response[treatment == 0]) > 0:
            loss += q_loss(q0[treatment==0], response[treatment==0])
            
        loss.backward()
        
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)    
        optimizer.step()
        scheduler.step()

        run_loss += loss.item()
        
    run_idx = idx

    # Evaluation.
    train_loss = run_loss / (run_idx + 1)
    train_effect, _, _, _ = est_casual_effect(train_loader, model, effect, estimation, eval_loss=False)
    test_effect, g_loss_test, q1_loss_test, q0_loss_test = est_casual_effect(test_loader, model, effect, estimation, g_loss=prop_score_loss, q_loss=q_loss)
    test_loss = q1_loss_test + q0_loss_test
    test_loss += g_loss_test
    
    train_loss_hist.append(train_loss)
    test_loss_hist.append(test_loss)
    est_effect.append(test_effect)
    print(f'''epoch: {e} / {epoch}, time cost: {(time.time() - start):.2f} sec, 
          Loss: [Train: {train_loss:.5f}], [Test: {test_loss:.5f}],
          Effect: [{effect}-{estimation}], [train: {train_effect:.5f}], [test: {test_effect:.5f}]''')
    print('*'* 80)
    start = time.time()
    run_loss = 0.

print('Finish training...')

# With only 1 group(s) to train.
# Out:
# epoch: 1 / 300, time cost: 35.98 sec,
#           Loss: [Train: 2.42556], [Test: 2.42816],
#           Effect: [ate-q], [train: 0.09124], [test: 0.09124]
# ********************************************************************************
# epoch: 2 / 300, time cost: 42.03 sec,
#           Loss: [Train: 2.42151], [Test: 2.42445],
#           Effect: [ate-q], [train: 0.07761], [test: 0.07761]
# ********************************************************************************
# epoch: 3 / 300, time cost: 41.57 sec,
#           Loss: [Train: 2.41673], [Test: 2.41990],
#           Effect: [ate-q], [train: 0.08061], [test: 0.08061]
# ********************************************************************************
# epoch: 4 / 300, time cost: 42.44 sec,
#           Loss: [Train: 2.41133], [Test: 2.41530],
#           Effect: [ate-q], [train: 0.09093], [test: 0.09093]
# ********************************************************************************
# epoch: 5 / 300, time cost: 42.72 sec,
#           Loss: [Train: 2.40590], [Test: 2.41124],
#           Effect: [ate-q], [train: 0.08730], [test: 0.08734]
# ********************************************************************************
# epoch: 6 / 300, time cost: 41.34 sec,
#           Loss: [Train: 2.40131], [Test: 2.40868],
#           Effect: [ate-q], [train: 0.08168], [test: 0.08174]
# ********************************************************************************
# epoch: 7 / 300, time cost: 42.28 sec,
#           Loss: [Train: 2.39735], [Test: 2.40654],
#           Effect: [ate-q], [train: 0.08805], [test: 0.08811]
# ********************************************************************************
# epoch: 8 / 300, time cost: 42.18 sec,
#           Loss: [Train: 2.39387], [Test: 2.40459],
#           Effect: [ate-q], [train: 0.08854], [test: 0.08863]
# ********************************************************************************
# epoch: 9 / 300, time cost: 42.38 sec,
#           Loss: [Train: 2.39125], [Test: 2.40371],
#           Effect: [ate-q], [train: 0.07815], [test: 0.07823]
# ********************************************************************************
# epoch: 10 / 300, time cost: 42.25 sec,
#           Loss: [Train: 2.38821], [Test: 2.40328],
#           Effect: [ate-q], [train: 0.06217], [test: 0.06227]
# ********************************************************************************
# epoch: 11 / 300, time cost: 42.30 sec,
#           Loss: [Train: 2.38533], [Test: 2.40200],
#           Effect: [ate-q], [train: 0.08286], [test: 0.08296]
# ********************************************************************************
# epoch: 12 / 300, time cost: 43.79 sec,
#           Loss: [Train: 2.38238], [Test: 2.40085],
#           Effect: [ate-q], [train: 0.07739], [test: 0.07750]
# ********************************************************************************
# epoch: 13 / 300, time cost: 42.27 sec,
#           Loss: [Train: 2.37993], [Test: 2.40158],
#           Effect: [ate-q], [train: 0.07131], [test: 0.07144]
# ********************************************************************************
# epoch: 14 / 300, time cost: 42.04 sec,
#           Loss: [Train: 2.37701], [Test: 2.40054],
#           Effect: [ate-q], [train: 0.06801], [test: 0.06818]
# ********************************************************************************
# epoch: 15 / 300, time cost: 42.17 sec,
#           Loss: [Train: 2.37370], [Test: 2.40031],
#           Effect: [ate-q], [train: 0.07078], [test: 0.07100]
# ********************************************************************************
# epoch: 16 / 300, time cost: 41.90 sec,
#           Loss: [Train: 2.37023], [Test: 2.39984],
#           Effect: [ate-q], [train: 0.06783], [test: 0.06808]
# ********************************************************************************
# epoch: 17 / 300, time cost: 42.08 sec,
#           Loss: [Train: 2.36584], [Test: 2.40088],
#           Effect: [ate-q], [train: 0.05992], [test: 0.06024]
# ********************************************************************************
# epoch: 18 / 300, time cost: 42.15 sec,
#           Loss: [Train: 2.36127], [Test: 2.40133],
#           Effect: [ate-q], [train: 0.07361], [test: 0.07398]
# ********************************************************************************
# epoch: 19 / 300, time cost: 42.22 sec,
#           Loss: [Train: 2.35601], [Test: 2.40232],
#           Effect: [ate-q], [train: 0.07660], [test: 0.07705]
# ********************************************************************************
# epoch: 20 / 300, time cost: 42.29 sec,
#           Loss: [Train: 2.34987], [Test: 2.40577],
#           Effect: [ate-q], [train: 0.05044], [test: 0.05093]
# ********************************************************************************
# epoch: 21 / 300, time cost: 42.28 sec,
#           Loss: [Train: 2.34348], [Test: 2.40732],
#           Effect: [ate-q], [train: 0.05529], [test: 0.05583]
# ********************************************************************************
# epoch: 22 / 300, time cost: 42.31 sec,
#           Loss: [Train: 2.33634], [Test: 2.41401],
#           Effect: [ate-q], [train: 0.02665], [test: 0.02717]
# ********************************************************************************
# epoch: 23 / 300, time cost: 42.38 sec,
#           Loss: [Train: 2.32904], [Test: 2.41671],
#           Effect: [ate-q], [train: 0.04690], [test: 0.04749]
# ********************************************************************************
# epoch: 24 / 300, time cost: 42.21 sec,
#           Loss: [Train: 2.32132], [Test: 2.42185],
#           Effect: [ate-q], [train: 0.04237], [test: 0.04290]
# ********************************************************************************
# epoch: 25 / 300, time cost: 42.19 sec,
#           Loss: [Train: 2.31406], [Test: 2.43054],
#           Effect: [ate-q], [train: 0.03808], [test: 0.03862]
# ********************************************************************************
# epoch: 26 / 300, time cost: 42.56 sec,
#           Loss: [Train: 2.30720], [Test: 2.43405],
#           Effect: [ate-q], [train: 0.11528], [test: 0.11610]
# ********************************************************************************
# epoch: 27 / 300, time cost: 42.35 sec,
#           Loss: [Train: 2.29991], [Test: 2.44098],
#           Effect: [ate-q], [train: 0.04611], [test: 0.04676]
# ********************************************************************************
# epoch: 28 / 300, time cost: 42.83 sec,
#           Loss: [Train: 2.29397], [Test: 2.44982],
#           Effect: [ate-q], [train: 0.04326], [test: 0.04389]
# ********************************************************************************
# epoch: 29 / 300, time cost: 42.77 sec,
#           Loss: [Train: 2.28748], [Test: 2.45247],
#           Effect: [ate-q], [train: 0.05214], [test: 0.05275]
# ********************************************************************************
# epoch: 30 / 300, time cost: 42.67 sec,
#           Loss: [Train: 2.28038], [Test: 2.46061],
#           Effect: [ate-q], [train: 0.10692], [test: 0.10778]
# ********************************************************************************
# epoch: 31 / 300, time cost: 43.66 sec,
#           Loss: [Train: 2.27428], [Test: 2.46846],
#           Effect: [ate-q], [train: 0.01810], [test: 0.01875]
# ********************************************************************************
# epoch: 32 / 300, time cost: 42.01 sec,
#           Loss: [Train: 2.26777], [Test: 2.47285],
#           Effect: [ate-q], [train: 0.06312], [test: 0.06383]
# ********************************************************************************
# epoch: 33 / 300, time cost: 41.99 sec,
#           Loss: [Train: 2.26152], [Test: 2.47924],
#           Effect: [ate-q], [train: 0.08172], [test: 0.08252]
# ********************************************************************************
# epoch: 34 / 300, time cost: 41.96 sec,
#           Loss: [Train: 2.25562], [Test: 2.48758],
#           Effect: [ate-q], [train: 0.05781], [test: 0.05860]
# ********************************************************************************
# epoch: 35 / 300, time cost: 41.97 sec,
#           Loss: [Train: 2.24877], [Test: 2.50056],
#           Effect: [ate-q], [train: 0.03876], [test: 0.03941]
# ********************************************************************************
# epoch: 36 / 300, time cost: 42.08 sec,
#           Loss: [Train: 2.24249], [Test: 2.51078],
#           Effect: [ate-q], [train: 0.09339], [test: 0.09431]
# ********************************************************************************
# epoch: 37 / 300, time cost: 42.05 sec,
#           Loss: [Train: 2.23645], [Test: 2.50936],
#           Effect: [ate-q], [train: 0.06406], [test: 0.06482]
# ********************************************************************************
# epoch: 38 / 300, time cost: 42.09 sec,
#           Loss: [Train: 2.23007], [Test: 2.51711],
#           Effect: [ate-q], [train: 0.05370], [test: 0.05441]
# ********************************************************************************
# epoch: 39 / 300, time cost: 42.07 sec,
#           Loss: [Train: 2.22458], [Test: 2.52695],
#           Effect: [ate-q], [train: 0.05497], [test: 0.05571]
# ********************************************************************************
# epoch: 40 / 300, time cost: 42.07 sec,
#           Loss: [Train: 2.21807], [Test: 2.53696],
#           Effect: [ate-q], [train: 0.06075], [test: 0.06145]
# ********************************************************************************
# epoch: 41 / 300, time cost: 42.23 sec,
#           Loss: [Train: 2.21257], [Test: 2.54437],
#           Effect: [ate-q], [train: 0.02109], [test: 0.02170]
# ********************************************************************************
# epoch: 42 / 300, time cost: 42.07 sec,
#           Loss: [Train: 2.20673], [Test: 2.55041],
#           Effect: [ate-q], [train: 0.04593], [test: 0.04643]
# ********************************************************************************
# epoch: 43 / 300, time cost: 42.65 sec,
#           Loss: [Train: 2.20128], [Test: 2.55617],
#           Effect: [ate-q], [train: 0.06626], [test: 0.06688]
# ********************************************************************************
# epoch: 44 / 300, time cost: 41.94 sec,
#           Loss: [Train: 2.19579], [Test: 2.56474],
#           Effect: [ate-q], [train: 0.06132], [test: 0.06192]
# ********************************************************************************
# epoch: 45 / 300, time cost: 42.36 sec,
#           Loss: [Train: 2.19111], [Test: 2.57722],
#           Effect: [ate-q], [train: 0.11713], [test: 0.11799]
# ********************************************************************************
# epoch: 46 / 300, time cost: 42.04 sec,
#           Loss: [Train: 2.18551], [Test: 2.58219],
#           Effect: [ate-q], [train: 0.08035], [test: 0.08103]
# ********************************************************************************
# epoch: 47 / 300, time cost: 42.03 sec,
#           Loss: [Train: 2.18086], [Test: 2.59033],
#           Effect: [ate-q], [train: 0.08097], [test: 0.08172]
# ********************************************************************************
# epoch: 48 / 300, time cost: 42.01 sec,
#           Loss: [Train: 2.17526], [Test: 2.59830],
#           Effect: [ate-q], [train: 0.05589], [test: 0.05642]
# ********************************************************************************
# epoch: 49 / 300, time cost: 41.74 sec,
#           Loss: [Train: 2.17066], [Test: 2.61268],
#           Effect: [ate-q], [train: 0.05145], [test: 0.05196]
# ********************************************************************************
# epoch: 50 / 300, time cost: 42.04 sec,
#           Loss: [Train: 2.16595], [Test: 2.62046],
#           Effect: [ate-q], [train: 0.11745], [test: 0.11819]
# ********************************************************************************
# epoch: 51 / 300, time cost: 42.08 sec,
#           Loss: [Train: 2.16216], [Test: 2.62313],
#           Effect: [ate-q], [train: 0.08937], [test: 0.09012]
# ********************************************************************************
# epoch: 52 / 300, time cost: 41.91 sec,
#           Loss: [Train: 2.15747], [Test: 2.63160],
#           Effect: [ate-q], [train: 0.06926], [test: 0.06989]
# ********************************************************************************
# epoch: 53 / 300, time cost: 42.02 sec,
#           Loss: [Train: 2.15269], [Test: 2.64091],
#           Effect: [ate-q], [train: 0.05093], [test: 0.05145]
# ********************************************************************************
# epoch: 54 / 300, time cost: 42.00 sec,
#           Loss: [Train: 2.14923], [Test: 2.64872],
#           Effect: [ate-q], [train: 0.02928], [test: 0.02969]
# ********************************************************************************
# epoch: 55 / 300, time cost: 41.90 sec,
#           Loss: [Train: 2.14538], [Test: 2.66445],
#           Effect: [ate-q], [train: 0.05135], [test: 0.05190]
# ********************************************************************************
# epoch: 56 / 300, time cost: 43.76 sec,
#           Loss: [Train: 2.14187], [Test: 2.67067],
#           Effect: [ate-q], [train: 0.13234], [test: 0.13318]
# ********************************************************************************
# epoch: 57 / 300, time cost: 49.07 sec,
#           Loss: [Train: 2.13809], [Test: 2.67165],
#           Effect: [ate-q], [train: 0.07788], [test: 0.07848]
# ********************************************************************************
# epoch: 58 / 300, time cost: 48.67 sec,
#           Loss: [Train: 2.13437], [Test: 2.68442],
#           Effect: [ate-q], [train: 0.13052], [test: 0.13152]
# ********************************************************************************
# epoch: 59 / 300, time cost: 48.53 sec,
#           Loss: [Train: 2.13021], [Test: 2.69372],
#           Effect: [ate-q], [train: 0.00601], [test: 0.00618]
# ********************************************************************************
# epoch: 60 / 300, time cost: 47.16 sec,
#           Loss: [Train: 2.12629], [Test: 2.69671],
#           Effect: [ate-q], [train: 0.10138], [test: 0.10197]
# ********************************************************************************
# epoch: 61 / 300, time cost: 42.28 sec,
#           Loss: [Train: 2.12372], [Test: 2.72474],
#           Effect: [ate-q], [train: -0.06462], [test: -0.06455]
# ********************************************************************************
# epoch: 62 / 300, time cost: 42.27 sec,
#           Loss: [Train: 2.11939], [Test: 2.71159],
#           Effect: [ate-q], [train: 0.07241], [test: 0.07295]
# ********************************************************************************
# epoch: 63 / 300, time cost: 42.07 sec,
#           Loss: [Train: 2.11590], [Test: 2.72081],
#           Effect: [ate-q], [train: 0.05933], [test: 0.06000]
# ********************************************************************************
# epoch: 64 / 300, time cost: 42.30 sec,
#           Loss: [Train: 2.11208], [Test: 2.73122],
#           Effect: [ate-q], [train: 0.02416], [test: 0.02456]
# ********************************************************************************
# epoch: 65 / 300, time cost: 42.39 sec,
#           Loss: [Train: 2.10869], [Test: 2.73921],
#           Effect: [ate-q], [train: 0.05815], [test: 0.05878]
# ********************************************************************************
# epoch: 66 / 300, time cost: 42.02 sec,
#           Loss: [Train: 2.10662], [Test: 2.74424],
#           Effect: [ate-q], [train: 0.01492], [test: 0.01517]
# ********************************************************************************
# epoch: 67 / 300, time cost: 41.93 sec,
#           Loss: [Train: 2.10311], [Test: 2.76703],
#           Effect: [ate-q], [train: 0.11735], [test: 0.11810]
# ********************************************************************************
# epoch: 68 / 300, time cost: 41.94 sec,
#           Loss: [Train: 2.09999], [Test: 2.76524],
#           Effect: [ate-q], [train: 0.01700], [test: 0.01740]
# ********************************************************************************
# epoch: 69 / 300, time cost: 41.96 sec,
#           Loss: [Train: 2.09825], [Test: 2.77542],
#           Effect: [ate-q], [train: 0.15401], [test: 0.15486]
# ********************************************************************************
# epoch: 70 / 300, time cost: 41.89 sec,
#           Loss: [Train: 2.09391], [Test: 2.77674],
#           Effect: [ate-q], [train: 0.07236], [test: 0.07275]
# ********************************************************************************
# epoch: 71 / 300, time cost: 41.99 sec,
#           Loss: [Train: 2.09122], [Test: 2.79431],
#           Effect: [ate-q], [train: 0.13144], [test: 0.13238]
# ********************************************************************************
# epoch: 72 / 300, time cost: 42.25 sec,
#           Loss: [Train: 2.08711], [Test: 2.80525],
#           Effect: [ate-q], [train: 0.12813], [test: 0.12881]
# ********************************************************************************
# epoch: 73 / 300, time cost: 42.26 sec,
#           Loss: [Train: 2.08560], [Test: 2.81092],
#           Effect: [ate-q], [train: 0.04899], [test: 0.04956]
# ********************************************************************************
# epoch: 74 / 300, time cost: 41.87 sec,
#           Loss: [Train: 2.08311], [Test: 2.81567],
#           Effect: [ate-q], [train: 0.04576], [test: 0.04610]
# ********************************************************************************
# epoch: 75 / 300, time cost: 41.95 sec,
#           Loss: [Train: 2.07900], [Test: 2.82933],
#           Effect: [ate-q], [train: 0.07536], [test: 0.07582]
# ********************************************************************************
# epoch: 76 / 300, time cost: 41.79 sec,
#           Loss: [Train: 2.07656], [Test: 2.83156],
#           Effect: [ate-q], [train: 0.03936], [test: 0.03974]
# ********************************************************************************
# epoch: 77 / 300, time cost: 42.28 sec,
#           Loss: [Train: 2.07549], [Test: 2.84124],
#           Effect: [ate-q], [train: 0.07098], [test: 0.07155]
# ********************************************************************************
# epoch: 78 / 300, time cost: 42.80 sec,
#           Loss: [Train: 2.07205], [Test: 2.84861],
#           Effect: [ate-q], [train: 0.04627], [test: 0.04688]
# ********************************************************************************
# epoch: 79 / 300, time cost: 42.63 sec,
#           Loss: [Train: 2.07061], [Test: 2.85017],
#           Effect: [ate-q], [train: 0.10579], [test: 0.10658]
# ********************************************************************************
# epoch: 80 / 300, time cost: 42.27 sec,
#           Loss: [Train: 2.06706], [Test: 2.86262],
#           Effect: [ate-q], [train: 0.07556], [test: 0.07612]
# ********************************************************************************
# epoch: 81 / 300, time cost: 41.89 sec,
#           Loss: [Train: 2.06544], [Test: 2.87216],
#           Effect: [ate-q], [train: 0.06665], [test: 0.06717]
# ********************************************************************************
# epoch: 82 / 300, time cost: 41.94 sec,
#           Loss: [Train: 2.06294], [Test: 2.87487],
#           Effect: [ate-q], [train: 0.06820], [test: 0.06873]
# ********************************************************************************
# epoch: 83 / 300, time cost: 41.62 sec,
#           Loss: [Train: 2.06106], [Test: 2.88687],
#           Effect: [ate-q], [train: 0.09150], [test: 0.09182]
# ********************************************************************************
# epoch: 84 / 300, time cost: 41.79 sec,
#           Loss: [Train: 2.05685], [Test: 2.89867],
#           Effect: [ate-q], [train: 0.00659], [test: 0.00687]
# ********************************************************************************
# epoch: 85 / 300, time cost: 41.62 sec,
#           Loss: [Train: 2.05540], [Test: 2.90503],
#           Effect: [ate-q], [train: 0.05651], [test: 0.05691]
# ********************************************************************************
# epoch: 86 / 300, time cost: 42.16 sec,
#           Loss: [Train: 2.05262], [Test: 2.91339],
#           Effect: [ate-q], [train: 0.05323], [test: 0.05357]
# ********************************************************************************
# epoch: 87 / 300, time cost: 42.19 sec,
#           Loss: [Train: 2.05137], [Test: 2.92314],
#           Effect: [ate-q], [train: 0.01619], [test: 0.01647]
# ********************************************************************************
# epoch: 88 / 300, time cost: 42.09 sec,
#           Loss: [Train: 2.04913], [Test: 2.93975],
#           Effect: [ate-q], [train: 0.15225], [test: 0.15301]
# ********************************************************************************
# epoch: 89 / 300, time cost: 41.94 sec,
#           Loss: [Train: 2.04657], [Test: 2.95444],
#           Effect: [ate-q], [train: 0.07181], [test: 0.07234]
# ********************************************************************************
# epoch: 90 / 300, time cost: 42.99 sec,
#           Loss: [Train: 2.04470], [Test: 2.95543],
#           Effect: [ate-q], [train: 0.07625], [test: 0.07686]
# ********************************************************************************
# epoch: 91 / 300, time cost: 42.58 sec,
#           Loss: [Train: 2.04189], [Test: 2.95159],
#           Effect: [ate-q], [train: 0.05252], [test: 0.05293]
# ********************************************************************************
# epoch: 92 / 300, time cost: 43.24 sec,
#           Loss: [Train: 2.04012], [Test: 2.96219],
#           Effect: [ate-q], [train: 0.07913], [test: 0.07972]
# ********************************************************************************
# epoch: 93 / 300, time cost: 43.34 sec,
#           Loss: [Train: 2.03830], [Test: 2.97517],
#           Effect: [ate-q], [train: 0.08000], [test: 0.08044]
# ********************************************************************************
# epoch: 94 / 300, time cost: 42.75 sec,
#           Loss: [Train: 2.03647], [Test: 2.98120],
#           Effect: [ate-q], [train: 0.00889], [test: 0.00892]
# ********************************************************************************
# epoch: 95 / 300, time cost: 48.66 sec,
#           Loss: [Train: 2.03443], [Test: 2.98878],
#           Effect: [ate-q], [train: 0.09206], [test: 0.09235]
# ********************************************************************************
# epoch: 96 / 300, time cost: 48.68 sec,
#           Loss: [Train: 2.03419], [Test: 2.99862],
#           Effect: [ate-q], [train: 0.02670], [test: 0.02703]
# ********************************************************************************
# epoch: 97 / 300, time cost: 48.95 sec,
#           Loss: [Train: 2.02996], [Test: 3.01036],
#           Effect: [ate-q], [train: -0.00673], [test: -0.00656]
# ********************************************************************************
# epoch: 98 / 300, time cost: 48.89 sec,
#           Loss: [Train: 2.02716], [Test: 3.01551],
#           Effect: [ate-q], [train: 0.05615], [test: 0.05673]
# ********************************************************************************
# epoch: 99 / 300, time cost: 48.50 sec,
#           Loss: [Train: 2.02662], [Test: 3.03907],
#           Effect: [ate-q], [train: 0.02283], [test: 0.02313]
# ********************************************************************************
# epoch: 100 / 300, time cost: 42.33 sec,
#           Loss: [Train: 2.02594], [Test: 3.04916],
#           Effect: [ate-q], [train: 0.11699], [test: 0.11730]
# ********************************************************************************
# epoch: 101 / 300, time cost: 42.51 sec,
#           Loss: [Train: 2.02469], [Test: 3.04811],
#           Effect: [ate-q], [train: 0.01234], [test: 0.01259]
# ********************************************************************************
# epoch: 102 / 300, time cost: 42.48 sec,
#           Loss: [Train: 2.02000], [Test: 3.04973],
#           Effect: [ate-q], [train: 0.03072], [test: 0.03081]
# ********************************************************************************
# epoch: 103 / 300, time cost: 41.99 sec,
#           Loss: [Train: 2.01980], [Test: 3.06608],
#           Effect: [ate-q], [train: 0.02939], [test: 0.02961]
# ********************************************************************************
# epoch: 104 / 300, time cost: 42.04 sec,
#           Loss: [Train: 2.01730], [Test: 3.06027],
#           Effect: [ate-q], [train: 0.03664], [test: 0.03681]
# ********************************************************************************
# epoch: 105 / 300, time cost: 41.90 sec,
#           Loss: [Train: 2.01584], [Test: 3.07787],
#           Effect: [ate-q], [train: 0.02148], [test: 0.02154]
# ********************************************************************************
# epoch: 106 / 300, time cost: 41.84 sec,
#           Loss: [Train: 2.01697], [Test: 3.07962],
#           Effect: [ate-q], [train: 0.06144], [test: 0.06146]
# ********************************************************************************
# epoch: 107 / 300, time cost: 41.91 sec,
#           Loss: [Train: 2.01339], [Test: 3.09896],
#           Effect: [ate-q], [train: 0.01343], [test: 0.01330]
# ********************************************************************************
# epoch: 108 / 300, time cost: 40.54 sec,
#           Loss: [Train: 2.01283], [Test: 3.09970],
#           Effect: [ate-q], [train: 0.11714], [test: 0.11733]
# ********************************************************************************
# epoch: 109 / 300, time cost: 40.71 sec,
#           Loss: [Train: 2.00864], [Test: 3.10518],
#           Effect: [ate-q], [train: 0.13552], [test: 0.13593]
# ********************************************************************************
# epoch: 110 / 300, time cost: 42.18 sec,
#           Loss: [Train: 2.01006], [Test: 3.10837],
#           Effect: [ate-q], [train: 0.11421], [test: 0.11451]
# ********************************************************************************
# epoch: 111 / 300, time cost: 42.28 sec,
#           Loss: [Train: 2.00775], [Test: 3.11625],
#           Effect: [ate-q], [train: 0.09337], [test: 0.09332]
# ********************************************************************************
# epoch: 112 / 300, time cost: 42.11 sec,
#           Loss: [Train: 2.00523], [Test: 3.14799],
#           Effect: [ate-q], [train: -0.06673], [test: -0.06655]
# ********************************************************************************
# epoch: 113 / 300, time cost: 42.25 sec,
#           Loss: [Train: 2.00335], [Test: 3.12326],
#           Effect: [ate-q], [train: 0.07969], [test: 0.07982]
# ********************************************************************************
# epoch: 114 / 300, time cost: 42.61 sec,
#           Loss: [Train: 2.00284], [Test: 3.13466],
#           Effect: [ate-q], [train: 0.11329], [test: 0.11327]
# ********************************************************************************
# epoch: 115 / 300, time cost: 42.24 sec,
#           Loss: [Train: 2.00162], [Test: 3.14482],
#           Effect: [ate-q], [train: 0.06608], [test: 0.06632]
# ********************************************************************************
# epoch: 116 / 300, time cost: 42.17 sec,
#           Loss: [Train: 1.99858], [Test: 3.15571],
#           Effect: [ate-q], [train: 0.01933], [test: 0.01925]
# ********************************************************************************
# epoch: 117 / 300, time cost: 42.18 sec,
#           Loss: [Train: 1.99762], [Test: 3.16292],
#           Effect: [ate-q], [train: 0.03284], [test: 0.03294]
# ********************************************************************************
# epoch: 118 / 300, time cost: 42.03 sec,
#           Loss: [Train: 1.99718], [Test: 3.17105],
#           Effect: [ate-q], [train: 0.13842], [test: 0.13845]
# ********************************************************************************
# epoch: 119 / 300, time cost: 42.07 sec,
#           Loss: [Train: 1.99572], [Test: 3.17998],
#           Effect: [ate-q], [train: 0.10846], [test: 0.10837]
# ********************************************************************************
# epoch: 120 / 300, time cost: 42.05 sec,
#           Loss: [Train: 1.99328], [Test: 3.20142],
#           Effect: [ate-q], [train: 0.13284], [test: 0.13284]
# ********************************************************************************
# epoch: 121 / 300, time cost: 42.35 sec,
#           Loss: [Train: 1.99405], [Test: 3.19542],
#           Effect: [ate-q], [train: 0.09667], [test: 0.09647]
# ********************************************************************************
# epoch: 122 / 300, time cost: 42.08 sec,
#           Loss: [Train: 1.99239], [Test: 3.21638],
#           Effect: [ate-q], [train: -0.03318], [test: -0.03345]
# ********************************************************************************
# epoch: 123 / 300, time cost: 42.12 sec,
#           Loss: [Train: 1.98834], [Test: 3.22485],
#           Effect: [ate-q], [train: 0.00925], [test: 0.00919]
# ********************************************************************************
# epoch: 124 / 300, time cost: 42.22 sec,
#           Loss: [Train: 1.98855], [Test: 3.22979],
#           Effect: [ate-q], [train: 0.14585], [test: 0.14573]
# ********************************************************************************
# epoch: 125 / 300, time cost: 42.06 sec,
#           Loss: [Train: 1.98699], [Test: 3.23402],
#           Effect: [ate-q], [train: 0.13811], [test: 0.13808]
# ********************************************************************************
# epoch: 126 / 300, time cost: 42.36 sec,
#           Loss: [Train: 1.98483], [Test: 3.24103],
#           Effect: [ate-q], [train: 0.07470], [test: 0.07471]
# ********************************************************************************
# epoch: 127 / 300, time cost: 42.47 sec,
#           Loss: [Train: 1.98472], [Test: 3.24489],
#           Effect: [ate-q], [train: 0.07270], [test: 0.07260]
# ********************************************************************************
# epoch: 128 / 300, time cost: 42.23 sec,
#           Loss: [Train: 1.98306], [Test: 3.25700],
#           Effect: [ate-q], [train: 0.13618], [test: 0.13605]
# ********************************************************************************
# epoch: 129 / 300, time cost: 41.91 sec,
#           Loss: [Train: 1.98277], [Test: 3.27243],
#           Effect: [ate-q], [train: -0.01111], [test: -0.01152]
# ********************************************************************************
# epoch: 130 / 300, time cost: 42.09 sec,
#           Loss: [Train: 1.98015], [Test: 3.27976],
#           Effect: [ate-q], [train: 0.07768], [test: 0.07743]
# ********************************************************************************
# epoch: 131 / 300, time cost: 42.00 sec,
#           Loss: [Train: 1.97959], [Test: 3.27866],
#           Effect: [ate-q], [train: 0.01830], [test: 0.01823]
# ********************************************************************************
# epoch: 132 / 300, time cost: 42.13 sec,
#           Loss: [Train: 1.97910], [Test: 3.27822],
#           Effect: [ate-q], [train: 0.03434], [test: 0.03410]
# ********************************************************************************
# epoch: 133 / 300, time cost: 42.62 sec,
#           Loss: [Train: 1.97746], [Test: 3.30306],
#           Effect: [ate-q], [train: -0.04667], [test: -0.04676]
# ********************************************************************************
# epoch: 134 / 300, time cost: 48.48 sec,
#           Loss: [Train: 1.97499], [Test: 3.30791],
#           Effect: [ate-q], [train: 0.00785], [test: 0.00763]
# ********************************************************************************
# epoch: 135 / 300, time cost: 42.17 sec,
#           Loss: [Train: 1.97301], [Test: 3.29886],
#           Effect: [ate-q], [train: 0.06664], [test: 0.06621]
# ********************************************************************************
# epoch: 136 / 300, time cost: 42.37 sec,
#           Loss: [Train: 1.97356], [Test: 3.31612],
#           Effect: [ate-q], [train: 0.02160], [test: 0.02108]
# ********************************************************************************
# epoch: 137 / 300, time cost: 42.30 sec,
#           Loss: [Train: 1.97373], [Test: 3.32615],
#           Effect: [ate-q], [train: 0.13066], [test: 0.13017]
# ********************************************************************************
# epoch: 138 / 300, time cost: 42.27 sec,
#           Loss: [Train: 1.97131], [Test: 3.32777],
#           Effect: [ate-q], [train: 0.12498], [test: 0.12455]
# ********************************************************************************
# epoch: 139 / 300, time cost: 42.18 sec,
#           Loss: [Train: 1.96954], [Test: 3.32947],
#           Effect: [ate-q], [train: 0.10498], [test: 0.10450]
# ********************************************************************************
# epoch: 140 / 300, time cost: 42.15 sec,
#           Loss: [Train: 1.96740], [Test: 3.33722],
#           Effect: [ate-q], [train: 0.10680], [test: 0.10634]
# ********************************************************************************
# epoch: 141 / 300, time cost: 42.33 sec,
#           Loss: [Train: 1.96686], [Test: 3.34117],
#           Effect: [ate-q], [train: 0.07007], [test: 0.06980]
# ********************************************************************************
# epoch: 142 / 300, time cost: 42.42 sec,
#           Loss: [Train: 1.96567], [Test: 3.36393],
#           Effect: [ate-q], [train: -0.04132], [test: -0.04158]
# ********************************************************************************
# epoch: 143 / 300, time cost: 42.51 sec,
#           Loss: [Train: 1.96451], [Test: 3.36150],
#           Effect: [ate-q], [train: 0.02405], [test: 0.02355]
# ********************************************************************************
# epoch: 144 / 300, time cost: 42.11 sec,
#           Loss: [Train: 1.96478], [Test: 3.36415],
#           Effect: [ate-q], [train: 0.08179], [test: 0.08134]
# ********************************************************************************
# epoch: 145 / 300, time cost: 42.15 sec,
#           Loss: [Train: 1.96313], [Test: 3.37658],
#           Effect: [ate-q], [train: 0.00608], [test: 0.00562]
# ********************************************************************************
# epoch: 146 / 300, time cost: 42.12 sec,
#           Loss: [Train: 1.96181], [Test: 3.37475],
#           Effect: [ate-q], [train: 0.04673], [test: 0.04630]
# ********************************************************************************
# epoch: 147 / 300, time cost: 41.89 sec,
#           Loss: [Train: 1.96270], [Test: 3.38327],
#           Effect: [ate-q], [train: 0.13587], [test: 0.13534]
# ********************************************************************************
# epoch: 148 / 300, time cost: 42.04 sec,
#           Loss: [Train: 1.95910], [Test: 3.38800],
#           Effect: [ate-q], [train: 0.08270], [test: 0.08233]
# ********************************************************************************
# epoch: 149 / 300, time cost: 42.07 sec,
#           Loss: [Train: 1.95845], [Test: 3.40598],
#           Effect: [ate-q], [train: -0.02105], [test: -0.02135]
# ********************************************************************************
# epoch: 150 / 300, time cost: 42.20 sec,
#           Loss: [Train: 1.95825], [Test: 3.39066],
#           Effect: [ate-q], [train: 0.07394], [test: 0.07360]
# ********************************************************************************
# epoch: 151 / 300, time cost: 42.13 sec,
#           Loss: [Train: 1.95667], [Test: 3.40406],
#           Effect: [ate-q], [train: 0.08890], [test: 0.08858]
# ********************************************************************************
# epoch: 152 / 300, time cost: 42.23 sec,
#           Loss: [Train: 1.95565], [Test: 3.40621],
#           Effect: [ate-q], [train: 0.06900], [test: 0.06853]
# ********************************************************************************
# epoch: 153 / 300, time cost: 42.25 sec,
#           Loss: [Train: 1.95521], [Test: 3.42170],
#           Effect: [ate-q], [train: 0.08058], [test: 0.08028]
# ********************************************************************************
# epoch: 154 / 300, time cost: 42.02 sec,
#           Loss: [Train: 1.95434], [Test: 3.42605],
#           Effect: [ate-q], [train: 0.07583], [test: 0.07562]
# ********************************************************************************
# epoch: 155 / 300, time cost: 42.21 sec,
#           Loss: [Train: 1.95323], [Test: 3.43602],
#           Effect: [ate-q], [train: 0.14428], [test: 0.14365]
# ********************************************************************************
# epoch: 156 / 300, time cost: 42.31 sec,
#           Loss: [Train: 1.95079], [Test: 3.43657],
#           Effect: [ate-q], [train: 0.05298], [test: 0.05250]
# ********************************************************************************
# epoch: 157 / 300, time cost: 42.15 sec,
#           Loss: [Train: 1.95134], [Test: 3.43501],
#           Effect: [ate-q], [train: 0.04396], [test: 0.04357]
# ********************************************************************************
# epoch: 158 / 300, time cost: 42.11 sec,
#           Loss: [Train: 1.95053], [Test: 3.44280],
#           Effect: [ate-q], [train: 0.12026], [test: 0.11955]
# ********************************************************************************
# epoch: 159 / 300, time cost: 42.09 sec,
#           Loss: [Train: 1.94867], [Test: 3.45880],
#           Effect: [ate-q], [train: 0.16341], [test: 0.16294]
# ********************************************************************************
# epoch: 160 / 300, time cost: 41.95 sec,
#           Loss: [Train: 1.94794], [Test: 3.45419],
#           Effect: [ate-q], [train: 0.05237], [test: 0.05180]
# ********************************************************************************
# epoch: 161 / 300, time cost: 42.19 sec,
#           Loss: [Train: 1.94687], [Test: 3.47075],
#           Effect: [ate-q], [train: 0.00568], [test: 0.00511]
# ********************************************************************************
# epoch: 162 / 300, time cost: 42.40 sec,
#           Loss: [Train: 1.94777], [Test: 3.47897],
#           Effect: [ate-q], [train: -0.02603], [test: -0.02659]
# ********************************************************************************
# epoch: 163 / 300, time cost: 42.48 sec,
#           Loss: [Train: 1.94483], [Test: 3.47233],
#           Effect: [ate-q], [train: 0.08077], [test: 0.07996]
# ********************************************************************************
# epoch: 164 / 300, time cost: 42.35 sec,
#           Loss: [Train: 1.94493], [Test: 3.49899],
#           Effect: [ate-q], [train: 0.02753], [test: 0.02696]
# ********************************************************************************
# epoch: 165 / 300, time cost: 42.20 sec,
#           Loss: [Train: 1.94371], [Test: 3.49079],
#           Effect: [ate-q], [train: 0.05234], [test: 0.05189]
# ********************************************************************************
# epoch: 166 / 300, time cost: 41.75 sec,
#           Loss: [Train: 1.94334], [Test: 3.49124],
#           Effect: [ate-q], [train: 0.05092], [test: 0.05044]
# ********************************************************************************
# epoch: 167 / 300, time cost: 41.85 sec,
#           Loss: [Train: 1.94237], [Test: 3.49924],
#           Effect: [ate-q], [train: 0.12839], [test: 0.12768]
# ********************************************************************************
# epoch: 168 / 300, time cost: 41.94 sec,
#           Loss: [Train: 1.94094], [Test: 3.51039],
#           Effect: [ate-q], [train: 0.08391], [test: 0.08357]
# ********************************************************************************
# epoch: 169 / 300, time cost: 41.79 sec,
#           Loss: [Train: 1.93947], [Test: 3.52282],
#           Effect: [ate-q], [train: 0.01416], [test: 0.01375]
# ********************************************************************************
# epoch: 170 / 300, time cost: 41.88 sec,
#           Loss: [Train: 1.93999], [Test: 3.52037],
#           Effect: [ate-q], [train: 0.01542], [test: 0.01493]
# ********************************************************************************
# epoch: 171 / 300, time cost: 42.11 sec,
#           Loss: [Train: 1.93944], [Test: 3.52899],
#           Effect: [ate-q], [train: 0.02043], [test: 0.01983]
# ********************************************************************************
# epoch: 172 / 300, time cost: 41.87 sec,
#           Loss: [Train: 1.93732], [Test: 3.53629],
#           Effect: [ate-q], [train: 0.06798], [test: 0.06739]
# ********************************************************************************
# epoch: 173 / 300, time cost: 42.00 sec,
#           Loss: [Train: 1.93749], [Test: 3.53929],
#           Effect: [ate-q], [train: 0.03024], [test: 0.02962]
# ********************************************************************************
# epoch: 174 / 300, time cost: 42.39 sec,
#           Loss: [Train: 1.93638], [Test: 3.54023],
#           Effect: [ate-q], [train: 0.07369], [test: 0.07313]
# ********************************************************************************
# epoch: 175 / 300, time cost: 42.35 sec,
#           Loss: [Train: 1.93666], [Test: 3.55786],
#           Effect: [ate-q], [train: -0.02221], [test: -0.02286]
# ********************************************************************************
# epoch: 176 / 300, time cost: 42.37 sec,
#           Loss: [Train: 1.93528], [Test: 3.55315],
#           Effect: [ate-q], [train: 0.01733], [test: 0.01693]
# ********************************************************************************
# epoch: 177 / 300, time cost: 42.30 sec,
#           Loss: [Train: 1.93334], [Test: 3.56490],
#           Effect: [ate-q], [train: 0.05825], [test: 0.05735]
# ********************************************************************************
# epoch: 178 / 300, time cost: 42.23 sec,
#           Loss: [Train: 1.93234], [Test: 3.56651],
#           Effect: [ate-q], [train: 0.05856], [test: 0.05776]
# ********************************************************************************
# epoch: 179 / 300, time cost: 42.68 sec,
#           Loss: [Train: 1.93239], [Test: 3.58231],
#           Effect: [ate-q], [train: 0.05533], [test: 0.05496]
# ********************************************************************************
# epoch: 180 / 300, time cost: 42.39 sec,
#           Loss: [Train: 1.93189], [Test: 3.57678],
#           Effect: [ate-q], [train: 0.07562], [test: 0.07489]
# ********************************************************************************
# epoch: 181 / 300, time cost: 42.14 sec,
#           Loss: [Train: 1.93055], [Test: 3.58288],
#           Effect: [ate-q], [train: 0.07667], [test: 0.07587]
# ********************************************************************************
# epoch: 182 / 300, time cost: 42.18 sec,
#           Loss: [Train: 1.92994], [Test: 3.60150],
#           Effect: [ate-q], [train: 0.07625], [test: 0.07555]
# ********************************************************************************
# epoch: 183 / 300, time cost: 42.11 sec,
#           Loss: [Train: 1.93002], [Test: 3.60193],
#           Effect: [ate-q], [train: 0.01296], [test: 0.01228]
# ********************************************************************************
# epoch: 184 / 300, time cost: 41.87 sec,
#           Loss: [Train: 1.92968], [Test: 3.61152],
#           Effect: [ate-q], [train: 0.02539], [test: 0.02480]
# ********************************************************************************
# epoch: 185 / 300, time cost: 41.98 sec,
#           Loss: [Train: 1.92707], [Test: 3.61567],
#           Effect: [ate-q], [train: 0.11188], [test: 0.11099]
# ********************************************************************************
# epoch: 186 / 300, time cost: 42.31 sec,
#           Loss: [Train: 1.92660], [Test: 3.62392],
#           Effect: [ate-q], [train: 0.05930], [test: 0.05891]
# ********************************************************************************
# epoch: 187 / 300, time cost: 42.21 sec,
#           Loss: [Train: 1.92586], [Test: 3.62652],
#           Effect: [ate-q], [train: 0.09991], [test: 0.09901]
# ********************************************************************************
# epoch: 188 / 300, time cost: 42.30 sec,
#           Loss: [Train: 1.92549], [Test: 3.63667],
#           Effect: [ate-q], [train: 0.05327], [test: 0.05257]
# ********************************************************************************
# epoch: 189 / 300, time cost: 42.33 sec,
#           Loss: [Train: 1.92453], [Test: 3.62913],
#           Effect: [ate-q], [train: 0.04263], [test: 0.04200]
# ********************************************************************************
# epoch: 190 / 300, time cost: 42.46 sec,
#           Loss: [Train: 1.92413], [Test: 3.64731],
#           Effect: [ate-q], [train: 0.09973], [test: 0.09887]
# ********************************************************************************
# epoch: 191 / 300, time cost: 42.81 sec,
#           Loss: [Train: 1.92294], [Test: 3.64754],
#           Effect: [ate-q], [train: 0.09800], [test: 0.09702]
# ********************************************************************************
# epoch: 192 / 300, time cost: 42.54 sec,
#           Loss: [Train: 1.92222], [Test: 3.65684],
#           Effect: [ate-q], [train: 0.06368], [test: 0.06311]
# ********************************************************************************
# epoch: 193 / 300, time cost: 42.40 sec,
#           Loss: [Train: 1.92171], [Test: 3.66675],
#           Effect: [ate-q], [train: 0.03782], [test: 0.03714]
# ********************************************************************************
# epoch: 194 / 300, time cost: 42.40 sec,
#           Loss: [Train: 1.92180], [Test: 3.67526],
#           Effect: [ate-q], [train: 0.16122], [test: 0.16010]
# ********************************************************************************
# epoch: 195 / 300, time cost: 42.19 sec,
#           Loss: [Train: 1.91984], [Test: 3.67807],
#           Effect: [ate-q], [train: 0.05754], [test: 0.05678]
# ********************************************************************************
# epoch: 196 / 300, time cost: 42.12 sec,
#           Loss: [Train: 1.92027], [Test: 3.67658],
#           Effect: [ate-q], [train: 0.06117], [test: 0.06008]
# ********************************************************************************
# epoch: 197 / 300, time cost: 42.37 sec,
#           Loss: [Train: 1.91813], [Test: 3.68592],
#           Effect: [ate-q], [train: 0.04379], [test: 0.04347]
# ********************************************************************************
# epoch: 198 / 300, time cost: 42.51 sec,
#           Loss: [Train: 1.91804], [Test: 3.67987],
#           Effect: [ate-q], [train: 0.04779], [test: 0.04702]
# ********************************************************************************
# epoch: 199 / 300, time cost: 42.27 sec,
#           Loss: [Train: 1.91809], [Test: 3.69494],
#           Effect: [ate-q], [train: 0.02866], [test: 0.02793]
# ********************************************************************************
# epoch: 200 / 300, time cost: 42.17 sec,
#           Loss: [Train: 1.91685], [Test: 3.70463],
#           Effect: [ate-q], [train: 0.12262], [test: 0.12167]
# ********************************************************************************
# epoch: 201 / 300, time cost: 42.31 sec,
#           Loss: [Train: 1.91618], [Test: 3.70283],
#           Effect: [ate-q], [train: -0.00062], [test: -0.00139]
# ********************************************************************************
# epoch: 202 / 300, time cost: 42.22 sec,
#           Loss: [Train: 1.91616], [Test: 3.71374],
#           Effect: [ate-q], [train: 0.09264], [test: 0.09188]
# ********************************************************************************
# epoch: 203 / 300, time cost: 42.43 sec,
#           Loss: [Train: 1.91503], [Test: 3.70971],
#           Effect: [ate-q], [train: 0.00116], [test: 0.00080]
# ********************************************************************************
# epoch: 204 / 300, time cost: 43.06 sec,
#           Loss: [Train: 1.91328], [Test: 3.71856],
#           Effect: [ate-q], [train: 0.14719], [test: 0.14622]
# ********************************************************************************
# epoch: 205 / 300, time cost: 42.46 sec,
#           Loss: [Train: 1.91284], [Test: 3.72594],
#           Effect: [ate-q], [train: 0.02299], [test: 0.02225]
# ********************************************************************************
# epoch: 206 / 300, time cost: 42.29 sec,
#           Loss: [Train: 1.91213], [Test: 3.74418],
# ...
# epoch: 233 / 300, time cost: 42.13 sec,
#           Loss: [Train: 1.89754], [Test: 3.85683],
#           Effect: [ate-q], [train: 0.04124], [test: 0.04036]
# ********************************************************************************
# epoch: 234 / 300, time cost: 41.98 sec,
#           Loss: [Train: 1.89680], [Test: 3.85618],
#           Effect: [ate-q], [train: 0.08161], [test: 0.08056]
# ********************************************************************************
# epoch: 235 / 300, time cost: 42.01 sec,
#           Loss: [Train: 1.89633], [Test: 3.86351],
#           Effect: [ate-q], [train: 0.03982], [test: 0.03881]
# ********************************************************************************
# epoch: 236 / 300, time cost: 42.40 sec,
#           Loss: [Train: 1.89535], [Test: 3.86308],
#           Effect: [ate-q], [train: 0.04653], [test: 0.04561]
# ********************************************************************************
# epoch: 237 / 300, time cost: 42.14 sec,
#           Loss: [Train: 1.89452], [Test: 3.87519],
#           Effect: [ate-q], [train: 0.03834], [test: 0.03750]
# ********************************************************************************
# epoch: 238 / 300, time cost: 43.09 sec,
#           Loss: [Train: 1.89460], [Test: 3.88364],
#           Effect: [ate-q], [train: 0.05543], [test: 0.05449]
# ********************************************************************************
# epoch: 239 / 300, time cost: 42.20 sec,
#           Loss: [Train: 1.89494], [Test: 3.87182],
#           Effect: [ate-q], [train: 0.09035], [test: 0.08916]
# ********************************************************************************
# epoch: 240 / 300, time cost: 41.90 sec,
#           Loss: [Train: 1.89420], [Test: 3.90099],
#           Effect: [ate-q], [train: 0.07709], [test: 0.07615]
# ********************************************************************************
# epoch: 241 / 300, time cost: 42.39 sec,
#           Loss: [Train: 1.89267], [Test: 3.89106],
#           Effect: [ate-q], [train: 0.00558], [test: 0.00488]
# ********************************************************************************
# epoch: 242 / 300, time cost: 41.90 sec,
#           Loss: [Train: 1.89266], [Test: 3.91101],
#           Effect: [ate-q], [train: 0.14479], [test: 0.14376]
# ********************************************************************************
# epoch: 243 / 300, time cost: 42.06 sec,
#           Loss: [Train: 1.89178], [Test: 3.88067],
#           Effect: [ate-q], [train: 0.03628], [test: 0.03550]
# ********************************************************************************
# epoch: 244 / 300, time cost: 41.83 sec,
#           Loss: [Train: 1.89204], [Test: 3.91151],
#           Effect: [ate-q], [train: 0.06022], [test: 0.05915]
# ********************************************************************************
# epoch: 245 / 300, time cost: 41.82 sec,
#           Loss: [Train: 1.89128], [Test: 3.90351],
#           Effect: [ate-q], [train: 0.01932], [test: 0.01845]
# ********************************************************************************
# epoch: 246 / 300, time cost: 41.59 sec,
#           Loss: [Train: 1.89047], [Test: 3.90447],
#           Effect: [ate-q], [train: 0.08727], [test: 0.08612]
# ********************************************************************************
# epoch: 247 / 300, time cost: 42.05 sec,
#           Loss: [Train: 1.89005], [Test: 3.92262],
#           Effect: [ate-q], [train: -0.01917], [test: -0.01980]
# ********************************************************************************
# epoch: 248 / 300, time cost: 42.10 sec,
#           Loss: [Train: 1.88980], [Test: 3.91652],
#           Effect: [ate-q], [train: 0.00851], [test: 0.00782]
# ********************************************************************************
# epoch: 249 / 300, time cost: 42.27 sec,
#           Loss: [Train: 1.88836], [Test: 3.91791],
#           Effect: [ate-q], [train: 0.01383], [test: 0.01287]
# ********************************************************************************
# epoch: 250 / 300, time cost: 41.75 sec,
#           Loss: [Train: 1.88848], [Test: 3.92855],
#           Effect: [ate-q], [train: 0.04790], [test: 0.04694]
# ********************************************************************************
# epoch: 251 / 300, time cost: 42.02 sec,
#           Loss: [Train: 1.88821], [Test: 3.92916],
#           Effect: [ate-q], [train: 0.08028], [test: 0.07903]
# ********************************************************************************
# epoch: 252 / 300, time cost: 41.83 sec,
#           Loss: [Train: 1.88831], [Test: 3.92409],
#           Effect: [ate-q], [train: 0.06579], [test: 0.06454]
# ********************************************************************************
# epoch: 253 / 300, time cost: 42.08 sec,
#           Loss: [Train: 1.88686], [Test: 3.93969],
#           Effect: [ate-q], [train: 0.01925], [test: 0.01853]
# ********************************************************************************
# epoch: 254 / 300, time cost: 41.94 sec,
#           Loss: [Train: 1.88740], [Test: 3.93354],
#           Effect: [ate-q], [train: 0.01845], [test: 0.01759]
# ********************************************************************************
# epoch: 255 / 300, time cost: 42.35 sec,
#           Loss: [Train: 1.88715], [Test: 3.94349],
#           Effect: [ate-q], [train: 0.01892], [test: 0.01789]
# ********************************************************************************
# epoch: 256 / 300, time cost: 41.83 sec,
#           Loss: [Train: 1.88615], [Test: 3.94615],
#           Effect: [ate-q], [train: 0.04230], [test: 0.04125]
# ********************************************************************************
# epoch: 257 / 300, time cost: 42.21 sec,
#           Loss: [Train: 1.88540], [Test: 3.95319],
#           Effect: [ate-q], [train: 0.09293], [test: 0.09184]
# ********************************************************************************
# epoch: 258 / 300, time cost: 42.43 sec,
#           Loss: [Train: 1.88478], [Test: 3.96219],
#           Effect: [ate-q], [train: 0.10053], [test: 0.09939]
# ********************************************************************************
# epoch: 259 / 300, time cost: 42.35 sec,
#           Loss: [Train: 1.88515], [Test: 3.96090],
#           Effect: [ate-q], [train: 0.02178], [test: 0.02082]
# ********************************************************************************
# epoch: 260 / 300, time cost: 42.29 sec,
#           Loss: [Train: 1.88417], [Test: 3.96430],
#           Effect: [ate-q], [train: 0.10430], [test: 0.10321]
# ********************************************************************************
# epoch: 261 / 300, time cost: 42.61 sec,
#           Loss: [Train: 1.88459], [Test: 3.97006],
#           Effect: [ate-q], [train: 0.04647], [test: 0.04562]
# ********************************************************************************
# epoch: 262 / 300, time cost: 42.42 sec,
#           Loss: [Train: 1.88374], [Test: 3.97098],
#           Effect: [ate-q], [train: 0.06394], [test: 0.06295]
# ********************************************************************************
# epoch: 263 / 300, time cost: 42.15 sec,
#           Loss: [Train: 1.88403], [Test: 3.97495],
#           Effect: [ate-q], [train: 0.06761], [test: 0.06660]
# ********************************************************************************
# epoch: 264 / 300, time cost: 42.83 sec,
#           Loss: [Train: 1.88209], [Test: 3.97228],
#           Effect: [ate-q], [train: 0.05509], [test: 0.05409]
# ********************************************************************************
# epoch: 265 / 300, time cost: 42.28 sec,
#           Loss: [Train: 1.88196], [Test: 3.97992],
#           Effect: [ate-q], [train: 0.02949], [test: 0.02865]
# ********************************************************************************
# epoch: 266 / 300, time cost: 42.05 sec,
#           Loss: [Train: 1.88190], [Test: 3.97884],
#           Effect: [ate-q], [train: 0.06477], [test: 0.06373]
# ********************************************************************************
# epoch: 267 / 300, time cost: 42.40 sec,
#           Loss: [Train: 1.88167], [Test: 3.98699],
#           Effect: [ate-q], [train: 0.10627], [test: 0.10522]
# ********************************************************************************
# epoch: 268 / 300, time cost: 41.95 sec,
#           Loss: [Train: 1.88117], [Test: 3.98748],
#           Effect: [ate-q], [train: 0.05371], [test: 0.05270]
# ********************************************************************************
# epoch: 269 / 300, time cost: 41.86 sec,
#           Loss: [Train: 1.88098], [Test: 3.98754],
#           Effect: [ate-q], [train: 0.05139], [test: 0.05039]
# ********************************************************************************
# epoch: 270 / 300, time cost: 41.72 sec,
#           Loss: [Train: 1.88039], [Test: 3.98914],
#           Effect: [ate-q], [train: 0.06650], [test: 0.06565]
# ********************************************************************************
# epoch: 271 / 300, time cost: 42.03 sec,
#           Loss: [Train: 1.88041], [Test: 3.99095],
#           Effect: [ate-q], [train: 0.07167], [test: 0.07080]
# ********************************************************************************
# epoch: 272 / 300, time cost: 41.75 sec,
#           Loss: [Train: 1.87988], [Test: 3.99108],
#           Effect: [ate-q], [train: 0.06769], [test: 0.06671]
# ********************************************************************************
# epoch: 273 / 300, time cost: 42.01 sec,
#           Loss: [Train: 1.87928], [Test: 3.99273],
#           Effect: [ate-q], [train: 0.07435], [test: 0.07334]
# ********************************************************************************
# epoch: 274 / 300, time cost: 42.47 sec,
#           Loss: [Train: 1.87901], [Test: 3.99942],
#           Effect: [ate-q], [train: 0.09806], [test: 0.09698]
# ********************************************************************************
# epoch: 275 / 300, time cost: 42.37 sec,
#           Loss: [Train: 1.87841], [Test: 3.99805],
#           Effect: [ate-q], [train: 0.03287], [test: 0.03197]
# ********************************************************************************
# epoch: 276 / 300, time cost: 42.20 sec,
#           Loss: [Train: 1.87868], [Test: 3.99472],
#           Effect: [ate-q], [train: 0.10199], [test: 0.10078]
# ********************************************************************************
# epoch: 277 / 300, time cost: 42.25 sec,
#           Loss: [Train: 1.87831], [Test: 4.00828],
#           Effect: [ate-q], [train: -0.00619], [test: -0.00676]
# ********************************************************************************
# epoch: 278 / 300, time cost: 42.06 sec,
#           Loss: [Train: 1.87830], [Test: 4.00543],
#           Effect: [ate-q], [train: 0.05655], [test: 0.05568]
# ********************************************************************************
# epoch: 279 / 300, time cost: 42.07 sec,
#           Loss: [Train: 1.87764], [Test: 4.00654],
#           Effect: [ate-q], [train: 0.05617], [test: 0.05544]
# ********************************************************************************
# epoch: 280 / 300, time cost: 42.15 sec,
#           Loss: [Train: 1.87688], [Test: 4.00731],
#           Effect: [ate-q], [train: 0.06935], [test: 0.06838]
# ********************************************************************************
# epoch: 281 / 300, time cost: 42.42 sec,
#           Loss: [Train: 1.87647], [Test: 4.00582],
#           Effect: [ate-q], [train: 0.06473], [test: 0.06384]
# ********************************************************************************
# epoch: 282 / 300, time cost: 42.30 sec,
#           Loss: [Train: 1.87606], [Test: 4.00717],
#           Effect: [ate-q], [train: 0.04920], [test: 0.04820]
# ********************************************************************************
# epoch: 283 / 300, time cost: 42.25 sec,
#           Loss: [Train: 1.87557], [Test: 4.00538],
#           Effect: [ate-q], [train: 0.04916], [test: 0.04814]
# ********************************************************************************
# epoch: 284 / 300, time cost: 42.26 sec,
#           Loss: [Train: 1.87530], [Test: 4.00971],
#           Effect: [ate-q], [train: 0.07262], [test: 0.07162]
# ********************************************************************************
# epoch: 285 / 300, time cost: 42.10 sec,
#           Loss: [Train: 1.87577], [Test: 4.01077],
#           Effect: [ate-q], [train: 0.05625], [test: 0.05518]
# ********************************************************************************
# epoch: 286 / 300, time cost: 42.60 sec,
#           Loss: [Train: 1.87496], [Test: 4.01637],
#           Effect: [ate-q], [train: 0.04231], [test: 0.04138]
# ********************************************************************************
# epoch: 287 / 300, time cost: 42.41 sec,
#           Loss: [Train: 1.87541], [Test: 4.01217],
#           Effect: [ate-q], [train: 0.08313], [test: 0.08206]
# ********************************************************************************
# epoch: 288 / 300, time cost: 42.78 sec,
#           Loss: [Train: 1.87473], [Test: 4.01991],
#           Effect: [ate-q], [train: 0.05552], [test: 0.05461]
# ********************************************************************************
# epoch: 289 / 300, time cost: 42.94 sec,
#           Loss: [Train: 1.87405], [Test: 4.01882],
#           Effect: [ate-q], [train: 0.03915], [test: 0.03824]
# ********************************************************************************
# epoch: 290 / 300, time cost: 42.70 sec,
#           Loss: [Train: 1.87364], [Test: 4.02096],
#           Effect: [ate-q], [train: 0.04979], [test: 0.04889]
# ********************************************************************************
# epoch: 291 / 300, time cost: 42.30 sec,
#           Loss: [Train: 1.87322], [Test: 4.01680],
#           Effect: [ate-q], [train: 0.06120], [test: 0.06013]
# ********************************************************************************
# epoch: 292 / 300, time cost: 42.05 sec,
#           Loss: [Train: 1.87260], [Test: 4.01531],
#           Effect: [ate-q], [train: 0.04038], [test: 0.03953]
# ********************************************************************************
# epoch: 293 / 300, time cost: 42.26 sec,
#           Loss: [Train: 1.87265], [Test: 4.01933],
#           Effect: [ate-q], [train: 0.04816], [test: 0.04740]
# ********************************************************************************
# epoch: 294 / 300, time cost: 42.17 sec,
#           Loss: [Train: 1.87310], [Test: 4.02012],
#           Effect: [ate-q], [train: 0.04271], [test: 0.04185]
# ********************************************************************************
# epoch: 295 / 300, time cost: 42.18 sec,
#           Loss: [Train: 1.87209], [Test: 4.02145],
#           Effect: [ate-q], [train: 0.07205], [test: 0.07104]
# ********************************************************************************
# epoch: 296 / 300, time cost: 42.20 sec,
#           Loss: [Train: 1.87252], [Test: 4.02494],
#           Effect: [ate-q], [train: 0.06541], [test: 0.06464]
# ********************************************************************************
# epoch: 297 / 300, time cost: 42.70 sec,
#           Loss: [Train: 1.87142], [Test: 4.02177],
#           Effect: [ate-q], [train: 0.06053], [test: 0.05960]
# ********************************************************************************
# epoch: 298 / 300, time cost: 42.68 sec,
#           Loss: [Train: 1.87192], [Test: 4.02326],
#           Effect: [ate-q], [train: 0.05256], [test: 0.05162]
# ********************************************************************************
# epoch: 299 / 300, time cost: 42.20 sec,
#           Loss: [Train: 1.87114], [Test: 4.02148],
#           Effect: [ate-q], [train: 0.04981], [test: 0.04890]
# ********************************************************************************
# epoch: 300 / 300, time cost: 42.29 sec,
#           Loss: [Train: 1.87158], [Test: 4.02017],
#           Effect: [ate-q], [train: 0.05679], [test: 0.05589]
# ********************************************************************************
# Finish training...

# %%
real = true_casual_effect(test_loader)
unadjust = (testset.response[testset.treatment == 1].mean() - testset.response[testset.treatment == 0].mean()).item()
show_result(train_loss_hist, test_loss_hist, est_effect, real, unadjust, epoch)

# %% [markdown]
# # Med

# %%
vocab = create_vocab(merged=True, uni_diag=True)
tokenizer = WordLevelBertTokenizer(vocab)

alpha = 0.25
beta = 5.
c = 0.2
i = 0.

# %%
start = time.time()
trainset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                             alpha=alpha, beta=beta, c=c, i=i, 
                             group=list(range(1)), max_length=512, min_length=10,
                             truncate_method='first', device=device, seed=1)

print(f'Load training set in {(time.time() - start):.2f} sec')

start = time.time()
testset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                            alpha=alpha, beta=beta, c=c, i=i, 
                            group=[9], max_length=512, min_length=10,
                            truncate_method='first', device=device)

print(f'Load validation set in {(time.time() - start):.2f} sec')
# Out:
# Load training set in 73.08 sec
# Load validation set in 69.06 sec

# %%
train_loader = DataLoader(trainset, batch_size=bsz, drop_last=True, shuffle=True)
test_loader = DataLoader(testset, batch_size=2048, drop_last=True, shuffle=True)

# %%
real_att_q = true_casual_effect(test_loader)

print(f'Real: [effect: ate], [estimation: q], [value: {real_att_q:.5f}]')
print(f'Unadjusted: [value: {(testset.response[testset.treatment == 1].mean() - testset.response[testset.treatment == 0].mean()).item():.4f}]')
# Out:
# Real: [effect: ate], [estimation: q], [value: 0.06024]
# Unadjusted: [value: 0.1403]

# %%
trained_bert = '/nfs/turbo/lsa-regier/bert-results/results/behrt/MLM/merged/unidiag/checkpoint-6018425/'
# trained_bert = '/home/liutianc/emr/bert/results/behrt/MLM/merged/unidiag/checkpoint-6018425/'

model = BertForMaskedLM.from_pretrained(trained_bert)
token_embed = model.get_input_embeddings()
model = CausalBOW(token_embed, learnable_docu_embed=False, hidden_size=hidden_size, prop_is_logit=True).to(device)

pos_portion = trainset.treatment.mean()
pos_weight = (1 - pos_portion) / pos_portion

# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
epoch_iter = len(train_loader)
total_steps = epoch * epoch_iter

optimizer = AdamW(model.parameters(), lr=1e-4, eps=1e-8)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

q_loss = nn.BCELoss()
# prop_score_loss = nn.BCELoss()
prop_score_loss = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# Please specify the effect and estimation we want to use here.
effect = 'ate'
estimation = 'q'

effect = effect.lower()
estimation = estimation.lower()
assert effect in ['att', 'ate'], f'Wrong effect: {effect}...'
assert estimation in ['q', 'plugin'], f'Wrong estimation: {estimation}...'

# %%
rs_loss, rq1_loss, rq0_loss = [0.] * 3

train_loss_hist, test_loss_hist, est_effect = [], [], []
for e in range(1, epoch + 1):
    model.train()
    start = time.time()
    run_loss = 0.
    for idx, (tokens, treatment, response) in enumerate(train_loader):
        optimizer.zero_grad()
        prop_score, q1, q0 = model(tokens)
        
        loss = prop_score_loss(prop_score, treatment)
        if len(response[treatment == 1]) > 0:
            loss += q_loss(q1[treatment==1], response[treatment==1])# * pos_weight
            
        if len(response[treatment == 0]) > 0:
            loss += q_loss(q0[treatment==0], response[treatment==0])
            
        loss.backward()
        
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)    
        optimizer.step()
        scheduler.step()

        run_loss += loss.item()
        
    run_idx = idx

    # Evaluation.
    train_loss = run_loss / (run_idx + 1)
    train_effect, _, _, _ = est_casual_effect(train_loader, model, effect, estimation, eval_loss=False)
    test_effect, g_loss_test, q1_loss_test, q0_loss_test = est_casual_effect(test_loader, model, effect, estimation, g_loss=prop_score_loss, q_loss=q_loss)
    test_loss = q1_loss_test + q0_loss_test
    test_loss += g_loss_test
    
    train_loss_hist.append(train_loss)
    test_loss_hist.append(test_loss)
    est_effect.append(test_effect)
    print(f'''epoch: {e} / {epoch}, time cost: {(time.time() - start):.2f} sec, 
          Loss: [Train: {train_loss:.5f}], [Test: {test_loss:.5f}],
          Effect: [{effect}-{estimation}], [train: {train_effect:.5f}], [test: {test_effect:.5f}]''')
    print('*'* 80)
    start = time.time()
    run_loss = 0.

print('Finish training...')

# With only 1 group(s) to train.
# Out:
# epoch: 1 / 300, time cost: 38.73 sec,
#           Loss: [Train: 2.39875], [Test: 2.40094],
#           Effect: [ate-q], [train: 0.13660], [test: 0.13658]
# ********************************************************************************
# epoch: 2 / 300, time cost: 43.27 sec,
#           Loss: [Train: 2.39186], [Test: 2.39485],
#           Effect: [ate-q], [train: 0.12052], [test: 0.12051]
# ********************************************************************************
# epoch: 3 / 300, time cost: 41.66 sec,
#           Loss: [Train: 2.38097], [Test: 2.38058],
#           Effect: [ate-q], [train: 0.12520], [test: 0.12523]
# ********************************************************************************
# epoch: 4 / 300, time cost: 41.30 sec,
#           Loss: [Train: 2.36350], [Test: 2.36700],
#           Effect: [ate-q], [train: 0.11816], [test: 0.11834]
# ********************************************************************************
# epoch: 5 / 300, time cost: 41.86 sec,
#           Loss: [Train: 2.35081], [Test: 2.36092],
#           Effect: [ate-q], [train: 0.11619], [test: 0.11643]
# ********************************************************************************
# epoch: 6 / 300, time cost: 40.04 sec,
#           Loss: [Train: 2.34311], [Test: 2.35696],
#           Effect: [ate-q], [train: 0.10856], [test: 0.10883]
# ********************************************************************************
# epoch: 7 / 300, time cost: 45.22 sec,
#           Loss: [Train: 2.33584], [Test: 2.35368],
#           Effect: [ate-q], [train: 0.09531], [test: 0.09560]
# ********************************************************************************
# epoch: 8 / 300, time cost: 42.50 sec,
#           Loss: [Train: 2.32881], [Test: 2.35089],
#           Effect: [ate-q], [train: 0.12260], [test: 0.12298]
# ********************************************************************************
# epoch: 9 / 300, time cost: 42.29 sec,
#           Loss: [Train: 2.32308], [Test: 2.34891],
#           Effect: [ate-q], [train: 0.08903], [test: 0.08945]
# ********************************************************************************
# epoch: 10 / 300, time cost: 42.58 sec,
#           Loss: [Train: 2.31629], [Test: 2.34978],
#           Effect: [ate-q], [train: 0.06333], [test: 0.06385]
# ********************************************************************************
# epoch: 11 / 300, time cost: 42.76 sec,
#           Loss: [Train: 2.30985], [Test: 2.34823],
#           Effect: [ate-q], [train: 0.12619], [test: 0.12676]
# ********************************************************************************
# epoch: 12 / 300, time cost: 42.82 sec,
#           Loss: [Train: 2.30286], [Test: 2.34537],
#           Effect: [ate-q], [train: 0.09136], [test: 0.09204]
# ********************************************************************************
# epoch: 13 / 300, time cost: 42.56 sec,
#           Loss: [Train: 2.29638], [Test: 2.34685],
#           Effect: [ate-q], [train: 0.10263], [test: 0.10346]
# ********************************************************************************
# epoch: 14 / 300, time cost: 42.50 sec,
#           Loss: [Train: 2.28973], [Test: 2.35172],
#           Effect: [ate-q], [train: 0.12804], [test: 0.12902]
# ********************************************************************************
# epoch: 15 / 300, time cost: 42.76 sec,
#           Loss: [Train: 2.28269], [Test: 2.34933],
#           Effect: [ate-q], [train: 0.06818], [test: 0.06925]
# ********************************************************************************
# epoch: 16 / 300, time cost: 42.41 sec,
#           Loss: [Train: 2.27547], [Test: 2.34936],
#           Effect: [ate-q], [train: 0.10188], [test: 0.10306]
# ********************************************************************************
# epoch: 17 / 300, time cost: 42.62 sec,
#           Loss: [Train: 2.26766], [Test: 2.35184],
#           Effect: [ate-q], [train: 0.09403], [test: 0.09540]
# ********************************************************************************
# epoch: 18 / 300, time cost: 42.93 sec,
#           Loss: [Train: 2.26036], [Test: 2.35645],
#           Effect: [ate-q], [train: 0.05545], [test: 0.05679]
# ********************************************************************************
# epoch: 19 / 300, time cost: 42.30 sec,
#           Loss: [Train: 2.25367], [Test: 2.35670],
#           Effect: [ate-q], [train: 0.07201], [test: 0.07352]
# ********************************************************************************
# epoch: 20 / 300, time cost: 41.99 sec,
#           Loss: [Train: 2.24564], [Test: 2.36506],
#           Effect: [ate-q], [train: 0.03535], [test: 0.03695]
# ********************************************************************************
# epoch: 21 / 300, time cost: 42.61 sec,
#           Loss: [Train: 2.23837], [Test: 2.36487],
#           Effect: [ate-q], [train: 0.07424], [test: 0.07604]
# ********************************************************************************
# epoch: 22 / 300, time cost: 42.77 sec,
#           Loss: [Train: 2.23144], [Test: 2.37178],
#           Effect: [ate-q], [train: 0.03505], [test: 0.03684]
# ********************************************************************************
# epoch: 23 / 300, time cost: 42.68 sec,
#           Loss: [Train: 2.22483], [Test: 2.37565],
#           Effect: [ate-q], [train: 0.04301], [test: 0.04488]
# ********************************************************************************
# epoch: 24 / 300, time cost: 42.94 sec,
#           Loss: [Train: 2.21703], [Test: 2.37954],
#           Effect: [ate-q], [train: 0.03599], [test: 0.03790]
# ********************************************************************************
# epoch: 25 / 300, time cost: 42.64 sec,
#           Loss: [Train: 2.21047], [Test: 2.38718],
#           Effect: [ate-q], [train: 0.04599], [test: 0.04801]
# ********************************************************************************
# epoch: 26 / 300, time cost: 42.43 sec,
#           Loss: [Train: 2.20360], [Test: 2.38843],
#           Effect: [ate-q], [train: 0.11920], [test: 0.12171]
# ********************************************************************************
# epoch: 27 / 300, time cost: 42.60 sec,
#           Loss: [Train: 2.19838], [Test: 2.39431],
#           Effect: [ate-q], [train: 0.05621], [test: 0.05847]
# ********************************************************************************
# epoch: 28 / 300, time cost: 42.53 sec,
#           Loss: [Train: 2.19284], [Test: 2.40194],
#           Effect: [ate-q], [train: 0.05620], [test: 0.05860]
# ********************************************************************************
# epoch: 29 / 300, time cost: 42.97 sec,
#           Loss: [Train: 2.18731], [Test: 2.40831],
#           Effect: [ate-q], [train: 0.03222], [test: 0.03448]
# ********************************************************************************
# epoch: 30 / 300, time cost: 42.53 sec,
#           Loss: [Train: 2.17999], [Test: 2.41411],
#           Effect: [ate-q], [train: 0.12516], [test: 0.12784]
# ********************************************************************************
# epoch: 31 / 300, time cost: 42.94 sec,
#           Loss: [Train: 2.17467], [Test: 2.41916],
#           Effect: [ate-q], [train: 0.01901], [test: 0.02137]
# ********************************************************************************
# epoch: 32 / 300, time cost: 42.72 sec,
#           Loss: [Train: 2.16964], [Test: 2.42079],
#           Effect: [ate-q], [train: 0.04511], [test: 0.04752]
# ********************************************************************************
# epoch: 33 / 300, time cost: 42.70 sec,
#           Loss: [Train: 2.16356], [Test: 2.42708],
#           Effect: [ate-q], [train: 0.07991], [test: 0.08246]
# ********************************************************************************
# epoch: 34 / 300, time cost: 42.99 sec,
#           Loss: [Train: 2.15938], [Test: 2.43114],
#           Effect: [ate-q], [train: 0.04669], [test: 0.04922]
# ********************************************************************************
# epoch: 35 / 300, time cost: 42.65 sec,
#           Loss: [Train: 2.15251], [Test: 2.44735],
#           Effect: [ate-q], [train: 0.01295], [test: 0.01533]
# ********************************************************************************
# epoch: 36 / 300, time cost: 42.77 sec,
#           Loss: [Train: 2.14741], [Test: 2.44707],
#           Effect: [ate-q], [train: 0.09649], [test: 0.09927]
# ********************************************************************************
# epoch: 37 / 300, time cost: 43.08 sec,
#           Loss: [Train: 2.14332], [Test: 2.44968],
#           Effect: [ate-q], [train: 0.03590], [test: 0.03829]
# ********************************************************************************
# epoch: 38 / 300, time cost: 42.62 sec,
#           Loss: [Train: 2.13684], [Test: 2.45287],
#           Effect: [ate-q], [train: 0.03850], [test: 0.04088]
# ********************************************************************************
# epoch: 39 / 300, time cost: 42.12 sec,
#           Loss: [Train: 2.13185], [Test: 2.46496],
#           Effect: [ate-q], [train: 0.09054], [test: 0.09317]
# ********************************************************************************
# epoch: 40 / 300, time cost: 42.73 sec,
#           Loss: [Train: 2.12603], [Test: 2.46642],
#           Effect: [ate-q], [train: 0.07095], [test: 0.07347]
# ********************************************************************************
# epoch: 41 / 300, time cost: 42.67 sec,
#           Loss: [Train: 2.12074], [Test: 2.47348],
#           Effect: [ate-q], [train: 0.03631], [test: 0.03882]
# ********************************************************************************
# epoch: 42 / 300, time cost: 42.55 sec,
#           Loss: [Train: 2.11584], [Test: 2.48424],
#           Effect: [ate-q], [train: 0.02465], [test: 0.02673]
# ********************************************************************************
# epoch: 43 / 300, time cost: 42.78 sec,
#           Loss: [Train: 2.11031], [Test: 2.48626],
#           Effect: [ate-q], [train: 0.03810], [test: 0.04050]
# ********************************************************************************
# epoch: 44 / 300, time cost: 42.89 sec,
#           Loss: [Train: 2.10483], [Test: 2.49078],
#           Effect: [ate-q], [train: 0.06760], [test: 0.06995]
# ********************************************************************************
# epoch: 45 / 300, time cost: 42.76 sec,
#           Loss: [Train: 2.09986], [Test: 2.50125],
#           Effect: [ate-q], [train: 0.09791], [test: 0.10039]
# ********************************************************************************
# epoch: 46 / 300, time cost: 42.24 sec,
#           Loss: [Train: 2.09559], [Test: 2.50276],
#           Effect: [ate-q], [train: 0.05389], [test: 0.05627]
# ********************************************************************************
# epoch: 47 / 300, time cost: 44.00 sec,
#           Loss: [Train: 2.09072], [Test: 2.51134],
#           Effect: [ate-q], [train: 0.05472], [test: 0.05718]
# ********************************************************************************
# epoch: 48 / 300, time cost: 49.00 sec,
#           Loss: [Train: 2.08545], [Test: 2.51551],
#           Effect: [ate-q], [train: 0.07475], [test: 0.07716]
# ********************************************************************************
# epoch: 49 / 300, time cost: 43.63 sec,
#           Loss: [Train: 2.08056], [Test: 2.52567],
#           Effect: [ate-q], [train: 0.05769], [test: 0.06001]
# ********************************************************************************
# epoch: 50 / 300, time cost: 43.34 sec,
#           Loss: [Train: 2.07658], [Test: 2.53832],
#           Effect: [ate-q], [train: 0.11229], [test: 0.11469]
# ********************************************************************************
# epoch: 51 / 300, time cost: 43.13 sec,
#           Loss: [Train: 2.07263], [Test: 2.53513],
#           Effect: [ate-q], [train: 0.08719], [test: 0.08979]
# ********************************************************************************
# epoch: 52 / 300, time cost: 42.36 sec,
#           Loss: [Train: 2.06827], [Test: 2.54501],
#           Effect: [ate-q], [train: 0.06908], [test: 0.07141]
# ********************************************************************************
# epoch: 53 / 300, time cost: 42.55 sec,
#           Loss: [Train: 2.06402], [Test: 2.55600],
#           Effect: [ate-q], [train: 0.02506], [test: 0.02725]
# ********************************************************************************
# epoch: 54 / 300, time cost: 42.58 sec,
#           Loss: [Train: 2.05781], [Test: 2.55893],
#           Effect: [ate-q], [train: 0.02284], [test: 0.02523]
# ********************************************************************************
# epoch: 55 / 300, time cost: 42.13 sec,
#           Loss: [Train: 2.05450], [Test: 2.56916],
#           Effect: [ate-q], [train: 0.06054], [test: 0.06301]
# ********************************************************************************
# epoch: 56 / 300, time cost: 42.70 sec,
#           Loss: [Train: 2.05199], [Test: 2.57046],
#           Effect: [ate-q], [train: 0.12763], [test: 0.13029]
# ********************************************************************************
# epoch: 57 / 300, time cost: 42.83 sec,
#           Loss: [Train: 2.04822], [Test: 2.57413],
#           Effect: [ate-q], [train: 0.07305], [test: 0.07563]
# ********************************************************************************
# epoch: 58 / 300, time cost: 42.98 sec,
#           Loss: [Train: 2.04417], [Test: 2.57955],
#           Effect: [ate-q], [train: 0.11082], [test: 0.11363]
# ********************************************************************************
# epoch: 59 / 300, time cost: 42.59 sec,
#           Loss: [Train: 2.04119], [Test: 2.59157],
#           Effect: [ate-q], [train: 0.02047], [test: 0.02272]
# ********************************************************************************
# epoch: 60 / 300, time cost: 42.45 sec,
#           Loss: [Train: 2.03704], [Test: 2.59405],
#           Effect: [ate-q], [train: 0.06383], [test: 0.06618]
# ********************************************************************************
# epoch: 61 / 300, time cost: 42.73 sec,
#           Loss: [Train: 2.03459], [Test: 2.62922],
#           Effect: [ate-q], [train: -0.07084], [test: -0.06901]
# ********************************************************************************
# epoch: 62 / 300, time cost: 42.70 sec,
#           Loss: [Train: 2.03157], [Test: 2.60814],
#           Effect: [ate-q], [train: 0.02403], [test: 0.02625]
# ********************************************************************************
# epoch: 63 / 300, time cost: 42.42 sec,
#           Loss: [Train: 2.02770], [Test: 2.61745],
#           Effect: [ate-q], [train: 0.03911], [test: 0.04160]
# ********************************************************************************
# epoch: 64 / 300, time cost: 43.10 sec,
#           Loss: [Train: 2.02292], [Test: 2.63281],
#           Effect: [ate-q], [train: 0.01927], [test: 0.02161]
# ********************************************************************************
# epoch: 65 / 300, time cost: 42.39 sec,
#           Loss: [Train: 2.02113], [Test: 2.63362],
#           Effect: [ate-q], [train: 0.04567], [test: 0.04835]
# ********************************************************************************
# epoch: 66 / 300, time cost: 42.33 sec,
#           Loss: [Train: 2.01809], [Test: 2.64582],
#           Effect: [ate-q], [train: 0.00589], [test: 0.00798]
# ********************************************************************************
# epoch: 67 / 300, time cost: 42.75 sec,
#           Loss: [Train: 2.01536], [Test: 2.65284],
#           Effect: [ate-q], [train: 0.10998], [test: 0.11256]
# ********************************************************************************
# epoch: 68 / 300, time cost: 42.59 sec,
#           Loss: [Train: 2.01216], [Test: 2.65937],
#           Effect: [ate-q], [train: 0.01838], [test: 0.02062]
# ********************************************************************************
# epoch: 69 / 300, time cost: 42.74 sec,
#           Loss: [Train: 2.01048], [Test: 2.66402],
#           Effect: [ate-q], [train: 0.13366], [test: 0.13665]
# ********************************************************************************
# epoch: 70 / 300, time cost: 42.71 sec,
#           Loss: [Train: 2.00637], [Test: 2.66478],
#           Effect: [ate-q], [train: 0.07959], [test: 0.08204]
# ********************************************************************************
# epoch: 71 / 300, time cost: 42.78 sec,
#           Loss: [Train: 2.00400], [Test: 2.67305],
#           Effect: [ate-q], [train: 0.11096], [test: 0.11379]
# ********************************************************************************
# epoch: 72 / 300, time cost: 42.72 sec,
#           Loss: [Train: 1.99980], [Test: 2.68022],
#           Effect: [ate-q], [train: 0.10874], [test: 0.11138]
# ********************************************************************************
# epoch: 73 / 300, time cost: 42.54 sec,
#           Loss: [Train: 1.99811], [Test: 2.69699],
#           Effect: [ate-q], [train: 0.01375], [test: 0.01602]
# ********************************************************************************
# epoch: 74 / 300, time cost: 42.72 sec,
#           Loss: [Train: 1.99578], [Test: 2.70444],
#           Effect: [ate-q], [train: 0.00291], [test: 0.00504]
# ********************************************************************************
# epoch: 75 / 300, time cost: 42.76 sec,
#           Loss: [Train: 1.99213], [Test: 2.70949],
#           Effect: [ate-q], [train: 0.05978], [test: 0.06223]
# ********************************************************************************
# epoch: 76 / 300, time cost: 42.49 sec,
#           Loss: [Train: 1.98998], [Test: 2.70536],
#           Effect: [ate-q], [train: 0.02936], [test: 0.03177]
# ********************************************************************************
# epoch: 77 / 300, time cost: 42.76 sec,
#           Loss: [Train: 1.98804], [Test: 2.72024],
#           Effect: [ate-q], [train: 0.07255], [test: 0.07532]
# ********************************************************************************
# epoch: 78 / 300, time cost: 42.20 sec,
#           Loss: [Train: 1.98653], [Test: 2.72693],
#           Effect: [ate-q], [train: -0.00029], [test: 0.00209]
# ********************************************************************************
# epoch: 79 / 300, time cost: 42.39 sec,
#           Loss: [Train: 1.98412], [Test: 2.73265],
#           Effect: [ate-q], [train: 0.09845], [test: 0.10109]
# ********************************************************************************
# epoch: 80 / 300, time cost: 42.55 sec,
#           Loss: [Train: 1.98067], [Test: 2.73832],
#           Effect: [ate-q], [train: 0.03703], [test: 0.03941]
# ********************************************************************************
# epoch: 81 / 300, time cost: 42.40 sec,
#           Loss: [Train: 1.97912], [Test: 2.74594],
#           Effect: [ate-q], [train: 0.08229], [test: 0.08495]
# ********************************************************************************
# epoch: 82 / 300, time cost: 42.56 sec,
#           Loss: [Train: 1.97670], [Test: 2.75264],
#           Effect: [ate-q], [train: 0.04867], [test: 0.05108]
# ********************************************************************************
# epoch: 83 / 300, time cost: 43.05 sec,
#           Loss: [Train: 1.97686], [Test: 2.75130],
#           Effect: [ate-q], [train: 0.07425], [test: 0.07678]
# ********************************************************************************
# epoch: 84 / 300, time cost: 42.58 sec,
#           Loss: [Train: 1.97230], [Test: 2.77540],
#           Effect: [ate-q], [train: -0.01454], [test: -0.01236]
# ********************************************************************************
# epoch: 85 / 300, time cost: 42.74 sec,
#           Loss: [Train: 1.97071], [Test: 2.77720],
#           Effect: [ate-q], [train: 0.00762], [test: 0.00986]
# ********************************************************************************
# epoch: 86 / 300, time cost: 42.78 sec,
#           Loss: [Train: 1.96846], [Test: 2.78181],
#           Effect: [ate-q], [train: 0.00859], [test: 0.01088]
# ********************************************************************************
# epoch: 87 / 300, time cost: 42.93 sec,
#           Loss: [Train: 1.96709], [Test: 2.79733],
#           Effect: [ate-q], [train: -0.00290], [test: -0.00067]
# ********************************************************************************
# epoch: 88 / 300, time cost: 42.95 sec,
#           Loss: [Train: 1.96529], [Test: 2.78699],
#           Effect: [ate-q], [train: 0.12415], [test: 0.12688]
# ********************************************************************************
# epoch: 89 / 300, time cost: 42.76 sec,
#           Loss: [Train: 1.96287], [Test: 2.80412],
#           Effect: [ate-q], [train: 0.02148], [test: 0.02390]
# ********************************************************************************
# epoch: 90 / 300, time cost: 42.43 sec,
#           Loss: [Train: 1.96064], [Test: 2.81858],
#           Effect: [ate-q], [train: 0.04386], [test: 0.04646]
# ********************************************************************************
# epoch: 91 / 300, time cost: 41.02 sec,
#           Loss: [Train: 1.95841], [Test: 2.81080],
#           Effect: [ate-q], [train: 0.01926], [test: 0.02184]
# ********************************************************************************
# epoch: 92 / 300, time cost: 41.19 sec,
#           Loss: [Train: 1.95652], [Test: 2.82567],
#           Effect: [ate-q], [train: 0.04395], [test: 0.04654]
# ********************************************************************************
# epoch: 93 / 300, time cost: 42.80 sec,
#           Loss: [Train: 1.95503], [Test: 2.82680],
#           Effect: [ate-q], [train: 0.04050], [test: 0.04285]
# ********************************************************************************
# epoch: 94 / 300, time cost: 42.60 sec,
#           Loss: [Train: 1.95333], [Test: 2.83601],
#           Effect: [ate-q], [train: 0.00850], [test: 0.01055]
# ********************************************************************************
# epoch: 95 / 300, time cost: 42.73 sec,
#           Loss: [Train: 1.95120], [Test: 2.84039],
#           Effect: [ate-q], [train: 0.03013], [test: 0.03234]
# ********************************************************************************
# epoch: 96 / 300, time cost: 42.92 sec,
#           Loss: [Train: 1.95063], [Test: 2.84509],
#           Effect: [ate-q], [train: 0.02288], [test: 0.02527]
# ********************************************************************************
# epoch: 97 / 300, time cost: 42.70 sec,
#           Loss: [Train: 1.94732], [Test: 2.85124],
#           Effect: [ate-q], [train: 0.02172], [test: 0.02391]
# ********************************************************************************
# epoch: 98 / 300, time cost: 42.18 sec,
#           Loss: [Train: 1.94474], [Test: 2.84754],
#           Effect: [ate-q], [train: 0.06044], [test: 0.06301]
# ********************************************************************************
# epoch: 99 / 300, time cost: 42.70 sec,
#           Loss: [Train: 1.94493], [Test: 2.86867],
#           Effect: [ate-q], [train: 0.02615], [test: 0.02870]
# ********************************************************************************
# epoch: 100 / 300, time cost: 42.71 sec,
#           Loss: [Train: 1.94460], [Test: 2.86700],
#           Effect: [ate-q], [train: 0.05606], [test: 0.05833]
# ********************************************************************************
# epoch: 101 / 300, time cost: 42.65 sec,
#           Loss: [Train: 1.94223], [Test: 2.88592],
#           Effect: [ate-q], [train: -0.02398], [test: -0.02185]
# ********************************************************************************
# epoch: 102 / 300, time cost: 42.47 sec,
#           Loss: [Train: 1.93816], [Test: 2.90030],
#           Effect: [ate-q], [train: 0.01531], [test: 0.01723]
# ********************************************************************************
# epoch: 103 / 300, time cost: 42.98 sec,
#           Loss: [Train: 1.93872], [Test: 2.90373],
#           Effect: [ate-q], [train: -0.00538], [test: -0.00340]
# ********************************************************************************
# epoch: 104 / 300, time cost: 42.84 sec,
#           Loss: [Train: 1.93623], [Test: 2.90851],
#           Effect: [ate-q], [train: -0.00904], [test: -0.00695]
# ********************************************************************************
# epoch: 105 / 300, time cost: 42.82 sec,
#           Loss: [Train: 1.93355], [Test: 2.90279],
#           Effect: [ate-q], [train: 0.01495], [test: 0.01709]
# ********************************************************************************
# epoch: 106 / 300, time cost: 43.07 sec,
#           Loss: [Train: 1.93527], [Test: 2.90110],
#           Effect: [ate-q], [train: 0.06269], [test: 0.06479]
# ********************************************************************************
# epoch: 107 / 300, time cost: 42.86 sec,
#           Loss: [Train: 1.93253], [Test: 2.91663],
#           Effect: [ate-q], [train: 0.03930], [test: 0.04114]
# ********************************************************************************
# epoch: 108 / 300, time cost: 43.04 sec,
#           Loss: [Train: 1.93081], [Test: 2.90938],
#           Effect: [ate-q], [train: 0.07574], [test: 0.07794]
# ********************************************************************************
# epoch: 109 / 300, time cost: 42.97 sec,
#           Loss: [Train: 1.92677], [Test: 2.91794],
#           Effect: [ate-q], [train: 0.11185], [test: 0.11422]
# ********************************************************************************
# epoch: 110 / 300, time cost: 42.91 sec,
#           Loss: [Train: 1.92813], [Test: 2.91552],
#           Effect: [ate-q], [train: 0.10295], [test: 0.10541]
# ********************************************************************************
# epoch: 111 / 300, time cost: 42.18 sec,
#           Loss: [Train: 1.92590], [Test: 2.93420],
#           Effect: [ate-q], [train: 0.05668], [test: 0.05881]
# ********************************************************************************
# epoch: 112 / 300, time cost: 42.25 sec,
#           Loss: [Train: 1.92414], [Test: 2.97688],
#           Effect: [ate-q], [train: -0.08432], [test: -0.08238]
# ********************************************************************************
# epoch: 113 / 300, time cost: 42.73 sec,
#           Loss: [Train: 1.92192], [Test: 2.93748],
#           Effect: [ate-q], [train: 0.06862], [test: 0.07077]
# ********************************************************************************
# epoch: 114 / 300, time cost: 42.56 sec,
#           Loss: [Train: 1.92167], [Test: 2.94002],
#           Effect: [ate-q], [train: 0.08717], [test: 0.08932]
# ********************************************************************************
# epoch: 115 / 300, time cost: 42.40 sec,
#           Loss: [Train: 1.92000], [Test: 2.96277],
#           Effect: [ate-q], [train: 0.02668], [test: 0.02875]
# ********************************************************************************
# epoch: 116 / 300, time cost: 42.87 sec,
#           Loss: [Train: 1.91698], [Test: 2.97426],
#           Effect: [ate-q], [train: -0.01295], [test: -0.01083]
# ********************************************************************************
# epoch: 117 / 300, time cost: 42.31 sec,
#           Loss: [Train: 1.91627], [Test: 2.97011],
#           Effect: [ate-q], [train: 0.01190], [test: 0.01403]
# ********************************************************************************
# epoch: 118 / 300, time cost: 42.15 sec,
#           Loss: [Train: 1.91544], [Test: 2.96567],
#           Effect: [ate-q], [train: 0.10789], [test: 0.11001]
# ********************************************************************************
# epoch: 119 / 300, time cost: 42.54 sec,
#           Loss: [Train: 1.91401], [Test: 2.97031],
#           Effect: [ate-q], [train: 0.07266], [test: 0.07462]
# ********************************************************************************
# epoch: 120 / 300, time cost: 42.87 sec,
#           Loss: [Train: 1.91148], [Test: 2.96901],
#           Effect: [ate-q], [train: 0.10525], [test: 0.10739]
# ********************************************************************************
# epoch: 121 / 300, time cost: 42.88 sec,
#           Loss: [Train: 1.91163], [Test: 2.99173],
#           Effect: [ate-q], [train: 0.06190], [test: 0.06379]
# ********************************************************************************
# epoch: 122 / 300, time cost: 42.77 sec,
#           Loss: [Train: 1.91096], [Test: 3.03982],
#           Effect: [ate-q], [train: -0.07498], [test: -0.07319]
# ********************************************************************************
# epoch: 123 / 300, time cost: 43.20 sec,
#           Loss: [Train: 1.90708], [Test: 3.01750],
#           Effect: [ate-q], [train: 0.00617], [test: 0.00821]
# ********************************************************************************
# epoch: 124 / 300, time cost: 44.16 sec,
#           Loss: [Train: 1.90704], [Test: 2.99449],
#           Effect: [ate-q], [train: 0.13468], [test: 0.13688]
# ********************************************************************************
# epoch: 125 / 300, time cost: 49.25 sec,
#           Loss: [Train: 1.90462], [Test: 3.00555],
#           Effect: [ate-q], [train: 0.07935], [test: 0.08147]
# ********************************************************************************
# epoch: 126 / 300, time cost: 49.07 sec,
#           Loss: [Train: 1.90320], [Test: 3.01512],
#           Effect: [ate-q], [train: 0.03702], [test: 0.03910]
# ********************************************************************************
# epoch: 127 / 300, time cost: 49.54 sec,
#           Loss: [Train: 1.90323], [Test: 3.02659],
#           Effect: [ate-q], [train: 0.03559], [test: 0.03755]
# ********************************************************************************
# epoch: 128 / 300, time cost: 45.59 sec,
#           Loss: [Train: 1.90094], [Test: 3.01296],
#           Effect: [ate-q], [train: 0.11693], [test: 0.11922]
# ********************************************************************************
# epoch: 129 / 300, time cost: 42.73 sec,
#           Loss: [Train: 1.90143], [Test: 3.05127],
#           Effect: [ate-q], [train: -0.04417], [test: -0.04230]
# ********************************************************************************
# epoch: 130 / 300, time cost: 42.63 sec,
#           Loss: [Train: 1.89864], [Test: 3.03086],
#           Effect: [ate-q], [train: 0.06476], [test: 0.06706]
# ********************************************************************************
# epoch: 131 / 300, time cost: 42.49 sec,
#           Loss: [Train: 1.89749], [Test: 3.05179],
#           Effect: [ate-q], [train: -0.02058], [test: -0.01856]
# ********************************************************************************
# epoch: 132 / 300, time cost: 43.41 sec,
#           Loss: [Train: 1.89723], [Test: 3.05202],
#           Effect: [ate-q], [train: -0.00601], [test: -0.00417]
# ********************************************************************************
# epoch: 133 / 300, time cost: 42.88 sec,
#           Loss: [Train: 1.89501], [Test: 3.08374],
#           Effect: [ate-q], [train: -0.07278], [test: -0.07099]
# ********************************************************************************
# epoch: 134 / 300, time cost: 42.78 sec,
#           Loss: [Train: 1.89346], [Test: 3.07669],
#           Effect: [ate-q], [train: -0.04864], [test: -0.04664]
# ********************************************************************************
# epoch: 135 / 300, time cost: 42.56 sec,
#           Loss: [Train: 1.89118], [Test: 3.05299],
#           Effect: [ate-q], [train: 0.05219], [test: 0.05400]
# ********************************************************************************
# epoch: 136 / 300, time cost: 42.57 sec,
#           Loss: [Train: 1.89116], [Test: 3.06704],
#           Effect: [ate-q], [train: 0.03531], [test: 0.03711]
# ********************************************************************************
# epoch: 137 / 300, time cost: 42.74 sec,
#           Loss: [Train: 1.89067], [Test: 3.06141],
#           Effect: [ate-q], [train: 0.07905], [test: 0.08085]
# ********************************************************************************
# epoch: 138 / 300, time cost: 44.21 sec,
#           Loss: [Train: 1.88912], [Test: 3.07077],
#           Effect: [ate-q], [train: 0.10899], [test: 0.11087]
# ********************************************************************************
# epoch: 139 / 300, time cost: 45.70 sec,
#           Loss: [Train: 1.88749], [Test: 3.07240],
#           Effect: [ate-q], [train: 0.06022], [test: 0.06202]
# ********************************************************************************
# epoch: 140 / 300, time cost: 42.47 sec,
#           Loss: [Train: 1.88580], [Test: 3.07526],
#           Effect: [ate-q], [train: 0.11007], [test: 0.11187]
# ********************************************************************************
# epoch: 141 / 300, time cost: 43.14 sec,
#           Loss: [Train: 1.88399], [Test: 3.08352],
#           Effect: [ate-q], [train: 0.05493], [test: 0.05684]
# ********************************************************************************
# epoch: 142 / 300, time cost: 42.56 sec,
#           Loss: [Train: 1.88312], [Test: 3.11584],
#           Effect: [ate-q], [train: -0.03956], [test: -0.03780]
# ********************************************************************************
# epoch: 143 / 300, time cost: 42.79 sec,
#           Loss: [Train: 1.88197], [Test: 3.11130],
#           Effect: [ate-q], [train: -0.00642], [test: -0.00466]
# ********************************************************************************
# epoch: 144 / 300, time cost: 42.98 sec,
#           Loss: [Train: 1.88154], [Test: 3.10687],
#           Effect: [ate-q], [train: 0.06347], [test: 0.06526]
# ********************************************************************************
# epoch: 145 / 300, time cost: 42.58 sec,
#           Loss: [Train: 1.87981], [Test: 3.10898],
#           Effect: [ate-q], [train: -0.00188], [test: -0.00003]
# ********************************************************************************
# epoch: 146 / 300, time cost: 42.81 sec,
#           Loss: [Train: 1.87926], [Test: 3.11293],
#           Effect: [ate-q], [train: 0.01641], [test: 0.01825]
# ********************************************************************************
# epoch: 147 / 300, time cost: 42.79 sec,
#           Loss: [Train: 1.87924], [Test: 3.10373],
#           Effect: [ate-q], [train: 0.09919], [test: 0.10110]
# ********************************************************************************
# epoch: 148 / 300, time cost: 43.13 sec,
#           Loss: [Train: 1.87621], [Test: 3.12644],
#           Effect: [ate-q], [train: 0.06821], [test: 0.07006]
# ********************************************************************************
# epoch: 149 / 300, time cost: 40.88 sec,
#           Loss: [Train: 1.87497], [Test: 3.15248],
#           Effect: [ate-q], [train: -0.03197], [test: -0.02999]
# ********************************************************************************
# epoch: 150 / 300, time cost: 40.84 sec,
#           Loss: [Train: 1.87485], [Test: 3.13426],
#           Effect: [ate-q], [train: 0.04750], [test: 0.04935]
# ********************************************************************************
# epoch: 151 / 300, time cost: 41.10 sec,
#           Loss: [Train: 1.87319], [Test: 3.13712],
#           Effect: [ate-q], [train: 0.05424], [test: 0.05622]
# ********************************************************************************
# epoch: 152 / 300, time cost: 41.13 sec,
#           Loss: [Train: 1.87141], [Test: 3.13977],
#           Effect: [ate-q], [train: 0.06471], [test: 0.06667]
# ********************************************************************************
# epoch: 153 / 300, time cost: 40.93 sec,
#           Loss: [Train: 1.87136], [Test: 3.15098],
#           Effect: [ate-q], [train: 0.04622], [test: 0.04835]
# ********************************************************************************
# epoch: 154 / 300, time cost: 41.07 sec,
#           Loss: [Train: 1.87027], [Test: 3.15680],
#           Effect: [ate-q], [train: 0.03892], [test: 0.04103]
# ********************************************************************************
# epoch: 155 / 300, time cost: 40.66 sec,
#           Loss: [Train: 1.86878], [Test: 3.14886],
#           Effect: [ate-q], [train: 0.12939], [test: 0.13123]
# ********************************************************************************
# epoch: 156 / 300, time cost: 40.97 sec,
#           Loss: [Train: 1.86703], [Test: 3.17898],
#           Effect: [ate-q], [train: 0.00558], [test: 0.00736]
# ********************************************************************************
# epoch: 157 / 300, time cost: 41.06 sec,
#           Loss: [Train: 1.86738], [Test: 3.18370],
#           Effect: [ate-q], [train: 0.00072], [test: 0.00261]
# ********************************************************************************
# epoch: 158 / 300, time cost: 41.09 sec,
#           Loss: [Train: 1.86581], [Test: 3.18247],
#           Effect: [ate-q], [train: 0.07338], [test: 0.07499]
# ********************************************************************************
# epoch: 159 / 300, time cost: 41.07 sec,
#           Loss: [Train: 1.86398], [Test: 3.17278],
#           Effect: [ate-q], [train: 0.12413], [test: 0.12616]
# ********************************************************************************
# epoch: 160 / 300, time cost: 41.15 sec,
#           Loss: [Train: 1.86417], [Test: 3.19215],
#           Effect: [ate-q], [train: 0.00344], [test: 0.00538]
# ********************************************************************************
# epoch: 161 / 300, time cost: 41.35 sec,
#           Loss: [Train: 1.86120], [Test: 3.20399],
#           Effect: [ate-q], [train: -0.00011], [test: 0.00177]
# ********************************************************************************
# epoch: 162 / 300, time cost: 42.71 sec,
#           Loss: [Train: 1.86290], [Test: 3.21791],
#           Effect: [ate-q], [train: -0.00436], [test: -0.00264]
# ********************************************************************************
# epoch: 163 / 300, time cost: 42.52 sec,
#           Loss: [Train: 1.85923], [Test: 3.19345],
#           Effect: [ate-q], [train: 0.05813], [test: 0.05968]
# ********************************************************************************
# epoch: 164 / 300, time cost: 42.54 sec,
#           Loss: [Train: 1.85987], [Test: 3.21087],
#           Effect: [ate-q], [train: 0.00720], [test: 0.00910]
# ********************************************************************************
# epoch: 165 / 300, time cost: 42.37 sec,
#           Loss: [Train: 1.85784], [Test: 3.21196],
#           Effect: [ate-q], [train: 0.02343], [test: 0.02539]
# ********************************************************************************
# epoch: 166 / 300, time cost: 43.15 sec,
#           Loss: [Train: 1.85791], [Test: 3.21446],
#           Effect: [ate-q], [train: 0.04654], [test: 0.04843]
# ********************************************************************************
# epoch: 167 / 300, time cost: 42.63 sec,
#           Loss: [Train: 1.85684], [Test: 3.20325],
#           Effect: [ate-q], [train: 0.07815], [test: 0.07989]
# ********************************************************************************
# epoch: 168 / 300, time cost: 42.29 sec,
#           Loss: [Train: 1.85535], [Test: 3.21504],
#           Effect: [ate-q], [train: 0.07842], [test: 0.08057]
# ********************************************************************************
# epoch: 169 / 300, time cost: 41.64 sec,
#           Loss: [Train: 1.85330], [Test: 3.25716],
#           Effect: [ate-q], [train: -0.02725], [test: -0.02541]
# ********************************************************************************
# epoch: 170 / 300, time cost: 41.35 sec,
#           Loss: [Train: 1.85346], [Test: 3.23462],
#           Effect: [ate-q], [train: -0.00271], [test: -0.00064]
# ********************************************************************************
# epoch: 171 / 300, time cost: 42.46 sec,
#           Loss: [Train: 1.85217], [Test: 3.23659],
#           Effect: [ate-q], [train: 0.01178], [test: 0.01362]
# ********************************************************************************
# epoch: 172 / 300, time cost: 42.56 sec,
#           Loss: [Train: 1.85091], [Test: 3.23536],
#           Effect: [ate-q], [train: 0.04120], [test: 0.04320]
# ********************************************************************************
# epoch: 173 / 300, time cost: 42.87 sec,
#           Loss: [Train: 1.84977], [Test: 3.25374],
#           Effect: [ate-q], [train: -0.00105], [test: 0.00088]
# ********************************************************************************
# epoch: 174 / 300, time cost: 42.52 sec,
#           Loss: [Train: 1.84898], [Test: 3.24523],
#           Effect: [ate-q], [train: 0.03329], [test: 0.03535]
# ********************************************************************************
# epoch: 175 / 300, time cost: 42.01 sec,
#           Loss: [Train: 1.84862], [Test: 3.27693],
#           Effect: [ate-q], [train: -0.03787], [test: -0.03616]
# ********************************************************************************
# epoch: 176 / 300, time cost: 42.79 sec,
#           Loss: [Train: 1.84704], [Test: 3.26854],
#           Effect: [ate-q], [train: -0.01210], [test: -0.01018]
# ********************************************************************************
# epoch: 177 / 300, time cost: 42.30 sec,
#           Loss: [Train: 1.84555], [Test: 3.25096],
#           Effect: [ate-q], [train: 0.04038], [test: 0.04204]
# ********************************************************************************
# epoch: 178 / 300, time cost: 42.48 sec,
#           Loss: [Train: 1.84465], [Test: 3.25477],
#           Effect: [ate-q], [train: 0.04151], [test: 0.04322]
# ********************************************************************************
# epoch: 179 / 300, time cost: 42.86 sec,
#           Loss: [Train: 1.84349], [Test: 3.27197],
#           Effect: [ate-q], [train: 0.04600], [test: 0.04805]
# ********************************************************************************
# epoch: 180 / 300, time cost: 42.41 sec,
#           Loss: [Train: 1.84361], [Test: 3.26485],
#           Effect: [ate-q], [train: 0.07073], [test: 0.07253]
# ********************************************************************************
# epoch: 181 / 300, time cost: 42.18 sec,
#           Loss: [Train: 1.84144], [Test: 3.28091],
#           Effect: [ate-q], [train: 0.05738], [test: 0.05913]
# ********************************************************************************
# epoch: 182 / 300, time cost: 42.41 sec,
#           Loss: [Train: 1.84014], [Test: 3.28200],
#           Effect: [ate-q], [train: 0.09286], [test: 0.09472]
# ********************************************************************************
# epoch: 183 / 300, time cost: 42.94 sec,
#           Loss: [Train: 1.84070], [Test: 3.30538],
#           Effect: [ate-q], [train: 0.00514], [test: 0.00702]
# ********************************************************************************
# epoch: 184 / 300, time cost: 42.83 sec,
#           Loss: [Train: 1.83969], [Test: 3.29925],
#           Effect: [ate-q], [train: 0.03059], [test: 0.03241]
# ********************************************************************************
# epoch: 185 / 300, time cost: 46.65 sec,
#           Loss: [Train: 1.83766], [Test: 3.28579],
#           Effect: [ate-q], [train: 0.07702], [test: 0.07890]
# ********************************************************************************
# epoch: 186 / 300, time cost: 42.85 sec,
#           Loss: [Train: 1.83734], [Test: 3.29362],
#           Effect: [ate-q], [train: 0.04619], [test: 0.04830]
# ********************************************************************************
# epoch: 187 / 300, time cost: 42.74 sec,
#           Loss: [Train: 1.83584], [Test: 3.29420],
#           Effect: [ate-q], [train: 0.07795], [test: 0.07972]
# ********************************************************************************
# epoch: 188 / 300, time cost: 42.22 sec,
#           Loss: [Train: 1.83543], [Test: 3.34075],
#           Effect: [ate-q], [train: 0.03564], [test: 0.03721]
# ********************************************************************************
# epoch: 189 / 300, time cost: 42.33 sec,
#           Loss: [Train: 1.83483], [Test: 3.32252],
#           Effect: [ate-q], [train: 0.00753], [test: 0.00933]
# ********************************************************************************
# epoch: 190 / 300, time cost: 42.75 sec,
#           Loss: [Train: 1.83314], [Test: 3.30960],
#           Effect: [ate-q], [train: 0.05682], [test: 0.05855]
# ********************************************************************************
# epoch: 191 / 300, time cost: 42.75 sec,
#           Loss: [Train: 1.83246], [Test: 3.31522],
#           Effect: [ate-q], [train: 0.09492], [test: 0.09661]
# ********************************************************************************
# epoch: 192 / 300, time cost: 42.65 sec,
#           Loss: [Train: 1.83120], [Test: 3.31853],
#           Effect: [ate-q], [train: 0.05871], [test: 0.06077]
# ********************************************************************************
# epoch: 193 / 300, time cost: 43.03 sec,
#           Loss: [Train: 1.82980], [Test: 3.33521],
#           Effect: [ate-q], [train: 0.02322], [test: 0.02519]
# ********************************************************************************
# epoch: 194 / 300, time cost: 42.72 sec,
#           Loss: [Train: 1.82961], [Test: 3.32867],
#           Effect: [ate-q], [train: 0.12670], [test: 0.12834]
# ********************************************************************************
# epoch: 195 / 300, time cost: 42.43 sec,
#           Loss: [Train: 1.82735], [Test: 3.33544],
#           Effect: [ate-q], [train: 0.04808], [test: 0.04979]
# ********************************************************************************
# epoch: 196 / 300, time cost: 42.44 sec,
#           Loss: [Train: 1.82870], [Test: 3.33798],
#           Effect: [ate-q], [train: 0.05861], [test: 0.06031]
# ********************************************************************************
# epoch: 197 / 300, time cost: 42.70 sec,
#           Loss: [Train: 1.82557], [Test: 3.36200],
#           Effect: [ate-q], [train: 0.02104], [test: 0.02331]
# ********************************************************************************
# epoch: 198 / 300, time cost: 42.75 sec,
#           Loss: [Train: 1.82509], [Test: 3.36188],
#           Effect: [ate-q], [train: 0.04605], [test: 0.04772]
# ********************************************************************************
# epoch: 199 / 300, time cost: 42.53 sec,
#           Loss: [Train: 1.82569], [Test: 3.37253],
#           Effect: [ate-q], [train: 0.00910], [test: 0.01092]
# ********************************************************************************
# epoch: 200 / 300, time cost: 42.92 sec,
#           Loss: [Train: 1.82381], [Test: 3.35053],
#           Effect: [ate-q], [train: 0.10223], [test: 0.10394]
# ********************************************************************************
# epoch: 201 / 300, time cost: 42.70 sec,
#           Loss: [Train: 1.82331], [Test: 3.38546],
#           Effect: [ate-q], [train: -0.00907], [test: -0.00739]
# ********************************************************************************
# epoch: 202 / 300, time cost: 42.36 sec,
#           Loss: [Train: 1.82222], [Test: 3.37677],
#           Effect: [ate-q], [train: 0.03232], [test: 0.03420]
# ********************************************************************************
# epoch: 203 / 300, time cost: 42.40 sec,
#           Loss: [Train: 1.82121], [Test: 3.41831],
#           Effect: [ate-q], [train: -0.04139], [test: -0.03927]
# ********************************************************************************
# epoch: 204 / 300, time cost: 42.70 sec,
#           Loss: [Train: 1.81962], [Test: 3.36858],
#           Effect: [ate-q], [train: 0.10227], [test: 0.10404]
# ********************************************************************************
# epoch: 205 / 300, time cost: 42.53 sec,
#           Loss: [Train: 1.81874], [Test: 3.41674],
#           Effect: [ate-q], [train: -0.02836], [test: -0.02636]
# ********************************************************************************
# epoch: 206 / 300, time cost: 42.51 sec,
# ...
# epoch: 233 / 300, time cost: 42.68 sec,
#           Loss: [Train: 1.79816], [Test: 3.49934],
#           Effect: [ate-q], [train: 0.03955], [test: 0.04134]
# ********************************************************************************
# epoch: 234 / 300, time cost: 42.95 sec,
#           Loss: [Train: 1.79749], [Test: 3.49874],
#           Effect: [ate-q], [train: 0.04882], [test: 0.05044]
# ********************************************************************************
# epoch: 235 / 300, time cost: 42.81 sec,
#           Loss: [Train: 1.79677], [Test: 3.50284],
#           Effect: [ate-q], [train: 0.03595], [test: 0.03751]
# ********************************************************************************
# epoch: 236 / 300, time cost: 43.13 sec,
#           Loss: [Train: 1.79621], [Test: 3.51896],
#           Effect: [ate-q], [train: 0.02538], [test: 0.02716]
# ********************************************************************************
# epoch: 237 / 300, time cost: 42.44 sec,
#           Loss: [Train: 1.79528], [Test: 3.51643],
#           Effect: [ate-q], [train: 0.01661], [test: 0.01843]
# ********************************************************************************
# epoch: 238 / 300, time cost: 42.42 sec,
#           Loss: [Train: 1.79459], [Test: 3.50785],
#           Effect: [ate-q], [train: 0.03786], [test: 0.03965]
# ********************************************************************************
# epoch: 239 / 300, time cost: 42.80 sec,
#           Loss: [Train: 1.79485], [Test: 3.51259],
#           Effect: [ate-q], [train: 0.07277], [test: 0.07433]
# ********************************************************************************
# epoch: 240 / 300, time cost: 41.71 sec,
#           Loss: [Train: 1.79365], [Test: 3.53217],
#           Effect: [ate-q], [train: 0.04682], [test: 0.04876]
# ********************************************************************************
# epoch: 241 / 300, time cost: 42.30 sec,
#           Loss: [Train: 1.79182], [Test: 3.55752],
#           Effect: [ate-q], [train: -0.02836], [test: -0.02636]
# ********************************************************************************
# epoch: 242 / 300, time cost: 42.74 sec,
#           Loss: [Train: 1.79221], [Test: 3.52399],
#           Effect: [ate-q], [train: 0.11169], [test: 0.11357]
# ********************************************************************************
# epoch: 243 / 300, time cost: 42.38 sec,
#           Loss: [Train: 1.79173], [Test: 3.52216],
#           Effect: [ate-q], [train: 0.04333], [test: 0.04506]
# ********************************************************************************
# epoch: 244 / 300, time cost: 41.80 sec,
#           Loss: [Train: 1.79124], [Test: 3.53676],
#           Effect: [ate-q], [train: 0.01838], [test: 0.02017]
# ********************************************************************************
# epoch: 245 / 300, time cost: 42.34 sec,
#           Loss: [Train: 1.79034], [Test: 3.55939],
#           Effect: [ate-q], [train: 0.01550], [test: 0.01710]
# ********************************************************************************
# epoch: 246 / 300, time cost: 42.18 sec,
#           Loss: [Train: 1.78958], [Test: 3.53899],
#           Effect: [ate-q], [train: 0.04650], [test: 0.04812]
# ********************************************************************************
# epoch: 247 / 300, time cost: 42.51 sec,
#           Loss: [Train: 1.78905], [Test: 3.59749],
#           Effect: [ate-q], [train: -0.04357], [test: -0.04155]
# ********************************************************************************
# epoch: 248 / 300, time cost: 42.39 sec,
#           Loss: [Train: 1.78817], [Test: 3.57118],
#           Effect: [ate-q], [train: -0.00509], [test: -0.00315]
# ********************************************************************************
# epoch: 249 / 300, time cost: 42.31 sec,
#           Loss: [Train: 1.78767], [Test: 3.58342],
#           Effect: [ate-q], [train: -0.01167], [test: -0.01003]
# ********************************************************************************
# epoch: 250 / 300, time cost: 42.60 sec,
#           Loss: [Train: 1.78686], [Test: 3.56053],
#           Effect: [ate-q], [train: 0.02599], [test: 0.02772]
# ********************************************************************************
# epoch: 251 / 300, time cost: 42.54 sec,
#           Loss: [Train: 1.78647], [Test: 3.55674],
#           Effect: [ate-q], [train: 0.04399], [test: 0.04553]
# ********************************************************************************
# epoch: 252 / 300, time cost: 42.57 sec,
#           Loss: [Train: 1.78693], [Test: 3.58048],
#           Effect: [ate-q], [train: 0.03581], [test: 0.03734]
# ********************************************************************************
# epoch: 253 / 300, time cost: 42.88 sec,
#           Loss: [Train: 1.78492], [Test: 3.57485],
#           Effect: [ate-q], [train: 0.01877], [test: 0.02072]
# ********************************************************************************
# epoch: 254 / 300, time cost: 42.85 sec,
#           Loss: [Train: 1.78510], [Test: 3.58990],
#           Effect: [ate-q], [train: -0.00441], [test: -0.00275]
# ********************************************************************************
# epoch: 255 / 300, time cost: 43.20 sec,
#           Loss: [Train: 1.78473], [Test: 3.59563],
#           Effect: [ate-q], [train: -0.02786], [test: -0.02619]
# ********************************************************************************
# epoch: 256 / 300, time cost: 43.13 sec,
#           Loss: [Train: 1.78386], [Test: 3.58162],
#           Effect: [ate-q], [train: 0.01831], [test: 0.02004]
# ********************************************************************************
# epoch: 257 / 300, time cost: 42.28 sec,
#           Loss: [Train: 1.78291], [Test: 3.56759],
#           Effect: [ate-q], [train: 0.07271], [test: 0.07446]
# ********************************************************************************
# epoch: 258 / 300, time cost: 42.52 sec,
#           Loss: [Train: 1.78242], [Test: 3.58458],
#           Effect: [ate-q], [train: 0.05693], [test: 0.05860]
# ********************************************************************************
# epoch: 259 / 300, time cost: 42.62 sec,
#           Loss: [Train: 1.78251], [Test: 3.59546],
#           Effect: [ate-q], [train: -0.00614], [test: -0.00451]
# ********************************************************************************
# epoch: 260 / 300, time cost: 42.43 sec,
#           Loss: [Train: 1.78136], [Test: 3.57281],
#           Effect: [ate-q], [train: 0.07022], [test: 0.07194]
# ********************************************************************************
# epoch: 261 / 300, time cost: 42.41 sec,
#           Loss: [Train: 1.78160], [Test: 3.59617],
#           Effect: [ate-q], [train: 0.02276], [test: 0.02460]
# ********************************************************************************
# epoch: 262 / 300, time cost: 43.13 sec,
#           Loss: [Train: 1.78136], [Test: 3.58616],
#           Effect: [ate-q], [train: 0.07021], [test: 0.07181]
# ********************************************************************************
# epoch: 263 / 300, time cost: 42.45 sec,
#           Loss: [Train: 1.78072], [Test: 3.60018],
#           Effect: [ate-q], [train: 0.04464], [test: 0.04623]
# ********************************************************************************
# epoch: 264 / 300, time cost: 41.54 sec,
#           Loss: [Train: 1.77898], [Test: 3.60186],
#           Effect: [ate-q], [train: 0.02173], [test: 0.02353]
# ********************************************************************************
# epoch: 265 / 300, time cost: 42.07 sec,
#           Loss: [Train: 1.77876], [Test: 3.61431],
#           Effect: [ate-q], [train: 0.00396], [test: 0.00576]
# ********************************************************************************
# epoch: 266 / 300, time cost: 42.20 sec,
#           Loss: [Train: 1.77847], [Test: 3.60871],
#           Effect: [ate-q], [train: 0.02438], [test: 0.02607]
# ********************************************************************************
# epoch: 267 / 300, time cost: 42.38 sec,
#           Loss: [Train: 1.77886], [Test: 3.59794],
#           Effect: [ate-q], [train: 0.05977], [test: 0.06147]
# ********************************************************************************
# epoch: 268 / 300, time cost: 42.12 sec,
#           Loss: [Train: 1.77783], [Test: 3.61783],
#           Effect: [ate-q], [train: 0.02312], [test: 0.02498]
# ********************************************************************************
# epoch: 269 / 300, time cost: 42.61 sec,
#           Loss: [Train: 1.77752], [Test: 3.60700],
#           Effect: [ate-q], [train: 0.03712], [test: 0.03871]
# ********************************************************************************
# epoch: 270 / 300, time cost: 42.24 sec,
#           Loss: [Train: 1.77661], [Test: 3.61317],
#           Effect: [ate-q], [train: 0.03912], [test: 0.04099]
# ********************************************************************************
# epoch: 271 / 300, time cost: 42.54 sec,
#           Loss: [Train: 1.77676], [Test: 3.60746],
#           Effect: [ate-q], [train: 0.05198], [test: 0.05379]
# ********************************************************************************
# epoch: 272 / 300, time cost: 42.58 sec,
#           Loss: [Train: 1.77618], [Test: 3.61039],
#           Effect: [ate-q], [train: 0.04787], [test: 0.04955]
# ********************************************************************************
# epoch: 273 / 300, time cost: 42.00 sec,
#           Loss: [Train: 1.77575], [Test: 3.61012],
#           Effect: [ate-q], [train: 0.03209], [test: 0.03385]
# ********************************************************************************
# epoch: 274 / 300, time cost: 42.61 sec,
#           Loss: [Train: 1.77516], [Test: 3.61478],
#           Effect: [ate-q], [train: 0.06328], [test: 0.06505]
# ********************************************************************************
# epoch: 275 / 300, time cost: 42.77 sec,
#           Loss: [Train: 1.77456], [Test: 3.63465],
#           Effect: [ate-q], [train: 0.00099], [test: 0.00278]
# ********************************************************************************
# epoch: 276 / 300, time cost: 42.11 sec,
#           Loss: [Train: 1.77478], [Test: 3.61108],
#           Effect: [ate-q], [train: 0.06346], [test: 0.06509]
# ********************************************************************************
# epoch: 277 / 300, time cost: 42.44 sec,
#           Loss: [Train: 1.77396], [Test: 3.65038],
#           Effect: [ate-q], [train: -0.02869], [test: -0.02664]
# ********************************************************************************
# epoch: 278 / 300, time cost: 42.45 sec,
#           Loss: [Train: 1.77385], [Test: 3.63141],
#           Effect: [ate-q], [train: 0.03572], [test: 0.03747]
# ********************************************************************************
# epoch: 279 / 300, time cost: 42.42 sec,
#           Loss: [Train: 1.77335], [Test: 3.63148],
#           Effect: [ate-q], [train: 0.02359], [test: 0.02559]
# ********************************************************************************
# epoch: 280 / 300, time cost: 42.31 sec,
#           Loss: [Train: 1.77277], [Test: 3.63241],
#           Effect: [ate-q], [train: 0.04439], [test: 0.04630]
# ********************************************************************************
# epoch: 281 / 300, time cost: 42.56 sec,
#           Loss: [Train: 1.77234], [Test: 3.63422],
#           Effect: [ate-q], [train: 0.03089], [test: 0.03267]
# ********************************************************************************
# epoch: 282 / 300, time cost: 42.54 sec,
#           Loss: [Train: 1.77161], [Test: 3.63641],
#           Effect: [ate-q], [train: 0.03270], [test: 0.03432]
# ********************************************************************************
# epoch: 283 / 300, time cost: 42.00 sec,
#           Loss: [Train: 1.77101], [Test: 3.63090],
#           Effect: [ate-q], [train: 0.03110], [test: 0.03264]
# ********************************************************************************
# epoch: 284 / 300, time cost: 42.54 sec,
#           Loss: [Train: 1.77136], [Test: 3.63729],
#           Effect: [ate-q], [train: 0.04015], [test: 0.04184]
# ********************************************************************************
# epoch: 285 / 300, time cost: 42.26 sec,
#           Loss: [Train: 1.77105], [Test: 3.64287],
#           Effect: [ate-q], [train: 0.03454], [test: 0.03610]
# ********************************************************************************
# epoch: 286 / 300, time cost: 42.18 sec,
#           Loss: [Train: 1.77039], [Test: 3.64784],
#           Effect: [ate-q], [train: 0.01486], [test: 0.01661]
# ********************************************************************************
# epoch: 287 / 300, time cost: 42.43 sec,
#           Loss: [Train: 1.77043], [Test: 3.63560],
#           Effect: [ate-q], [train: 0.05856], [test: 0.06025]
# ********************************************************************************
# epoch: 288 / 300, time cost: 42.60 sec,
#           Loss: [Train: 1.76999], [Test: 3.63987],
#           Effect: [ate-q], [train: 0.03389], [test: 0.03567]
# ********************************************************************************
# epoch: 289 / 300, time cost: 42.44 sec,
#           Loss: [Train: 1.76943], [Test: 3.64518],
#           Effect: [ate-q], [train: 0.01943], [test: 0.02125]
# ********************************************************************************
# epoch: 290 / 300, time cost: 49.51 sec,
#           Loss: [Train: 1.76936], [Test: 3.65122],
#           Effect: [ate-q], [train: 0.01933], [test: 0.02111]
# ********************************************************************************
# epoch: 291 / 300, time cost: 49.48 sec,
#           Loss: [Train: 1.76914], [Test: 3.64460],
#           Effect: [ate-q], [train: 0.04013], [test: 0.04186]
# ********************************************************************************
# epoch: 292 / 300, time cost: 49.47 sec,
#           Loss: [Train: 1.76819], [Test: 3.65431],
#           Effect: [ate-q], [train: 0.01890], [test: 0.02072]
# ********************************************************************************
# epoch: 293 / 300, time cost: 48.88 sec,
#           Loss: [Train: 1.76786], [Test: 3.65120],
#           Effect: [ate-q], [train: 0.01947], [test: 0.02137]
# ********************************************************************************
# epoch: 294 / 300, time cost: 42.57 sec,
#           Loss: [Train: 1.76848], [Test: 3.64992],
#           Effect: [ate-q], [train: 0.02345], [test: 0.02521]
# ********************************************************************************
# epoch: 295 / 300, time cost: 42.98 sec,
#           Loss: [Train: 1.76769], [Test: 3.64393],
#           Effect: [ate-q], [train: 0.04251], [test: 0.04424]
# ********************************************************************************
# epoch: 296 / 300, time cost: 42.66 sec,
#           Loss: [Train: 1.76773], [Test: 3.64721],
#           Effect: [ate-q], [train: 0.03401], [test: 0.03592]
# ********************************************************************************
# epoch: 297 / 300, time cost: 42.89 sec,
#           Loss: [Train: 1.76720], [Test: 3.65023],
#           Effect: [ate-q], [train: 0.03346], [test: 0.03519]
# ********************************************************************************
# epoch: 298 / 300, time cost: 42.81 sec,
#           Loss: [Train: 1.76731], [Test: 3.65103],
#           Effect: [ate-q], [train: 0.02587], [test: 0.02768]
# ********************************************************************************
# epoch: 299 / 300, time cost: 42.71 sec,
#           Loss: [Train: 1.76611], [Test: 3.65257],
#           Effect: [ate-q], [train: 0.02282], [test: 0.02464]
# ********************************************************************************
# epoch: 300 / 300, time cost: 42.23 sec,
#           Loss: [Train: 1.76701], [Test: 3.65030],
#           Effect: [ate-q], [train: 0.03024], [test: 0.03205]
# ********************************************************************************
# Finish training...

# %%
real = true_casual_effect(test_loader)
unadjust = (testset.response[testset.treatment == 1].mean() - testset.response[testset.treatment == 0].mean()).item()
show_result(train_loss_hist, test_loss_hist, est_effect, real, unadjust, epoch)

# %% [markdown]
# # High

# %%
vocab = create_vocab(merged=True, uni_diag=True)
tokenizer = WordLevelBertTokenizer(vocab)

alpha = 0.75
beta = 25.
c = 0.2
i = 0.

# %%
start = time.time()
trainset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                             alpha=alpha, beta=beta, c=c, i=i, 
                             group=list(range(1)), max_length=512, min_length=10,
                             truncate_method='first', device=device, seed=1)

print(f'Load training set in {(time.time() - start):.2f} sec')

start = time.time()
testset = CausalBertDataset(tokenizer=tokenizer, data_type='merged', is_unidiag=True,
                            alpha=alpha, beta=beta, c=c, i=i, 
                            group=[9], max_length=512, min_length=10,
                            truncate_method='first', device=device)

print(f'Load validation set in {(time.time() - start):.2f} sec')
# Out:
# Load training set in 68.82 sec
# Load validation set in 71.46 sec

# %%
train_loader = DataLoader(trainset, batch_size=bsz, drop_last=True, shuffle=True)
test_loader = DataLoader(testset, batch_size=2048, drop_last=True, shuffle=True)

# %%
real_att_q = true_casual_effect(test_loader)

print(f'Real: [effect: ate], [estimation: q], [value: {real_att_q:.5f}]')
print(f'Unadjusted: [value: {(testset.response[testset.treatment == 1].mean() - testset.response[testset.treatment == 0].mean()).item():.4f}]')
# Out:
# Real: [effect: ate], [estimation: q], [value: 0.16917]
# Unadjusted: [value: 0.2379]

# %%
trained_bert = '/nfs/turbo/lsa-regier/bert-results/results/behrt/MLM/merged/unidiag/checkpoint-6018425/'
# trained_bert = '/home/liutianc/emr/bert/results/behrt/MLM/merged/unidiag/checkpoint-6018425/'

model = BertForMaskedLM.from_pretrained(trained_bert)
token_embed = model.get_input_embeddings()
model = CausalBOW(token_embed, learnable_docu_embed=False, hidden_size=hidden_size, prop_is_logit=True).to(device)

pos_portion = trainset.treatment.mean()
pos_weight = (1 - pos_portion) / pos_portion

# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
epoch_iter = len(train_loader)
total_steps = epoch * epoch_iter

optimizer = AdamW(model.parameters(), lr=1e-4, eps=1e-8)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

q_loss = nn.BCELoss()
# prop_score_loss = nn.BCELoss()
prop_score_loss = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# Please specify the effect and estimation we want to use here.
effect = 'ate'
estimation = 'q'

effect = effect.lower()
estimation = estimation.lower()
assert effect in ['att', 'ate'], f'Wrong effect: {effect}...'
assert estimation in ['q', 'plugin'], f'Wrong estimation: {estimation}...'

# %%
rs_loss, rq1_loss, rq0_loss = [0.] * 3

train_loss_hist, test_loss_hist, est_effect = [], [], []
for e in range(1, epoch + 1):
    model.train()
    start = time.time()
    run_loss = 0.
    for idx, (tokens, treatment, response) in enumerate(train_loader):
        optimizer.zero_grad()
        prop_score, q1, q0 = model(tokens)
        
        loss = prop_score_loss(prop_score, treatment)
        if len(response[treatment == 1]) > 0:
            loss += q_loss(q1[treatment==1], response[treatment==1])# * pos_weight
            
        if len(response[treatment == 0]) > 0:
            loss += q_loss(q0[treatment==0], response[treatment==0])
            
        loss.backward()
        
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)    
        optimizer.step()
        scheduler.step()

        run_loss += loss.item()
        
    run_idx = idx

    # Evaluation.
    train_loss = run_loss / (run_idx + 1)
    train_effect, _, _, _ = est_casual_effect(train_loader, model, effect, estimation, eval_loss=False)
    test_effect, g_loss_test, q1_loss_test, q0_loss_test = est_casual_effect(test_loader, model, effect, estimation, g_loss=prop_score_loss, q_loss=q_loss)
    test_loss = q1_loss_test + q0_loss_test
    test_loss += g_loss_test
    
    train_loss_hist.append(train_loss)
    test_loss_hist.append(test_loss)
    est_effect.append(test_effect)
    print(f'''epoch: {e} / {epoch}, time cost: {(time.time() - start):.2f} sec, 
          Loss: [Train: {train_loss:.5f}], [Test: {test_loss:.5f}],
          Effect: [{effect}-{estimation}], [train: {train_effect:.5f}], [test: {test_effect:.5f}]''')
    print('*'* 80)
    start = time.time()
    run_loss = 0.

print('Finish training...')

# With only 1 group(s) to train.
# Out:
# epoch: 1 / 300, time cost: 37.48 sec,
#           Loss: [Train: 2.32169], [Test: 2.31949],
#           Effect: [ate-q], [train: 0.24169], [test: 0.24167]
# ********************************************************************************
# epoch: 2 / 300, time cost: 42.45 sec,
#           Loss: [Train: 2.30684], [Test: 2.31418],
#           Effect: [ate-q], [train: 0.22984], [test: 0.22982]
# ********************************************************************************
# epoch: 3 / 300, time cost: 41.08 sec,
#           Loss: [Train: 2.29935], [Test: 2.30624],
#           Effect: [ate-q], [train: 0.23875], [test: 0.23875]
# ********************************************************************************
# epoch: 4 / 300, time cost: 41.33 sec,
#           Loss: [Train: 2.28864], [Test: 2.29528],
#           Effect: [ate-q], [train: 0.22760], [test: 0.22766]
# ********************************************************************************
# epoch: 5 / 300, time cost: 41.32 sec,
#           Loss: [Train: 2.27582], [Test: 2.28671],
#           Effect: [ate-q], [train: 0.23112], [test: 0.23123]
# ********************************************************************************
# epoch: 6 / 300, time cost: 41.83 sec,
#           Loss: [Train: 2.26677], [Test: 2.28170],
#           Effect: [ate-q], [train: 0.21561], [test: 0.21576]
# ********************************************************************************
# epoch: 7 / 300, time cost: 41.50 sec,
#           Loss: [Train: 2.25954], [Test: 2.27790],
#           Effect: [ate-q], [train: 0.20664], [test: 0.20680]
# ********************************************************************************
# epoch: 8 / 300, time cost: 41.14 sec,
#           Loss: [Train: 2.25253], [Test: 2.27461],
#           Effect: [ate-q], [train: 0.22377], [test: 0.22398]
# ********************************************************************************
# epoch: 9 / 300, time cost: 41.02 sec,
#           Loss: [Train: 2.24712], [Test: 2.27226],
#           Effect: [ate-q], [train: 0.21379], [test: 0.21405]
# ********************************************************************************
# epoch: 10 / 300, time cost: 41.71 sec,
#           Loss: [Train: 2.24121], [Test: 2.27120],
#           Effect: [ate-q], [train: 0.18291], [test: 0.18326]
# ********************************************************************************
# epoch: 11 / 300, time cost: 43.38 sec,
#           Loss: [Train: 2.23524], [Test: 2.26838],
#           Effect: [ate-q], [train: 0.19916], [test: 0.19953]
# ********************************************************************************
# epoch: 12 / 300, time cost: 41.55 sec,
#           Loss: [Train: 2.22908], [Test: 2.26669],
#           Effect: [ate-q], [train: 0.19835], [test: 0.19882]
# ********************************************************************************
# epoch: 13 / 300, time cost: 41.73 sec,
#           Loss: [Train: 2.22340], [Test: 2.26783],
#           Effect: [ate-q], [train: 0.22121], [test: 0.22178]
# ********************************************************************************
# epoch: 14 / 300, time cost: 39.67 sec,
#           Loss: [Train: 2.21763], [Test: 2.26966],
#           Effect: [ate-q], [train: 0.21652], [test: 0.21717]
# ********************************************************************************
# epoch: 15 / 300, time cost: 41.20 sec,
#           Loss: [Train: 2.21120], [Test: 2.26613],
#           Effect: [ate-q], [train: 0.20530], [test: 0.20610]
# ********************************************************************************
# epoch: 16 / 300, time cost: 40.80 sec,
#           Loss: [Train: 2.20469], [Test: 2.26765],
#           Effect: [ate-q], [train: 0.21028], [test: 0.21114]
# ********************************************************************************
# epoch: 17 / 300, time cost: 40.86 sec,
#           Loss: [Train: 2.19712], [Test: 2.26896],
#           Effect: [ate-q], [train: 0.20084], [test: 0.20185]
# ********************************************************************************
# epoch: 18 / 300, time cost: 40.94 sec,
#           Loss: [Train: 2.18990], [Test: 2.26924],
#           Effect: [ate-q], [train: 0.17426], [test: 0.17535]
# ********************************************************************************
# epoch: 19 / 300, time cost: 39.68 sec,
#           Loss: [Train: 2.18314], [Test: 2.27070],
#           Effect: [ate-q], [train: 0.18858], [test: 0.18979]
# ********************************************************************************
# epoch: 20 / 300, time cost: 39.90 sec,
#           Loss: [Train: 2.17549], [Test: 2.27437],
#           Effect: [ate-q], [train: 0.16020], [test: 0.16160]
# ********************************************************************************
# epoch: 21 / 300, time cost: 39.95 sec,
#           Loss: [Train: 2.16782], [Test: 2.27588],
#           Effect: [ate-q], [train: 0.17439], [test: 0.17595]
# ********************************************************************************
# epoch: 22 / 300, time cost: 39.95 sec,
#           Loss: [Train: 2.16037], [Test: 2.28106],
#           Effect: [ate-q], [train: 0.14959], [test: 0.15124]
# ********************************************************************************
# epoch: 23 / 300, time cost: 39.80 sec,
#           Loss: [Train: 2.15324], [Test: 2.28257],
#           Effect: [ate-q], [train: 0.15718], [test: 0.15902]
# ********************************************************************************
# epoch: 24 / 300, time cost: 39.70 sec,
#           Loss: [Train: 2.14450], [Test: 2.28588],
#           Effect: [ate-q], [train: 0.15310], [test: 0.15505]
# ********************************************************************************
# epoch: 25 / 300, time cost: 39.72 sec,
#           Loss: [Train: 2.13691], [Test: 2.28948],
#           Effect: [ate-q], [train: 0.18678], [test: 0.18897]
# ********************************************************************************
# epoch: 26 / 300, time cost: 40.87 sec,
#           Loss: [Train: 2.12943], [Test: 2.29552],
#           Effect: [ate-q], [train: 0.21183], [test: 0.21426]
# ********************************************************************************
# epoch: 27 / 300, time cost: 39.75 sec,
#           Loss: [Train: 2.12089], [Test: 2.29929],
#           Effect: [ate-q], [train: 0.17017], [test: 0.17257]
# ********************************************************************************
# epoch: 28 / 300, time cost: 40.63 sec,
#           Loss: [Train: 2.11285], [Test: 2.30634],
#           Effect: [ate-q], [train: 0.18401], [test: 0.18674]
# ********************************************************************************
# epoch: 29 / 300, time cost: 47.56 sec,
#           Loss: [Train: 2.10526], [Test: 2.31150],
#           Effect: [ate-q], [train: 0.14232], [test: 0.14499]
# ********************************************************************************
# epoch: 30 / 300, time cost: 47.42 sec,
#           Loss: [Train: 2.09709], [Test: 2.31989],
#           Effect: [ate-q], [train: 0.20988], [test: 0.21272]
# ********************************************************************************
# epoch: 31 / 300, time cost: 45.19 sec,
#           Loss: [Train: 2.08944], [Test: 2.32595],
#           Effect: [ate-q], [train: 0.12806], [test: 0.13086]
# ********************************************************************************
# epoch: 32 / 300, time cost: 39.93 sec,
#           Loss: [Train: 2.08204], [Test: 2.33230],
#           Effect: [ate-q], [train: 0.18982], [test: 0.19288]
# ********************************************************************************
# epoch: 33 / 300, time cost: 39.72 sec,
#           Loss: [Train: 2.07538], [Test: 2.33933],
#           Effect: [ate-q], [train: 0.19770], [test: 0.20075]
# ********************************************************************************
# epoch: 34 / 300, time cost: 39.80 sec,
#           Loss: [Train: 2.06871], [Test: 2.35067],
#           Effect: [ate-q], [train: 0.17278], [test: 0.17581]
# ********************************************************************************
# epoch: 35 / 300, time cost: 39.79 sec,
#           Loss: [Train: 2.06164], [Test: 2.35139],
#           Effect: [ate-q], [train: 0.15717], [test: 0.16043]
# ********************************************************************************
# epoch: 36 / 300, time cost: 39.60 sec,
#           Loss: [Train: 2.05537], [Test: 2.38269],
#           Effect: [ate-q], [train: 0.20286], [test: 0.20597]
# ********************************************************************************
# epoch: 37 / 300, time cost: 41.36 sec,
#           Loss: [Train: 2.04934], [Test: 2.36747],
#           Effect: [ate-q], [train: 0.16528], [test: 0.16836]
# ********************************************************************************
# epoch: 38 / 300, time cost: 41.37 sec,
#           Loss: [Train: 2.04239], [Test: 2.37396],
#           Effect: [ate-q], [train: 0.14588], [test: 0.14902]
# ********************************************************************************
# epoch: 39 / 300, time cost: 41.13 sec,
#           Loss: [Train: 2.03757], [Test: 2.40313],
#           Effect: [ate-q], [train: 0.20289], [test: 0.20581]
# ********************************************************************************
# epoch: 40 / 300, time cost: 41.18 sec,
#           Loss: [Train: 2.03111], [Test: 2.39654],
#           Effect: [ate-q], [train: 0.14479], [test: 0.14769]
# ********************************************************************************
# epoch: 41 / 300, time cost: 40.92 sec,
#           Loss: [Train: 2.02540], [Test: 2.40106],
#           Effect: [ate-q], [train: 0.12779], [test: 0.13086]
# ********************************************************************************
# epoch: 42 / 300, time cost: 40.67 sec,
#           Loss: [Train: 2.01970], [Test: 2.41135],
#           Effect: [ate-q], [train: 0.15107], [test: 0.15406]
# ********************************************************************************
# epoch: 43 / 300, time cost: 40.79 sec,
#           Loss: [Train: 2.01485], [Test: 2.42149],
#           Effect: [ate-q], [train: 0.10393], [test: 0.10696]
# ********************************************************************************
# epoch: 44 / 300, time cost: 40.65 sec,
#           Loss: [Train: 2.00964], [Test: 2.43110],
#           Effect: [ate-q], [train: 0.15874], [test: 0.16161]
# ********************************************************************************
# epoch: 45 / 300, time cost: 41.39 sec,
#           Loss: [Train: 2.00436], [Test: 2.44226],
#           Effect: [ate-q], [train: 0.18355], [test: 0.18665]
# ********************************************************************************
# epoch: 46 / 300, time cost: 42.65 sec,
#           Loss: [Train: 2.00067], [Test: 2.45273],
#           Effect: [ate-q], [train: 0.17972], [test: 0.18294]
# ********************************************************************************
# epoch: 47 / 300, time cost: 47.21 sec,
#           Loss: [Train: 1.99555], [Test: 2.45512],
#           Effect: [ate-q], [train: 0.12567], [test: 0.12892]
# ********************************************************************************
# epoch: 48 / 300, time cost: 44.73 sec,
#           Loss: [Train: 1.99002], [Test: 2.46249],
#           Effect: [ate-q], [train: 0.15854], [test: 0.16174]
# ********************************************************************************
# epoch: 49 / 300, time cost: 41.19 sec,
#           Loss: [Train: 1.98645], [Test: 2.47766],
#           Effect: [ate-q], [train: 0.16226], [test: 0.16546]
# ********************************************************************************
# epoch: 50 / 300, time cost: 41.20 sec,
#           Loss: [Train: 1.98238], [Test: 2.48920],
#           Effect: [ate-q], [train: 0.20649], [test: 0.20971]
# ********************************************************************************
# epoch: 51 / 300, time cost: 41.14 sec,
#           Loss: [Train: 1.97835], [Test: 2.49170],
#           Effect: [ate-q], [train: 0.18351], [test: 0.18698]
# ********************************************************************************
# epoch: 52 / 300, time cost: 41.15 sec,
#           Loss: [Train: 1.97463], [Test: 2.50165],
#           Effect: [ate-q], [train: 0.15901], [test: 0.16211]
# ********************************************************************************
# epoch: 53 / 300, time cost: 41.51 sec,
#           Loss: [Train: 1.97052], [Test: 2.50716],
#           Effect: [ate-q], [train: 0.15044], [test: 0.15372]
# ********************************************************************************
# epoch: 54 / 300, time cost: 39.69 sec,
#           Loss: [Train: 1.96703], [Test: 2.51255],
#           Effect: [ate-q], [train: 0.12118], [test: 0.12448]
# ********************************************************************************
# epoch: 55 / 300, time cost: 39.63 sec,
#           Loss: [Train: 1.96331], [Test: 2.53948],
#           Effect: [ate-q], [train: 0.21647], [test: 0.21988]
# ********************************************************************************
# epoch: 56 / 300, time cost: 39.59 sec,
#           Loss: [Train: 1.96024], [Test: 2.54214],
#           Effect: [ate-q], [train: 0.20752], [test: 0.21079]
# ********************************************************************************
# epoch: 57 / 300, time cost: 39.48 sec,
#           Loss: [Train: 1.95729], [Test: 2.55097],
#           Effect: [ate-q], [train: 0.18765], [test: 0.19093]
# ********************************************************************************
# epoch: 58 / 300, time cost: 39.50 sec,
#           Loss: [Train: 1.95296], [Test: 2.57236],
#           Effect: [ate-q], [train: 0.18901], [test: 0.19214]
# ********************************************************************************
# epoch: 59 / 300, time cost: 39.44 sec,
#           Loss: [Train: 1.95029], [Test: 2.57674],
#           Effect: [ate-q], [train: 0.15977], [test: 0.16302]
# ********************************************************************************
# epoch: 60 / 300, time cost: 39.40 sec,
#           Loss: [Train: 1.94762], [Test: 2.58818],
#           Effect: [ate-q], [train: 0.17184], [test: 0.17498]
# ********************************************************************************
# epoch: 61 / 300, time cost: 39.91 sec,
#           Loss: [Train: 1.94435], [Test: 2.60514],
#           Effect: [ate-q], [train: 0.04311], [test: 0.04591]
# ********************************************************************************
# epoch: 62 / 300, time cost: 39.98 sec,
#           Loss: [Train: 1.94090], [Test: 2.61138],
#           Effect: [ate-q], [train: 0.15374], [test: 0.15667]
# ********************************************************************************
# epoch: 63 / 300, time cost: 39.85 sec,
#           Loss: [Train: 1.93807], [Test: 2.60943],
#           Effect: [ate-q], [train: 0.12874], [test: 0.13174]
# ********************************************************************************
# epoch: 64 / 300, time cost: 39.82 sec,
#           Loss: [Train: 1.93366], [Test: 2.61493],
#           Effect: [ate-q], [train: 0.10661], [test: 0.10991]
# ********************************************************************************
# epoch: 65 / 300, time cost: 41.05 sec,
#           Loss: [Train: 1.93159], [Test: 2.63993],
#           Effect: [ate-q], [train: 0.12990], [test: 0.13317]
# ********************************************************************************
# epoch: 66 / 300, time cost: 40.71 sec,
#           Loss: [Train: 1.92961], [Test: 2.65440],
#           Effect: [ate-q], [train: 0.12631], [test: 0.12888]
# ********************************************************************************
# epoch: 67 / 300, time cost: 40.98 sec,
#           Loss: [Train: 1.92623], [Test: 2.70091],
#           Effect: [ate-q], [train: 0.20922], [test: 0.21226]
# ********************************************************************************
# epoch: 68 / 300, time cost: 40.70 sec,
#           Loss: [Train: 1.92315], [Test: 2.67019],
#           Effect: [ate-q], [train: 0.15104], [test: 0.15394]
# ********************************************************************************
# epoch: 69 / 300, time cost: 40.71 sec,
#           Loss: [Train: 1.92049], [Test: 2.68859],
#           Effect: [ate-q], [train: 0.22776], [test: 0.23136]
# ********************************************************************************
# epoch: 70 / 300, time cost: 41.27 sec,
#           Loss: [Train: 1.91889], [Test: 2.69993],
#           Effect: [ate-q], [train: 0.18539], [test: 0.18842]
# ********************************************************************************
# epoch: 71 / 300, time cost: 41.18 sec,
#           Loss: [Train: 1.91493], [Test: 2.70798],
#           Effect: [ate-q], [train: 0.18716], [test: 0.19042]
# ********************************************************************************
# epoch: 72 / 300, time cost: 41.24 sec,
#           Loss: [Train: 1.91117], [Test: 2.72012],
#           Effect: [ate-q], [train: 0.18897], [test: 0.19208]
# ********************************************************************************
# epoch: 73 / 300, time cost: 44.14 sec,
#           Loss: [Train: 1.91052], [Test: 2.73062],
#           Effect: [ate-q], [train: 0.09472], [test: 0.09762]
# ********************************************************************************
# epoch: 74 / 300, time cost: 40.70 sec,
#           Loss: [Train: 1.90772], [Test: 2.74022],
#           Effect: [ate-q], [train: 0.13850], [test: 0.14131]
# ********************************************************************************
# epoch: 75 / 300, time cost: 41.12 sec,
#           Loss: [Train: 1.90409], [Test: 2.75103],
#           Effect: [ate-q], [train: 0.17209], [test: 0.17517]
# ********************************************************************************
# epoch: 76 / 300, time cost: 40.85 sec,
#           Loss: [Train: 1.90191], [Test: 2.78290],
#           Effect: [ate-q], [train: 0.17938], [test: 0.18246]
# ********************************************************************************
# epoch: 77 / 300, time cost: 41.26 sec,
#           Loss: [Train: 1.90140], [Test: 2.78065],
#           Effect: [ate-q], [train: 0.21021], [test: 0.21347]
# ********************************************************************************
# epoch: 78 / 300, time cost: 41.60 sec,
#           Loss: [Train: 1.89751], [Test: 2.78241],
#           Effect: [ate-q], [train: 0.10415], [test: 0.10720]
# ********************************************************************************
# epoch: 79 / 300, time cost: 41.46 sec,
#           Loss: [Train: 1.89661], [Test: 2.79583],
#           Effect: [ate-q], [train: 0.20562], [test: 0.20886]
# ********************************************************************************
# epoch: 80 / 300, time cost: 40.99 sec,
#           Loss: [Train: 1.89293], [Test: 2.83736],
#           Effect: [ate-q], [train: 0.16781], [test: 0.17077]
# ********************************************************************************
# epoch: 81 / 300, time cost: 41.05 sec,
#           Loss: [Train: 1.89114], [Test: 2.82859],
#           Effect: [ate-q], [train: 0.18945], [test: 0.19264]
# ********************************************************************************
# epoch: 82 / 300, time cost: 40.71 sec,
#           Loss: [Train: 1.88850], [Test: 2.83331],
#           Effect: [ate-q], [train: 0.14825], [test: 0.15106]
# ********************************************************************************
# epoch: 83 / 300, time cost: 40.98 sec,
#           Loss: [Train: 1.88860], [Test: 2.85145],
#           Effect: [ate-q], [train: 0.16632], [test: 0.16931]
# ********************************************************************************
# epoch: 84 / 300, time cost: 40.96 sec,
#           Loss: [Train: 1.88442], [Test: 2.86967],
#           Effect: [ate-q], [train: 0.11372], [test: 0.11638]
# ********************************************************************************
# epoch: 85 / 300, time cost: 41.01 sec,
#           Loss: [Train: 1.88278], [Test: 2.88856],
#           Effect: [ate-q], [train: 0.13814], [test: 0.14091]
# ********************************************************************************
# epoch: 86 / 300, time cost: 41.25 sec,
#           Loss: [Train: 1.88057], [Test: 2.89199],
#           Effect: [ate-q], [train: 0.13907], [test: 0.14183]
# ********************************************************************************
# epoch: 87 / 300, time cost: 41.25 sec,
#           Loss: [Train: 1.87875], [Test: 2.90316],
#           Effect: [ate-q], [train: 0.09180], [test: 0.09459]
# ********************************************************************************
# epoch: 88 / 300, time cost: 41.04 sec,
#           Loss: [Train: 1.87776], [Test: 2.90751],
#           Effect: [ate-q], [train: 0.17043], [test: 0.17324]
# ********************************************************************************
# epoch: 89 / 300, time cost: 41.01 sec,
#           Loss: [Train: 1.87554], [Test: 2.92381],
#           Effect: [ate-q], [train: 0.10339], [test: 0.10637]
# ********************************************************************************
# epoch: 90 / 300, time cost: 41.25 sec,
#           Loss: [Train: 1.87278], [Test: 2.91986],
#           Effect: [ate-q], [train: 0.13816], [test: 0.14133]
# ********************************************************************************
# epoch: 91 / 300, time cost: 41.05 sec,
#           Loss: [Train: 1.87005], [Test: 2.94690],
#           Effect: [ate-q], [train: 0.13331], [test: 0.13623]
# ********************************************************************************
# epoch: 92 / 300, time cost: 41.10 sec,
#           Loss: [Train: 1.86946], [Test: 2.96170],
#           Effect: [ate-q], [train: 0.19587], [test: 0.19917]
# ********************************************************************************
# epoch: 93 / 300, time cost: 41.05 sec,
#           Loss: [Train: 1.86685], [Test: 2.97907],
#           Effect: [ate-q], [train: 0.14359], [test: 0.14613]
# ********************************************************************************
# epoch: 94 / 300, time cost: 41.16 sec,
#           Loss: [Train: 1.86385], [Test: 2.99291],
#           Effect: [ate-q], [train: 0.13862], [test: 0.14091]
# ********************************************************************************
# epoch: 95 / 300, time cost: 41.50 sec,
#           Loss: [Train: 1.86223], [Test: 2.99629],
#           Effect: [ate-q], [train: 0.11440], [test: 0.11692]
# ********************************************************************************
# epoch: 96 / 300, time cost: 41.31 sec,
#           Loss: [Train: 1.86157], [Test: 2.99621],
#           Effect: [ate-q], [train: 0.12216], [test: 0.12503]
# ********************************************************************************
# epoch: 97 / 300, time cost: 41.23 sec,
#           Loss: [Train: 1.85939], [Test: 3.01411],
#           Effect: [ate-q], [train: 0.15878], [test: 0.16149]
# ********************************************************************************
# epoch: 98 / 300, time cost: 41.27 sec,
#           Loss: [Train: 1.85646], [Test: 3.03091],
#           Effect: [ate-q], [train: 0.17918], [test: 0.18199]
# ********************************************************************************
# epoch: 99 / 300, time cost: 40.96 sec,
#           Loss: [Train: 1.85635], [Test: 3.01222],
#           Effect: [ate-q], [train: 0.11962], [test: 0.12287]
# ********************************************************************************
# epoch: 100 / 300, time cost: 41.19 sec,
#           Loss: [Train: 1.85543], [Test: 3.07332],
#           Effect: [ate-q], [train: 0.15377], [test: 0.15662]
# ********************************************************************************
# epoch: 101 / 300, time cost: 41.00 sec,
#           Loss: [Train: 1.85197], [Test: 3.06201],
#           Effect: [ate-q], [train: 0.08863], [test: 0.09140]
# ********************************************************************************
# epoch: 102 / 300, time cost: 39.52 sec,
#           Loss: [Train: 1.84995], [Test: 3.06887],
#           Effect: [ate-q], [train: 0.14671], [test: 0.14922]
# ********************************************************************************
# epoch: 103 / 300, time cost: 40.09 sec,
#           Loss: [Train: 1.84827], [Test: 3.13291],
#           Effect: [ate-q], [train: 0.14071], [test: 0.14333]
# ********************************************************************************
# epoch: 104 / 300, time cost: 40.44 sec,
#           Loss: [Train: 1.84624], [Test: 3.09249],
#           Effect: [ate-q], [train: 0.11787], [test: 0.12033]
# ********************************************************************************
# epoch: 105 / 300, time cost: 46.48 sec,
#           Loss: [Train: 1.84467], [Test: 3.11441],
#           Effect: [ate-q], [train: 0.09638], [test: 0.09904]
# ********************************************************************************
# epoch: 106 / 300, time cost: 39.89 sec,
#           Loss: [Train: 1.84509], [Test: 3.10338],
#           Effect: [ate-q], [train: 0.13955], [test: 0.14230]
# ********************************************************************************
# epoch: 107 / 300, time cost: 39.79 sec,
#           Loss: [Train: 1.84218], [Test: 3.14175],
#           Effect: [ate-q], [train: 0.18436], [test: 0.18700]
# ********************************************************************************
# epoch: 108 / 300, time cost: 39.74 sec,
#           Loss: [Train: 1.84036], [Test: 3.16341],
#           Effect: [ate-q], [train: 0.18228], [test: 0.18515]
# ********************************************************************************
# epoch: 109 / 300, time cost: 40.34 sec,
#           Loss: [Train: 1.83840], [Test: 3.17604],
#           Effect: [ate-q], [train: 0.21707], [test: 0.21989]
# ********************************************************************************
# epoch: 110 / 300, time cost: 39.63 sec,
#           Loss: [Train: 1.83762], [Test: 3.18773],
#           Effect: [ate-q], [train: 0.19041], [test: 0.19318]
# ********************************************************************************
# epoch: 111 / 300, time cost: 40.24 sec,
#           Loss: [Train: 1.83545], [Test: 3.17853],
#           Effect: [ate-q], [train: 0.15279], [test: 0.15540]
# ********************************************************************************
# epoch: 112 / 300, time cost: 41.62 sec,
#           Loss: [Train: 1.83423], [Test: 3.21584],
#           Effect: [ate-q], [train: 0.04495], [test: 0.04749]
# ********************************************************************************
# epoch: 113 / 300, time cost: 41.35 sec,
#           Loss: [Train: 1.83176], [Test: 3.21032],
#           Effect: [ate-q], [train: 0.16994], [test: 0.17278]
# ********************************************************************************
# epoch: 114 / 300, time cost: 41.32 sec,
#           Loss: [Train: 1.83256], [Test: 3.25339],
#           Effect: [ate-q], [train: 0.22026], [test: 0.22307]
# ********************************************************************************
# epoch: 115 / 300, time cost: 41.39 sec,
#           Loss: [Train: 1.82805], [Test: 3.24974],
#           Effect: [ate-q], [train: 0.13658], [test: 0.13909]
# ********************************************************************************
# epoch: 116 / 300, time cost: 40.89 sec,
#           Loss: [Train: 1.82843], [Test: 3.26413],
#           Effect: [ate-q], [train: 0.14890], [test: 0.15152]
# ********************************************************************************
# epoch: 117 / 300, time cost: 40.79 sec,
#           Loss: [Train: 1.82471], [Test: 3.27317],
#           Effect: [ate-q], [train: 0.13101], [test: 0.13373]
# ********************************************************************************
# epoch: 118 / 300, time cost: 40.78 sec,
#           Loss: [Train: 1.82376], [Test: 3.32522],
#           Effect: [ate-q], [train: 0.23739], [test: 0.24020]
# ********************************************************************************
# epoch: 119 / 300, time cost: 41.21 sec,
#           Loss: [Train: 1.82374], [Test: 3.31822],
#           Effect: [ate-q], [train: 0.17963], [test: 0.18219]
# ********************************************************************************
# epoch: 120 / 300, time cost: 41.04 sec,
#           Loss: [Train: 1.82018], [Test: 3.33914],
#           Effect: [ate-q], [train: 0.21183], [test: 0.21447]
# ********************************************************************************
# epoch: 121 / 300, time cost: 41.03 sec,
#           Loss: [Train: 1.82138], [Test: 3.34766],
#           Effect: [ate-q], [train: 0.16644], [test: 0.16892]
# ********************************************************************************
# epoch: 122 / 300, time cost: 41.00 sec,
#           Loss: [Train: 1.81821], [Test: 3.35334],
#           Effect: [ate-q], [train: 0.08378], [test: 0.08611]
# ********************************************************************************
# epoch: 123 / 300, time cost: 40.87 sec,
#           Loss: [Train: 1.81560], [Test: 3.39336],
#           Effect: [ate-q], [train: 0.08118], [test: 0.08363]
# ********************************************************************************
# epoch: 124 / 300, time cost: 40.68 sec,
#           Loss: [Train: 1.81552], [Test: 3.40906],
#           Effect: [ate-q], [train: 0.24950], [test: 0.25231]
# ********************************************************************************
# epoch: 125 / 300, time cost: 40.89 sec,
#           Loss: [Train: 1.81327], [Test: 3.36538],
#           Effect: [ate-q], [train: 0.18006], [test: 0.18251]
# ********************************************************************************
# epoch: 126 / 300, time cost: 40.71 sec,
#           Loss: [Train: 1.81205], [Test: 3.39801],
#           Effect: [ate-q], [train: 0.17481], [test: 0.17723]
# ********************************************************************************
# epoch: 127 / 300, time cost: 41.49 sec,
#           Loss: [Train: 1.80989], [Test: 3.38949],
#           Effect: [ate-q], [train: 0.10893], [test: 0.11148]
# ********************************************************************************
# epoch: 128 / 300, time cost: 41.36 sec,
#           Loss: [Train: 1.80936], [Test: 3.43054],
#           Effect: [ate-q], [train: 0.22205], [test: 0.22501]
# ********************************************************************************
# epoch: 129 / 300, time cost: 41.18 sec,
#           Loss: [Train: 1.80961], [Test: 3.44609],
#           Effect: [ate-q], [train: 0.04799], [test: 0.05022]
# ********************************************************************************
# epoch: 130 / 300, time cost: 41.04 sec,
#           Loss: [Train: 1.80650], [Test: 3.45872],
#           Effect: [ate-q], [train: 0.12415], [test: 0.12683]
# ********************************************************************************
# epoch: 131 / 300, time cost: 41.03 sec,
#           Loss: [Train: 1.80445], [Test: 3.43697],
#           Effect: [ate-q], [train: 0.07071], [test: 0.07348]
# ********************************************************************************
# epoch: 132 / 300, time cost: 40.85 sec,
#           Loss: [Train: 1.80408], [Test: 3.47533],
#           Effect: [ate-q], [train: 0.13630], [test: 0.13858]
# ********************************************************************************
# epoch: 133 / 300, time cost: 40.70 sec,
#           Loss: [Train: 1.80237], [Test: 3.46418],
#           Effect: [ate-q], [train: 0.04139], [test: 0.04373]
# ********************************************************************************
# epoch: 134 / 300, time cost: 40.85 sec,
#           Loss: [Train: 1.80095], [Test: 3.52559],
#           Effect: [ate-q], [train: 0.11083], [test: 0.11333]
# ********************************************************************************
# epoch: 135 / 300, time cost: 41.49 sec,
#           Loss: [Train: 1.79788], [Test: 3.52560],
#           Effect: [ate-q], [train: 0.18506], [test: 0.18732]
# ********************************************************************************
# epoch: 136 / 300, time cost: 41.42 sec,
#           Loss: [Train: 1.79830], [Test: 3.52384],
#           Effect: [ate-q], [train: 0.16785], [test: 0.17014]
# ********************************************************************************
# epoch: 137 / 300, time cost: 40.98 sec,
#           Loss: [Train: 1.79721], [Test: 3.53451],
#           Effect: [ate-q], [train: 0.17824], [test: 0.18048]
# ********************************************************************************
# epoch: 138 / 300, time cost: 41.15 sec,
#           Loss: [Train: 1.79584], [Test: 3.51587],
#           Effect: [ate-q], [train: 0.17528], [test: 0.17790]
# ********************************************************************************
# epoch: 139 / 300, time cost: 40.93 sec,
#           Loss: [Train: 1.79394], [Test: 3.51182],
#           Effect: [ate-q], [train: 0.14555], [test: 0.14801]
# ********************************************************************************
# epoch: 140 / 300, time cost: 40.89 sec,
#           Loss: [Train: 1.79184], [Test: 3.56206],
#           Effect: [ate-q], [train: 0.16753], [test: 0.16985]
# ********************************************************************************
# epoch: 141 / 300, time cost: 40.92 sec,
#           Loss: [Train: 1.79078], [Test: 3.54880],
#           Effect: [ate-q], [train: 0.14136], [test: 0.14387]
# ********************************************************************************
# epoch: 142 / 300, time cost: 42.07 sec,
#           Loss: [Train: 1.78826], [Test: 3.58344],
#           Effect: [ate-q], [train: 0.03753], [test: 0.04002]
# ********************************************************************************
# epoch: 143 / 300, time cost: 47.42 sec,
#           Loss: [Train: 1.78742], [Test: 3.59233],
#           Effect: [ate-q], [train: 0.16072], [test: 0.16342]
# ********************************************************************************
# epoch: 144 / 300, time cost: 41.38 sec,
#           Loss: [Train: 1.78804], [Test: 3.59869],
#           Effect: [ate-q], [train: 0.16926], [test: 0.17199]
# ********************************************************************************
# epoch: 145 / 300, time cost: 41.10 sec,
#           Loss: [Train: 1.78531], [Test: 3.62672],
#           Effect: [ate-q], [train: 0.07935], [test: 0.08165]
# ********************************************************************************
# epoch: 146 / 300, time cost: 41.11 sec,
#           Loss: [Train: 1.78411], [Test: 3.64342],
#           Effect: [ate-q], [train: 0.11679], [test: 0.11896]
# ********************************************************************************
# epoch: 147 / 300, time cost: 40.96 sec,
#           Loss: [Train: 1.78406], [Test: 3.66303],
#           Effect: [ate-q], [train: 0.21537], [test: 0.21790]
# ********************************************************************************
# epoch: 148 / 300, time cost: 40.84 sec,
#           Loss: [Train: 1.78104], [Test: 3.67297],
#           Effect: [ate-q], [train: 0.18998], [test: 0.19244]
# ********************************************************************************
# epoch: 149 / 300, time cost: 40.86 sec,
#           Loss: [Train: 1.77965], [Test: 3.70300],
#           Effect: [ate-q], [train: 0.07536], [test: 0.07775]
# ********************************************************************************
# epoch: 150 / 300, time cost: 40.77 sec,
#           Loss: [Train: 1.77919], [Test: 3.66451],
#           Effect: [ate-q], [train: 0.14684], [test: 0.14946]
# ********************************************************************************
# epoch: 151 / 300, time cost: 41.12 sec,
#           Loss: [Train: 1.77819], [Test: 3.74629],
#           Effect: [ate-q], [train: 0.16106], [test: 0.16344]
# ********************************************************************************
# epoch: 152 / 300, time cost: 41.28 sec,
#           Loss: [Train: 1.77607], [Test: 3.71387],
#           Effect: [ate-q], [train: 0.16324], [test: 0.16581]
# ********************************************************************************
# epoch: 153 / 300, time cost: 41.01 sec,
#           Loss: [Train: 1.77464], [Test: 3.77937],
#           Effect: [ate-q], [train: 0.14412], [test: 0.14637]
# ********************************************************************************
# epoch: 154 / 300, time cost: 40.88 sec,
#           Loss: [Train: 1.77431], [Test: 3.79713],
#           Effect: [ate-q], [train: 0.15650], [test: 0.15900]
# ********************************************************************************
# epoch: 155 / 300, time cost: 41.09 sec,
#           Loss: [Train: 1.77283], [Test: 3.84688],
#           Effect: [ate-q], [train: 0.23291], [test: 0.23514]
# ********************************************************************************
# epoch: 156 / 300, time cost: 40.72 sec,
#           Loss: [Train: 1.77090], [Test: 3.76917],
#           Effect: [ate-q], [train: 0.14530], [test: 0.14757]
# ********************************************************************************
# epoch: 157 / 300, time cost: 41.04 sec,
#           Loss: [Train: 1.76969], [Test: 3.79183],
#           Effect: [ate-q], [train: 0.11383], [test: 0.11634]
# ********************************************************************************
# epoch: 158 / 300, time cost: 41.01 sec,
#           Loss: [Train: 1.76868], [Test: 3.76506],
#           Effect: [ate-q], [train: 0.16882], [test: 0.17111]
# ********************************************************************************
# epoch: 159 / 300, time cost: 40.90 sec,
#           Loss: [Train: 1.76670], [Test: 3.81896],
#           Effect: [ate-q], [train: 0.19500], [test: 0.19720]
# ********************************************************************************
# epoch: 160 / 300, time cost: 41.36 sec,
#           Loss: [Train: 1.76615], [Test: 3.85273],
#           Effect: [ate-q], [train: 0.13573], [test: 0.13813]
# ********************************************************************************
# epoch: 161 / 300, time cost: 41.38 sec,
#           Loss: [Train: 1.76351], [Test: 3.90771],
#           Effect: [ate-q], [train: 0.12665], [test: 0.12881]
# ********************************************************************************
# epoch: 162 / 300, time cost: 41.15 sec,
#           Loss: [Train: 1.76575], [Test: 3.83209],
#           Effect: [ate-q], [train: 0.07557], [test: 0.07783]
# ********************************************************************************
# epoch: 163 / 300, time cost: 41.05 sec,
#           Loss: [Train: 1.76214], [Test: 3.87288],
#           Effect: [ate-q], [train: 0.16163], [test: 0.16370]
# ********************************************************************************
# epoch: 164 / 300, time cost: 40.87 sec,
#           Loss: [Train: 1.76263], [Test: 3.95506],
#           Effect: [ate-q], [train: 0.12827], [test: 0.13063]
# ********************************************************************************
# epoch: 165 / 300, time cost: 40.93 sec,
#           Loss: [Train: 1.75927], [Test: 3.91753],
#           Effect: [ate-q], [train: 0.13373], [test: 0.13604]
# ********************************************************************************
# epoch: 166 / 300, time cost: 40.82 sec,
#           Loss: [Train: 1.75881], [Test: 3.94170],
#           Effect: [ate-q], [train: 0.14584], [test: 0.14823]
# ********************************************************************************
# epoch: 167 / 300, time cost: 40.64 sec,
#           Loss: [Train: 1.75755], [Test: 3.95434],
#           Effect: [ate-q], [train: 0.17935], [test: 0.18164]
# ********************************************************************************
# epoch: 168 / 300, time cost: 40.56 sec,
#           Loss: [Train: 1.75619], [Test: 3.95231],
#           Effect: [ate-q], [train: 0.15297], [test: 0.15553]
# ********************************************************************************
# epoch: 169 / 300, time cost: 41.48 sec,
#           Loss: [Train: 1.75563], [Test: 3.98342],
#           Effect: [ate-q], [train: 0.08788], [test: 0.09021]
# ********************************************************************************
# epoch: 170 / 300, time cost: 42.60 sec,
#           Loss: [Train: 1.75578], [Test: 4.00588],
#           Effect: [ate-q], [train: 0.11571], [test: 0.11820]
# ********************************************************************************
# epoch: 171 / 300, time cost: 47.24 sec,
#           Loss: [Train: 1.75369], [Test: 3.98564],
#           Effect: [ate-q], [train: 0.10235], [test: 0.10479]
# ********************************************************************************
# epoch: 172 / 300, time cost: 47.32 sec,
#           Loss: [Train: 1.75245], [Test: 4.02779],
#           Effect: [ate-q], [train: 0.14586], [test: 0.14794]
# ********************************************************************************
# epoch: 173 / 300, time cost: 47.11 sec,
#           Loss: [Train: 1.75162], [Test: 4.00005],
#           Effect: [ate-q], [train: 0.09565], [test: 0.09787]
# ********************************************************************************
# epoch: 174 / 300, time cost: 47.24 sec,
#           Loss: [Train: 1.74978], [Test: 4.03586],
#           Effect: [ate-q], [train: 0.14653], [test: 0.14869]
# ********************************************************************************
# epoch: 175 / 300, time cost: 47.00 sec,
#           Loss: [Train: 1.74994], [Test: 4.02532],
#           Effect: [ate-q], [train: 0.07177], [test: 0.07412]
# ********************************************************************************
# epoch: 176 / 300, time cost: 41.02 sec,
#           Loss: [Train: 1.74765], [Test: 4.03330],
#           Effect: [ate-q], [train: 0.07284], [test: 0.07539]
# ********************************************************************************
# epoch: 177 / 300, time cost: 41.50 sec,
#           Loss: [Train: 1.74698], [Test: 4.06147],
#           Effect: [ate-q], [train: 0.13456], [test: 0.13690]
# ********************************************************************************
# epoch: 178 / 300, time cost: 41.25 sec,
#           Loss: [Train: 1.74593], [Test: 4.09158],
#           Effect: [ate-q], [train: 0.14959], [test: 0.15167]
# ********************************************************************************
# epoch: 179 / 300, time cost: 40.90 sec,
#           Loss: [Train: 1.74442], [Test: 4.11369],
#           Effect: [ate-q], [train: 0.13117], [test: 0.13332]
# ********************************************************************************
# epoch: 180 / 300, time cost: 40.67 sec,
#           Loss: [Train: 1.74386], [Test: 4.13000],
#           Effect: [ate-q], [train: 0.18460], [test: 0.18685]
# ********************************************************************************
# epoch: 181 / 300, time cost: 40.94 sec,
#           Loss: [Train: 1.74238], [Test: 4.13122],
#           Effect: [ate-q], [train: 0.15271], [test: 0.15490]
# ********************************************************************************
# epoch: 182 / 300, time cost: 40.74 sec,
#           Loss: [Train: 1.74115], [Test: 4.20962],
#           Effect: [ate-q], [train: 0.21781], [test: 0.21982]
# ********************************************************************************
# epoch: 183 / 300, time cost: 40.95 sec,
#           Loss: [Train: 1.74160], [Test: 4.16361],
#           Effect: [ate-q], [train: 0.10071], [test: 0.10285]
# ********************************************************************************
# epoch: 184 / 300, time cost: 40.71 sec,
#           Loss: [Train: 1.73915], [Test: 4.20060],
#           Effect: [ate-q], [train: 0.14555], [test: 0.14740]
# ********************************************************************************
# epoch: 185 / 300, time cost: 40.45 sec,
#           Loss: [Train: 1.73813], [Test: 4.19403],
#           Effect: [ate-q], [train: 0.20109], [test: 0.20335]
# ********************************************************************************
# epoch: 186 / 300, time cost: 41.25 sec,
#           Loss: [Train: 1.73717], [Test: 4.20229],
#           Effect: [ate-q], [train: 0.14114], [test: 0.14333]
# ********************************************************************************
# epoch: 187 / 300, time cost: 41.18 sec,
#           Loss: [Train: 1.73526], [Test: 4.19681],
#           Effect: [ate-q], [train: 0.17379], [test: 0.17593]
# ********************************************************************************
# epoch: 188 / 300, time cost: 41.04 sec,
#           Loss: [Train: 1.73554], [Test: 4.16462],
#           Effect: [ate-q], [train: 0.17174], [test: 0.17395]
# ********************************************************************************
# epoch: 189 / 300, time cost: 41.08 sec,
#           Loss: [Train: 1.73441], [Test: 4.19252],
#           Effect: [ate-q], [train: 0.09673], [test: 0.09913]
# ********************************************************************************
# epoch: 190 / 300, time cost: 41.13 sec,
#           Loss: [Train: 1.73264], [Test: 4.24309],
#           Effect: [ate-q], [train: 0.15683], [test: 0.15873]
# ********************************************************************************
# epoch: 191 / 300, time cost: 40.93 sec,
#           Loss: [Train: 1.73305], [Test: 4.26404],
#           Effect: [ate-q], [train: 0.20626], [test: 0.20802]
# ********************************************************************************
# epoch: 192 / 300, time cost: 40.92 sec,
#           Loss: [Train: 1.73025], [Test: 4.24363],
#           Effect: [ate-q], [train: 0.13763], [test: 0.13982]
# ********************************************************************************
# epoch: 193 / 300, time cost: 40.93 sec,
#           Loss: [Train: 1.73019], [Test: 4.27492],
#           Effect: [ate-q], [train: 0.10299], [test: 0.10505]
# ********************************************************************************
# epoch: 194 / 300, time cost: 41.15 sec,
#           Loss: [Train: 1.72842], [Test: 4.24724],
#           Effect: [ate-q], [train: 0.19889], [test: 0.20114]
# ********************************************************************************
# epoch: 195 / 300, time cost: 41.53 sec,
#           Loss: [Train: 1.72760], [Test: 4.30400],
#           Effect: [ate-q], [train: 0.10540], [test: 0.10736]
# ********************************************************************************
# epoch: 196 / 300, time cost: 41.13 sec,
#           Loss: [Train: 1.72844], [Test: 4.34193],
#           Effect: [ate-q], [train: 0.15832], [test: 0.16048]
# ********************************************************************************
# epoch: 197 / 300, time cost: 41.10 sec,
#           Loss: [Train: 1.72473], [Test: 4.30356],
#           Effect: [ate-q], [train: 0.11130], [test: 0.11375]
# ********************************************************************************
# epoch: 198 / 300, time cost: 41.05 sec,
#           Loss: [Train: 1.72568], [Test: 4.30000],
#           Effect: [ate-q], [train: 0.14246], [test: 0.14449]
# ********************************************************************************
# epoch: 199 / 300, time cost: 40.63 sec,
#           Loss: [Train: 1.72493], [Test: 4.34759],
#           Effect: [ate-q], [train: 0.10142], [test: 0.10353]
# ********************************************************************************
# epoch: 200 / 300, time cost: 40.54 sec,
#           Loss: [Train: 1.72331], [Test: 4.38905],
#           Effect: [ate-q], [train: 0.20554], [test: 0.20749]
# ********************************************************************************
# epoch: 201 / 300, time cost: 41.01 sec,
#           Loss: [Train: 1.72286], [Test: 4.33313],
#           Effect: [ate-q], [train: 0.11007], [test: 0.11203]
# ********************************************************************************
# epoch: 202 / 300, time cost: 40.91 sec,
#           Loss: [Train: 1.72113], [Test: 4.38962],
#           Effect: [ate-q], [train: 0.13604], [test: 0.13822]
# ********************************************************************************
# epoch: 203 / 300, time cost: 41.07 sec,
#           Loss: [Train: 1.72081], [Test: 4.38476],
#           Effect: [ate-q], [train: 0.09911], [test: 0.10143]
# ********************************************************************************
# epoch: 204 / 300, time cost: 41.31 sec,
#           Loss: [Train: 1.71953], [Test: 4.38490],
#           Effect: [ate-q], [train: 0.19036], [test: 0.19233]
# ********************************************************************************
# epoch: 205 / 300, time cost: 41.16 sec,
#           Loss: [Train: 1.71834], [Test: 4.44967],
#           Effect: [ate-q], [train: 0.09653], [test: 0.09863]
# ********************************************************************************
# epoch: 206 / 300, time cost: 41.02 sec,
#           Loss: [Train: 1.71754], [Test: 4.46044],
# ...
# epoch: 233 / 300, time cost: 40.55 sec,
#           Loss: [Train: 1.69591], [Test: 4.70566],
#           Effect: [ate-q], [train: 0.15021], [test: 0.15208]
# ********************************************************************************
# epoch: 234 / 300, time cost: 41.40 sec,
#           Loss: [Train: 1.69412], [Test: 4.69967],
#           Effect: [ate-q], [train: 0.14675], [test: 0.14894]
# ********************************************************************************
# epoch: 235 / 300, time cost: 41.24 sec,
#           Loss: [Train: 1.69383], [Test: 4.69359],
#           Effect: [ate-q], [train: 0.13020], [test: 0.13203]
# ********************************************************************************
# epoch: 236 / 300, time cost: 41.20 sec,
#           Loss: [Train: 1.69354], [Test: 4.73480],
#           Effect: [ate-q], [train: 0.13528], [test: 0.13704]
# ********************************************************************************
# epoch: 237 / 300, time cost: 41.05 sec,
#           Loss: [Train: 1.69245], [Test: 4.74542],
#           Effect: [ate-q], [train: 0.12668], [test: 0.12846]
# ********************************************************************************
# epoch: 238 / 300, time cost: 40.89 sec,
#           Loss: [Train: 1.69127], [Test: 4.80091],
#           Effect: [ate-q], [train: 0.15008], [test: 0.15154]
# ********************************************************************************
# epoch: 239 / 300, time cost: 41.49 sec,
#           Loss: [Train: 1.69176], [Test: 4.76946],
#           Effect: [ate-q], [train: 0.17224], [test: 0.17358]
# ********************************************************************************
# epoch: 240 / 300, time cost: 41.51 sec,
#           Loss: [Train: 1.69033], [Test: 4.82445],
#           Effect: [ate-q], [train: 0.14545], [test: 0.14702]
# ********************************************************************************
# epoch: 241 / 300, time cost: 41.19 sec,
#           Loss: [Train: 1.68896], [Test: 4.80118],
#           Effect: [ate-q], [train: 0.08230], [test: 0.08411]
# ********************************************************************************
# epoch: 242 / 300, time cost: 41.16 sec,
#           Loss: [Train: 1.68916], [Test: 4.86688],
#           Effect: [ate-q], [train: 0.20273], [test: 0.20443]
# ********************************************************************************
# epoch: 243 / 300, time cost: 41.32 sec,
#           Loss: [Train: 1.68839], [Test: 4.75386],
#           Effect: [ate-q], [train: 0.14153], [test: 0.14335]
# ********************************************************************************
# epoch: 244 / 300, time cost: 41.01 sec,
#           Loss: [Train: 1.68790], [Test: 4.86954],
#           Effect: [ate-q], [train: 0.13196], [test: 0.13356]
# ********************************************************************************
# epoch: 245 / 300, time cost: 41.14 sec,
#           Loss: [Train: 1.68722], [Test: 4.75803],
#           Effect: [ate-q], [train: 0.10515], [test: 0.10692]
# ********************************************************************************
# epoch: 246 / 300, time cost: 41.08 sec,
#           Loss: [Train: 1.68648], [Test: 4.82662],
#           Effect: [ate-q], [train: 0.12136], [test: 0.12277]
# ********************************************************************************
# epoch: 247 / 300, time cost: 41.21 sec,
#           Loss: [Train: 1.68568], [Test: 4.74809],
#           Effect: [ate-q], [train: 0.04829], [test: 0.05058]
# ********************************************************************************
# epoch: 248 / 300, time cost: 41.07 sec,
#           Loss: [Train: 1.68545], [Test: 4.87780],
#           Effect: [ate-q], [train: 0.11342], [test: 0.11505]
# ********************************************************************************
# epoch: 249 / 300, time cost: 41.16 sec,
#           Loss: [Train: 1.68421], [Test: 4.81988],
#           Effect: [ate-q], [train: 0.09138], [test: 0.09326]
# ********************************************************************************
# epoch: 250 / 300, time cost: 41.00 sec,
#           Loss: [Train: 1.68309], [Test: 4.90107],
#           Effect: [ate-q], [train: 0.13899], [test: 0.14041]
# ********************************************************************************
# epoch: 251 / 300, time cost: 40.74 sec,
#           Loss: [Train: 1.68354], [Test: 4.86826],
#           Effect: [ate-q], [train: 0.15517], [test: 0.15658]
# ********************************************************************************
# epoch: 252 / 300, time cost: 40.79 sec,
#           Loss: [Train: 1.68329], [Test: 4.88461],
#           Effect: [ate-q], [train: 0.15790], [test: 0.15917]
# ********************************************************************************
# epoch: 253 / 300, time cost: 40.90 sec,
#           Loss: [Train: 1.68201], [Test: 4.91420],
#           Effect: [ate-q], [train: 0.12045], [test: 0.12231]
# ********************************************************************************
# epoch: 254 / 300, time cost: 40.87 sec,
#           Loss: [Train: 1.68140], [Test: 4.87593],
#           Effect: [ate-q], [train: 0.09792], [test: 0.09967]
# ********************************************************************************
# epoch: 255 / 300, time cost: 40.83 sec,
#           Loss: [Train: 1.68132], [Test: 4.90258],
#           Effect: [ate-q], [train: 0.10156], [test: 0.10308]
# ********************************************************************************
# epoch: 256 / 300, time cost: 40.54 sec,
#           Loss: [Train: 1.67983], [Test: 4.89768],
#           Effect: [ate-q], [train: 0.12376], [test: 0.12521]
# ********************************************************************************
# epoch: 257 / 300, time cost: 39.94 sec,
#           Loss: [Train: 1.68013], [Test: 4.91516],
#           Effect: [ate-q], [train: 0.16473], [test: 0.16624]
# ********************************************************************************
# epoch: 258 / 300, time cost: 41.22 sec,
#           Loss: [Train: 1.67852], [Test: 4.92452],
#           Effect: [ate-q], [train: 0.15741], [test: 0.15898]
# ********************************************************************************
# epoch: 259 / 300, time cost: 39.48 sec,
#           Loss: [Train: 1.67900], [Test: 4.92430],
#           Effect: [ate-q], [train: 0.12036], [test: 0.12164]
# ********************************************************************************
# epoch: 260 / 300, time cost: 39.35 sec,
#           Loss: [Train: 1.67757], [Test: 4.95373],
#           Effect: [ate-q], [train: 0.15059], [test: 0.15210]
# ********************************************************************************
# epoch: 261 / 300, time cost: 39.49 sec,
#           Loss: [Train: 1.67790], [Test: 4.95512],
#           Effect: [ate-q], [train: 0.11789], [test: 0.11945]
# ********************************************************************************
# epoch: 262 / 300, time cost: 39.27 sec,
#           Loss: [Train: 1.67738], [Test: 4.96776],
#           Effect: [ate-q], [train: 0.17468], [test: 0.17608]
# ********************************************************************************
# epoch: 263 / 300, time cost: 39.35 sec,
#           Loss: [Train: 1.67695], [Test: 4.95226],
#           Effect: [ate-q], [train: 0.15260], [test: 0.15414]
# ********************************************************************************
# epoch: 264 / 300, time cost: 39.22 sec,
#           Loss: [Train: 1.67563], [Test: 4.96794],
#           Effect: [ate-q], [train: 0.12921], [test: 0.13065]
# ********************************************************************************
# epoch: 265 / 300, time cost: 39.20 sec,
#           Loss: [Train: 1.67588], [Test: 4.98560],
#           Effect: [ate-q], [train: 0.11157], [test: 0.11293]
# ********************************************************************************
# epoch: 266 / 300, time cost: 39.63 sec,
#           Loss: [Train: 1.67514], [Test: 4.97220],
#           Effect: [ate-q], [train: 0.14557], [test: 0.14695]
# ********************************************************************************
# epoch: 267 / 300, time cost: 39.69 sec,
#           Loss: [Train: 1.67485], [Test: 4.99699],
#           Effect: [ate-q], [train: 0.15740], [test: 0.15882]
# ********************************************************************************
# epoch: 268 / 300, time cost: 39.45 sec,
#           Loss: [Train: 1.67427], [Test: 4.99166],
#           Effect: [ate-q], [train: 0.11592], [test: 0.11746]
# ********************************************************************************
# epoch: 269 / 300, time cost: 39.36 sec,
#           Loss: [Train: 1.67367], [Test: 5.02643],
#           Effect: [ate-q], [train: 0.14750], [test: 0.14889]
# ********************************************************************************
# epoch: 270 / 300, time cost: 39.78 sec,
#           Loss: [Train: 1.67294], [Test: 5.02917],
#           Effect: [ate-q], [train: 0.13453], [test: 0.13602]
# ********************************************************************************
# epoch: 271 / 300, time cost: 39.67 sec,
#           Loss: [Train: 1.67350], [Test: 5.01198],
#           Effect: [ate-q], [train: 0.15194], [test: 0.15349]
# ********************************************************************************
# epoch: 272 / 300, time cost: 39.63 sec,
#           Loss: [Train: 1.67245], [Test: 5.02695],
#           Effect: [ate-q], [train: 0.14626], [test: 0.14769]
# ********************************************************************************
# epoch: 273 / 300, time cost: 39.60 sec,
#           Loss: [Train: 1.67112], [Test: 5.04341],
#           Effect: [ate-q], [train: 0.14270], [test: 0.14419]
# ********************************************************************************
# epoch: 274 / 300, time cost: 39.56 sec,
#           Loss: [Train: 1.67132], [Test: 5.07502],
#           Effect: [ate-q], [train: 0.16662], [test: 0.16778]
# ********************************************************************************
# epoch: 275 / 300, time cost: 40.06 sec,
#           Loss: [Train: 1.67065], [Test: 5.05867],
#           Effect: [ate-q], [train: 0.11922], [test: 0.12063]
# ********************************************************************************
# epoch: 276 / 300, time cost: 40.03 sec,
#           Loss: [Train: 1.67052], [Test: 5.05189],
#           Effect: [ate-q], [train: 0.15566], [test: 0.15688]
# ********************************************************************************
# epoch: 277 / 300, time cost: 39.78 sec,
#           Loss: [Train: 1.67024], [Test: 5.05824],
#           Effect: [ate-q], [train: 0.08553], [test: 0.08700]
# ********************************************************************************
# epoch: 278 / 300, time cost: 39.78 sec,
#           Loss: [Train: 1.66939], [Test: 5.04605],
#           Effect: [ate-q], [train: 0.14901], [test: 0.15067]
# ********************************************************************************
# epoch: 279 / 300, time cost: 39.84 sec,
#           Loss: [Train: 1.66954], [Test: 5.08507],
#           Effect: [ate-q], [train: 0.12053], [test: 0.12197]
# ********************************************************************************
# epoch: 280 / 300, time cost: 39.73 sec,
#           Loss: [Train: 1.66954], [Test: 5.10666],
#           Effect: [ate-q], [train: 0.14955], [test: 0.15076]
# ********************************************************************************
# epoch: 281 / 300, time cost: 39.61 sec,
#           Loss: [Train: 1.66806], [Test: 5.07856],
#           Effect: [ate-q], [train: 0.13021], [test: 0.13162]
# ********************************************************************************
# epoch: 282 / 300, time cost: 39.77 sec,
#           Loss: [Train: 1.66747], [Test: 5.06646],
#           Effect: [ate-q], [train: 0.13414], [test: 0.13554]
# ********************************************************************************
# epoch: 283 / 300, time cost: 39.88 sec,
#           Loss: [Train: 1.66702], [Test: 5.06657],
#           Effect: [ate-q], [train: 0.13589], [test: 0.13725]
# ********************************************************************************
# epoch: 284 / 300, time cost: 39.62 sec,
#           Loss: [Train: 1.66722], [Test: 5.09203],
#           Effect: [ate-q], [train: 0.13764], [test: 0.13894]
# ********************************************************************************
# epoch: 285 / 300, time cost: 39.83 sec,
#           Loss: [Train: 1.66659], [Test: 5.06695],
#           Effect: [ate-q], [train: 0.12518], [test: 0.12651]
# ********************************************************************************
# epoch: 286 / 300, time cost: 39.96 sec,
#           Loss: [Train: 1.66591], [Test: 5.08364],
#           Effect: [ate-q], [train: 0.12202], [test: 0.12337]
# ********************************************************************************
# epoch: 287 / 300, time cost: 39.87 sec,
#           Loss: [Train: 1.66623], [Test: 5.09013],
#           Effect: [ate-q], [train: 0.15042], [test: 0.15191]
# ********************************************************************************
# epoch: 288 / 300, time cost: 39.97 sec,
#           Loss: [Train: 1.66594], [Test: 5.10342],
#           Effect: [ate-q], [train: 0.14254], [test: 0.14390]
# ********************************************************************************
# epoch: 289 / 300, time cost: 39.77 sec,
#           Loss: [Train: 1.66533], [Test: 5.09281],
#           Effect: [ate-q], [train: 0.12111], [test: 0.12248]
# ********************************************************************************
# epoch: 290 / 300, time cost: 39.69 sec,
#           Loss: [Train: 1.66511], [Test: 5.09223],
#           Effect: [ate-q], [train: 0.11524], [test: 0.11660]
# ********************************************************************************
# epoch: 291 / 300, time cost: 39.70 sec,
#           Loss: [Train: 1.66450], [Test: 5.11269],
#           Effect: [ate-q], [train: 0.14470], [test: 0.14599]
# ********************************************************************************
# epoch: 292 / 300, time cost: 40.78 sec,
#           Loss: [Train: 1.66411], [Test: 5.11513],
#           Effect: [ate-q], [train: 0.12452], [test: 0.12594]
# ********************************************************************************
# epoch: 293 / 300, time cost: 47.15 sec,
#           Loss: [Train: 1.66379], [Test: 5.11146],
#           Effect: [ate-q], [train: 0.13086], [test: 0.13221]
# ********************************************************************************
# epoch: 294 / 300, time cost: 42.19 sec,
#           Loss: [Train: 1.66439], [Test: 5.10733],
#           Effect: [ate-q], [train: 0.13065], [test: 0.13197]
# ********************************************************************************
# epoch: 295 / 300, time cost: 41.26 sec,
#           Loss: [Train: 1.66337], [Test: 5.10985],
#           Effect: [ate-q], [train: 0.14292], [test: 0.14423]
# ********************************************************************************
# epoch: 296 / 300, time cost: 40.95 sec,
#           Loss: [Train: 1.66344], [Test: 5.11320],
#           Effect: [ate-q], [train: 0.13416], [test: 0.13566]
# ********************************************************************************
# epoch: 297 / 300, time cost: 40.61 sec,
#           Loss: [Train: 1.66268], [Test: 5.11328],
#           Effect: [ate-q], [train: 0.13638], [test: 0.13783]
# ********************************************************************************
# epoch: 298 / 300, time cost: 41.14 sec,
#           Loss: [Train: 1.66295], [Test: 5.10430],
#           Effect: [ate-q], [train: 0.12685], [test: 0.12827]
# ********************************************************************************
# epoch: 299 / 300, time cost: 40.98 sec,
#           Loss: [Train: 1.66179], [Test: 5.11278],
#           Effect: [ate-q], [train: 0.12547], [test: 0.12677]
# ********************************************************************************
# epoch: 300 / 300, time cost: 41.03 sec,
#           Loss: [Train: 1.66264], [Test: 5.12044],
#           Effect: [ate-q], [train: 0.13424], [test: 0.13567]
# ********************************************************************************
# Finish training...

# %%
real = true_casual_effect(test_loader)
unadjust = (testset.response[testset.treatment == 1].mean() - testset.response[testset.treatment == 0].mean()).item()
show_result(train_loss_hist, test_loss_hist, est_effect, real, unadjust, epoch)
